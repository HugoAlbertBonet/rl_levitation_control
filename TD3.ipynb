# %%
from gymnasium import Env
from gymnasium.spaces.box import Box
import numpy as np
import random
from stable_baselines3 import TD3
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.noise import NormalActionNoise
import wandb
from wandb.integration.sb3 import WandbCallback
import os
import matplotlib.pyplot as plt
import scipy.io
import scipy
import numpy as np
import pickle
import warnings
import math
from typing import Callable
warnings.filterwarnings("ignore")

# %%
class Bobina():
  """ 
  Coil model for the Hybrid Electromagnetic Suspension
  """
  def __init__(self, masa_pod = 200, airgap = 23):
    self.masa_pod = masa_pod
    self.airgap = airgap
    self.aceleracion = []
    self.velocidad = []
    mat = scipy.io.loadmat('./coil/hems.mat')
    self.hems = mat["hems"][0][0]
    self.airgaps = self.hems[0][0]
    self.currents = self.hems[1][0]
    self.force_vertical = pickle.load(open("./coil/mlp_vertical.pkl", 'rb'))
    self.flux = self.hems[3]
    self.force_horizontal = self.hems[4]
    self.inductance = pickle.load(open("./coil/rf_inductance.pkl", 'rb'))
    self.resistance = self.hems[6][0][0]
    self.min_distance = self.airgaps[0]
    self.max_distance = self.airgaps[-1]
    self.airgapinicial = airgap
    self.crash = False
    self.current = 0
    self.steps_RL = []

  def integral(self, lista, h = 1):
    return sum(h*(lista[i]+lista[i+1])/2 for i in range(len(lista)-1))

  def RL(self, airgap, target_voltage, temperature):
    # Resistance-Inductance circuit

    # Get resistance of the coil
    R = self.R(current = self.current, temperature = temperature)   
    V = target_voltage
    I = self.current
    L = self.L(airgap = airgap, current = self.current)
    dIdt = ((V/R) - I)/(L/R)                                      
    self.steps_RL.append(dIdt)                                   
    current = self.integral(self.steps_RL, h = 0.001)                          
    return current                                                  

  def R(self, current, temperature):
    return self.resistance                                         

  def L(self, airgap, current):
    # Return predicted inductance
    return float(self.inductance.predict(np.array([[airgap, current]]))[0])

  def vertical_force(self, airgap, target_voltage, temperature):
    # Get current from RL circuit
    I = self.RL(airgap = airgap, target_voltage = target_voltage, temperature = temperature) 
    
    # Clip result
    if I > 45:
      I = 45
    elif I < -45:
      I = -45
    self.current = I
    # Get vertical force from 
    FI = self.FI_vertical(airgap = airgap, current = I)                    
    return FI, I


  def FI_vertical(self, airgap, current):
    # Return predicted vertical force
    return float(self.force_vertical.predict(np.array([[airgap, current]])))    


  def next_airgap(self, masa_pod, vertical_force, verbose = False):
    # Devide the mass of the pod by 4 coils
    masa = masa_pod/4  
    # Calculate weight
    peso = masa * 9.8    
    # Get total force                                                       
    fuerza = peso - vertical_force
    if verbose: print("Fuerza resultante: ", fuerza)   
    # Calculate acceleration                                     
    aceleracion = fuerza/masa
    if verbose: print("Aceleración: ", aceleracion)                                         
    self.aceleracion.append(aceleracion)       
    # Calculate velocity                                
    velocidad = self.integral(self.aceleracion, 0.001)
    if verbose: print("Integral primera (velocidad): ", velocidad)                          
    self.velocidad.append(velocidad)               
    # Calculate position (x1000 as to transform from m to mm)                            
    posicion = self.airgapinicial + self.integral(self.velocidad, 0.001)*1000 
    if verbose: print("Integral segunda (posición): ", posicion)

    # Clip position
    if posicion > self.max_distance:
      airgap = self.max_distance
      self.aceleracion = [0]
      self.velocidad = [0]  
      self.crash = True     
      self.airgapinicial = self.max_distance                                               
    elif posicion < self.min_distance:
      airgap = self.min_distance
      self.aceleracion = [0]
      self.velocidad = [0]
      self.crash = True
      self.airgapinicial = self.min_distance
    else: airgap = posicion
    return airgap, velocidad

  def step(self, target_voltage, verbose = False):
    # Calculate vertical force and current
    vertical_force, self.current = self.vertical_force(airgap = self.airgap, target_voltage = target_voltage, temperature = 40)
    if verbose: print("Fuerza vertical: ", vertical_force)
    # Calculate next airgap and velocity
    self.airgap, velocidad = self.next_airgap(self.masa_pod, vertical_force, verbose = verbose)
    #noise = np.random.normal(0,0.5)
    #self.airgap = self.airgap + noise     
    return (np.float32(self.airgap), np.float32(velocidad), np.float32(self.airgap - 19.5), np.float32(self.current)), self.crash
  
class BobinaEnv(Env):
  """
  Custom Gym Environment for the Hybrid Electromagnetic Suspension, considering just one coil.
  """
  def __init__(self, masa_pod = 200, airgap = 10, duration = 10):
    # Actions: Voltage applied to the coil
    self.action_space = Box(low=np.array([-100]), high = np.array([50]), dtype=np.float32)
    # Observations: Airgap to the ceiling, velocity, distance to the objective, current of the coil
    self.observation_space = Box(low=np.array([10, -np.inf, -10, -45]), high = np.array([23, np.inf, 10, 45]), dtype=np.float32)
    # Initial parameters
    self.state = np.array([airgap, 0, airgap - 19.5, 0])
    self.airgapinicial = airgap
    self.duration = duration
    self.timeleft = duration
    self.crash = False
    self.masa_pod = masa_pod
    self.bobina = Bobina(masa_pod = self.masa_pod, airgap = self.airgapinicial)
    self.steps = []
    self.airgap = airgap
    self.distancia = 0
    self.velocidad = 0
    self.current = 0


  def step(self, action):
    # Apply action
    self.state, self.crash = self.bobina.step(action[0])
    self.airgap, self.velocidad, self.distancia, self.current = self.state

    # Reduce the time of the experiment
    self.timeleft -= 0.001

    # Calculate reward
    if self.airgap >= 23: reward = -100
    elif self.airgap <= 10: reward = -100
    else: reward = -abs(self.current)

    # Check if experiment is done
    if self.timeleft <= 0:
      truncated = True
    else: truncated = False
    # Set placeholder for info
    info = {}
    # Only if we implemented the crash
    if self.crash:
      reward = - 500000
      terminated = True
    else:
      terminated = False
    self.steps.append(self.state)
    return self.state, reward, terminated, truncated, info


  def render(self, yes = "yes"):
    # create data
    x = list(range(0,len(self.steps)))
    y = [step[0] for step in self.steps]
    objective = [19.5]*len(self.steps)

    # plot lines
    fig = plt.figure(figsize=(10,5))
    ax = fig.add_subplot(111)
    ax.tick_params(axis='x', colors='white')    #setting up X-axis tick color to red
    ax.tick_params(axis='y', colors='white')  #setting up Y-axis tick color to black

    plt.plot(x, y, label = "States")
    plt.plot(x, objective, label = "Objective")
    plt.legend()
    plt.show()

  def reset(self, seed = 0):
    # Reset experiment choosing randomly the start (ceiling or floor)
    airgap = random.choice([19.5])
    self.state = self.airgapinicial
    self.bobina = Bobina(masa_pod = self.masa_pod, airgap = airgap)
    # Reset time
    self.timeleft = self.duration
    self.crash = False
    self.steps = []
    return self.state, seed

# %%
run = wandb.init(
    project="1gdltd3",
    sync_tensorboard=True,
    monitor_gym=True,
)

# Create log dir
log_dir = "1gdltd3/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = BobinaEnv( airgap = 19.5,duration = 4 )
env = Monitor(env, log_dir)

def linear_schedule(initial_value: float) -> Callable[[float], float]:
    """
    Linear learning rate schedule.

    :param initial_value: Initial learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return progress_remaining * initial_value

    return func

n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

model = TD3("MlpPolicy", env, learning_rate= linear_schedule(0.0001), action_noise=action_noise, verbose=1)
# Out:
# Finishing last run (ID:whnl7iwk) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">zany-aardvark-2</strong> at: <a href='https://wandb.ai/hyperloopupv/1gdltd3/runs/whnl7iwk' target="_blank">https://wandb.ai/hyperloopupv/1gdltd3/runs/whnl7iwk</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>.\wandb\run-20231220_131252-whnl7iwk\logs</code>
# Successfully finished last run (ID:whnl7iwk). Initializing new run:<br/>
# wandb version 0.16.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\wandb\run-20231220_151012-qxzw9926</code>
# Syncing run <strong><a href='https://wandb.ai/hyperloopupv/1gdltd3/runs/qxzw9926' target="_blank">polished-bush-3</a></strong> to <a href='https://wandb.ai/hyperloopupv/1gdltd3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hyperloopupv/1gdltd3' target="_blank">https://wandb.ai/hyperloopupv/1gdltd3</a>
#  View run at <a href='https://wandb.ai/hyperloopupv/1gdltd3/runs/qxzw9926' target="_blank">https://wandb.ai/hyperloopupv/1gdltd3/runs/qxzw9926</a>
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
model.policy
# Out:
# TD3Policy(
#   (actor): Actor(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (mu): Sequential(
#       (0): Linear(in_features=4, out_features=400, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=400, out_features=300, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=300, out_features=1, bias=True)
#       (5): Tanh()
#     )
#   )
#   (actor_target): Actor(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (mu): Sequential(
#       (0): Linear(in_features=4, out_features=400, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=400, out_features=300, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=300, out_features=1, bias=True)
#       (5): Tanh()
#     )
#   )
#   (critic): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=5, out_features=400, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=400, out_features=300, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=300, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=5, out_features=400, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=400, out_features=300, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=300, out_features=1, bias=True)
#     )
#   )
#   (critic_target): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=5, out_features=400, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=400, out_features=300, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=300, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=5, out_features=400, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=400, out_features=300, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=300, out_features=1, bias=True)
#     )
#   )
# )

# %%
# Create checkpoint callback
checkpoint_callback = CheckpointCallback(
    save_freq=10000, save_path=log_dir, name_prefix="rl_td3_1gdl_fromobj_current"
)

# Train the agent
model.learn(total_timesteps=20000000,
    callback=[
        checkpoint_callback,
        WandbCallback(
            gradient_save_freq=10000,
            model_save_path=f"models/td3current",
            model_save_freq=10000,
            verbose=2,
        ),
    ],
)
# Out:
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 88        |
# |    ep_rew_mean     | -5.02e+05 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 48        |
# |    time_elapsed    | 7         |
# |    total_timesteps | 352       |
# | train/             |           |
# |    actor_loss      | 118       |
# |    critic_loss     | 3.33e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 245       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 65        |
# |    ep_rew_mean     | -5.02e+05 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 45        |
# |    time_elapsed    | 11        |
# |    total_timesteps | 520       |
# | train/             |           |
# |    actor_loss      | 469       |
# |    critic_loss     | 7.01e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 413       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 57.3      |
# |    ep_rew_mean     | -5.02e+05 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 44        |
# |    time_elapsed    | 15        |
# |    total_timesteps | 688       |
# | train/             |           |
# |    actor_loss      | 1.18e+03  |
# |    critic_loss     | 7.33e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 581       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 61.1      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 45        |
# |    time_elapsed    | 21        |
# |    total_timesteps | 977       |
# | train/             |           |
# |    actor_loss      | 2.23e+03  |
# |    critic_loss     | 8.61e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 832       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 65.2      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 44        |
# |    time_elapsed    | 29        |
# |    total_timesteps | 1303      |
# | train/             |           |
# |    actor_loss      | 3.54e+03  |
# |    critic_loss     | 6.51e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1153      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 70.5      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 43        |
# |    time_elapsed    | 38        |
# |    total_timesteps | 1693      |
# | train/             |           |
# |    actor_loss      | 4.87e+03  |
# |    critic_loss     | 6.97e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1526      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 75.9      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 43        |
# |    time_elapsed    | 49        |
# |    total_timesteps | 2124      |
# | train/             |           |
# |    actor_loss      | 6.8e+03   |
# |    critic_loss     | 7.41e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1943      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81.5      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 42        |
# |    time_elapsed    | 61        |
# |    total_timesteps | 2607      |
# | train/             |           |
# |    actor_loss      | 8.72e+03  |
# |    critic_loss     | 6.61e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 2417      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 88.7      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 42        |
# |    time_elapsed    | 75        |
# |    total_timesteps | 3193      |
# | train/             |           |
# |    actor_loss      | 1.13e+04  |
# |    critic_loss     | 5.59e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 2946      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 94        |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 41        |
# |    time_elapsed    | 89        |
# |    total_timesteps | 3761      |
# | train/             |           |
# |    actor_loss      | 1.47e+04  |
# |    critic_loss     | 4.85e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3571      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 97.1      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 41        |
# |    time_elapsed    | 102       |
# |    total_timesteps | 4273      |
# | train/             |           |
# |    actor_loss      | 1.78e+04  |
# |    critic_loss     | 4.43e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 4080      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.5      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 41        |
# |    time_elapsed    | 115       |
# |    total_timesteps | 4778      |
# | train/             |           |
# |    actor_loss      | 2.12e+04  |
# |    critic_loss     | 4.69e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 4600      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.7      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 41        |
# |    time_elapsed    | 126       |
# |    total_timesteps | 5186      |
# | train/             |           |
# |    actor_loss      | 2.45e+04  |
# |    critic_loss     | 4.14e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 5026      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.1      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 40        |
# |    time_elapsed    | 135       |
# |    total_timesteps | 5552      |
# | train/             |           |
# |    actor_loss      | 2.79e+04  |
# |    critic_loss     | 4.98e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 5421      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 96.8      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 40        |
# |    time_elapsed    | 142       |
# |    total_timesteps | 5810      |
# | train/             |           |
# |    actor_loss      | 3.02e+04  |
# |    critic_loss     | 4.83e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 5682      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 94.5      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 40        |
# |    time_elapsed    | 148       |
# |    total_timesteps | 6047      |
# | train/             |           |
# |    actor_loss      | 3.2e+04   |
# |    critic_loss     | 4.72e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 5924      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 92.3      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 40        |
# |    time_elapsed    | 154       |
# |    total_timesteps | 6274      |
# | train/             |           |
# |    actor_loss      | 3.46e+04  |
# |    critic_loss     | 4.47e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 6153      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 90.2      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 40        |
# |    time_elapsed    | 159       |
# |    total_timesteps | 6495      |
# | train/             |           |
# |    actor_loss      | 3.7e+04   |
# |    critic_loss     | 4.48e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 6375      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 88.3      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 40        |
# |    time_elapsed    | 164       |
# |    total_timesteps | 6712      |
# | train/             |           |
# |    actor_loss      | 3.88e+04  |
# |    critic_loss     | 4.21e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 6593      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 86.5      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 40        |
# |    time_elapsed    | 170       |
# |    total_timesteps | 6919      |
# | train/             |           |
# |    actor_loss      | 4.15e+04  |
# |    critic_loss     | 3.88e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 6803      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 84.8      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 40        |
# |    time_elapsed    | 175       |
# |    total_timesteps | 7119      |
# | train/             |           |
# |    actor_loss      | 4.43e+04  |
# |    critic_loss     | 5.37e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 7005      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 83.1      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 88        |
# |    fps             | 40        |
# |    time_elapsed    | 180       |
# |    total_timesteps | 7316      |
# | train/             |           |
# |    actor_loss      | 4.66e+04  |
# |    critic_loss     | 4.24e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 7202      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 81.6      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 92        |
# |    fps             | 40        |
# |    time_elapsed    | 185       |
# |    total_timesteps | 7504      |
# | train/             |           |
# |    actor_loss      | 4.89e+04  |
# |    critic_loss     | 4.85e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 7393      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 80.1      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 96        |
# |    fps             | 40        |
# |    time_elapsed    | 189       |
# |    total_timesteps | 7690      |
# | train/             |           |
# |    actor_loss      | 5.03e+04  |
# |    critic_loss     | 5.29e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 7579      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 78.7      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 40        |
# |    time_elapsed    | 194       |
# |    total_timesteps | 7872      |
# | train/             |           |
# |    actor_loss      | 5.38e+04  |
# |    critic_loss     | 3.56e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 7762      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 77        |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 104       |
# |    fps             | 40        |
# |    time_elapsed    | 198       |
# |    total_timesteps | 8053      |
# | train/             |           |
# |    actor_loss      | 5.74e+04  |
# |    critic_loss     | 6.1e+09   |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 7943      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 77.1      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 108       |
# |    fps             | 40        |
# |    time_elapsed    | 203       |
# |    total_timesteps | 8231      |
# | train/             |           |
# |    actor_loss      | 5.92e+04  |
# |    critic_loss     | 4.64e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 8122      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 77.2      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 112       |
# |    fps             | 40        |
# |    time_elapsed    | 207       |
# |    total_timesteps | 8407      |
# | train/             |           |
# |    actor_loss      | 6.18e+04  |
# |    critic_loss     | 4.35e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 8298      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 76.1      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 116       |
# |    fps             | 40        |
# |    time_elapsed    | 212       |
# |    total_timesteps | 8583      |
# | train/             |           |
# |    actor_loss      | 6.47e+04  |
# |    critic_loss     | 4.36e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 8474      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 74.6      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 120       |
# |    fps             | 40        |
# |    time_elapsed    | 216       |
# |    total_timesteps | 8759      |
# | train/             |           |
# |    actor_loss      | 6.79e+04  |
# |    critic_loss     | 4.67e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 8650      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 72.4      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 124       |
# |    fps             | 40        |
# |    time_elapsed    | 220       |
# |    total_timesteps | 8935      |
# | train/             |           |
# |    actor_loss      | 7e+04     |
# |    critic_loss     | 5.42e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 8826      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 69.9      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 128       |
# |    fps             | 40        |
# |    time_elapsed    | 225       |
# |    total_timesteps | 9110      |
# | train/             |           |
# |    actor_loss      | 7.48e+04  |
# |    critic_loss     | 5.07e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 9001      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 66.8      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 132       |
# |    fps             | 40        |
# |    time_elapsed    | 229       |
# |    total_timesteps | 9283      |
# | train/             |           |
# |    actor_loss      | 7.61e+04  |
# |    critic_loss     | 4.32e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 9174      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 62.6      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 136       |
# |    fps             | 40        |
# |    time_elapsed    | 234       |
# |    total_timesteps | 9456      |
# | train/             |           |
# |    actor_loss      | 8.01e+04  |
# |    critic_loss     | 4.75e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 9348      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 58.7      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 140       |
# |    fps             | 40        |
# |    time_elapsed    | 238       |
# |    total_timesteps | 9628      |
# | train/             |           |
# |    actor_loss      | 8.31e+04  |
# |    critic_loss     | 4.86e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 9520      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 55.3      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 144       |
# |    fps             | 40        |
# |    time_elapsed    | 242       |
# |    total_timesteps | 9800      |
# | train/             |           |
# |    actor_loss      | 8.53e+04  |
# |    critic_loss     | 3.41e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 9692      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 51.9      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 148       |
# |    fps             | 40        |
# |    time_elapsed    | 247       |
# |    total_timesteps | 9972      |
# | train/             |           |
# |    actor_loss      | 8.83e+04  |
# |    critic_loss     | 4.11e+09  |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 9864      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 49.6      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 152       |
# |    fps             | 40        |
# |    time_elapsed    | 251       |
# |    total_timesteps | 10144     |
# | train/             |           |
# |    actor_loss      | 9.12e+04  |
# |    critic_loss     | 4.26e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 10036     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 47.6      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 156       |
# |    fps             | 40        |
# |    time_elapsed    | 256       |
# |    total_timesteps | 10316     |
# | train/             |           |
# |    actor_loss      | 9.49e+04  |
# |    critic_loss     | 4.59e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 10208     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 46.8      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 160       |
# |    fps             | 40        |
# |    time_elapsed    | 260       |
# |    total_timesteps | 10488     |
# | train/             |           |
# |    actor_loss      | 9.73e+04  |
# |    critic_loss     | 4.51e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 10380     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 46.1      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 164       |
# |    fps             | 40        |
# |    time_elapsed    | 265       |
# |    total_timesteps | 10660     |
# | train/             |           |
# |    actor_loss      | 1.02e+05  |
# |    critic_loss     | 3.03e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 10552     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 45.6      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 168       |
# |    fps             | 40        |
# |    time_elapsed    | 269       |
# |    total_timesteps | 10832     |
# | train/             |           |
# |    actor_loss      | 1.02e+05  |
# |    critic_loss     | 3.91e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 10724     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 45.1      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 172       |
# |    fps             | 40        |
# |    time_elapsed    | 274       |
# |    total_timesteps | 11004     |
# | train/             |           |
# |    actor_loss      | 1.07e+05  |
# |    critic_loss     | 4.31e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 10896     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 44.6      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 176       |
# |    fps             | 40        |
# |    time_elapsed    | 278       |
# |    total_timesteps | 11176     |
# | train/             |           |
# |    actor_loss      | 1.09e+05  |
# |    critic_loss     | 2.94e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 11068     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 44.3      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 180       |
# |    fps             | 40        |
# |    time_elapsed    | 283       |
# |    total_timesteps | 11348     |
# | train/             |           |
# |    actor_loss      | 1.12e+05  |
# |    critic_loss     | 3.89e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 11240     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 44        |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 184       |
# |    fps             | 40        |
# |    time_elapsed    | 287       |
# |    total_timesteps | 11520     |
# | train/             |           |
# |    actor_loss      | 1.18e+05  |
# |    critic_loss     | 3.75e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 11412     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.8      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 188       |
# |    fps             | 40        |
# |    time_elapsed    | 291       |
# |    total_timesteps | 11692     |
# | train/             |           |
# |    actor_loss      | 1.2e+05   |
# |    critic_loss     | 3.07e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 11584     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.6      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 192       |
# |    fps             | 40        |
# |    time_elapsed    | 296       |
# |    total_timesteps | 11864     |
# | train/             |           |
# |    actor_loss      | 1.22e+05  |
# |    critic_loss     | 3.11e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 11756     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.5      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 196       |
# |    fps             | 40        |
# |    time_elapsed    | 300       |
# |    total_timesteps | 12036     |
# | train/             |           |
# |    actor_loss      | 1.26e+05  |
# |    critic_loss     | 3.3e+09   |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 11928     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.4      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 200       |
# |    fps             | 40        |
# |    time_elapsed    | 304       |
# |    total_timesteps | 12208     |
# | train/             |           |
# |    actor_loss      | 1.28e+05  |
# |    critic_loss     | 3.55e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 12100     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.3      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 204       |
# |    fps             | 40        |
# |    time_elapsed    | 309       |
# |    total_timesteps | 12380     |
# | train/             |           |
# |    actor_loss      | 1.31e+05  |
# |    critic_loss     | 3.4e+09   |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 12272     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.2      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 208       |
# |    fps             | 40        |
# |    time_elapsed    | 313       |
# |    total_timesteps | 12552     |
# | train/             |           |
# |    actor_loss      | 1.34e+05  |
# |    critic_loss     | 3.3e+09   |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 12444     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.2      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 212       |
# |    fps             | 40        |
# |    time_elapsed    | 318       |
# |    total_timesteps | 12724     |
# | train/             |           |
# |    actor_loss      | 1.39e+05  |
# |    critic_loss     | 3.93e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 12616     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.1      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 216       |
# |    fps             | 40        |
# |    time_elapsed    | 322       |
# |    total_timesteps | 12896     |
# | train/             |           |
# |    actor_loss      | 1.43e+05  |
# |    critic_loss     | 3.18e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 12788     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.1      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 220       |
# |    fps             | 40        |
# |    time_elapsed    | 326       |
# |    total_timesteps | 13068     |
# | train/             |           |
# |    actor_loss      | 1.45e+05  |
# |    critic_loss     | 3.91e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 12960     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43        |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 224       |
# |    fps             | 40        |
# |    time_elapsed    | 330       |
# |    total_timesteps | 13240     |
# | train/             |           |
# |    actor_loss      | 1.5e+05   |
# |    critic_loss     | 3.06e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 13132     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43        |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 228       |
# |    fps             | 40        |
# |    time_elapsed    | 335       |
# |    total_timesteps | 13412     |
# | train/             |           |
# |    actor_loss      | 1.5e+05   |
# |    critic_loss     | 2.78e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 13304     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43        |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 232       |
# |    fps             | 40        |
# |    time_elapsed    | 339       |
# |    total_timesteps | 13584     |
# | train/             |           |
# |    actor_loss      | 1.54e+05  |
# |    critic_loss     | 3.02e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 13476     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43        |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 236       |
# |    fps             | 40        |
# |    time_elapsed    | 343       |
# |    total_timesteps | 13756     |
# | train/             |           |
# |    actor_loss      | 1.57e+05  |
# |    critic_loss     | 3.58e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 13648     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43        |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 240       |
# |    fps             | 40        |
# |    time_elapsed    | 348       |
# |    total_timesteps | 13928     |
# | train/             |           |
# |    actor_loss      | 1.61e+05  |
# |    critic_loss     | 3.44e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 13820     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43        |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 244       |
# |    fps             | 40        |
# |    time_elapsed    | 352       |
# |    total_timesteps | 14100     |
# | train/             |           |
# |    actor_loss      | 1.63e+05  |
# |    critic_loss     | 2.64e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 13992     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43        |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 248       |
# |    fps             | 40        |
# |    time_elapsed    | 356       |
# |    total_timesteps | 14272     |
# | train/             |           |
# |    actor_loss      | 1.65e+05  |
# |    critic_loss     | 2.7e+09   |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 14164     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43        |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 252       |
# |    fps             | 40        |
# |    time_elapsed    | 361       |
# |    total_timesteps | 14446     |
# | train/             |           |
# |    actor_loss      | 1.68e+05  |
# |    critic_loss     | 2.41e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 14337     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43        |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 256       |
# |    fps             | 39        |
# |    time_elapsed    | 365       |
# |    total_timesteps | 14621     |
# | train/             |           |
# |    actor_loss      | 1.71e+05  |
# |    critic_loss     | 2.5e+09   |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 14512     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.1      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 260       |
# |    fps             | 39        |
# |    time_elapsed    | 370       |
# |    total_timesteps | 14797     |
# | train/             |           |
# |    actor_loss      | 1.75e+05  |
# |    critic_loss     | 2.82e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 14688     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.1      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 264       |
# |    fps             | 39        |
# |    time_elapsed    | 374       |
# |    total_timesteps | 14973     |
# | train/             |           |
# |    actor_loss      | 1.77e+05  |
# |    critic_loss     | 2.48e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 14864     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.2      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 268       |
# |    fps             | 39        |
# |    time_elapsed    | 379       |
# |    total_timesteps | 15149     |
# | train/             |           |
# |    actor_loss      | 1.79e+05  |
# |    critic_loss     | 2.39e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 15040     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.2      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 272       |
# |    fps             | 39        |
# |    time_elapsed    | 383       |
# |    total_timesteps | 15325     |
# | train/             |           |
# |    actor_loss      | 1.81e+05  |
# |    critic_loss     | 2.55e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 15216     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.2      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 276       |
# |    fps             | 39        |
# |    time_elapsed    | 388       |
# |    total_timesteps | 15501     |
# | train/             |           |
# |    actor_loss      | 1.86e+05  |
# |    critic_loss     | 2.95e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 15392     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.3      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 280       |
# |    fps             | 39        |
# |    time_elapsed    | 392       |
# |    total_timesteps | 15677     |
# | train/             |           |
# |    actor_loss      | 1.9e+05   |
# |    critic_loss     | 2.03e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 15568     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.3      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 284       |
# |    fps             | 39        |
# |    time_elapsed    | 396       |
# |    total_timesteps | 15853     |
# | train/             |           |
# |    actor_loss      | 1.88e+05  |
# |    critic_loss     | 1.99e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 15744     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.4      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 288       |
# |    fps             | 39        |
# |    time_elapsed    | 401       |
# |    total_timesteps | 16029     |
# | train/             |           |
# |    actor_loss      | 1.9e+05   |
# |    critic_loss     | 2.31e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 15920     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 43.4      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 292       |
# |    fps             | 39        |
# |    time_elapsed    | 405       |
# |    total_timesteps | 16205     |
# | train/             |           |
# |    actor_loss      | 1.96e+05  |
# |    critic_loss     | 2.02e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 16096     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 45.4      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 296       |
# |    fps             | 40        |
# |    time_elapsed    | 414       |
# |    total_timesteps | 16578     |
# | train/             |           |
# |    actor_loss      | 1.98e+05  |
# |    critic_loss     | 2.3e+09   |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 16384     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 48.5      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 300       |
# |    fps             | 40        |
# |    time_elapsed    | 426       |
# |    total_timesteps | 17059     |
# | train/             |           |
# |    actor_loss      | 2.02e+05  |
# |    critic_loss     | 2.14e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 16873     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 51.8      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 304       |
# |    fps             | 40        |
# |    time_elapsed    | 438       |
# |    total_timesteps | 17562     |
# | train/             |           |
# |    actor_loss      | 2.06e+05  |
# |    critic_loss     | 1.92e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 17369     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 55.7      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 308       |
# |    fps             | 40        |
# |    time_elapsed    | 452       |
# |    total_timesteps | 18123     |
# | train/             |           |
# |    actor_loss      | 2.1e+05   |
# |    critic_loss     | 2.25e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 17918     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 60.3      |
# |    ep_rew_mean     | -5.02e+05 |
# | time/              |           |
# |    episodes        | 312       |
# |    fps             | 40        |
# |    time_elapsed    | 468       |
# |    total_timesteps | 18754     |
# | train/             |           |
# |    actor_loss      | 2.14e+05  |
# |    critic_loss     | 1.61e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 18519     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 66.4      |
# |    ep_rew_mean     | -5.02e+05 |
# | time/              |           |
# |    episodes        | 316       |
# |    fps             | 40        |
# |    time_elapsed    | 486       |
# |    total_timesteps | 19540     |
# | train/             |           |
# |    actor_loss      | 2.16e+05  |
# |    critic_loss     | 1.67e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 19236     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 69.3      |
# |    ep_rew_mean     | -5.02e+05 |
# | time/              |           |
# |    episodes        | 320       |
# |    fps             | 40        |
# |    time_elapsed    | 497       |
# |    total_timesteps | 19996     |
# | train/             |           |
# |    actor_loss      | 2.19e+05  |
# |    critic_loss     | 1.89e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 19823     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 71.8      |
# |    ep_rew_mean     | -5.02e+05 |
# | time/              |           |
# |    episodes        | 324       |
# |    fps             | 40        |
# |    time_elapsed    | 505       |
# |    total_timesteps | 20415     |
# | train/             |           |
# |    actor_loss      | 2.19e+05  |
# |    critic_loss     | 1.58e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 20245     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 74        |
# |    ep_rew_mean     | -5.02e+05 |
# | time/              |           |
# |    episodes        | 328       |
# |    fps             | 40        |
# |    time_elapsed    | 514       |
# |    total_timesteps | 20817     |
# | train/             |           |
# |    actor_loss      | 2.2e+05   |
# |    critic_loss     | 1.69e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 20653     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 76.2      |
# |    ep_rew_mean     | -5.02e+05 |
# | time/              |           |
# |    episodes        | 332       |
# |    fps             | 40        |
# |    time_elapsed    | 522       |
# |    total_timesteps | 21202     |
# | train/             |           |
# |    actor_loss      | 2.19e+05  |
# |    critic_loss     | 1.6e+09   |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 21042     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 78.3      |
# |    ep_rew_mean     | -5.02e+05 |
# | time/              |           |
# |    episodes        | 336       |
# |    fps             | 40        |
# |    time_elapsed    | 531       |
# |    total_timesteps | 21584     |
# | train/             |           |
# |    actor_loss      | 2.17e+05  |
# |    critic_loss     | 1.27e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 21424     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 80.3      |
# |    ep_rew_mean     | -5.02e+05 |
# | time/              |           |
# |    episodes        | 340       |
# |    fps             | 40        |
# |    time_elapsed    | 541       |
# |    total_timesteps | 21957     |
# | train/             |           |
# |    actor_loss      | 2.22e+05  |
# |    critic_loss     | 1.53e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 21798     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 82.3      |
# |    ep_rew_mean     | -5.02e+05 |
# | time/              |           |
# |    episodes        | 344       |
# |    fps             | 40        |
# |    time_elapsed    | 550       |
# |    total_timesteps | 22326     |
# | train/             |           |
# |    actor_loss      | 2.16e+05  |
# |    critic_loss     | 1.58e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 22169     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 84.2      |
# |    ep_rew_mean     | -5.02e+05 |
# | time/              |           |
# |    episodes        | 348       |
# |    fps             | 40        |
# |    time_elapsed    | 559       |
# |    total_timesteps | 22694     |
# | train/             |           |
# |    actor_loss      | 2.2e+05   |
# |    critic_loss     | 1.64e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 22537     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 86.1      |
# |    ep_rew_mean     | -5.02e+05 |
# | time/              |           |
# |    episodes        | 352       |
# |    fps             | 40        |
# |    time_elapsed    | 569       |
# |    total_timesteps | 23059     |
# | train/             |           |
# |    actor_loss      | 2.19e+05  |
# |    critic_loss     | 1.48e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 22904     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 88        |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 356       |
# |    fps             | 40        |
# |    time_elapsed    | 578       |
# |    total_timesteps | 23418     |
# | train/             |           |
# |    actor_loss      | 2.17e+05  |
# |    critic_loss     | 1.51e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 23263     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 89.8      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 360       |
# |    fps             | 40        |
# |    time_elapsed    | 587       |
# |    total_timesteps | 23775     |
# | train/             |           |
# |    actor_loss      | 2.15e+05  |
# |    critic_loss     | 1.49e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 23621     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 91.5      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 364       |
# |    fps             | 40        |
# |    time_elapsed    | 596       |
# |    total_timesteps | 24128     |
# | train/             |           |
# |    actor_loss      | 2.19e+05  |
# |    critic_loss     | 1.79e+09  |
# |    learning_rate   | 9.99e-05  |
# |    n_updates       | 23975     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 93.2      |
# |    ep_rew_mean     | -5.01e+05 |
# | time/              |           |
# |    episodes        | 368       |
# ...
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> model.learn(total_timesteps=20000000,
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a>     callback=[
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a>         checkpoint_callback,
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a>         WandbCallback(
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a>             gradient_save_freq=10000,
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a>             model_save_path=f"models/td3current",
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=12'>13</a>             model_save_freq=10000,
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=13'>14</a>             verbose=2,
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=14'>15</a>         ),
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a>     ],
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=16'>17</a> )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\td3\td3.py:222, in TD3.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     213 def learn(
#     214     self: SelfTD3,
#     215     total_timesteps: int,
#    (...)
#     220     progress_bar: bool = False,
#     221 ) -> SelfTD3:
# --> 222     return super().learn(
#     223         total_timesteps=total_timesteps,
#     224         callback=callback,
#     225         log_interval=log_interval,
#     226         tb_log_name=tb_log_name,
#     227         reset_num_timesteps=reset_num_timesteps,
#     228         progress_bar=progress_bar,
#     229     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\off_policy_algorithm.py:312, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     309 callback.on_training_start(locals(), globals())
#     311 while self.num_timesteps < total_timesteps:
# --> 312     rollout = self.collect_rollouts(
#     313         self.env,
#     314         train_freq=self.train_freq,
#     315         action_noise=self.action_noise,
#     316         callback=callback,
#     317         learning_starts=self.learning_starts,
#     318         replay_buffer=self.replay_buffer,
#     319         log_interval=log_interval,
#     320     )
#     322     if rollout.continue_training is False:
#     323         break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\off_policy_algorithm.py:544, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     541 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     543 # Rescale and perform action
# --> 544 new_obs, rewards, dones, infos = env.step(actions)
#     546 self.num_timesteps += env.num_envs
#     547 num_collected_steps += 1
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:197, in VecEnv.step(self, actions)
#     190 """
#     191 Step the environments with the given action
#     192
#     193 :param actions: the action
#     194 :return: observation, reward, done, information
#     195 """
#     196 self.step_async(actions)
# --> 197 return self.step_wait()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\TD3.ipynb Cell 5 line BobinaEnv.step(self, action)
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=138'>139</a> def step(self, action):
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=139'>140</a>   # Apply action
# --> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=140'>141</a>   self.state, self.crash = self.bobina.step(action[0])
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=141'>142</a>   self.airgap, self.velocidad, self.distancia, self.current = self.state
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=143'>144</a>   # Reduce the time of the experiment
#
# c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\TD3.ipynb Cell 5 line Bobina.step(self, target_voltage, verbose)
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=104'>105</a> def step(self, target_voltage, verbose = False):
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=105'>106</a>   # Calculate vertical force and current
# --> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=106'>107</a>   vertical_force, self.current = self.vertical_force(airgap = self.airgap, target_voltage = target_voltage, temperature = 40)
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=107'>108</a>   if verbose: print("Fuerza vertical: ", vertical_force)
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=108'>109</a>   # Calculate next airgap and velocity
#
# c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\TD3.ipynb Cell 5 line Bobina.vertical_force(self, airgap, target_voltage, temperature)
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=48'>49</a> def vertical_force(self, airgap, target_voltage, temperature):
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=49'>50</a>   # Get current from RL circuit
# ---> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=50'>51</a>   I = self.RL(airgap = airgap, target_voltage = target_voltage, temperature = temperature)
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=52'>53</a>   # Clip result
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=53'>54</a>   if I > 45:
#
# c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\TD3.ipynb Cell 5 line Bobina.RL(self, airgap, target_voltage, temperature)
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=33'>34</a> V = target_voltage
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=34'>35</a> I = self.current
# ---> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=35'>36</a> L = self.L(airgap = airgap, current = self.current)
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=36'>37</a> dIdt = ((V/R) - I)/(L/R)
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=37'>38</a> self.steps_RL.append(dIdt)
#
# c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\TD3.ipynb Cell 5 line Bobina.L(self, airgap, current)
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=44'>45</a> def L(self, airgap, current):
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=45'>46</a>   # Return predicted inductance
# ---> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/TD3.ipynb#W6sZmlsZQ%3D%3D?line=46'>47</a>   return float(self.inductance.predict(np.array([[airgap, current]]))[0])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\ensemble\_forest.py:1004, in ForestRegressor.predict(self, X)
#    1002 # Parallel loop
#    1003 lock = threading.Lock()
# -> 1004 Parallel(n_jobs=n_jobs, verbose=self.verbose, require="sharedmem")(
#    1005     delayed(_accumulate_prediction)(e.predict, X, [y_hat], lock)
#    1006     for e in self.estimators_
#    1007 )
#    1009 y_hat /= len(self.estimators_)
#    1011 return y_hat
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\ensemble\_forest.py:664, in _accumulate_prediction(predict, X, out, lock)
#     657 def _accumulate_prediction(predict, X, out, lock):
#     658     """
#     659     This is a utility function for joblib's Parallel.
#     660
#     661     It can't go locally in ForestClassifier or ForestRegressor, because joblib
#     662     complains that it cannot pickle it when placed there.
#     663     """
# --> 664     prediction = predict(X, check_input=False)
#     665     with lock:
#     666         if len(out) == 1:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\tree\_classes.py:506, in BaseDecisionTree.predict(self, X, check_input)
#     504 check_is_fitted(self)
#     505 X = self._validate_X_predict(X, check_input)
# --> 506 proba = self.tree_.predict(X)
#     507 n_samples = X.shape[0]
#     509 # Classification
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
model.policy
# Out:
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (pi_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (vf_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=4, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=4, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=1, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
import numpy as np
import torch as th
import time

MODEL_PATH = f"models/ppocuadratico/model.zip"

# Create and wrap the environment
env = BobinaEnv(duration = 4)

# Load the trained agent
model = PPO.load(MODEL_PATH, env=env)

# Evaluate the agent
for i in range(5):
    obs, seed = env.reset()
    done = False
    episode_reward = 0
    velocidad = 0
    current = 0
    observations = []
    noises = []
    error = obs -19.5
    timepredict = 0
    timemodel = 0
    while not done:
        #noise = random.uniform(-1, 1)
        #obs = obs + noise
        observations.append(obs)
        #noises.append(noise)
        t1 = time.time()
        action, _states = model.predict(np.array([obs, velocidad, error, current]), deterministic=True)
        t2 = time.time()
        #print(action)
        #if env.airgap > 10.1: action = max(action, [-50])
        #print(action)
        t3 = time.time()
        state, reward, terminated, truncated, info = env.step(np.array(action))
        t4 = time.time()
        obs, velocidad, error, current = state
        done = truncated or terminated
        episode_reward += reward
        timepredict += t2 - t1
        timemodel += t4 - t3
        noises.append(action)
    print("Time predict", timepredict)
    print("Time model", timemodel)
    print("Episode reward", episode_reward)
    #print(noises)
    env.render("yes")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Time predict 2.038398504257202
# Time model 28.249844074249268
# Episode reward -345011.91880669864
# Time predict 2.0703630447387695
# Time model 28.64287042617798
# Episode reward -345011.91880669864
# Time predict 1.9565157890319824
# Time model 28.91672706604004
# Episode reward -345011.91880669864
# Time predict 2.0105221271514893
# Time model 28.061734914779663
# Episode reward -345011.91880669864
# Time predict 2.001551866531372
# Time model 27.71768879890442
# Episode reward -345011.91880669864
