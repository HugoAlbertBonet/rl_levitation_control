# %%
from gymnasium import Env
from gymnasium.spaces.box import Box
import numpy as np
import random
from stable_baselines3 import SAC
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback, StopTrainingOnRewardThreshold, EvalCallback
from stable_baselines3.common.noise import NormalActionNoise
import wandb
from wandb.integration.sb3 import WandbCallback
import os
import matplotlib.pyplot as plt
import scipy.io
import numpy as np
import pickle
import warnings
import math
warnings.filterwarnings("ignore")

# %%
class BobinaEnvTest(Env):
  """
  Custom Gym Environment for the Hybrid Electromagnetic Suspension, considering just two degrees of freedom.
  """
  def __init__(self, alive = 20, masa_pod = 250, airgap = 16.3, duration = 10, dist_cm = 0.7, inercia= 70, min_distance = 9, max_distance = 22.5):
    # Actions: Voltage applied to the coil
    self.action_space = Box(low=np.array([-100, -100]), high = np.array([100, 100]), dtype=np.float32)
    # Observations: Airgap to the ceiling, velocity, distance to the objective, current of the coil
    self.observation_space = Box(low=np.array([-10, -10, -np.inf, -np.inf, -45, -45]), high = np.array([10, 10, np.inf, np.inf, 45, 45]), dtype=np.float32)
    # Initial parameters
    airgap = random.uniform(15.3, 17.3)
    self.state = np.array([airgap - 16.3, airgap - 16.3, 0, 0, 0, 0])
    self.airgapinicial = airgap
    self.duration = duration
    self.timeleft = duration
    self.crash = False
    self.masa_pod = masa_pod
    self.sistema = TwoGDL(masa_pod = self.masa_pod, airgap = self.airgapinicial, dist_cm = dist_cm, inercia= inercia, min_distance = min_distance, max_distance = max_distance)
    self.steps = []
    self.airgap1 = airgap
    self.airgap2 = airgap
    self.distancia1 = 0
    self.distancia2 = 0
    self.velocidad = 0
    self.current1 = 0
    self.current2 = 0
    self.alive = alive
    self.vel = 0
    self.velangular = 0


  def step(self, action):
    # Apply action
    self.state, self.crash, angulo, error = self.sistema.step(action[0],action[1])
    self.distancia1, self.distancia2, self.vel, self.velangular, self.current1, self.current2 = self.state

    # Reduce the time of the experiment
    self.timeleft -= 0.001

    # Calculate reward
    reward = -abs(self.distancia1) -abs(self.distancia2) - 10000*self.crash

    """if self.airgap >= 23: reward = -500
    elif self.airgap <= 10: reward = -500
    else: reward = -abs(self.current)"""

    # Check if experiment is done
    if self.timeleft <= 0:
      truncated = True
    else: truncated = False
    # Set placeholder for info
    info = {}
    # Only if we implemented the crash
    """if self.crash:
      reward = - 100000
      terminated = True
    else:
      terminated = False"""
    terminated = False
    self.steps.append(self.state)
    return self.state, reward, terminated, truncated, info


  def render(self, yes = "yes", normalize = True, seed = 0):
    # create data
    x = list(range(0,len(self.steps)))
    y1 = [16.3+step[0] for step in self.steps]
    y2 = [16.3+step[1] for step in self.steps]
    objective = [16.3]*len(self.steps)

    # plot lines
    fig = plt.figure(figsize=(10,5))
    ax = fig.add_subplot(111)
    #ax.tick_params(axis='x', colors='white')    #setting up X-axis tick color to red
    #ax.tick_params(axis='y', colors='white')  #setting up Y-axis tick color to black
    if normalize: ax.set_ylim(bottom=8, top=23)
    plt.xlabel("Time (s)") #, color='white')
    plt.ylabel("Airgap (mm)") #, color='white')
    plt.title("Airgap evolution") #, color='white')

    plt.plot(x, y1, label = "Airgap 1")
    plt.plot(x, y2, label = "Airgap 2")
    plt.plot(x, objective, label = "Objective")
    plt.legend()
    #if self.steps[0][0] < 0: plt.savefig("images/top-2gdl8x8nocrash.png")
    #else: plt.savefig("images/bottom-2gdl8x8nocrash.png")
    plt.savefig(f"images/2gdl8x8nocrashsituation{seed}.png")
    plt.show()

  def reset(self, seed = 0):
    # Reset experiment choosing randomly the start (ceiling or floor)
    airgap = random.uniform(9.5, 22)
    #self.state = np.array([airgap - 16.3, airgap - 16.3, 0, 0, 0, 0])
    self.sistema = TwoGDL(masa_pod = self.masa_pod, airgap = airgap, dist_cm = 0.7, inercia= 70, min_distance = 9, max_distance = 22.5)
    angulo = random.uniform(-0.008, 0.008)
    self.vel = random.uniform(-0.2, 0.2)
    self.velangular = random.uniform(-0.3, 0.3)
    self.current1 = 0
    self.current2 = 0
    airgap1, airgap2 = self.sistema.pos2airgap(pos = airgap, theta = angulo)
    self.distancia1, self.distancia2 = airgap1-16.3, airgap2-16.3
    self.state= self.distancia1, self.distancia2, self.vel, self.velangular, self.current1, self.current2
    self.sistema.integral_aceleracion = self.vel
    self.sistema.integral_alpha = self.velangular
    self.sistema.integral_omega = angulo
    self.state, self.crash = self.sistema.step(0,0)
    self.distancia11, self.distancia12, self.distancia21, self.distancia22, self.current1, self.current2 = self.state
    
    # Reset time
    self.timeleft = self.duration
    self.crash = False
    self.steps = []
    return self.state, seed

# %%
class BobinaEnv(Env):
  """
  Custom Gym Environment for the Hybrid Electromagnetic Suspension, considering just two degrees of freedom.
  """
  def __init__(self, alive = 20, masa_pod = 250, airgap = 16.3, duration = 10, dist_cm = 0.7, inercia= 70, min_distance = 9, max_distance = 22.5):
    # Actions: Voltage applied to the coil
    self.action_space = Box(low=np.array([-100, -100]), high = np.array([100, 100]), dtype=np.float32)
    # Observations: Airgap to the ceiling, velocity, distance to the objective, current of the coil
    self.observation_space = Box(low=np.array([-10, -10, -10, -10, -10, -10, -45, -45]), high = np.array([10, 10, 10, 10, 10, 10, 45, 45]), dtype=np.float32)
    # Initial parameters
    airgap = random.choice([16.3, 16.3])
    self.state = np.array([airgap - 16.3, airgap - 16.3, airgap - 16.3, airgap - 16.3, airgap - 16.3, airgap - 16.3, 0, 0])
    self.airgapinicial = airgap
    self.duration = duration
    self.timeleft = duration
    self.crash = False
    self.masa_pod = masa_pod
    self.sistema = TwoGDL(masa_pod = self.masa_pod, airgap = self.airgapinicial, dist_cm = dist_cm, inercia= inercia, min_distance = min_distance, max_distance = max_distance)
    self.steps = []
    self.airgap1 = airgap
    self.airgap2 = airgap
    self.distancia1 = 0
    self.distancia2 = 0
    self.velocidad = 0
    self.current1 = 0
    self.current2 = 0
    self.alive = alive
    self.vel = 0
    self.velangular = 0


  def step(self, action):
    # Apply action
    self.state, self.crash = self.sistema.step(action[0],action[1])
    self.distancia11, self.distancia12, self.distancia13, self.distancia21, self.distancia22, self.distancia23, self.current1, self.current2 = self.state

    # Reduce the time of the experiment
    self.timeleft -= 0.001

    # Calculate reward
    reward = -abs(self.distancia13) -abs(self.distancia23) - 10000*self.crash

    """if self.airgap >= 23: reward = -500
    elif self.airgap <= 10: reward = -500
    else: reward = -abs(self.current)"""

    # Check if experiment is done
    if self.timeleft <= 0:
      truncated = True
    else: truncated = False
    # Set placeholder for info
    info = {}
    # Only if we implemented the crash
    """if self.crash:
      reward = - 100000
      terminated = True
    else:
      terminated = False"""
    terminated = False
    self.steps.append(self.state)
    return self.state, reward, terminated, truncated, info


  def render(self, yes = "yes", normalize = True, seed = 0):
    # create data
    x = list(range(0,len(self.steps)))
    y1 = [16.3+step[0] for step in self.steps]
    y2 = [16.3+step[2] for step in self.steps]
    objective = [16.3]*len(self.steps)

    # plot lines
    fig = plt.figure(figsize=(10,5))
    ax = fig.add_subplot(111)
    #ax.tick_params(axis='x', colors='white')    #setting up X-axis tick color to red
    #ax.tick_params(axis='y', colors='white')  #setting up Y-axis tick color to black
    if normalize: ax.set_ylim(bottom=8, top=23)
    plt.xlabel("Time (s)") #, color='white')
    plt.ylabel("Airgap (mm)") #, color='white')
    plt.title("Airgap evolution") #, color='white')

    plt.plot(x, y1, label = "Airgap 1")
    plt.plot(x, y2, label = "Airgap 2")
    plt.plot(x, objective, label = "Objective")
    plt.legend()
    #if self.steps[0][0] < 0: plt.savefig("images/top-2gdl8x8nocrash.png")
    #else: plt.savefig("images/bottom-2gdl8x8nocrash.png")
    plt.savefig(f"images/2gdl8x8nocrashsituation{seed}.png")
    plt.show()

  def reset(self, seed = 0):
    # Reset experiment choosing randomly the start (ceiling or floor)
    airgap = random.choice([10, 21])
    self.state = np.array([airgap - 16.3, airgap - 16.3, airgap - 16.3, airgap - 16.3, airgap - 16.3, airgap - 16.3, 0, 0])
    self.sistema = TwoGDL(masa_pod = self.masa_pod, airgap = airgap, dist_cm = 0.7, inercia= 70, min_distance = 9, max_distance = 22.5)
    
    # Reset time
    self.timeleft = self.duration
    self.crash = False
    self.steps = []
    return self.state, seed

# %%
class Bobina():
  """ 
  Coil model for the Hybrid Electromagnetic Suspension
  """
  def __init__(self, masa_pod = 250, airgap = 22.5, min_distance = 9, max_distance = 22.5):
    self.masa_pod = masa_pod
    self.airgap = airgap
    self.aceleracion = []
    self.velocidad = []
    mat = scipy.io.loadmat('./coil/hems.mat')
    self.hems = mat["hems"][0][0]
    self.airgaps = self.hems[0][0]
    self.currents = self.hems[1][0]
    self.force_vertical = pickle.load(open("./coil/mlp_vertical.pkl", 'rb'))
    self.flux = self.hems[3]
    self.force_horizontal = self.hems[4]
    self.inductance = pickle.load(open("./coil/rf_inductance.pkl", 'rb'))
    self.resistance = self.hems[6][0][0]
    self.min_distance = min_distance
    self.max_distance = max_distance
    self.airgapinicial = airgap
    self.crash = False
    self.current = 0
    self.steps_RL = []

  def integral(self, lista, h = 1):
    return sum(h*(lista[i]+lista[i+1])/2 for i in range(len(lista)-1))

  def RL(self, airgap, target_voltage, temperature):
    # Resistance-Inductance circuit

    # Get resistance of the coil
    R = self.R(current = self.current, temperature = temperature)   
    V = target_voltage
    I = self.current
    L = self.L(airgap = airgap, current = self.current)
    dIdt = ((V/R) - I)/(L/R)                                      
    self.steps_RL.append(dIdt)                                   
    current = self.integral(self.steps_RL, h = 0.001)                          
    return current                                                  

  def R(self, current, temperature):
    return self.resistance                                         

  def L(self, airgap, current):
    # Return predicted inductance
    return float(self.inductance.predict(np.array([[airgap, current]]))[0])

  def vertical_force(self, airgap, target_voltage, temperature):
    # Get current from RL circuit
    I = self.RL(airgap = airgap, target_voltage = target_voltage, temperature = temperature) 
    
    # Clip result
    if I > 45:
      I = 45
    elif I < -45:
      I = -45
    self.current = I
    # Get vertical force from 
    FI = self.FI_vertical(airgap = airgap, current = I)                    
    return FI, I


  def FI_vertical(self, airgap, current):
    # Return predicted vertical force
    return float(self.force_vertical.predict(np.array([[airgap, current]])))    


  def next_airgap(self, masa_pod, vertical_force, verbose = False):
    # Devide the mass of the pod by 4 coils
    masa = masa_pod/4  
    # Calculate weight
    peso = masa * 9.8    
    # Get total force                                                       
    fuerza = peso - vertical_force
    if verbose: print("Fuerza resultante: ", fuerza)   
    # Calculate acceleration                                     
    aceleracion = fuerza/masa
    if verbose: print("Aceleración: ", aceleracion)                                         
    self.aceleracion.append(aceleracion)       
    # Calculate velocity                                
    velocidad = self.integral(self.aceleracion, 0.001)
    if verbose: print("Integral primera (velocidad): ", velocidad)                          
    self.velocidad.append(velocidad)               
    # Calculate position (x1000 as to transform from m to mm)                            
    posicion = self.airgapinicial + self.integral(self.velocidad, 0.001)*1000 
    if verbose: print("Integral segunda (posición): ", posicion)

    # Clip position
    if posicion > self.max_distance:
      airgap = self.max_distance
      self.aceleracion = [0]
      self.velocidad = [0]  
      #self.crash = True     
      self.airgapinicial = self.max_distance                                               
    elif posicion < self.min_distance:
      airgap = self.min_distance
      self.aceleracion = [0]
      self.velocidad = [0]
      #self.crash = True
      self.airgapinicial = self.min_distance
    else: airgap = posicion
    return airgap, velocidad

  def step(self, target_voltage, verbose = False):
    # Calculate vertical force and current
    vertical_force, self.current = self.vertical_force(airgap = self.airgap, target_voltage = target_voltage, temperature = 40)
    if verbose: print("Fuerza vertical: ", vertical_force)
    # Calculate next airgap and velocity
    self.airgap, velocidad = self.next_airgap(self.masa_pod, vertical_force, verbose = verbose)
    #noise = np.random.normal(0,0.5)
    #self.airgap = self.airgap + noise     
    return (np.float32(self.airgap), np.float32(velocidad), np.float32(self.airgap - 16.3), np.float32(self.current)), self.crash

# %%
class TwoGDL():
    def __init__(self, masa_pod = 250, airgap = 22.5, dist_cm = 0.7, inercia= 70, min_distance = 9, max_distance = 22.5):
        self.masa_pod = masa_pod
        self.airgap1 = airgap
        self.airgap1_list = [airgap, airgap]
        self.airgap2 = airgap
        self.airgap2_list = [airgap, airgap]
        self.dist_cm = dist_cm
        self.inercia = inercia
        self.airgapinicial = airgap
        self.min_distance = min_distance
        self.max_distance = max_distance
        self.b1 = Bobina(masa_pod = self.masa_pod, airgap = self.airgap1, min_distance = self.min_distance, max_distance = self.max_distance)
        self.b2 = Bobina(masa_pod = self.masa_pod, airgap = self.airgap2, min_distance = self.min_distance, max_distance = self.max_distance)
        self.crash = False
        self.angulo = [0]
        self.alpha = [0]
        self.integral_alpha = 0
        self.omega = [0]
        self.integral_omega = 0
        self.altura = [0]
        self.aceleracion = [0]
        self.integral_aceleracion = 0
        self.velocidad = [0]
        self.integral_velocidad = 0
    
    def integral(self, lista, h = 1):
        return sum(h*(lista[i]+lista[i+1])/2 for i in range(len(lista)-1))
    
    def fast_integral(self, last, lista, h = 0.001):
        return last + h*(lista[-1]+lista[-2])/2
    
    def get_angulo(self, f1, f2):
        F1 = f1*self.dist_cm
        F2 = -f2*self.dist_cm
        M = F1+F2
        alpha = M/self.inercia
        self.alpha.append(alpha)
        omega = self.fast_integral(self.integral_alpha, self.alpha, 0.001)
        self.integral_alpha = omega
        self.omega.append(omega)
        angulo = self.fast_integral(self.integral_omega, self.omega, 0.001)
        self.integral_omega = angulo
        self.angulo.append(angulo)
        return angulo
    
    def get_altura(self, f1, f2):
        F = (self.masa_pod/2)*9.8 - f1 - f2
        a = F/(self.masa_pod/2)
        self.aceleracion.append(a)
        v = self.fast_integral(self.integral_aceleracion, self.aceleracion, 0.001)
        self.integral_aceleracion = v
        self.velocidad.append(v)
        zpos = self.fast_integral(self.integral_velocidad,self.velocidad, 0.001)
        self.integral_velocidad = zpos
        zpos = self.airgapinicial + zpos*1000
        self.altura.append(zpos)
        return zpos
    
    def pos2airgap(self, pos, theta):
        airgap1 = pos + self.dist_cm*math.sin(theta)*1000
        airgap2 = pos - self.dist_cm*math.sin(theta)*1000
        return airgap1, airgap2
    
    def step(self, target_voltage1, target_voltage2, verbose = False):
        # Calculate vertical force and current
        vertical_force1, current1 = self.b1.vertical_force(airgap = self.airgap1, target_voltage = target_voltage1, temperature = 40)
        vertical_force2, current2 = self.b2.vertical_force(airgap = self.airgap2, target_voltage = target_voltage2, temperature = 40)
        if verbose: print("Fuerza vertical 1: ", vertical_force1)
        if verbose: print("Fuerza vertical 2: ", vertical_force2)
        angulo = self.get_angulo(f1 = vertical_force1, f2 = vertical_force2)
        zpos = self.get_altura(f1 = vertical_force1, f2 = vertical_force2)
        self.airgap1, self.airgap2 = self.pos2airgap(pos = zpos, theta = angulo)
        self.airgap1_list.append(self.airgap1)
        self.airgap2_list.append(self.airgap2)
        if verbose: print("Airgap 1: ", self.airgap1)
        if verbose: print("Airgap 2: ", self.airgap2)
        if self.airgap1 > self.max_distance or self.airgap2 > self.max_distance:
            self.airgap1 = self.max_distance
            self.airgap2 = self.max_distance
            #self.crash = True
            self.angulo = [0]
            self.alpha = [0]
            self.integral_alpha = 0
            self.omega = [0]
            self.integral_omega = 0
            self.altura = [0]
            self.aceleracion = [0]
            self.integral_aceleracion = 0
            self.velocidad = [0]
            self.integral_velocidad = 0
            self.airgapinicial = self.max_distance
        elif self.airgap1 < self.min_distance or self.airgap2 < self.min_distance:
            self.airgap1 = self.min_distance
            self.airgap2 = self.min_distance
            #self.crash = True
            self.angulo = [0]
            self.alpha = [0]
            self.integral_alpha = 0
            self.omega = [0]
            self.integral_omega = 0
            self.altura = [0]
            self.aceleracion = [0]
            self.integral_aceleracion = 0
            self.velocidad = [0]
            self.integral_velocidad = 0
            self.airgapinicial = self.min_distance
        #return (np.float32(self.airgap1 -16.3), np.float32(self.airgap2-16.3), np.float32(current1), np.float32(current2)), self.crash
        #return (np.float32(self.airgap1 -16.3), np.float32(self.airgap2-16.3), np.float32(self.integral_aceleracion), np.float32(self.integral_alpha), np.float32(current1), np.float32(current2)), self.crash, angulo, zpos - 16.3
        return (np.float32(self.airgap1_list[-2] -16.3), np.float32(self.airgap1_list[-1] -16.3), np.float32(self.airgap2_list[-2] -16.3), np.float32(self.airgap2_list[-1] -16.3), np.float32(current1), np.float32(current2)), self.crash
        #añadir una que returnee los 2 errores y las 2 velocidades

# %%
run = wandb.init(
    project="2gdl",
    sync_tensorboard=True,
    monitor_gym=True,
)
# Out:
# Finishing last run (ID:ie2rym5q) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▂▃▅▆██████▇▇▇▇███████████████████████</td></tr><tr><td>time/fps</td><td>████████████████▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/actor_loss</td><td>▇███▇▅▅▄▃▃▂▂▁▁▂▂▁▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/critic_loss</td><td>▂▆▇█▇▇▅▇▆▄▂▁▁▂▁▁▂▁▁▁▇▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/ent_coef</td><td>▅█▂▂▃▃▃▂▂▂▂▁▁▁▂▁▂▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂</td></tr><tr><td>train/ent_coef_loss</td><td>▄▅▃▃▅▃▅▂▆▄▃▂▄▃▂▃▂▄▄▃▃▂▃▃█▄▄▁▃▅▄▆▇▆▄▅▄▃▆▆</td></tr><tr><td>train/learning_rate</td><td>████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>5140000</td></tr><tr><td>rollout/ep_len_mean</td><td>5000.0</td></tr><tr><td>rollout/ep_rew_mean</td><td>-4141.50781</td></tr><tr><td>time/fps</td><td>38.0</td></tr><tr><td>train/actor_loss</td><td>63.33214</td></tr><tr><td>train/critic_loss</td><td>1.51051</td></tr><tr><td>train/ent_coef</td><td>0.0078</td></tr><tr><td>train/ent_coef_loss</td><td>1.61105</td></tr><tr><td>train/learning_rate</td><td>0.00049</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">golden-surf-32</strong> at: <a href='https://wandb.ai/hyperloopupv/2gdl/runs/ie2rym5q' target="_blank">https://wandb.ai/hyperloopupv/2gdl/runs/ie2rym5q</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20240123_234600-ie2rym5q\logs</code>
# Successfully finished last run (ID:ie2rym5q). Initializing new run:<br/>
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\rl_levitation_control\wandb\run-20240125_131913-hf9xcwkr</code>
# Syncing run <strong><a href='https://wandb.ai/hyperloopupv/2gdl/runs/hf9xcwkr' target="_blank">ancient-sun-33</a></strong> to <a href='https://wandb.ai/hyperloopupv/2gdl' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hyperloopupv/2gdl' target="_blank">https://wandb.ai/hyperloopupv/2gdl</a>
#  View run at <a href='https://wandb.ai/hyperloopupv/2gdl/runs/hf9xcwkr' target="_blank">https://wandb.ai/hyperloopupv/2gdl/runs/hf9xcwkr</a>

# %%
# Create log dir
log_dir = "2gdl/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = BobinaEnv( duration = 5 )
env = Monitor(env, log_dir)

# %%
from typing import Callable

def linear_schedule(initial_value: float) -> Callable[[float], float]:
    """
    Linear learning rate schedule.

    :param initial_value: Initial learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return progress_remaining * initial_value

    return func

# para el critic , qf=[400, 300], para el actor pi=[300, 200]
policy_kwargs = dict(net_arch=dict(pi=[8, 8], qf=[256, 256]))
model = SAC("MlpPolicy", env,learning_rate = linear_schedule(0.001), policy_kwargs=policy_kwargs, verbose=1, tensorboard_log=log_dir, device="auto")
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
MODEL_PATH = f"models/2gdl8x8framestack-success16/model.zip"

# Create and wrap the environment
env = BobinaEnv(duration = 5)

# Load the trained agent
model = SAC.load(MODEL_PATH, env=env, learning_rate = linear_schedule(0.0001))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Create checkpoint callback
checkpoint_callback = CheckpointCallback(
    save_freq=10000, save_path=log_dir, name_prefix="2gdl"
)


callback_on_best = StopTrainingOnRewardThreshold(reward_threshold=-350, verbose=1)
eval_callback = EvalCallback(env, callback_on_new_best=callback_on_best, verbose=1)

# %%
# Train the agent
model.learn(total_timesteps=10000000,
    callback=[
        checkpoint_callback,
        callback_on_best,
        WandbCallback(
            gradient_save_freq=10000,
            model_save_path=f"models/2gdl8x8framestack",
            model_save_freq=10000,
            verbose=2,
        ),
    ],
)
# Out:
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Logging to 2gdl/SAC_47
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -7.2e+04 |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 34       |
# |    time_elapsed    | 577      |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | 1.42e+03 |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.051    |
# |    ent_coef_loss   | 2.89     |
# |    learning_rate   | 9.98e-05 |
# |    n_updates       | 3699798  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.23e+04 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 33        |
# |    time_elapsed    | 1182      |
# |    total_timesteps | 40000     |
# | train/             |           |
# |    actor_loss      | 1.45e+03  |
# |    critic_loss     | 1.81      |
# |    ent_coef        | 0.0765    |
# |    ent_coef_loss   | -0.483    |
# |    learning_rate   | 9.96e-05  |
# |    n_updates       | 3719798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.24e+04 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 32        |
# |    time_elapsed    | 1820      |
# |    total_timesteps | 60000     |
# | train/             |           |
# |    actor_loss      | 1.45e+03  |
# |    critic_loss     | 2.9       |
# |    ent_coef        | 0.0154    |
# |    ent_coef_loss   | -2.49     |
# |    learning_rate   | 9.94e-05  |
# |    n_updates       | 3739798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.26e+04 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 32        |
# |    time_elapsed    | 2449      |
# |    total_timesteps | 80000     |
# | train/             |           |
# |    actor_loss      | 1.46e+03  |
# |    critic_loss     | 3.89      |
# |    ent_coef        | 0.0122    |
# |    ent_coef_loss   | 1.77      |
# |    learning_rate   | 9.92e-05  |
# |    n_updates       | 3759798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.26e+04 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 32        |
# |    time_elapsed    | 3059      |
# |    total_timesteps | 100000    |
# | train/             |           |
# |    actor_loss      | 1.46e+03  |
# |    critic_loss     | 9.14      |
# |    ent_coef        | 0.0255    |
# |    ent_coef_loss   | 1.09      |
# |    learning_rate   | 9.9e-05   |
# |    n_updates       | 3779798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.26e+04 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 32        |
# |    time_elapsed    | 3650      |
# |    total_timesteps | 120000    |
# | train/             |           |
# |    actor_loss      | 1.46e+03  |
# |    critic_loss     | 2.13      |
# |    ent_coef        | 0.0335    |
# |    ent_coef_loss   | 0.452     |
# |    learning_rate   | 9.88e-05  |
# |    n_updates       | 3799798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.25e+04 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 32        |
# |    time_elapsed    | 4276      |
# |    total_timesteps | 140000    |
# | train/             |           |
# |    actor_loss      | 1.46e+03  |
# |    critic_loss     | 4         |
# |    ent_coef        | 0.0271    |
# |    ent_coef_loss   | 1.4       |
# |    learning_rate   | 9.86e-05  |
# |    n_updates       | 3819798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.25e+04 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 32        |
# |    time_elapsed    | 4902      |
# |    total_timesteps | 160000    |
# | train/             |           |
# |    actor_loss      | 1.47e+03  |
# |    critic_loss     | 24.1      |
# |    ent_coef        | 0.0257    |
# |    ent_coef_loss   | 0.233     |
# |    learning_rate   | 9.84e-05  |
# |    n_updates       | 3839798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.18e+04 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 32        |
# |    time_elapsed    | 5529      |
# |    total_timesteps | 180000    |
# | train/             |           |
# |    actor_loss      | 1.45e+03  |
# |    critic_loss     | 18.9      |
# |    ent_coef        | 0.0564    |
# |    ent_coef_loss   | 0.848     |
# |    learning_rate   | 9.82e-05  |
# |    n_updates       | 3859798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.11e+04 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 32        |
# |    time_elapsed    | 6164      |
# |    total_timesteps | 200000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 4.69      |
# |    ent_coef        | 0.0325    |
# |    ent_coef_loss   | 1.22      |
# |    learning_rate   | 9.8e-05   |
# |    n_updates       | 3879798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.12e+04 |
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 32        |
# |    time_elapsed    | 6790      |
# |    total_timesteps | 220000    |
# | train/             |           |
# |    actor_loss      | 1.44e+03  |
# |    critic_loss     | 0.781     |
# |    ent_coef        | 0.0249    |
# |    ent_coef_loss   | 0.564     |
# |    learning_rate   | 9.78e-05  |
# |    n_updates       | 3899798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.13e+04 |
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 32        |
# |    time_elapsed    | 7417      |
# |    total_timesteps | 240000    |
# | train/             |           |
# |    actor_loss      | 1.45e+03  |
# |    critic_loss     | 1.72      |
# |    ent_coef        | 0.044     |
# |    ent_coef_loss   | -0.278    |
# |    learning_rate   | 9.76e-05  |
# |    n_updates       | 3919798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.11e+04 |
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 32        |
# |    time_elapsed    | 8050      |
# |    total_timesteps | 260000    |
# | train/             |           |
# |    actor_loss      | 1.45e+03  |
# |    critic_loss     | 2.35      |
# |    ent_coef        | 0.0324    |
# |    ent_coef_loss   | -1.09     |
# |    learning_rate   | 9.74e-05  |
# |    n_updates       | 3939798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.13e+04 |
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 32        |
# |    time_elapsed    | 8687      |
# |    total_timesteps | 280000    |
# | train/             |           |
# |    actor_loss      | 1.44e+03  |
# |    critic_loss     | 0.234     |
# |    ent_coef        | 0.0186    |
# |    ent_coef_loss   | -1.65     |
# |    learning_rate   | 9.72e-05  |
# |    n_updates       | 3959798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.14e+04 |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 32        |
# |    time_elapsed    | 9321      |
# |    total_timesteps | 300000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 1.07      |
# |    ent_coef        | 0.0257    |
# |    ent_coef_loss   | 0.0937    |
# |    learning_rate   | 9.7e-05   |
# |    n_updates       | 3979798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.14e+04 |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 32        |
# |    time_elapsed    | 9947      |
# |    total_timesteps | 320000    |
# | train/             |           |
# |    actor_loss      | 1.44e+03  |
# |    critic_loss     | 3.85      |
# |    ent_coef        | 0.0279    |
# |    ent_coef_loss   | 0.387     |
# |    learning_rate   | 9.68e-05  |
# |    n_updates       | 3999798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.15e+04 |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 32        |
# |    time_elapsed    | 10575     |
# |    total_timesteps | 340000    |
# | train/             |           |
# |    actor_loss      | 1.44e+03  |
# |    critic_loss     | 1.83      |
# |    ent_coef        | 0.0151    |
# |    ent_coef_loss   | -0.023    |
# |    learning_rate   | 9.66e-05  |
# |    n_updates       | 4019798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.16e+04 |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 32        |
# |    time_elapsed    | 11211     |
# |    total_timesteps | 360000    |
# | train/             |           |
# |    actor_loss      | 1.44e+03  |
# |    critic_loss     | 6.37      |
# |    ent_coef        | 0.017     |
# |    ent_coef_loss   | 0.179     |
# |    learning_rate   | 9.64e-05  |
# |    n_updates       | 4039798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.15e+04 |
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 32        |
# |    time_elapsed    | 11841     |
# |    total_timesteps | 380000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 9.72      |
# |    ent_coef        | 0.0268    |
# |    ent_coef_loss   | 3.72      |
# |    learning_rate   | 9.62e-05  |
# |    n_updates       | 4059798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.11e+04 |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 32        |
# |    time_elapsed    | 12454     |
# |    total_timesteps | 400000    |
# | train/             |           |
# |    actor_loss      | 1.42e+03  |
# |    critic_loss     | 1.69      |
# |    ent_coef        | 0.0191    |
# |    ent_coef_loss   | -0.00409  |
# |    learning_rate   | 9.6e-05   |
# |    n_updates       | 4079798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.09e+04 |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 32        |
# |    time_elapsed    | 13030     |
# |    total_timesteps | 420000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 2.07      |
# |    ent_coef        | 0.0384    |
# |    ent_coef_loss   | -0.592    |
# |    learning_rate   | 9.58e-05  |
# |    n_updates       | 4099798   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -7.1e+04 |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 32       |
# |    time_elapsed    | 13662    |
# |    total_timesteps | 440000   |
# | train/             |          |
# |    actor_loss      | 1.42e+03 |
# |    critic_loss     | 1.11     |
# |    ent_coef        | 0.0176   |
# |    ent_coef_loss   | -1.29    |
# |    learning_rate   | 9.56e-05 |
# |    n_updates       | 4119798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -7.1e+04 |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 32       |
# |    time_elapsed    | 14299    |
# |    total_timesteps | 460000   |
# | train/             |          |
# |    actor_loss      | 1.42e+03 |
# |    critic_loss     | 2.97     |
# |    ent_coef        | 0.00885  |
# |    ent_coef_loss   | -4.36    |
# |    learning_rate   | 9.54e-05 |
# |    n_updates       | 4139798  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.08e+04 |
# | time/              |           |
# |    episodes        | 96        |
# |    fps             | 32        |
# |    time_elapsed    | 14935     |
# |    total_timesteps | 480000    |
# | train/             |           |
# |    actor_loss      | 1.42e+03  |
# |    critic_loss     | 0.152     |
# |    ent_coef        | 0.0148    |
# |    ent_coef_loss   | -3.93     |
# |    learning_rate   | 9.52e-05  |
# |    n_updates       | 4159798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.08e+04 |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 32        |
# |    time_elapsed    | 15568     |
# |    total_timesteps | 500000    |
# | train/             |           |
# |    actor_loss      | 1.42e+03  |
# |    critic_loss     | 1.87      |
# |    ent_coef        | 0.0174    |
# |    ent_coef_loss   | 7.66      |
# |    learning_rate   | 9.5e-05   |
# |    n_updates       | 4179798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.06e+04 |
# | time/              |           |
# |    episodes        | 104       |
# |    fps             | 32        |
# |    time_elapsed    | 16194     |
# |    total_timesteps | 520000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 0.384     |
# |    ent_coef        | 0.00857   |
# |    ent_coef_loss   | -1.5      |
# |    learning_rate   | 9.48e-05  |
# |    n_updates       | 4199798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.06e+04 |
# | time/              |           |
# |    episodes        | 108       |
# |    fps             | 32        |
# |    time_elapsed    | 16820     |
# |    total_timesteps | 540000    |
# | train/             |           |
# |    actor_loss      | 1.4e+03   |
# |    critic_loss     | 59.3      |
# |    ent_coef        | 0.0211    |
# |    ent_coef_loss   | -1.17     |
# |    learning_rate   | 9.46e-05  |
# |    n_updates       | 4219798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.05e+04 |
# | time/              |           |
# |    episodes        | 112       |
# |    fps             | 32        |
# |    time_elapsed    | 17456     |
# |    total_timesteps | 560000    |
# | train/             |           |
# |    actor_loss      | 1.41e+03  |
# |    critic_loss     | 9.84      |
# |    ent_coef        | 0.0258    |
# |    ent_coef_loss   | -0.271    |
# |    learning_rate   | 9.44e-05  |
# |    n_updates       | 4239798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.04e+04 |
# | time/              |           |
# |    episodes        | 116       |
# |    fps             | 32        |
# |    time_elapsed    | 18092     |
# |    total_timesteps | 580000    |
# | train/             |           |
# |    actor_loss      | 1.42e+03  |
# |    critic_loss     | 8.49      |
# |    ent_coef        | 0.0168    |
# |    ent_coef_loss   | 0.248     |
# |    learning_rate   | 9.42e-05  |
# |    n_updates       | 4259798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.04e+04 |
# | time/              |           |
# |    episodes        | 120       |
# |    fps             | 32        |
# |    time_elapsed    | 18728     |
# |    total_timesteps | 600000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 1.32      |
# |    ent_coef        | 0.00944   |
# |    ent_coef_loss   | 2.69      |
# |    learning_rate   | 9.4e-05   |
# |    n_updates       | 4279798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.04e+04 |
# | time/              |           |
# |    episodes        | 124       |
# |    fps             | 32        |
# |    time_elapsed    | 19354     |
# |    total_timesteps | 620000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 1.12      |
# |    ent_coef        | 0.026     |
# |    ent_coef_loss   | 0.337     |
# |    learning_rate   | 9.38e-05  |
# |    n_updates       | 4299798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.04e+04 |
# | time/              |           |
# |    episodes        | 128       |
# |    fps             | 32        |
# |    time_elapsed    | 19981     |
# |    total_timesteps | 640000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 0.704     |
# |    ent_coef        | 0.0197    |
# |    ent_coef_loss   | -1.14     |
# |    learning_rate   | 9.36e-05  |
# |    n_updates       | 4319798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.04e+04 |
# | time/              |           |
# |    episodes        | 132       |
# |    fps             | 32        |
# |    time_elapsed    | 20605     |
# |    total_timesteps | 660000    |
# | train/             |           |
# |    actor_loss      | 1.44e+03  |
# |    critic_loss     | 0.891     |
# |    ent_coef        | 0.0132    |
# |    ent_coef_loss   | 0.811     |
# |    learning_rate   | 9.34e-05  |
# |    n_updates       | 4339798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.07e+04 |
# | time/              |           |
# |    episodes        | 136       |
# |    fps             | 32        |
# |    time_elapsed    | 21231     |
# |    total_timesteps | 680000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 11.2      |
# |    ent_coef        | 0.0149    |
# |    ent_coef_loss   | 2.59      |
# |    learning_rate   | 9.32e-05  |
# |    n_updates       | 4359798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.05e+04 |
# | time/              |           |
# |    episodes        | 140       |
# |    fps             | 32        |
# |    time_elapsed    | 21864     |
# |    total_timesteps | 700000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 13.3      |
# |    ent_coef        | 0.0288    |
# |    ent_coef_loss   | -0.432    |
# |    learning_rate   | 9.3e-05   |
# |    n_updates       | 4379798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.04e+04 |
# | time/              |           |
# |    episodes        | 144       |
# |    fps             | 32        |
# |    time_elapsed    | 22493     |
# |    total_timesteps | 720000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 1.11      |
# |    ent_coef        | 0.0285    |
# |    ent_coef_loss   | 2.72      |
# |    learning_rate   | 9.28e-05  |
# |    n_updates       | 4399798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.04e+04 |
# | time/              |           |
# |    episodes        | 148       |
# |    fps             | 31        |
# |    time_elapsed    | 23130     |
# |    total_timesteps | 740000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 6.09      |
# |    ent_coef        | 0.0108    |
# |    ent_coef_loss   | -0.642    |
# |    learning_rate   | 9.26e-05  |
# |    n_updates       | 4419798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.05e+04 |
# | time/              |           |
# |    episodes        | 152       |
# |    fps             | 32        |
# |    time_elapsed    | 23718     |
# |    total_timesteps | 760000    |
# | train/             |           |
# |    actor_loss      | 1.42e+03  |
# |    critic_loss     | 2.08      |
# |    ent_coef        | 0.0256    |
# |    ent_coef_loss   | 0.0967    |
# |    learning_rate   | 9.24e-05  |
# |    n_updates       | 4439798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.05e+04 |
# | time/              |           |
# |    episodes        | 156       |
# |    fps             | 32        |
# |    time_elapsed    | 24344     |
# |    total_timesteps | 780000    |
# | train/             |           |
# |    actor_loss      | 1.42e+03  |
# |    critic_loss     | 5.5       |
# |    ent_coef        | 0.0163    |
# |    ent_coef_loss   | -2.43     |
# |    learning_rate   | 9.22e-05  |
# |    n_updates       | 4459798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.04e+04 |
# | time/              |           |
# |    episodes        | 160       |
# |    fps             | 32        |
# |    time_elapsed    | 24982     |
# |    total_timesteps | 800000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 3.56      |
# |    ent_coef        | 0.0118    |
# |    ent_coef_loss   | 0.577     |
# |    learning_rate   | 9.2e-05   |
# |    n_updates       | 4479798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -7.02e+04 |
# | time/              |           |
# |    episodes        | 164       |
# |    fps             | 32        |
# |    time_elapsed    | 25612     |
# |    total_timesteps | 820000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 15.4      |
# |    ent_coef        | 0.0368    |
# |    ent_coef_loss   | 2.74      |
# |    learning_rate   | 9.18e-05  |
# |    n_updates       | 4499798   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -7e+04   |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 32       |
# |    time_elapsed    | 26242    |
# |    total_timesteps | 840000   |
# | train/             |          |
# |    actor_loss      | 1.45e+03 |
# |    critic_loss     | 2.64     |
# |    ent_coef        | 0.0534   |
# |    ent_coef_loss   | 1.4      |
# |    learning_rate   | 9.16e-05 |
# |    n_updates       | 4519798  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.99e+04 |
# | time/              |           |
# |    episodes        | 172       |
# |    fps             | 32        |
# |    time_elapsed    | 26870     |
# |    total_timesteps | 860000    |
# | train/             |           |
# |    actor_loss      | 1.48e+03  |
# |    critic_loss     | 3.74      |
# |    ent_coef        | 0.0293    |
# |    ent_coef_loss   | -0.335    |
# |    learning_rate   | 9.14e-05  |
# |    n_updates       | 4539798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.98e+04 |
# | time/              |           |
# |    episodes        | 176       |
# |    fps             | 31        |
# |    time_elapsed    | 27505     |
# |    total_timesteps | 880000    |
# | train/             |           |
# |    actor_loss      | 1.44e+03  |
# |    critic_loss     | 8.99      |
# |    ent_coef        | 0.0337    |
# |    ent_coef_loss   | -0.259    |
# |    learning_rate   | 9.12e-05  |
# |    n_updates       | 4559798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.99e+04 |
# | time/              |           |
# |    episodes        | 180       |
# |    fps             | 31        |
# |    time_elapsed    | 28142     |
# |    total_timesteps | 900000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 3.43      |
# |    ent_coef        | 0.0255    |
# |    ent_coef_loss   | 1.79      |
# |    learning_rate   | 9.1e-05   |
# |    n_updates       | 4579798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.96e+04 |
# | time/              |           |
# |    episodes        | 184       |
# |    fps             | 31        |
# |    time_elapsed    | 28772     |
# |    total_timesteps | 920000    |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 2.19      |
# |    ent_coef        | 0.0441    |
# |    ent_coef_loss   | -0.252    |
# |    learning_rate   | 9.08e-05  |
# |    n_updates       | 4599798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.95e+04 |
# | time/              |           |
# |    episodes        | 188       |
# |    fps             | 31        |
# |    time_elapsed    | 29405     |
# |    total_timesteps | 940000    |
# | train/             |           |
# |    actor_loss      | 1.42e+03  |
# |    critic_loss     | 1.29      |
# |    ent_coef        | 0.0231    |
# |    ent_coef_loss   | 0.919     |
# |    learning_rate   | 9.06e-05  |
# |    n_updates       | 4619798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.95e+04 |
# | time/              |           |
# |    episodes        | 192       |
# |    fps             | 31        |
# |    time_elapsed    | 30038     |
# |    total_timesteps | 960000    |
# | train/             |           |
# |    actor_loss      | 1.42e+03  |
# |    critic_loss     | 0.824     |
# |    ent_coef        | 0.0204    |
# |    ent_coef_loss   | -0.658    |
# |    learning_rate   | 9.04e-05  |
# |    n_updates       | 4639798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.97e+04 |
# | time/              |           |
# |    episodes        | 196       |
# |    fps             | 31        |
# |    time_elapsed    | 30676     |
# |    total_timesteps | 980000    |
# | train/             |           |
# |    actor_loss      | 1.42e+03  |
# |    critic_loss     | 7.85      |
# |    ent_coef        | 0.0205    |
# |    ent_coef_loss   | 1.2       |
# |    learning_rate   | 9.02e-05  |
# |    n_updates       | 4659798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.96e+04 |
# | time/              |           |
# |    episodes        | 200       |
# |    fps             | 31        |
# |    time_elapsed    | 31315     |
# |    total_timesteps | 1000000   |
# | train/             |           |
# |    actor_loss      | 1.42e+03  |
# |    critic_loss     | 2.42      |
# |    ent_coef        | 0.0266    |
# |    ent_coef_loss   | -0.641    |
# |    learning_rate   | 9e-05     |
# |    n_updates       | 4679798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.97e+04 |
# | time/              |           |
# |    episodes        | 204       |
# |    fps             | 31        |
# |    time_elapsed    | 31953     |
# |    total_timesteps | 1020000   |
# | train/             |           |
# |    actor_loss      | 1.41e+03  |
# |    critic_loss     | 4.69      |
# |    ent_coef        | 0.0244    |
# |    ent_coef_loss   | 0.69      |
# |    learning_rate   | 8.98e-05  |
# |    n_updates       | 4699798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.95e+04 |
# | time/              |           |
# |    episodes        | 208       |
# |    fps             | 31        |
# |    time_elapsed    | 32583     |
# |    total_timesteps | 1040000   |
# | train/             |           |
# |    actor_loss      | 1.42e+03  |
# |    critic_loss     | 6.29      |
# |    ent_coef        | 0.0261    |
# |    ent_coef_loss   | 0.147     |
# |    learning_rate   | 8.96e-05  |
# |    n_updates       | 4719798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.95e+04 |
# | time/              |           |
# |    episodes        | 212       |
# |    fps             | 31        |
# |    time_elapsed    | 33186     |
# |    total_timesteps | 1060000   |
# | train/             |           |
# |    actor_loss      | 1.42e+03  |
# |    critic_loss     | 2.57      |
# |    ent_coef        | 0.0126    |
# |    ent_coef_loss   | -2.82     |
# |    learning_rate   | 8.94e-05  |
# |    n_updates       | 4739798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.96e+04 |
# | time/              |           |
# |    episodes        | 216       |
# |    fps             | 31        |
# |    time_elapsed    | 33783     |
# |    total_timesteps | 1080000   |
# | train/             |           |
# |    actor_loss      | 1.42e+03  |
# |    critic_loss     | 14.3      |
# |    ent_coef        | 0.011     |
# |    ent_coef_loss   | -1.58     |
# |    learning_rate   | 8.92e-05  |
# |    n_updates       | 4759798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.94e+04 |
# | time/              |           |
# |    episodes        | 220       |
# |    fps             | 31        |
# |    time_elapsed    | 34407     |
# |    total_timesteps | 1100000   |
# | train/             |           |
# |    actor_loss      | 1.41e+03  |
# |    critic_loss     | 3.96      |
# |    ent_coef        | 0.0218    |
# |    ent_coef_loss   | 1.82      |
# |    learning_rate   | 8.9e-05   |
# |    n_updates       | 4779798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.93e+04 |
# | time/              |           |
# |    episodes        | 224       |
# |    fps             | 31        |
# |    time_elapsed    | 35037     |
# |    total_timesteps | 1120000   |
# | train/             |           |
# |    actor_loss      | 1.43e+03  |
# |    critic_loss     | 0.96      |
# |    ent_coef        | 0.0243    |
# |    ent_coef_loss   | -2.19     |
# |    learning_rate   | 8.88e-05  |
# |    n_updates       | 4799798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.91e+04 |
# | time/              |           |
# |    episodes        | 228       |
# |    fps             | 31        |
# |    time_elapsed    | 35668     |
# |    total_timesteps | 1140000   |
# | train/             |           |
# |    actor_loss      | 1.42e+03  |
# |    critic_loss     | 6.35      |
# |    ent_coef        | 0.017     |
# |    ent_coef_loss   | -0.928    |
# |    learning_rate   | 8.86e-05  |
# |    n_updates       | 4819798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.87e+04 |
# | time/              |           |
# |    episodes        | 232       |
# |    fps             | 31        |
# |    time_elapsed    | 36296     |
# |    total_timesteps | 1160000   |
# | train/             |           |
# |    actor_loss      | 1.41e+03  |
# |    critic_loss     | 3.2       |
# |    ent_coef        | 0.0161    |
# |    ent_coef_loss   | -0.201    |
# |    learning_rate   | 8.84e-05  |
# |    n_updates       | 4839798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.85e+04 |
# | time/              |           |
# |    episodes        | 236       |
# |    fps             | 31        |
# |    time_elapsed    | 36923     |
# |    total_timesteps | 1180000   |
# | train/             |           |
# |    actor_loss      | 1.39e+03  |
# |    critic_loss     | 3.44      |
# |    ent_coef        | 0.0165    |
# |    ent_coef_loss   | -1.93     |
# |    learning_rate   | 8.82e-05  |
# |    n_updates       | 4859798   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -6.8e+04 |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 31       |
# |    time_elapsed    | 37552    |
# |    total_timesteps | 1200000  |
# | train/             |          |
# |    actor_loss      | 1.4e+03  |
# |    critic_loss     | 9.17     |
# |    ent_coef        | 0.0144   |
# |    ent_coef_loss   | 0.321    |
# |    learning_rate   | 8.8e-05  |
# |    n_updates       | 4879798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -6.8e+04 |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 31       |
# |    time_elapsed    | 38180    |
# |    total_timesteps | 1220000  |
# | train/             |          |
# |    actor_loss      | 1.39e+03 |
# |    critic_loss     | 2.99     |
# |    ent_coef        | 0.0214   |
# |    ent_coef_loss   | 0.661    |
# |    learning_rate   | 8.78e-05 |
# |    n_updates       | 4899798  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.77e+04 |
# | time/              |           |
# |    episodes        | 248       |
# |    fps             | 31        |
# |    time_elapsed    | 38810     |
# |    total_timesteps | 1240000   |
# | train/             |           |
# |    actor_loss      | 1.4e+03   |
# |    critic_loss     | 0.515     |
# |    ent_coef        | 0.0155    |
# |    ent_coef_loss   | -2.28     |
# |    learning_rate   | 8.76e-05  |
# |    n_updates       | 4919798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.74e+04 |
# | time/              |           |
# |    episodes        | 252       |
# |    fps             | 31        |
# |    time_elapsed    | 39418     |
# |    total_timesteps | 1260000   |
# | train/             |           |
# |    actor_loss      | 1.4e+03   |
# |    critic_loss     | 2.52      |
# |    ent_coef        | 0.019     |
# |    ent_coef_loss   | -2.05     |
# |    learning_rate   | 8.74e-05  |
# |    n_updates       | 4939798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.71e+04 |
# | time/              |           |
# |    episodes        | 256       |
# |    fps             | 31        |
# |    time_elapsed    | 40019     |
# |    total_timesteps | 1280000   |
# | train/             |           |
# |    actor_loss      | 1.38e+03  |
# |    critic_loss     | 12.1      |
# |    ent_coef        | 0.00906   |
# |    ent_coef_loss   | 1.6       |
# |    learning_rate   | 8.72e-05  |
# |    n_updates       | 4959798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.65e+04 |
# | time/              |           |
# |    episodes        | 260       |
# |    fps             | 31        |
# |    time_elapsed    | 40648     |
# |    total_timesteps | 1300000   |
# | train/             |           |
# |    actor_loss      | 1.38e+03  |
# |    critic_loss     | 8.03      |
# |    ent_coef        | 0.0126    |
# |    ent_coef_loss   | 1.63      |
# |    learning_rate   | 8.7e-05   |
# |    n_updates       | 4979798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.67e+04 |
# | time/              |           |
# |    episodes        | 264       |
# |    fps             | 31        |
# |    time_elapsed    | 41277     |
# |    total_timesteps | 1320000   |
# | train/             |           |
# |    actor_loss      | 1.37e+03  |
# |    critic_loss     | 1.82      |
# |    ent_coef        | 0.0296    |
# |    ent_coef_loss   | -1.44     |
# |    learning_rate   | 8.68e-05  |
# |    n_updates       | 4999798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.66e+04 |
# | time/              |           |
# |    episodes        | 268       |
# |    fps             | 31        |
# |    time_elapsed    | 41905     |
# |    total_timesteps | 1340000   |
# | train/             |           |
# |    actor_loss      | 1.38e+03  |
# |    critic_loss     | 2.36      |
# |    ent_coef        | 0.0342    |
# |    ent_coef_loss   | 8.83      |
# |    learning_rate   | 8.66e-05  |
# |    n_updates       | 5019798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.58e+04 |
# | time/              |           |
# |    episodes        | 272       |
# |    fps             | 31        |
# |    time_elapsed    | 42543     |
# |    total_timesteps | 1360000   |
# | train/             |           |
# |    actor_loss      | 1.36e+03  |
# |    critic_loss     | 7.55      |
# |    ent_coef        | 0.0874    |
# |    ent_coef_loss   | 1.05      |
# |    learning_rate   | 8.64e-05  |
# |    n_updates       | 5039798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.53e+04 |
# | time/              |           |
# |    episodes        | 276       |
# |    fps             | 31        |
# |    time_elapsed    | 43181     |
# |    total_timesteps | 1380000   |
# | train/             |           |
# |    actor_loss      | 1.36e+03  |
# |    critic_loss     | 5.03      |
# |    ent_coef        | 0.103     |
# |    ent_coef_loss   | 0.64      |
# |    learning_rate   | 8.62e-05  |
# |    n_updates       | 5059798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.48e+04 |
# | time/              |           |
# |    episodes        | 280       |
# |    fps             | 31        |
# |    time_elapsed    | 43819     |
# |    total_timesteps | 1400000   |
# | train/             |           |
# |    actor_loss      | 1.37e+03  |
# |    critic_loss     | 8.44      |
# |    ent_coef        | 0.0589    |
# |    ent_coef_loss   | 0.153     |
# |    learning_rate   | 8.6e-05   |
# |    n_updates       | 5079798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.38e+04 |
# | time/              |           |
# |    episodes        | 284       |
# |    fps             | 31        |
# |    time_elapsed    | 44457     |
# |    total_timesteps | 1420000   |
# | train/             |           |
# |    actor_loss      | 1.37e+03  |
# |    critic_loss     | 8.44      |
# |    ent_coef        | 0.0681    |
# |    ent_coef_loss   | -1.81     |
# |    learning_rate   | 8.58e-05  |
# |    n_updates       | 5099798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.33e+04 |
# | time/              |           |
# |    episodes        | 288       |
# |    fps             | 31        |
# |    time_elapsed    | 45096     |
# |    total_timesteps | 1440000   |
# | train/             |           |
# |    actor_loss      | 1.36e+03  |
# |    critic_loss     | 6.92      |
# |    ent_coef        | 0.082     |
# |    ent_coef_loss   | -1.13     |
# |    learning_rate   | 8.56e-05  |
# |    n_updates       | 5119798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.21e+04 |
# | time/              |           |
# |    episodes        | 292       |
# |    fps             | 31        |
# |    time_elapsed    | 45733     |
# |    total_timesteps | 1460000   |
# | train/             |           |
# |    actor_loss      | 1.33e+03  |
# |    critic_loss     | 44.3      |
# |    ent_coef        | 0.0557    |
# |    ent_coef_loss   | -1.34     |
# |    learning_rate   | 8.54e-05  |
# |    n_updates       | 5139798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.12e+04 |
# | time/              |           |
# |    episodes        | 296       |
# |    fps             | 31        |
# |    time_elapsed    | 46371     |
# |    total_timesteps | 1480000   |
# | train/             |           |
# |    actor_loss      | 1.33e+03  |
# |    critic_loss     | 11.4      |
# |    ent_coef        | 0.0733    |
# |    ent_coef_loss   | -1.01     |
# |    learning_rate   | 8.52e-05  |
# |    n_updates       | 5159798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -6.07e+04 |
# | time/              |           |
# |    episodes        | 300       |
# |    fps             | 31        |
# |    time_elapsed    | 47009     |
# |    total_timesteps | 1500000   |
# | train/             |           |
# |    actor_loss      | 1.35e+03  |
# |    critic_loss     | 16.1      |
# |    ent_coef        | 0.127     |
# |    ent_coef_loss   | 1.27      |
# |    learning_rate   | 8.5e-05   |
# |    n_updates       | 5179798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.97e+04 |
# | time/              |           |
# |    episodes        | 304       |
# |    fps             | 31        |
# |    time_elapsed    | 47648     |
# |    total_timesteps | 1520000   |
# | train/             |           |
# |    actor_loss      | 1.33e+03  |
# |    critic_loss     | 17.6      |
# |    ent_coef        | 0.0954    |
# |    ent_coef_loss   | 0.241     |
# |    learning_rate   | 8.48e-05  |
# |    n_updates       | 5199798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.86e+04 |
# | time/              |           |
# |    episodes        | 308       |
# |    fps             | 31        |
# |    time_elapsed    | 48278     |
# |    total_timesteps | 1540000   |
# | train/             |           |
# |    actor_loss      | 1.33e+03  |
# |    critic_loss     | 8.74      |
# |    ent_coef        | 0.0942    |
# |    ent_coef_loss   | -1.03     |
# |    learning_rate   | 8.46e-05  |
# |    n_updates       | 5219798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.83e+04 |
# | time/              |           |
# |    episodes        | 312       |
# |    fps             | 31        |
# |    time_elapsed    | 48905     |
# |    total_timesteps | 1560000   |
# | train/             |           |
# |    actor_loss      | 1.32e+03  |
# |    critic_loss     | 10.3      |
# |    ent_coef        | 0.104     |
# |    ent_coef_loss   | -0.436    |
# |    learning_rate   | 8.44e-05  |
# |    n_updates       | 5239798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.71e+04 |
# | time/              |           |
# |    episodes        | 316       |
# |    fps             | 31        |
# |    time_elapsed    | 49534     |
# |    total_timesteps | 1580000   |
# | train/             |           |
# |    actor_loss      | 1.32e+03  |
# |    critic_loss     | 14        |
# |    ent_coef        | 0.105     |
# |    ent_coef_loss   | -0.62     |
# |    learning_rate   | 8.42e-05  |
# |    n_updates       | 5259798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.72e+04 |
# | time/              |           |
# |    episodes        | 320       |
# |    fps             | 31        |
# |    time_elapsed    | 50163     |
# |    total_timesteps | 1600000   |
# | train/             |           |
# |    actor_loss      | 1.31e+03  |
# |    critic_loss     | 16.6      |
# |    ent_coef        | 0.12      |
# |    ent_coef_loss   | -0.0625   |
# |    learning_rate   | 8.4e-05   |
# |    n_updates       | 5279798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.65e+04 |
# | time/              |           |
# |    episodes        | 324       |
# |    fps             | 31        |
# |    time_elapsed    | 50801     |
# |    total_timesteps | 1620000   |
# ...
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.27e+04 |
# | time/              |           |
# |    episodes        | 912       |
# |    fps             | 31        |
# |    time_elapsed    | 143580    |
# |    total_timesteps | 4560000   |
# | train/             |           |
# |    actor_loss      | 1.03e+03  |
# |    critic_loss     | 4.85      |
# |    ent_coef        | 0.0525    |
# |    ent_coef_loss   | 1.42      |
# |    learning_rate   | 5.44e-05  |
# |    n_updates       | 8239798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.22e+04 |
# | time/              |           |
# |    episodes        | 916       |
# |    fps             | 31        |
# |    time_elapsed    | 144210    |
# |    total_timesteps | 4580000   |
# | train/             |           |
# |    actor_loss      | 1.07e+03  |
# |    critic_loss     | 1.88      |
# |    ent_coef        | 0.0323    |
# |    ent_coef_loss   | 0.952     |
# |    learning_rate   | 5.42e-05  |
# |    n_updates       | 8259798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.36e+04 |
# | time/              |           |
# |    episodes        | 920       |
# |    fps             | 31        |
# |    time_elapsed    | 144839    |
# |    total_timesteps | 4600000   |
# | train/             |           |
# |    actor_loss      | 1.1e+03   |
# |    critic_loss     | 2.86      |
# |    ent_coef        | 0.027     |
# |    ent_coef_loss   | -0.378    |
# |    learning_rate   | 5.4e-05   |
# |    n_updates       | 8279798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.36e+04 |
# | time/              |           |
# |    episodes        | 924       |
# |    fps             | 31        |
# |    time_elapsed    | 145465    |
# |    total_timesteps | 4620000   |
# | train/             |           |
# |    actor_loss      | 1.08e+03  |
# |    critic_loss     | 4.68      |
# |    ent_coef        | 0.0239    |
# |    ent_coef_loss   | 0.000484  |
# |    learning_rate   | 5.38e-05  |
# |    n_updates       | 8299798   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -5.4e+04 |
# | time/              |          |
# |    episodes        | 928      |
# |    fps             | 31       |
# |    time_elapsed    | 146095   |
# |    total_timesteps | 4640000  |
# | train/             |          |
# |    actor_loss      | 1.12e+03 |
# |    critic_loss     | 1.48     |
# |    ent_coef        | 0.0256   |
# |    ent_coef_loss   | -0.626   |
# |    learning_rate   | 5.36e-05 |
# |    n_updates       | 8319798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -5.4e+04 |
# | time/              |          |
# |    episodes        | 932      |
# |    fps             | 31       |
# |    time_elapsed    | 146723   |
# |    total_timesteps | 4660000  |
# | train/             |          |
# |    actor_loss      | 1.13e+03 |
# |    critic_loss     | 1.48     |
# |    ent_coef        | 0.024    |
# |    ent_coef_loss   | -1.01    |
# |    learning_rate   | 5.34e-05 |
# |    n_updates       | 8339798  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.49e+04 |
# | time/              |           |
# |    episodes        | 936       |
# |    fps             | 31        |
# |    time_elapsed    | 147351    |
# |    total_timesteps | 4680000   |
# | train/             |           |
# |    actor_loss      | 1.17e+03  |
# |    critic_loss     | 1.71      |
# |    ent_coef        | 0.0238    |
# |    ent_coef_loss   | -1.94     |
# |    learning_rate   | 5.32e-05  |
# |    n_updates       | 8359798   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -5.4e+04 |
# | time/              |          |
# |    episodes        | 940      |
# |    fps             | 31       |
# |    time_elapsed    | 147981   |
# |    total_timesteps | 4700000  |
# | train/             |          |
# |    actor_loss      | 1.08e+03 |
# |    critic_loss     | 5.91     |
# |    ent_coef        | 0.0252   |
# |    ent_coef_loss   | 1.62     |
# |    learning_rate   | 5.3e-05  |
# |    n_updates       | 8379798  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.36e+04 |
# | time/              |           |
# |    episodes        | 944       |
# |    fps             | 31        |
# |    time_elapsed    | 148611    |
# |    total_timesteps | 4720000   |
# | train/             |           |
# |    actor_loss      | 1.1e+03   |
# |    critic_loss     | 1.9       |
# |    ent_coef        | 0.0334    |
# |    ent_coef_loss   | -0.295    |
# |    learning_rate   | 5.28e-05  |
# |    n_updates       | 8399798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.45e+04 |
# | time/              |           |
# |    episodes        | 948       |
# |    fps             | 31        |
# |    time_elapsed    | 149239    |
# |    total_timesteps | 4740000   |
# | train/             |           |
# |    actor_loss      | 1.1e+03   |
# |    critic_loss     | 1.89      |
# |    ent_coef        | 0.031     |
# |    ent_coef_loss   | -1.11     |
# |    learning_rate   | 5.26e-05  |
# |    n_updates       | 8419798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.53e+04 |
# | time/              |           |
# |    episodes        | 952       |
# |    fps             | 31        |
# |    time_elapsed    | 149869    |
# |    total_timesteps | 4760000   |
# | train/             |           |
# |    actor_loss      | 1.06e+03  |
# |    critic_loss     | 1.51      |
# |    ent_coef        | 0.0224    |
# |    ent_coef_loss   | 0.556     |
# |    learning_rate   | 5.24e-05  |
# |    n_updates       | 8439798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.58e+04 |
# | time/              |           |
# |    episodes        | 956       |
# |    fps             | 31        |
# |    time_elapsed    | 150497    |
# |    total_timesteps | 4780000   |
# | train/             |           |
# |    actor_loss      | 1.1e+03   |
# |    critic_loss     | 2.65      |
# |    ent_coef        | 0.0214    |
# |    ent_coef_loss   | 1.06      |
# |    learning_rate   | 5.22e-05  |
# |    n_updates       | 8459798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.62e+04 |
# | time/              |           |
# |    episodes        | 960       |
# |    fps             | 31        |
# |    time_elapsed    | 151127    |
# |    total_timesteps | 4800000   |
# | train/             |           |
# |    actor_loss      | 1.16e+03  |
# |    critic_loss     | 1.11      |
# |    ent_coef        | 0.0191    |
# |    ent_coef_loss   | -1.78     |
# |    learning_rate   | 5.2e-05   |
# |    n_updates       | 8479798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.67e+04 |
# | time/              |           |
# |    episodes        | 964       |
# |    fps             | 31        |
# |    time_elapsed    | 151755    |
# |    total_timesteps | 4820000   |
# | train/             |           |
# |    actor_loss      | 1.16e+03  |
# |    critic_loss     | 1.31      |
# |    ent_coef        | 0.0149    |
# |    ent_coef_loss   | -0.87     |
# |    learning_rate   | 5.18e-05  |
# |    n_updates       | 8499798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.71e+04 |
# | time/              |           |
# |    episodes        | 968       |
# |    fps             | 31        |
# |    time_elapsed    | 152382    |
# |    total_timesteps | 4840000   |
# | train/             |           |
# |    actor_loss      | 1.1e+03   |
# |    critic_loss     | 1.62      |
# |    ent_coef        | 0.0118    |
# |    ent_coef_loss   | 0.98      |
# |    learning_rate   | 5.16e-05  |
# |    n_updates       | 8519798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.71e+04 |
# | time/              |           |
# |    episodes        | 972       |
# |    fps             | 31        |
# |    time_elapsed    | 153009    |
# |    total_timesteps | 4860000   |
# | train/             |           |
# |    actor_loss      | 1.09e+03  |
# |    critic_loss     | 2.72      |
# |    ent_coef        | 0.0128    |
# |    ent_coef_loss   | 1.5       |
# |    learning_rate   | 5.14e-05  |
# |    n_updates       | 8539798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.75e+04 |
# | time/              |           |
# |    episodes        | 976       |
# |    fps             | 31        |
# |    time_elapsed    | 153635    |
# |    total_timesteps | 4880000   |
# | train/             |           |
# |    actor_loss      | 1.15e+03  |
# |    critic_loss     | 3.08      |
# |    ent_coef        | 0.0137    |
# |    ent_coef_loss   | -0.689    |
# |    learning_rate   | 5.12e-05  |
# |    n_updates       | 8559798   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -5.8e+04 |
# | time/              |          |
# |    episodes        | 980      |
# |    fps             | 31       |
# |    time_elapsed    | 154262   |
# |    total_timesteps | 4900000  |
# | train/             |          |
# |    actor_loss      | 1.13e+03 |
# |    critic_loss     | 1.49     |
# |    ent_coef        | 0.013    |
# |    ent_coef_loss   | -0.708   |
# |    learning_rate   | 5.1e-05  |
# |    n_updates       | 8579798  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.84e+04 |
# | time/              |           |
# |    episodes        | 984       |
# |    fps             | 31        |
# |    time_elapsed    | 154891    |
# |    total_timesteps | 4920000   |
# | train/             |           |
# |    actor_loss      | 1.13e+03  |
# |    critic_loss     | 1.22      |
# |    ent_coef        | 0.0116    |
# |    ent_coef_loss   | -0.829    |
# |    learning_rate   | 5.08e-05  |
# |    n_updates       | 8599798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.88e+04 |
# | time/              |           |
# |    episodes        | 988       |
# |    fps             | 31        |
# |    time_elapsed    | 155518    |
# |    total_timesteps | 4940000   |
# | train/             |           |
# |    actor_loss      | 1.14e+03  |
# |    critic_loss     | 0.529     |
# |    ent_coef        | 0.00941   |
# |    ent_coef_loss   | 0.922     |
# |    learning_rate   | 5.06e-05  |
# |    n_updates       | 8619798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.84e+04 |
# | time/              |           |
# |    episodes        | 992       |
# |    fps             | 31        |
# |    time_elapsed    | 156145    |
# |    total_timesteps | 4960000   |
# | train/             |           |
# |    actor_loss      | 1.14e+03  |
# |    critic_loss     | 1.37      |
# |    ent_coef        | 0.00884   |
# |    ent_coef_loss   | 0.325     |
# |    learning_rate   | 5.04e-05  |
# |    n_updates       | 8639798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.84e+04 |
# | time/              |           |
# |    episodes        | 996       |
# |    fps             | 31        |
# |    time_elapsed    | 156774    |
# |    total_timesteps | 4980000   |
# | train/             |           |
# |    actor_loss      | 1.1e+03   |
# |    critic_loss     | 1.33      |
# |    ent_coef        | 0.0184    |
# |    ent_coef_loss   | 0.329     |
# |    learning_rate   | 5.02e-05  |
# |    n_updates       | 8659798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.88e+04 |
# | time/              |           |
# |    episodes        | 1000      |
# |    fps             | 31        |
# |    time_elapsed    | 157401    |
# |    total_timesteps | 5000000   |
# | train/             |           |
# |    actor_loss      | 1.1e+03   |
# |    critic_loss     | 0.848     |
# |    ent_coef        | 0.0138    |
# |    ent_coef_loss   | 1.02      |
# |    learning_rate   | 5e-05     |
# |    n_updates       | 8679798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.97e+04 |
# | time/              |           |
# |    episodes        | 1004      |
# |    fps             | 31        |
# |    time_elapsed    | 158030    |
# |    total_timesteps | 5020000   |
# | train/             |           |
# |    actor_loss      | 1.2e+03   |
# |    critic_loss     | 0.427     |
# |    ent_coef        | 0.0127    |
# |    ent_coef_loss   | -2.35     |
# |    learning_rate   | 4.98e-05  |
# |    n_updates       | 8699798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.84e+04 |
# | time/              |           |
# |    episodes        | 1008      |
# |    fps             | 31        |
# |    time_elapsed    | 158659    |
# |    total_timesteps | 5040000   |
# | train/             |           |
# |    actor_loss      | 1.11e+03  |
# |    critic_loss     | 2.29      |
# |    ent_coef        | 0.0123    |
# |    ent_coef_loss   | 0.127     |
# |    learning_rate   | 4.96e-05  |
# |    n_updates       | 8719798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.88e+04 |
# | time/              |           |
# |    episodes        | 1012      |
# |    fps             | 31        |
# |    time_elapsed    | 159294    |
# |    total_timesteps | 5060000   |
# | train/             |           |
# |    actor_loss      | 1.12e+03  |
# |    critic_loss     | 0.708     |
# |    ent_coef        | 0.0114    |
# |    ent_coef_loss   | 0.555     |
# |    learning_rate   | 4.94e-05  |
# |    n_updates       | 8739798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -5.84e+04 |
# | time/              |           |
# |    episodes        | 1016      |
# |    fps             | 31        |
# |    time_elapsed    | 159892    |
# |    total_timesteps | 5080000   |
# | train/             |           |
# |    actor_loss      | 1.09e+03  |
# |    critic_loss     | 0.994     |
# |    ent_coef        | 0.0117    |
# |    ent_coef_loss   | 0.261     |
# |    learning_rate   | 4.92e-05  |
# |    n_updates       | 8759798   |
# ----------------------------------

# %%
episodes = 3
state, seed = env.reset()
for episode in range(1, episodes+1):
    state, seed = env.reset()
    done = False
    score = 0
    while not done:
        action = env.action_space.sample()
        n_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# Episode:1 Score:-57087.66697450366
# Episode:2 Score:-57169.60609087738
# Episode:3 Score:-57424.86711319699

# %%
b = Bobina()
b.airgap = 9

# %%
b.step(100)
# Out:
# ((20.00214, -0.10582279, 3.7021403, 45.0), False)

# %%
import numpy as np
import torch as th
import time

MODEL_PATH = f"models/2gdl8x8framestack-success16/model.zip"

# Create and wrap the environment
env = BobinaEnv(duration = 6)

# Load the trained agent
model = SAC.load(MODEL_PATH, env=env, learning_rate = 0.00001)

# Evaluate the agent
for i in range(3):
    obs, seed = env.reset()
    print(obs)
    done = False
    episode_reward = 0
    velocidad = 0
    current = 0
    observations = []
    noises = []
    timepredict = 0
    timemodel = 0
    distancia11, distancia12, distancia21, distancia22, current1, current2 = obs
    while not done:
        #noise = random.uniform(-1, 1)
        #obs = obs + noise
        observations.append(obs)
        #noises.append(noise)
        t1 = time.time()
        action, _states = model.predict(np.array([distancia11, distancia12, distancia21, distancia22, current1, current2]), deterministic=True)
        t2 = time.time()
        #print(action)
        #if env.airgap > 10.1: action = max(action, [-50])
        #print(action)
        t3 = time.time()
        state, reward, terminated, truncated, info = env.step(np.array(action))
        t4 = time.time()
        distancia11, distancia12, distancia21, distancia22, current1, current2 = state
        done = truncated or terminated
        episode_reward += reward
        timepredict += t2 - t1
        timemodel += t4 - t3
        noises.append((current1, current2))
    print("Time predict", timepredict)
    print("Time model", timemodel)
    print("Episode reward", episode_reward)
    print(noises)
    env.render("yes", normalize = True, seed = i+5)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# [-6.3 -6.3 -6.3 -6.3  0.   0. ]
# Time predict 15.095194816589355
# Time model 62.32054114341736
# Episode reward -87573.95420265198
# [(0.0, 0.0), (-3.2662816, -3.148901), (-6.400122, -6.1701202), (-9.256033, -8.923398), (-11.832227, -11.40845), (-14.138507, -13.662225), (-16.235392, -15.71314), (-18.195957, -17.605167), (-20.040709, -19.385788), (-21.778748, -21.07069), (-23.420656, -22.666862), (-24.991014, -24.185968), (-26.490849, -25.633106), (-27.909407, -26.994411), (-29.242634, -28.268166), (-30.473904, -29.456003), (-31.5743, -30.553228), (-32.49929, -31.555899), (-33.197018, -32.46227), (-33.62967, -33.275185), (-33.79807, -34.003475), (-33.74985, -34.662197), (-33.56063, -35.269855), (-33.30519, -35.843452), (-33.039047, -36.39535), (-32.79531, -36.93312), (-32.589905, -37.460728), (-32.428257, -37.979877), (-30.784054, -37.510326), (-27.655947, -36.04358), (-24.643417, -34.895706), (-21.932222, -34.36584), (-19.811234, -34.320297), (-18.507463, -34.586227), (-17.90525, -35.014675), (-17.66087, -35.50143), (-17.513119, -35.990807), (-17.357784, -36.462616), (-17.177374, -36.914204), (-16.983814, -37.348255), (-16.790258, -37.767654), (-16.602825, -38.17399), (-16.422796, -38.567905), (-16.24846, -38.949707), (-16.079174, -39.31977), (-15.915796, -39.678528), (-15.757892, -40.02626), (-15.60528, -40.36332), (-15.457894, -40.690063), (-15.314213, -41.0067), (-15.174107, -41.3135), (-15.038679, -41.610874), (-14.907835, -41.899105), (-14.781321, -42.178455), (-14.658844, -42.44919), (-14.540271, -42.711563), (-14.425424, -42.965824), (-14.313319, -43.212193), (-14.203999, -43.45096), (-14.0984955, -43.682426), (-13.9968605, -43.906864), (-13.898613, -44.124428), (-13.803456, -44.33529), (-13.711317, -44.539646), (-13.621928, -44.73765), (-13.535218, -44.929512), (-13.451207, -45.0), (-13.381425, -45.0), (-13.341514, -45.0), (-13.32813, -45.0), (-13.32748, -45.0), (-13.33008, -45.0), (-13.332154, -45.0), (-13.333087, -45.0), (-13.333289, -45.0), (-13.333215, -45.0), (-13.333109, -45.0), (-13.333048, -45.0), (-13.333027, -45.0), (-13.333025, -45.0), (-13.333029, -45.0), (-13.333033, -45.0), (-13.333038, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333037, -45.0), (-13.33304, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333038, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333039, -45.0), (-13.333042, -45.0), (-13.33304, -45.0), (-13.333038, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333038, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333039, -45.0), (-13.333042, -45.0), (-13.33304, -45.0), (-13.333038, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333037, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333038, -45.0), (-13.333042, -45.0), (-13.33304, -45.0), (-13.333038, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333037, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333038, -45.0), (-13.333042, -45.0), (-13.33304, -45.0), (-13.333038, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333037, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333038, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333039, -45.0), (-13.333042, -45.0), (-13.33304, -45.0), (-13.333038, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333038, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333039, -45.0), (-13.333042, -45.0), (-13.33304, -45.0), (-13.333038, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333037, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333038, -45.0), (-13.333042, -45.0), (-13.33304, -45.0), (-13.333038, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333037, -45.0), (-13.333041, -45.0), (-13. ...
# [-6.3 -6.3 -6.3 -6.3  0.   0. ]
# Time predict 14.879611015319824
# Time model 62.11500120162964
# Episode reward -87573.95420265198
# [(0.0, 0.0), (-3.2662816, -3.148901), (-6.400122, -6.1701202), (-9.256033, -8.923398), (-11.832227, -11.40845), (-14.138507, -13.662225), (-16.235392, -15.71314), (-18.195957, -17.605167), (-20.040709, -19.385788), (-21.778748, -21.07069), (-23.420656, -22.666862), (-24.991014, -24.185968), (-26.490849, -25.633106), (-27.909407, -26.994411), (-29.242634, -28.268166), (-30.473904, -29.456003), (-31.5743, -30.553228), (-32.49929, -31.555899), (-33.197018, -32.46227), (-33.62967, -33.275185), (-33.79807, -34.003475), (-33.74985, -34.662197), (-33.56063, -35.269855), (-33.30519, -35.843452), (-33.039047, -36.39535), (-32.79531, -36.93312), (-32.589905, -37.460728), (-32.428257, -37.979877), (-30.784054, -37.510326), (-27.655947, -36.04358), (-24.643417, -34.895706), (-21.932222, -34.36584), (-19.811234, -34.320297), (-18.507463, -34.586227), (-17.90525, -35.014675), (-17.66087, -35.50143), (-17.513119, -35.990807), (-17.357784, -36.462616), (-17.177374, -36.914204), (-16.983814, -37.348255), (-16.790258, -37.767654), (-16.602825, -38.17399), (-16.422796, -38.567905), (-16.24846, -38.949707), (-16.079174, -39.31977), (-15.915796, -39.678528), (-15.757892, -40.02626), (-15.60528, -40.36332), (-15.457894, -40.690063), (-15.314213, -41.0067), (-15.174107, -41.3135), (-15.038679, -41.610874), (-14.907835, -41.899105), (-14.781321, -42.178455), (-14.658844, -42.44919), (-14.540271, -42.711563), (-14.425424, -42.965824), (-14.313319, -43.212193), (-14.203999, -43.45096), (-14.0984955, -43.682426), (-13.9968605, -43.906864), (-13.898613, -44.124428), (-13.803456, -44.33529), (-13.711317, -44.539646), (-13.621928, -44.73765), (-13.535218, -44.929512), (-13.451207, -45.0), (-13.381425, -45.0), (-13.341514, -45.0), (-13.32813, -45.0), (-13.32748, -45.0), (-13.33008, -45.0), (-13.332154, -45.0), (-13.333087, -45.0), (-13.333289, -45.0), (-13.333215, -45.0), (-13.333109, -45.0), (-13.333048, -45.0), (-13.333027, -45.0), (-13.333025, -45.0), (-13.333029, -45.0), (-13.333033, -45.0), (-13.333038, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333037, -45.0), (-13.33304, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333038, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333039, -45.0), (-13.333042, -45.0), (-13.33304, -45.0), (-13.333038, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333038, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333039, -45.0), (-13.333042, -45.0), (-13.33304, -45.0), (-13.333038, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333037, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333038, -45.0), (-13.333042, -45.0), (-13.33304, -45.0), (-13.333038, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333037, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333038, -45.0), (-13.333042, -45.0), (-13.33304, -45.0), (-13.333038, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333037, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333038, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333039, -45.0), (-13.333042, -45.0), (-13.33304, -45.0), (-13.333038, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333038, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333039, -45.0), (-13.333042, -45.0), (-13.33304, -45.0), (-13.333038, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333037, -45.0), (-13.333041, -45.0), (-13.333039, -45.0), (-13.333037, -45.0), (-13.333035, -45.0), (-13.333038, -45.0), (-13.333042, -45.0), (-13.33304, -45.0), (-13.333038, -45.0), (-13.333036, -45.0), (-13.3330345, -45.0), (-13.333037, -45.0), (-13.333041, -45.0), (-13. ...
# [4.7 4.7 4.7 4.7 0.  0. ]
# Time predict 14.780776739120483
# Time model 63.16072869300842
# Episode reward -2228.5139966849238
# [(0.0, 0.0), (2.9953916, 2.9953916), (5.969321, 5.969321), (8.9071045, 8.9071045), (11.848123, 11.848123), (14.800484, 14.800484), (17.737246, 17.737246), (20.657902, 20.657902), (23.611317, 23.611317), (26.57066, 26.57066), (29.418123, 29.418123), (32.103264, 32.103264), (34.632008, 34.632008), (37.01353, 37.013535), (39.254482, 39.254494), (41.360203, 41.36026), (43.33844, 43.33881), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (45.0, 45.0), (38.166454, 45.0), (31.309961, 45.0), (24.902962, 45.0), (18.921427, 45.0), (13.387801, 45.0), (8.550476, 45.0), (4.4299555, 45.0), (0.78879374, 45.0), (-2.4604504, 42.58009), (-5.405187, 35.557316), (-8.069072, 28.843195), (-10.290364, 22.604382), (-11.677735, 16.808414), (-10.603796, 11.453585), (-8.113588, 6.8014197), (-8.014453, 2.8434525), (-10.0242405, -0.68985516), (-12.274786, -3.8347366), (-14.503122, -6.666722), (-16.633585, -9.283392), (-18.653383, -11.723798), (-20.562113, -13.996415), (-22.363926, -16.080524), (-24.086058, -18.016365), (-25.742352, -19.858614), (-27.337355, -21.619371), (-28.876228, -23.306818), (-30.3409, -24.917746), (-31.673853, -26.301601), (-32.659378, -27.025137), (-32.899834, -26.806152), (-32.358067, -26.186306), (-31.500156, -26.01455), (-30.60976, -26.428585), (-29.59636, -27.05565), (-28.365582, -27.651974), (-26.996405, -28.207935), (-25.618607, -28.765865), (-24.297411, -29.321701), (-23.065102, -29.871609), (-21.945927, -30.422424), (-20.953827, -30.978184), (-20.102123, -31.53564), (-19.388683, -32.09459), (-18.791552, -32.64778), (-18.268873, -33.138596), (-17.80084, -33.530308), (-17.426634, -33.856026), (-17.181408, -34.152157), (-17.06328, -34.42624), (-17.051058, -34.66831), (-17.12554, -34.872078), (-17.276997, -35.041607), (-17.499176, -35.185352), (-17.782944, -35.309322), (-18.115723, -35.416214), (-18.487326, -35.50814), (-18.890871, -35.58821), (-19.316296, -35.659367), (-19.755283, -35.72371), (-20.201141, -35.783314), (-20.648651, -35.840816), (-21.09419, -35.89831), (-21.534836, -35.95763), (-21.96845, -36.020145), (-22.39194, -36.085655), (-22.803366, -36.153706), (-23.20006, -36.224224), (-23.579632, -36.29755), (-23.940767, -36.3743), (-24.284225, -36.454834), (-24.610456, -36.538742), (-24.91741, -36.624817), (-25.204275, -36.712143), (-25.471933, -36.800682), (-25.720804, -36.890335), (-25.950624, -36.980328), (-26.161018, -37.069614), (-26.351849, -37.157227), (-26.5227, -37.242336), (-26.67316, -37.324303), (-26.80293, -37.402496), (-26.91176, -37.47626), (-27.116762, -37.373173), (-27.557156, -36.863377), (-28.234695, -35.9987), (-29.091537, -34.994247), (-30.015478, -33.67919), (-30.92047, -31.822186), (-31.791824, -29.549166), (-32.621864, -27.008505), (-33.3996, -24.31309), (-34.110916, -21.534662), (-34.743908, -18.732237), (-35.300884, -15.97953), (-35.775894, -13.318974), (-36.139935, -10.7638035), (-36.359848, -8.359999), (-36.404922, -6.1441326), (-36.247948, -4.1521707), (-35.870743, -2.470294), (-35.27083, -1.1828948), (-34.461613, -0.33297005), (-33.46864, 0.09900516), (-32.323353, 0.18595499), (-31.060637, 0.009474398), (-29.715477, -0.3621796), (-28.31895, -0.8795633), (-26.894445, -1.5029694), (-25.457138, -2.200731), (-24.016901, -2.9584243), (-22.584595, -3.7617924), (-21.172907, -4.5933356), (-19.795063, -5.4485054), (-18.471167, -6.332482), (-17.222286, -7.233296), (-16.074797, -8.127003), (-15.054181, -8.996326), (-14.16592, -9.828338), (-13.4051285, -10.6164055), (-12.76714, -11.3544 ...

# %%
plt.savefig("images/floor-2gdl8x8nocrash.png")

# %%
import torch as th

from stable_baselines3 import SAC

#import onnx
import onnxruntime as ort
import numpy as np


class OnnxablePolicy(th.nn.Module):
    def __init__(self, actor: th.nn.Module):
        super().__init__()
        # Removing the flatten layer because it can't be onnxed
        self.actor = th.nn.Sequential(
            actor.latent_pi,
            actor.mu,
            # For gSDE
            # th.nn.Hardtanh(min_val=-actor.clip_mean, max_val=actor.clip_mean),
            # Squash the output
            th.nn.Tanh(),
        )

    def forward(self, observation: th.Tensor) -> th.Tensor:
        # NOTE: You may have to process (normalize) observation in the correct
        #       way before using this. See `common.preprocessing.preprocess_obs`
        return self.actor(observation)


# Example: model = SAC("MlpPolicy", "Pendulum-v1")
model = SAC.load(f"models/sac8x8h9.3/model.zip", device="cpu")
onnxable_model = OnnxablePolicy(model.policy.actor)

observation_size = model.observation_space.shape
dummy_input = th.randn(1, *observation_size)
th.onnx.export(
    onnxable_model,
    dummy_input,
    "./ONNX/1gdlComplexH98x8.onnx",
    opset_version=9,
    input_names=["input"],
)

##### Load and test with onnx

import onnxruntime as ort
import numpy as np

onnx_path = "./ONNX/1gdlComplexH98x8.onnx"

observation = np.zeros((1, *observation_size)).astype(np.float32)
ort_sess = ort.InferenceSession(onnx_path)
action = ort_sess.run(None, {"input": observation})
# Out:
# ============== Diagnostic Run torch.onnx.export version 2.0.0+cpu ==============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
model.policy
# Out:
# SACPolicy(
#   (actor): Actor(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (latent_pi): Sequential(
#       (0): Linear(in_features=4, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=8, bias=True)
#       (3): ReLU()
#     )
#     (mu): Linear(in_features=8, out_features=1, bias=True)
#     (log_std): Linear(in_features=8, out_features=1, bias=True)
#   )
#   (critic): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (critic_target): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )

# %%
# See "ONNX export" for imports and OnnxablePolicy
jit_path = "1gdlComplex.pt"

# Trace and optimize the module
traced_module = th.jit.trace(onnxable_model.eval(), dummy_input)
frozen_module = th.jit.freeze(traced_module)
frozen_module = th.jit.optimize_for_inference(frozen_module)
th.jit.save(frozen_module, jit_path)

##### Load and test with torch

import torch as th

dummy_input = th.randn(1, *observation_size)
loaded_module = th.jit.load(jit_path)
action_jit = loaded_module(dummy_input)
