# %%
from gymnasium import Env
from gymnasium.spaces.box import Box
import numpy as np
import random
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.noise import NormalActionNoise
import wandb
from wandb.integration.sb3 import WandbCallback
import os
import matplotlib.pyplot as plt
import scipy.io
import scipy
import numpy as np
import pickle
import warnings
import math
from typing import Callable
warnings.filterwarnings("ignore")

# %%
class Bobina():
  """ 
  Coil model for the Hybrid Electromagnetic Suspension
  """
  def __init__(self, masa_pod = 200, airgap = 23):
    self.masa_pod = masa_pod
    self.airgap = airgap
    self.aceleracion = []
    self.velocidad = []
    mat = scipy.io.loadmat('./coil/hems.mat')
    self.hems = mat["hems"][0][0]
    self.airgaps = self.hems[0][0]
    self.currents = self.hems[1][0]
    self.force_vertical = pickle.load(open("./coil/mlp_vertical.pkl", 'rb'))
    self.flux = self.hems[3]
    self.force_horizontal = self.hems[4]
    self.inductance = pickle.load(open("./coil/rf_inductance.pkl", 'rb'))
    self.resistance = self.hems[6][0][0]
    self.min_distance = self.airgaps[0]
    self.max_distance = self.airgaps[-1]
    self.airgapinicial = airgap
    self.crash = False
    self.current = 0
    self.steps_RL = []

  def integral(self, lista, h = 1):
    return sum(h*(lista[i]+lista[i+1])/2 for i in range(len(lista)-1))

  def RL(self, airgap, target_voltage, temperature):
    # Resistance-Inductance circuit

    # Get resistance of the coil
    R = self.R(current = self.current, temperature = temperature)   
    V = target_voltage
    I = self.current
    L = self.L(airgap = airgap, current = self.current)
    dIdt = ((V/R) - I)/(L/R)                                      
    self.steps_RL.append(dIdt)                                   
    current = self.integral(self.steps_RL, h = 0.001)                          
    return current                                                  

  def R(self, current, temperature):
    return self.resistance                                         

  def L(self, airgap, current):
    # Return predicted inductance
    return float(self.inductance.predict(np.array([[airgap, current]]))[0])

  def vertical_force(self, airgap, target_voltage, temperature):
    # Get current from RL circuit
    I = self.RL(airgap = airgap, target_voltage = target_voltage, temperature = temperature) 
    
    # Clip result
    if I > 45:
      I = 45
    elif I < -45:
      I = -45
    self.current = I
    # Get vertical force from 
    FI = self.FI_vertical(airgap = airgap, current = I)                    
    return FI, I


  def FI_vertical(self, airgap, current):
    # Return predicted vertical force
    return float(self.force_vertical.predict(np.array([[airgap, current]])))    


  def next_airgap(self, masa_pod, vertical_force, verbose = False):
    # Devide the mass of the pod by 4 coils
    masa = masa_pod/4  
    # Calculate weight
    peso = masa * 9.8    
    # Get total force                                                       
    fuerza = peso - vertical_force
    if verbose: print("Fuerza resultante: ", fuerza)   
    # Calculate acceleration                                     
    aceleracion = fuerza/masa
    if verbose: print("Aceleración: ", aceleracion)                                         
    self.aceleracion.append(aceleracion)       
    # Calculate velocity                                
    velocidad = self.integral(self.aceleracion, 0.001)
    if verbose: print("Integral primera (velocidad): ", velocidad)                          
    self.velocidad.append(velocidad)               
    # Calculate position (x1000 as to transform from m to mm)                            
    posicion = self.airgapinicial + self.integral(self.velocidad, 0.001)*1000 
    if verbose: print("Integral segunda (posición): ", posicion)

    # Clip position
    if posicion > self.max_distance:
      airgap = self.max_distance
      self.aceleracion = [0]
      self.velocidad = [0]  
      #self.crash = True     
      self.airgapinicial = self.max_distance                                               
    elif posicion < self.min_distance:
      airgap = self.min_distance
      self.aceleracion = [0]
      self.velocidad = [0]
      #self.crash = True
      self.airgapinicial = self.min_distance
    else: airgap = posicion
    return airgap, velocidad

  def step(self, target_voltage, verbose = False):
    # Calculate vertical force and current
    vertical_force, self.current = self.vertical_force(airgap = self.airgap, target_voltage = target_voltage, temperature = 40)
    if verbose: print("Fuerza vertical: ", vertical_force)
    # Calculate next airgap and velocity
    self.airgap, velocidad = self.next_airgap(self.masa_pod, vertical_force, verbose = verbose)
    #noise = np.random.normal(0,0.5)
    #self.airgap = self.airgap + noise     
    return (np.float32(self.airgap), np.float32(velocidad), np.float32(self.airgap - 19.5), np.float32(self.current)), self.crash
class BobinaEnv(Env):
  """
  Custom Gym Environment for the Hybrid Electromagnetic Suspension, considering just one coil.
  """
  def __init__(self, masa_pod = 200, airgap = 10, duration = 10):
    # Actions: Voltage applied to the coil
    self.action_space = Box(low=np.array([-100]), high = np.array([50]), dtype=np.float32)
    # Observations: Airgap to the ceiling, velocity, distance to the objective, current of the coil
    self.observation_space = Box(low=np.array([10, -np.inf, -10, -45]), high = np.array([23, np.inf, 10, 45]), dtype=np.float32)
    # Initial parameters
    self.state = np.array([airgap, 0, airgap - 19.5, 0])
    self.airgapinicial = airgap
    self.duration = duration
    self.timeleft = duration
    self.crash = False
    self.masa_pod = masa_pod
    self.bobina = Bobina(masa_pod = self.masa_pod, airgap = self.airgapinicial)
    self.steps = []
    self.airgap = airgap
    self.distancia = 0
    self.velocidad = 0
    self.current = 0


  def step(self, action):
    # Apply action
    self.state, self.crash = self.bobina.step(action[0])
    self.airgap, self.velocidad, self.distancia, self.current = self.state

    # Reduce the time of the experiment
    self.timeleft -= 0.001

    # Calculate reward
    reward = -abs(self.distancia)

    # Check if experiment is done
    if self.timeleft <= 0:
      truncated = True
    else: truncated = False
    # Set placeholder for info
    info = {}
    # Only if we implemented the crash
    if self.crash:
      reward = - 50000
      terminated = True
    else:
      terminated = False
    self.steps.append(self.state)
    return self.state, reward, terminated, truncated, info


  def render(self, yes = "yes"):
    # create data
    x = list(range(0,len(self.steps)))
    y = [step[0] for step in self.steps]
    objective = [19.5]*len(self.steps)

    # plot lines
    fig = plt.figure(figsize=(10,5))
    ax = fig.add_subplot(111)
    ax.tick_params(axis='x', colors='white')    #setting up X-axis tick color to red
    ax.tick_params(axis='y', colors='white')  #setting up Y-axis tick color to black

    plt.plot(x, y, label = "States")
    plt.plot(x, objective, label = "Objective")
    plt.legend()
    plt.show()

  def reset(self, seed = 0):
    # Reset experiment choosing randomly the start (ceiling or floor)
    airgap = random.choice([19.5])
    self.state = self.airgapinicial
    self.bobina = Bobina(masa_pod = self.masa_pod, airgap = airgap)
    # Reset time
    self.timeleft = self.duration
    self.crash = False
    self.steps = []
    return self.state, seed

# %%
run = wandb.init(
    project="1gdlppo",
    sync_tensorboard=True,
    monitor_gym=True,
)

# Create log dir
log_dir = "1gdlppo/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = BobinaEnv( airgap = 19.5,duration = 4 )
env = Monitor(env, log_dir)

def linear_schedule(initial_value: float) -> Callable[[float], float]:
    """
    Linear learning rate schedule.

    :param initial_value: Initial learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return progress_remaining * initial_value

    return func

model = PPO("MlpPolicy", env,learning_rate = linear_schedule(0.001), n_steps = 40000, batch_size=512, ent_coef=0.2, seed = 42, verbose=1, tensorboard_log=log_dir)
# Out:
# Finishing last run (ID:qvnlv7mi) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>PPO_5/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>PPO_5/rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_5/rollout/ep_rew_mean</td><td>▁▁▁▁▁▂▂▂▃▃▃▄▄▄▅▆▆▆▇▇████████████████████</td></tr><tr><td>PPO_5/time/fps</td><td>▂▁▂▅▅▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇███████████</td></tr><tr><td>PPO_5/train/approx_kl</td><td>▇███▄█▅▅▁█▃▃▃▄▅▃▂▂▃▆▃▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_5/train/clip_fraction</td><td>▇███▇██▆▁▇▃▄▄▄▅▄▂▃▄▆▄▃▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_5/train/clip_range</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_5/train/entropy_loss</td><td>██▇▇▆▆▆▆▅▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_5/train/explained_variance</td><td>▁▁▃▄▆▄▆▄▄█▇█▇███████████████████████████</td></tr><tr><td>PPO_5/train/learning_rate</td><td>████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁</td></tr><tr><td>PPO_5/train/loss</td><td>██▇▇▅▆▃▅▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_5/train/policy_gradient_loss</td><td>▄▄▄▄▆▄█▃▁▃▂▂▂▂▂▂▁▂▃▁▂▁▂▁▂▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>PPO_5/train/std</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▃▃▃▄▄▄▅▅▆▆▆▆▇▇█████</td></tr><tr><td>PPO_5/train/value_loss</td><td>██▇▇▅▆▃▅▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>PPO_5/global_step</td><td>1260000</td></tr><tr><td>PPO_5/rollout/ep_len_mean</td><td>4001.0</td></tr><tr><td>PPO_5/rollout/ep_rew_mean</td><td>-13836.55957</td></tr><tr><td>PPO_5/time/fps</td><td>179.0</td></tr><tr><td>PPO_5/train/approx_kl</td><td>0.0</td></tr><tr><td>PPO_5/train/clip_fraction</td><td>0.0</td></tr><tr><td>PPO_5/train/clip_range</td><td>0.2</td></tr><tr><td>PPO_5/train/entropy_loss</td><td>-9.68451</td></tr><tr><td>PPO_5/train/explained_variance</td><td>0.99534</td></tr><tr><td>PPO_5/train/learning_rate</td><td>0.0</td></tr><tr><td>PPO_5/train/loss</td><td>-1.92628</td></tr><tr><td>PPO_5/train/policy_gradient_loss</td><td>-0.0</td></tr><tr><td>PPO_5/train/std</td><td>3888.17285</td></tr><tr><td>PPO_5/train/value_loss</td><td>0.15241</td></tr><tr><td>global_step</td><td>1260000</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">robust-dragon-6</strong> at: <a href='https://wandb.ai/hyperloopupv/1gdlppo/runs/qvnlv7mi' target="_blank">https://wandb.ai/hyperloopupv/1gdlppo/runs/qvnlv7mi</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 3 other file(s)
# Find logs at: <code>.\wandb\run-20231209_230353-qvnlv7mi\logs</code>
# Successfully finished last run (ID:qvnlv7mi). Initializing new run:<br/>
# wandb version 0.16.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\wandb\run-20231210_010533-mvepdgy8</code>
# Syncing run <strong><a href='https://wandb.ai/hyperloopupv/1gdlppo/runs/mvepdgy8' target="_blank">splendid-bird-7</a></strong> to <a href='https://wandb.ai/hyperloopupv/1gdlppo' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hyperloopupv/1gdlppo' target="_blank">https://wandb.ai/hyperloopupv/1gdlppo</a>
#  View run at <a href='https://wandb.ai/hyperloopupv/1gdlppo/runs/mvepdgy8' target="_blank">https://wandb.ai/hyperloopupv/1gdlppo/runs/mvepdgy8</a>
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
# Create checkpoint callback
checkpoint_callback = CheckpointCallback(
    save_freq=10000, save_path=log_dir, name_prefix="rl_ppo_1gdlobj"
)

# Train the agent
model.learn(total_timesteps=1250000,
    callback=[
        checkpoint_callback,
        WandbCallback(
            gradient_save_freq=10000,
            model_save_path=f"models/{run.id}",
            model_save_freq=10000,
            verbose=2,
        ),
    ],
)
# Out:
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Logging to 1gdlppo/PPO_6
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -3.63e+04 |
# | time/              |           |
# |    fps             | 188       |
# |    iterations      | 1         |
# |    time_elapsed    | 212       |
# |    total_timesteps | 40000     |
# ----------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -3.63e+04  |
# | time/                   |            |
# |    fps                  | 188        |
# |    iterations           | 2          |
# |    time_elapsed         | 423        |
# |    total_timesteps      | 80000      |
# | train/                  |            |
# |    approx_kl            | 0.07758155 |
# |    clip_fraction        | 0.341      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.63      |
# |    explained_variance   | -0.00153   |
# |    learning_rate        | 0.000968   |
# |    loss                 | 4.58e+03   |
# |    n_updates            | 10         |
# |    policy_gradient_loss | 0.0176     |
# |    std                  | 1.36       |
# |    value_loss           | 1.57e+04   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -3.62e+04  |
# | time/                   |            |
# |    fps                  | 188        |
# |    iterations           | 3          |
# |    time_elapsed         | 636        |
# |    total_timesteps      | 120000     |
# | train/                  |            |
# |    approx_kl            | 0.08965904 |
# |    clip_fraction        | 0.357      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.95      |
# |    explained_variance   | 0.415      |
# |    learning_rate        | 0.000936   |
# |    loss                 | 5.13e+03   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | 0.0181     |
# |    std                  | 1.91       |
# |    value_loss           | 1.52e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -3.62e+04   |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 4           |
# |    time_elapsed         | 850         |
# |    total_timesteps      | 160000      |
# | train/                  |             |
# |    approx_kl            | 0.083389804 |
# |    clip_fraction        | 0.379       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.000904    |
# |    loss                 | 4.37e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.0193      |
# |    std                  | 2.64        |
# |    value_loss           | 1.35e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -3.53e+04   |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 5           |
# |    time_elapsed         | 1067        |
# |    total_timesteps      | 200000      |
# | train/                  |             |
# |    approx_kl            | 0.084792845 |
# |    clip_fraction        | 0.389       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.717       |
# |    learning_rate        | 0.000872    |
# |    loss                 | 3.76e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.0201      |
# |    std                  | 3.61        |
# |    value_loss           | 1.2e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -3.47e+04   |
# | time/                   |             |
# |    fps                  | 188         |
# |    iterations           | 6           |
# |    time_elapsed         | 1276        |
# |    total_timesteps      | 240000      |
# | train/                  |             |
# |    approx_kl            | 0.042222545 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.00084     |
# |    loss                 | 2.77e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.0196      |
# |    std                  | 4.51        |
# |    value_loss           | 8.58e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -3.39e+04  |
# | time/                   |            |
# |    fps                  | 187        |
# |    iterations           | 7          |
# |    time_elapsed         | 1491       |
# |    total_timesteps      | 280000     |
# | train/                  |            |
# |    approx_kl            | 0.04154901 |
# |    clip_fraction        | 0.126      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.1       |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.000808   |
# |    loss                 | 2.33e+03   |
# |    n_updates            | 60         |
# |    policy_gradient_loss | 0.0194     |
# |    std                  | 5.63       |
# |    value_loss           | 7.62e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -3.33e+04  |
# | time/                   |            |
# |    fps                  | 187        |
# |    iterations           | 8          |
# |    time_elapsed         | 1703       |
# |    total_timesteps      | 320000     |
# | train/                  |            |
# |    approx_kl            | 0.02984749 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.3       |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.000776   |
# |    loss                 | 1.88e+03   |
# |    n_updates            | 70         |
# |    policy_gradient_loss | 0.0157     |
# |    std                  | 6.78       |
# |    value_loss           | 6.29e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -3.32e+04   |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 9           |
# |    time_elapsed         | 1916        |
# |    total_timesteps      | 360000      |
# | train/                  |             |
# |    approx_kl            | 0.023928083 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.000744    |
# |    loss                 | 1.65e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.0135      |
# |    std                  | 7.97        |
# |    value_loss           | 5.61e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -3.21e+04  |
# | time/                   |            |
# |    fps                  | 187        |
# |    iterations           | 10         |
# |    time_elapsed         | 2132       |
# |    total_timesteps      | 400000     |
# | train/                  |            |
# |    approx_kl            | 0.03780714 |
# |    clip_fraction        | 0.103      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.64      |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.000712   |
# |    loss                 | 1.62e+03   |
# |    n_updates            | 90         |
# |    policy_gradient_loss | 0.0158     |
# |    std                  | 9.8        |
# |    value_loss           | 5.45e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -3.12e+04  |
# | time/                   |            |
# |    fps                  | 187        |
# |    iterations           | 11         |
# |    time_elapsed         | 2345       |
# |    total_timesteps      | 440000     |
# | train/                  |            |
# |    approx_kl            | 0.04245637 |
# |    clip_fraction        | 0.117      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.87      |
# |    explained_variance   | 0.976      |
# |    learning_rate        | 0.00068    |
# |    loss                 | 630        |
# |    n_updates            | 100        |
# |    policy_gradient_loss | 0.0198     |
# |    std                  | 12.2       |
# |    value_loss           | 2.43e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -3.06e+04   |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 12          |
# |    time_elapsed         | 2563        |
# |    total_timesteps      | 480000      |
# | train/                  |             |
# |    approx_kl            | 0.015595961 |
# |    clip_fraction        | 0.0721      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.000648    |
# |    loss                 | 1.02e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.00856     |
# |    std                  | 14          |
# |    value_loss           | 3.45e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -2.97e+04   |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 13          |
# |    time_elapsed         | 2789        |
# |    total_timesteps      | 520000      |
# | train/                  |             |
# |    approx_kl            | 0.019004324 |
# |    clip_fraction        | 0.0794      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.000616    |
# |    loss                 | 997         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00961     |
# |    std                  | 16.2        |
# |    value_loss           | 3.35e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -2.9e+04    |
# | time/                   |             |
# |    fps                  | 185         |
# |    iterations           | 14          |
# |    time_elapsed         | 3021        |
# |    total_timesteps      | 560000      |
# | train/                  |             |
# |    approx_kl            | 0.020079033 |
# |    clip_fraction        | 0.0812      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.000584    |
# |    loss                 | 909         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.0106      |
# |    std                  | 18.7        |
# |    value_loss           | 2.94e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -2.77e+04   |
# | time/                   |             |
# |    fps                  | 184         |
# |    iterations           | 15          |
# |    time_elapsed         | 3247        |
# |    total_timesteps      | 600000      |
# | train/                  |             |
# |    approx_kl            | 0.022366663 |
# |    clip_fraction        | 0.085       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.47       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.000552    |
# |    loss                 | 805         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.012       |
# |    std                  | 22.1        |
# |    value_loss           | 2.59e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -2.73e+04  |
# | time/                   |            |
# |    fps                  | 184        |
# |    iterations           | 16         |
# |    time_elapsed         | 3472       |
# |    total_timesteps      | 640000     |
# | train/                  |            |
# |    approx_kl            | 0.04826592 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.7       |
# |    explained_variance   | 0.99       |
# |    learning_rate        | 0.00052    |
# |    loss                 | 318        |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.0171     |
# |    std                  | 27.9       |
# |    value_loss           | 1.1e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -2.71e+04   |
# | time/                   |             |
# |    fps                  | 184         |
# |    iterations           | 17          |
# |    time_elapsed         | 3695        |
# |    total_timesteps      | 680000      |
# | train/                  |             |
# |    approx_kl            | 0.014063551 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.83       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.000488    |
# |    loss                 | 470         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00743     |
# |    std                  | 31.5        |
# |    value_loss           | 1.7e+03     |
# -----------------------------------------

# %%
import numpy as np
import torch as th
import time

MODEL_PATH = f"models/{run.id}/model.zip"

# Create and wrap the environment
env = BobinaEnv(duration = 4)

# Load the trained agent
model = PPO.load(MODEL_PATH, env=env)

# Evaluate the agent
for i in range(5):
    obs, seed = env.reset()
    done = False
    episode_reward = 0
    velocidad = 0
    current = 0
    observations = []
    noises = []
    error = obs -19.5
    timepredict = 0
    timemodel = 0
    while not done:
        #noise = random.uniform(-1, 1)
        #obs = obs + noise
        observations.append(obs)
        #noises.append(noise)
        t1 = time.time()
        action, _states = model.predict(np.array([obs, velocidad, error, current]), deterministic=True)
        t2 = time.time()
        #print(action)
        #if env.airgap > 10.1: action = max(action, [-50])
        #print(action)
        t3 = time.time()
        state, reward, terminated, truncated, info = env.step(np.array(action))
        t4 = time.time()
        obs, velocidad, error, current = state
        done = truncated or terminated
        episode_reward += reward
        timepredict += t2 - t1
        timemodel += t4 - t3
        noises.append(action)
    print("Time predict", timepredict)
    print("Time model", timemodel)
    print("Episode reward", episode_reward)
    print(noises)
    env.render("yes")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Time predict 1.4193804264068604
# Time model 20.111234664916992
# Episode reward -37382.42650440723
# [array([-3.2473938], dtype=float32), array([25.638208], dtype=float32), array([25.619669], dtype=float32), array([25.566145], dtype=float32), array([25.493687], dtype=float32), array([25.40323], dtype=float32), array([25.301609], dtype=float32), array([25.198454], dtype=float32), array([25.100096], dtype=float32), array([25.009151], dtype=float32), array([24.928684], dtype=float32), array([24.860405], dtype=float32), array([24.804037], dtype=float32), array([24.75737], dtype=float32), array([24.717268], dtype=float32), array([24.680813], dtype=float32), array([24.645857], dtype=float32), array([24.611265], dtype=float32), array([24.57638], dtype=float32), array([24.540861], dtype=float32), array([24.504725], dtype=float32), array([24.46816], dtype=float32), array([24.431341], dtype=float32), array([24.394674], dtype=float32), array([24.358103], dtype=float32), array([24.321753], dtype=float32), array([24.285946], dtype=float32), array([24.250761], dtype=float32), array([24.21602], dtype=float32), array([24.181776], dtype=float32), array([24.148293], dtype=float32), array([24.115591], dtype=float32), array([24.083496], dtype=float32), array([24.052004], dtype=float32), array([24.021301], dtype=float32), array([23.991344], dtype=float32), array([23.962084], dtype=float32), array([23.933268], dtype=float32), array([23.904816], dtype=float32), array([23.876835], dtype=float32), array([23.849197], dtype=float32), array([23.82177], dtype=float32), array([23.794443], dtype=float32), array([23.766842], dtype=float32), array([23.738821], dtype=float32), array([23.710337], dtype=float32), array([23.68123], dtype=float32), array([23.651463], dtype=float32), array([23.620869], dtype=float32), array([23.589293], dtype=float32), array([23.556585], dtype=float32), array([23.52265], dtype=float32), array([23.487432], dtype=float32), array([23.450914], dtype=float32), array([23.413034], dtype=float32), array([23.373878], dtype=float32), array([23.333647], dtype=float32), array([23.292492], dtype=float32), array([23.250578], dtype=float32), array([23.20806], dtype=float32), array([23.16503], dtype=float32), array([23.121592], dtype=float32), array([23.077808], dtype=float32), array([23.033602], dtype=float32), array([22.988813], dtype=float32), array([22.943127], dtype=float32), array([22.896107], dtype=float32), array([22.847164], dtype=float32), array([22.795565], dtype=float32), array([22.74039], dtype=float32), array([22.680527], dtype=float32), array([22.614622], dtype=float32), array([22.541067], dtype=float32), array([22.457926], dtype=float32), array([22.362934], dtype=float32), array([22.253475], dtype=float32), array([22.126642], dtype=float32), array([21.979342], dtype=float32), array([21.808525], dtype=float32), array([21.611513], dtype=float32), array([21.38644], dtype=float32), array([21.132685], dtype=float32), array([20.851238], dtype=float32), array([20.544666], dtype=float32), array([20.21661], dtype=float32), array([19.87086], dtype=float32), array([19.51032], dtype=float32), array([19.136034], dtype=float32), array([18.91208], dtype=float32), array([18.971285], dtype=float32), array([18.968666], dtype=float32), array([18.96632], dtype=float32), array([18.964195], dtype=float32), array([18.962265], dtype=float32), array([18.960505], dtype=float32), array([18.958897], dtype=float32), array([18.957422], dtype=float32), array([18.956064], dtype=float32), array([18.954807], dtype=float32), array([18.953642], dtype=float32), array([18.952559], dtype=float32), array([18.951546], dtype=float32), array([18.9506], dtype=float32), array([18.949707], dtype=float32), array([18.94887], dtype=float32), array([18.948076], dtype=float32), array([18.947329], dtype=float32), array([18.946619], dtype=float32), array([18.945948], dtype=float32), array([18.945309], dtype=float32), array([18.944702], dtype=float32), array([18.944126], dtype=float32), array([18.943577], dtype=float32), array([18.943056], dtype=float32), array([18.942556], dtype=flo ...
# Time predict 1.4370532035827637
# Time model 20.03788185119629
# Episode reward -37382.42650440723
# [array([-3.2473938], dtype=float32), array([25.638208], dtype=float32), array([25.619669], dtype=float32), array([25.566145], dtype=float32), array([25.493687], dtype=float32), array([25.40323], dtype=float32), array([25.301609], dtype=float32), array([25.198454], dtype=float32), array([25.100096], dtype=float32), array([25.009151], dtype=float32), array([24.928684], dtype=float32), array([24.860405], dtype=float32), array([24.804037], dtype=float32), array([24.75737], dtype=float32), array([24.717268], dtype=float32), array([24.680813], dtype=float32), array([24.645857], dtype=float32), array([24.611265], dtype=float32), array([24.57638], dtype=float32), array([24.540861], dtype=float32), array([24.504725], dtype=float32), array([24.46816], dtype=float32), array([24.431341], dtype=float32), array([24.394674], dtype=float32), array([24.358103], dtype=float32), array([24.321753], dtype=float32), array([24.285946], dtype=float32), array([24.250761], dtype=float32), array([24.21602], dtype=float32), array([24.181776], dtype=float32), array([24.148293], dtype=float32), array([24.115591], dtype=float32), array([24.083496], dtype=float32), array([24.052004], dtype=float32), array([24.021301], dtype=float32), array([23.991344], dtype=float32), array([23.962084], dtype=float32), array([23.933268], dtype=float32), array([23.904816], dtype=float32), array([23.876835], dtype=float32), array([23.849197], dtype=float32), array([23.82177], dtype=float32), array([23.794443], dtype=float32), array([23.766842], dtype=float32), array([23.738821], dtype=float32), array([23.710337], dtype=float32), array([23.68123], dtype=float32), array([23.651463], dtype=float32), array([23.620869], dtype=float32), array([23.589293], dtype=float32), array([23.556585], dtype=float32), array([23.52265], dtype=float32), array([23.487432], dtype=float32), array([23.450914], dtype=float32), array([23.413034], dtype=float32), array([23.373878], dtype=float32), array([23.333647], dtype=float32), array([23.292492], dtype=float32), array([23.250578], dtype=float32), array([23.20806], dtype=float32), array([23.16503], dtype=float32), array([23.121592], dtype=float32), array([23.077808], dtype=float32), array([23.033602], dtype=float32), array([22.988813], dtype=float32), array([22.943127], dtype=float32), array([22.896107], dtype=float32), array([22.847164], dtype=float32), array([22.795565], dtype=float32), array([22.74039], dtype=float32), array([22.680527], dtype=float32), array([22.614622], dtype=float32), array([22.541067], dtype=float32), array([22.457926], dtype=float32), array([22.362934], dtype=float32), array([22.253475], dtype=float32), array([22.126642], dtype=float32), array([21.979342], dtype=float32), array([21.808525], dtype=float32), array([21.611513], dtype=float32), array([21.38644], dtype=float32), array([21.132685], dtype=float32), array([20.851238], dtype=float32), array([20.544666], dtype=float32), array([20.21661], dtype=float32), array([19.87086], dtype=float32), array([19.51032], dtype=float32), array([19.136034], dtype=float32), array([18.91208], dtype=float32), array([18.971285], dtype=float32), array([18.968666], dtype=float32), array([18.96632], dtype=float32), array([18.964195], dtype=float32), array([18.962265], dtype=float32), array([18.960505], dtype=float32), array([18.958897], dtype=float32), array([18.957422], dtype=float32), array([18.956064], dtype=float32), array([18.954807], dtype=float32), array([18.953642], dtype=float32), array([18.952559], dtype=float32), array([18.951546], dtype=float32), array([18.9506], dtype=float32), array([18.949707], dtype=float32), array([18.94887], dtype=float32), array([18.948076], dtype=float32), array([18.947329], dtype=float32), array([18.946619], dtype=float32), array([18.945948], dtype=float32), array([18.945309], dtype=float32), array([18.944702], dtype=float32), array([18.944126], dtype=float32), array([18.943577], dtype=float32), array([18.943056], dtype=float32), array([18.942556], dtype=flo ...
# Time predict 1.4762678146362305
# Time model 20.069810390472412
# Episode reward -37382.42650440723
# [array([-3.2473938], dtype=float32), array([25.638208], dtype=float32), array([25.619669], dtype=float32), array([25.566145], dtype=float32), array([25.493687], dtype=float32), array([25.40323], dtype=float32), array([25.301609], dtype=float32), array([25.198454], dtype=float32), array([25.100096], dtype=float32), array([25.009151], dtype=float32), array([24.928684], dtype=float32), array([24.860405], dtype=float32), array([24.804037], dtype=float32), array([24.75737], dtype=float32), array([24.717268], dtype=float32), array([24.680813], dtype=float32), array([24.645857], dtype=float32), array([24.611265], dtype=float32), array([24.57638], dtype=float32), array([24.540861], dtype=float32), array([24.504725], dtype=float32), array([24.46816], dtype=float32), array([24.431341], dtype=float32), array([24.394674], dtype=float32), array([24.358103], dtype=float32), array([24.321753], dtype=float32), array([24.285946], dtype=float32), array([24.250761], dtype=float32), array([24.21602], dtype=float32), array([24.181776], dtype=float32), array([24.148293], dtype=float32), array([24.115591], dtype=float32), array([24.083496], dtype=float32), array([24.052004], dtype=float32), array([24.021301], dtype=float32), array([23.991344], dtype=float32), array([23.962084], dtype=float32), array([23.933268], dtype=float32), array([23.904816], dtype=float32), array([23.876835], dtype=float32), array([23.849197], dtype=float32), array([23.82177], dtype=float32), array([23.794443], dtype=float32), array([23.766842], dtype=float32), array([23.738821], dtype=float32), array([23.710337], dtype=float32), array([23.68123], dtype=float32), array([23.651463], dtype=float32), array([23.620869], dtype=float32), array([23.589293], dtype=float32), array([23.556585], dtype=float32), array([23.52265], dtype=float32), array([23.487432], dtype=float32), array([23.450914], dtype=float32), array([23.413034], dtype=float32), array([23.373878], dtype=float32), array([23.333647], dtype=float32), array([23.292492], dtype=float32), array([23.250578], dtype=float32), array([23.20806], dtype=float32), array([23.16503], dtype=float32), array([23.121592], dtype=float32), array([23.077808], dtype=float32), array([23.033602], dtype=float32), array([22.988813], dtype=float32), array([22.943127], dtype=float32), array([22.896107], dtype=float32), array([22.847164], dtype=float32), array([22.795565], dtype=float32), array([22.74039], dtype=float32), array([22.680527], dtype=float32), array([22.614622], dtype=float32), array([22.541067], dtype=float32), array([22.457926], dtype=float32), array([22.362934], dtype=float32), array([22.253475], dtype=float32), array([22.126642], dtype=float32), array([21.979342], dtype=float32), array([21.808525], dtype=float32), array([21.611513], dtype=float32), array([21.38644], dtype=float32), array([21.132685], dtype=float32), array([20.851238], dtype=float32), array([20.544666], dtype=float32), array([20.21661], dtype=float32), array([19.87086], dtype=float32), array([19.51032], dtype=float32), array([19.136034], dtype=float32), array([18.91208], dtype=float32), array([18.971285], dtype=float32), array([18.968666], dtype=float32), array([18.96632], dtype=float32), array([18.964195], dtype=float32), array([18.962265], dtype=float32), array([18.960505], dtype=float32), array([18.958897], dtype=float32), array([18.957422], dtype=float32), array([18.956064], dtype=float32), array([18.954807], dtype=float32), array([18.953642], dtype=float32), array([18.952559], dtype=float32), array([18.951546], dtype=float32), array([18.9506], dtype=float32), array([18.949707], dtype=float32), array([18.94887], dtype=float32), array([18.948076], dtype=float32), array([18.947329], dtype=float32), array([18.946619], dtype=float32), array([18.945948], dtype=float32), array([18.945309], dtype=float32), array([18.944702], dtype=float32), array([18.944126], dtype=float32), array([18.943577], dtype=float32), array([18.943056], dtype=float32), array([18.942556], dtype=flo ...
# Time predict 1.4087800979614258
# Time model 19.867220401763916
# Episode reward -37382.42650440723
# [array([-3.2473938], dtype=float32), array([25.638208], dtype=float32), array([25.619669], dtype=float32), array([25.566145], dtype=float32), array([25.493687], dtype=float32), array([25.40323], dtype=float32), array([25.301609], dtype=float32), array([25.198454], dtype=float32), array([25.100096], dtype=float32), array([25.009151], dtype=float32), array([24.928684], dtype=float32), array([24.860405], dtype=float32), array([24.804037], dtype=float32), array([24.75737], dtype=float32), array([24.717268], dtype=float32), array([24.680813], dtype=float32), array([24.645857], dtype=float32), array([24.611265], dtype=float32), array([24.57638], dtype=float32), array([24.540861], dtype=float32), array([24.504725], dtype=float32), array([24.46816], dtype=float32), array([24.431341], dtype=float32), array([24.394674], dtype=float32), array([24.358103], dtype=float32), array([24.321753], dtype=float32), array([24.285946], dtype=float32), array([24.250761], dtype=float32), array([24.21602], dtype=float32), array([24.181776], dtype=float32), array([24.148293], dtype=float32), array([24.115591], dtype=float32), array([24.083496], dtype=float32), array([24.052004], dtype=float32), array([24.021301], dtype=float32), array([23.991344], dtype=float32), array([23.962084], dtype=float32), array([23.933268], dtype=float32), array([23.904816], dtype=float32), array([23.876835], dtype=float32), array([23.849197], dtype=float32), array([23.82177], dtype=float32), array([23.794443], dtype=float32), array([23.766842], dtype=float32), array([23.738821], dtype=float32), array([23.710337], dtype=float32), array([23.68123], dtype=float32), array([23.651463], dtype=float32), array([23.620869], dtype=float32), array([23.589293], dtype=float32), array([23.556585], dtype=float32), array([23.52265], dtype=float32), array([23.487432], dtype=float32), array([23.450914], dtype=float32), array([23.413034], dtype=float32), array([23.373878], dtype=float32), array([23.333647], dtype=float32), array([23.292492], dtype=float32), array([23.250578], dtype=float32), array([23.20806], dtype=float32), array([23.16503], dtype=float32), array([23.121592], dtype=float32), array([23.077808], dtype=float32), array([23.033602], dtype=float32), array([22.988813], dtype=float32), array([22.943127], dtype=float32), array([22.896107], dtype=float32), array([22.847164], dtype=float32), array([22.795565], dtype=float32), array([22.74039], dtype=float32), array([22.680527], dtype=float32), array([22.614622], dtype=float32), array([22.541067], dtype=float32), array([22.457926], dtype=float32), array([22.362934], dtype=float32), array([22.253475], dtype=float32), array([22.126642], dtype=float32), array([21.979342], dtype=float32), array([21.808525], dtype=float32), array([21.611513], dtype=float32), array([21.38644], dtype=float32), array([21.132685], dtype=float32), array([20.851238], dtype=float32), array([20.544666], dtype=float32), array([20.21661], dtype=float32), array([19.87086], dtype=float32), array([19.51032], dtype=float32), array([19.136034], dtype=float32), array([18.91208], dtype=float32), array([18.971285], dtype=float32), array([18.968666], dtype=float32), array([18.96632], dtype=float32), array([18.964195], dtype=float32), array([18.962265], dtype=float32), array([18.960505], dtype=float32), array([18.958897], dtype=float32), array([18.957422], dtype=float32), array([18.956064], dtype=float32), array([18.954807], dtype=float32), array([18.953642], dtype=float32), array([18.952559], dtype=float32), array([18.951546], dtype=float32), array([18.9506], dtype=float32), array([18.949707], dtype=float32), array([18.94887], dtype=float32), array([18.948076], dtype=float32), array([18.947329], dtype=float32), array([18.946619], dtype=float32), array([18.945948], dtype=float32), array([18.945309], dtype=float32), array([18.944702], dtype=float32), array([18.944126], dtype=float32), array([18.943577], dtype=float32), array([18.943056], dtype=float32), array([18.942556], dtype=flo ...
# Time predict 1.4243059158325195
# Time model 19.746825218200684
# Episode reward -37382.42650440723
# [array([-3.2473938], dtype=float32), array([25.638208], dtype=float32), array([25.619669], dtype=float32), array([25.566145], dtype=float32), array([25.493687], dtype=float32), array([25.40323], dtype=float32), array([25.301609], dtype=float32), array([25.198454], dtype=float32), array([25.100096], dtype=float32), array([25.009151], dtype=float32), array([24.928684], dtype=float32), array([24.860405], dtype=float32), array([24.804037], dtype=float32), array([24.75737], dtype=float32), array([24.717268], dtype=float32), array([24.680813], dtype=float32), array([24.645857], dtype=float32), array([24.611265], dtype=float32), array([24.57638], dtype=float32), array([24.540861], dtype=float32), array([24.504725], dtype=float32), array([24.46816], dtype=float32), array([24.431341], dtype=float32), array([24.394674], dtype=float32), array([24.358103], dtype=float32), array([24.321753], dtype=float32), array([24.285946], dtype=float32), array([24.250761], dtype=float32), array([24.21602], dtype=float32), array([24.181776], dtype=float32), array([24.148293], dtype=float32), array([24.115591], dtype=float32), array([24.083496], dtype=float32), array([24.052004], dtype=float32), array([24.021301], dtype=float32), array([23.991344], dtype=float32), array([23.962084], dtype=float32), array([23.933268], dtype=float32), array([23.904816], dtype=float32), array([23.876835], dtype=float32), array([23.849197], dtype=float32), array([23.82177], dtype=float32), array([23.794443], dtype=float32), array([23.766842], dtype=float32), array([23.738821], dtype=float32), array([23.710337], dtype=float32), array([23.68123], dtype=float32), array([23.651463], dtype=float32), array([23.620869], dtype=float32), array([23.589293], dtype=float32), array([23.556585], dtype=float32), array([23.52265], dtype=float32), array([23.487432], dtype=float32), array([23.450914], dtype=float32), array([23.413034], dtype=float32), array([23.373878], dtype=float32), array([23.333647], dtype=float32), array([23.292492], dtype=float32), array([23.250578], dtype=float32), array([23.20806], dtype=float32), array([23.16503], dtype=float32), array([23.121592], dtype=float32), array([23.077808], dtype=float32), array([23.033602], dtype=float32), array([22.988813], dtype=float32), array([22.943127], dtype=float32), array([22.896107], dtype=float32), array([22.847164], dtype=float32), array([22.795565], dtype=float32), array([22.74039], dtype=float32), array([22.680527], dtype=float32), array([22.614622], dtype=float32), array([22.541067], dtype=float32), array([22.457926], dtype=float32), array([22.362934], dtype=float32), array([22.253475], dtype=float32), array([22.126642], dtype=float32), array([21.979342], dtype=float32), array([21.808525], dtype=float32), array([21.611513], dtype=float32), array([21.38644], dtype=float32), array([21.132685], dtype=float32), array([20.851238], dtype=float32), array([20.544666], dtype=float32), array([20.21661], dtype=float32), array([19.87086], dtype=float32), array([19.51032], dtype=float32), array([19.136034], dtype=float32), array([18.91208], dtype=float32), array([18.971285], dtype=float32), array([18.968666], dtype=float32), array([18.96632], dtype=float32), array([18.964195], dtype=float32), array([18.962265], dtype=float32), array([18.960505], dtype=float32), array([18.958897], dtype=float32), array([18.957422], dtype=float32), array([18.956064], dtype=float32), array([18.954807], dtype=float32), array([18.953642], dtype=float32), array([18.952559], dtype=float32), array([18.951546], dtype=float32), array([18.9506], dtype=float32), array([18.949707], dtype=float32), array([18.94887], dtype=float32), array([18.948076], dtype=float32), array([18.947329], dtype=float32), array([18.946619], dtype=float32), array([18.945948], dtype=float32), array([18.945309], dtype=float32), array([18.944702], dtype=float32), array([18.944126], dtype=float32), array([18.943577], dtype=float32), array([18.943056], dtype=float32), array([18.942556], dtype=flo ...
