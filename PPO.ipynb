# %%
from gymnasium import Env
from gymnasium.spaces.box import Box
import numpy as np
import random
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.noise import NormalActionNoise
import wandb
from wandb.integration.sb3 import WandbCallback
import os
import matplotlib.pyplot as plt
import scipy.io
import scipy
import numpy as np
import pickle
import warnings
import math
from typing import Callable
warnings.filterwarnings("ignore")

# %% [markdown]
# # Siguientes pasos
# * Si funciona:
#     * Variar situación inicial
#     * Añadir el crash
#     * Cambiar reward a corriente
# * Si no funciona:
#     * Añadir sigmoide al final
#     * Cambiar reward a corriente
#     * Añadir el crash

# %%
class Bobina():
  """ 
  Coil model for the Hybrid Electromagnetic Suspension
  """
  def __init__(self, masa_pod = 200, airgap = 23):
    self.masa_pod = masa_pod
    self.airgap = airgap
    self.aceleracion = []
    self.velocidad = []
    mat = scipy.io.loadmat('./coil/hems.mat')
    self.hems = mat["hems"][0][0]
    self.airgaps = self.hems[0][0]
    self.currents = self.hems[1][0]
    self.force_vertical = pickle.load(open("./coil/mlp_vertical.pkl", 'rb'))
    self.flux = self.hems[3]
    self.force_horizontal = self.hems[4]
    self.inductance = pickle.load(open("./coil/rf_inductance.pkl", 'rb'))
    self.resistance = self.hems[6][0][0]
    self.min_distance = self.airgaps[0]
    self.max_distance = self.airgaps[-1]
    self.airgapinicial = airgap
    self.crash = False
    self.current = 0
    self.steps_RL = []

  def integral(self, lista, h = 1):
    return sum(h*(lista[i]+lista[i+1])/2 for i in range(len(lista)-1))

  def RL(self, airgap, target_voltage, temperature):
    # Resistance-Inductance circuit

    # Get resistance of the coil
    R = self.R(current = self.current, temperature = temperature)   
    V = target_voltage
    I = self.current
    L = self.L(airgap = airgap, current = self.current)
    dIdt = ((V/R) - I)/(L/R)                                      
    self.steps_RL.append(dIdt)                                   
    current = self.integral(self.steps_RL, h = 0.001)                          
    return current                                                  

  def R(self, current, temperature):
    return self.resistance                                         

  def L(self, airgap, current):
    # Return predicted inductance
    return float(self.inductance.predict(np.array([[airgap, current]]))[0])

  def vertical_force(self, airgap, target_voltage, temperature):
    # Get current from RL circuit
    I = self.RL(airgap = airgap, target_voltage = target_voltage, temperature = temperature) 
    
    # Clip result
    if I > 45:
      I = 45
    elif I < -45:
      I = -45
    self.current = I
    # Get vertical force from 
    FI = self.FI_vertical(airgap = airgap, current = I)                    
    return FI, I


  def FI_vertical(self, airgap, current):
    # Return predicted vertical force
    return float(self.force_vertical.predict(np.array([[airgap, current]])))    


  def next_airgap(self, masa_pod, vertical_force, verbose = False):
    # Devide the mass of the pod by 4 coils
    masa = masa_pod/4  
    # Calculate weight
    peso = masa * 9.8    
    # Get total force                                                       
    fuerza = peso - vertical_force
    if verbose: print("Fuerza resultante: ", fuerza)   
    # Calculate acceleration                                     
    aceleracion = fuerza/masa
    if verbose: print("Aceleración: ", aceleracion)                                         
    self.aceleracion.append(aceleracion)       
    # Calculate velocity                                
    velocidad = self.integral(self.aceleracion, 0.001)
    if verbose: print("Integral primera (velocidad): ", velocidad)                          
    self.velocidad.append(velocidad)               
    # Calculate position (x1000 as to transform from m to mm)                            
    posicion = self.airgapinicial + self.integral(self.velocidad, 0.001)*1000 
    if verbose: print("Integral segunda (posición): ", posicion)

    # Clip position
    if posicion > self.max_distance:
      airgap = self.max_distance
      self.aceleracion = [0]
      self.velocidad = [0]  
      #self.crash = True     
      self.airgapinicial = self.max_distance                                               
    elif posicion < self.min_distance:
      airgap = self.min_distance
      self.aceleracion = [0]
      self.velocidad = [0]
      #self.crash = True
      self.airgapinicial = self.min_distance
    else: airgap = posicion
    return airgap, velocidad

  def step(self, target_voltage, verbose = False):
    # Calculate vertical force and current
    vertical_force, self.current = self.vertical_force(airgap = self.airgap, target_voltage = target_voltage, temperature = 40)
    if verbose: print("Fuerza vertical: ", vertical_force)
    # Calculate next airgap and velocity
    self.airgap, velocidad = self.next_airgap(self.masa_pod, vertical_force, verbose = verbose)
    #noise = np.random.normal(0,0.5)
    #self.airgap = self.airgap + noise     
    return (np.float32(self.airgap), np.float32(velocidad), np.float32(self.airgap - 19.5), np.float32(self.current)), self.crash
class BobinaEnv(Env):
  """
  Custom Gym Environment for the Hybrid Electromagnetic Suspension, considering just one coil.
  """
  def __init__(self, masa_pod = 200, airgap = 10, duration = 10):
    # Actions: Voltage applied to the coil
    self.action_space = Box(low=np.array([-100]), high = np.array([50]), dtype=np.float32)
    # Observations: Airgap to the ceiling, velocity, distance to the objective, current of the coil
    self.observation_space = Box(low=np.array([10, -np.inf, -10, -45]), high = np.array([23, np.inf, 10, 45]), dtype=np.float32)
    # Initial parameters
    self.state = np.array([airgap, 0, airgap - 19.5, 0])
    self.airgapinicial = airgap
    self.duration = duration
    self.timeleft = duration
    self.crash = False
    self.masa_pod = masa_pod
    self.bobina = Bobina(masa_pod = self.masa_pod, airgap = self.airgapinicial)
    self.steps = []
    self.airgap = airgap
    self.distancia = 0
    self.velocidad = 0
    self.current = 0


  def step(self, action):
    # Apply action
    self.state, self.crash = self.bobina.step(action[0])
    self.airgap, self.velocidad, self.distancia, self.current = self.state

    # Reduce the time of the experiment
    self.timeleft -= 0.001

    # Calculate reward
    if self.airgap >= 23: reward = -5000
    elif self.airgap <= 10: reward = -5000
    else: reward = -abs(self.current)

    # Check if experiment is done
    if self.timeleft <= 0:
      truncated = True
    else: truncated = False
    # Set placeholder for info
    info = {}
    # Only if we implemented the crash
    if self.crash:
      reward = - 50000
      terminated = True
    else:
      terminated = False
    self.steps.append(self.state)
    return self.state, reward, terminated, truncated, info


  def render(self, yes = "yes"):
    # create data
    x = list(range(0,len(self.steps)))
    y = [step[0] for step in self.steps]
    objective = [19.5]*len(self.steps)

    # plot lines
    fig = plt.figure(figsize=(10,5))
    ax = fig.add_subplot(111)
    ax.tick_params(axis='x', colors='white')    #setting up X-axis tick color to red
    ax.tick_params(axis='y', colors='white')  #setting up Y-axis tick color to black

    plt.plot(x, y, label = "States")
    plt.plot(x, objective, label = "Objective")
    plt.legend()
    plt.show()

  def reset(self, seed = 0):
    # Reset experiment choosing randomly the start (ceiling or floor)
    airgap = random.choice([19.5])
    self.state = self.airgapinicial
    self.bobina = Bobina(masa_pod = self.masa_pod, airgap = airgap)
    # Reset time
    self.timeleft = self.duration
    self.crash = False
    self.steps = []
    return self.state, seed

# %%
run = wandb.init(
    project="1gdlppo",
    sync_tensorboard=True,
    monitor_gym=True,
)

# Create log dir
log_dir = "1gdlppo/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = BobinaEnv( airgap = 19.5,duration = 4 )
env = Monitor(env, log_dir)

def linear_schedule(initial_value: float) -> Callable[[float], float]:
    """
    Linear learning rate schedule.

    :param initial_value: Initial learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return progress_remaining * initial_value

    return func

model = PPO("MlpPolicy", env,learning_rate = linear_schedule(0.001), n_steps = 80000, batch_size=512, ent_coef=0.2, seed = 42, verbose=1, tensorboard_log=log_dir)
# Out:
# Finishing last run (ID:vz1dd8g8) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▂▂▄▆▇████████████████████████████████</td></tr><tr><td>time/fps</td><td>▁▁▂▂▂▂▂▂▂▂▂▂▂▃▃▅▅▆▇███▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▆▇▇</td></tr><tr><td>train/approx_kl</td><td>▃▃▃▁▂▁▆▅▁▃▃▁▂▂▂▂▂▁▁▂▁▂▃▁▆█▇▆▄▇▆▃▅▆▄▅▆▃▅▅</td></tr><tr><td>train/clip_fraction</td><td>▅▅▅▂▂▂█▆▁▄▄▂▂▃▃▂▂▂▁▂▁▂▄▁▆▇▇▆▄▇▇▄▆▆▅▅▆▄▆▆</td></tr><tr><td>train/clip_range</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>█████▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▃▃▃▂▂▂▂▁▁▁</td></tr><tr><td>train/explained_variance</td><td>▁▂▃▅▆▆▆▆███████████████▅████████████████</td></tr><tr><td>train/learning_rate</td><td>███▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁</td></tr><tr><td>train/loss</td><td>██▇▆▅▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/policy_gradient_loss</td><td>▄▄▄▃▃▄█▆▁▂▂▁▁▁▂▁▂▁▁▁▁▁▂▁▂▃▃▃▂▃▃▂▂▂▂▂▂▂▃▂</td></tr><tr><td>train/std</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▃█</td></tr><tr><td>train/value_loss</td><td>██▇▅▅▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>8960000</td></tr><tr><td>rollout/ep_len_mean</td><td>4001.0</td></tr><tr><td>rollout/ep_rew_mean</td><td>-48346.01953</td></tr><tr><td>time/fps</td><td>143.0</td></tr><tr><td>train/approx_kl</td><td>0.19347</td></tr><tr><td>train/clip_fraction</td><td>0.413</td></tr><tr><td>train/clip_range</td><td>0.2</td></tr><tr><td>train/entropy_loss</td><td>-44.16264</td></tr><tr><td>train/explained_variance</td><td>0.99335</td></tr><tr><td>train/learning_rate</td><td>0.00056</td></tr><tr><td>train/loss</td><td>-8.63475</td></tr><tr><td>train/policy_gradient_loss</td><td>0.00696</td></tr><tr><td>train/std</td><td>4.718272675623993e+18</td></tr><tr><td>train/value_loss</td><td>9.22585</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stellar-feather-14</strong> at: <a href='https://wandb.ai/hyperloopupv/1gdlppo/runs/vz1dd8g8' target="_blank">https://wandb.ai/hyperloopupv/1gdlppo/runs/vz1dd8g8</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20231215_162803-vz1dd8g8\logs</code>
# Successfully finished last run (ID:vz1dd8g8). Initializing new run:<br/>
# wandb version 0.16.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\wandb\run-20231217_024844-h950a8l0</code>
# Syncing run <strong><a href='https://wandb.ai/hyperloopupv/1gdlppo/runs/h950a8l0' target="_blank">blooming-sunset-15</a></strong> to <a href='https://wandb.ai/hyperloopupv/1gdlppo' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hyperloopupv/1gdlppo' target="_blank">https://wandb.ai/hyperloopupv/1gdlppo</a>
#  View run at <a href='https://wandb.ai/hyperloopupv/1gdlppo/runs/h950a8l0' target="_blank">https://wandb.ai/hyperloopupv/1gdlppo/runs/h950a8l0</a>
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
import torch
model.policy.action_net = torch.nn.Sequential(
    torch.nn.Linear(in_features=64, out_features=1, bias=True),
    torch.nn.Sigmoid()
)

# %%
model.policy
# Out:
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (pi_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (vf_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=4, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=4, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Sequential(
#     (0): Linear(in_features=64, out_features=1, bias=True)
#     (1): Sigmoid()
#   )
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
# Create checkpoint callback
checkpoint_callback = CheckpointCallback(
    save_freq=10000, save_path=log_dir, name_prefix="rl_ppo_1gdlobj"
)

# Train the agent
model.learn(total_timesteps=20000000,
    callback=[
        checkpoint_callback,
        WandbCallback(
            gradient_save_freq=10000,
            model_save_path=f"models/ppocuadratico",
            model_save_freq=10000,
            verbose=2,
        ),
    ],
)
# Out:
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Logging to 1gdlppo/PPO_13
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.89e+07 |
# | time/              |           |
# |    fps             | 131       |
# |    iterations      | 1         |
# |    time_elapsed    | 607       |
# |    total_timesteps | 80000     |
# ----------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 133           |
# |    iterations           | 2             |
# |    time_elapsed         | 1202          |
# |    total_timesteps      | 160000        |
# | train/                  |               |
# |    approx_kl            | 0.00052105833 |
# |    clip_fraction        | 0.000551      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | -2.5e-06      |
# |    learning_rate        | 0.000996      |
# |    loss                 | 3.3e+09       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -2.71e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 6.64e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 133           |
# |    iterations           | 3             |
# |    time_elapsed         | 1799          |
# |    total_timesteps      | 240000        |
# | train/                  |               |
# |    approx_kl            | 0.00054291205 |
# |    clip_fraction        | 0.000641      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.46         |
# |    explained_variance   | 1.43e-05      |
# |    learning_rate        | 0.000992      |
# |    loss                 | 3.32e+09      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -5.13e-05     |
# |    std                  | 1.05          |
# |    value_loss           | 6.64e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 133           |
# |    iterations           | 4             |
# |    time_elapsed         | 2394          |
# |    total_timesteps      | 320000        |
# | train/                  |               |
# |    approx_kl            | 0.00054377096 |
# |    clip_fraction        | 0.000555      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.48         |
# |    explained_variance   | 1.34e-05      |
# |    learning_rate        | 0.000988      |
# |    loss                 | 3.31e+09      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -4.44e-05     |
# |    std                  | 1.07          |
# |    value_loss           | 6.63e+09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | -1.89e+07    |
# | time/                   |              |
# |    fps                  | 133          |
# |    iterations           | 5            |
# |    time_elapsed         | 2987         |
# |    total_timesteps      | 400000       |
# | train/                  |              |
# |    approx_kl            | 0.0004783588 |
# |    clip_fraction        | 0.000404     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 1.38e-05     |
# |    learning_rate        | 0.000984     |
# |    loss                 | 3.3e+09      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | 4.97e-05     |
# |    std                  | 1.1          |
# |    value_loss           | 6.63e+09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 134           |
# |    iterations           | 6             |
# |    time_elapsed         | 3580          |
# |    total_timesteps      | 480000        |
# | train/                  |               |
# |    approx_kl            | 0.00052138197 |
# |    clip_fraction        | 0.000519      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.53         |
# |    explained_variance   | 1.66e-05      |
# |    learning_rate        | 0.00098       |
# |    loss                 | 3.35e+09      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -6.85e-05     |
# |    std                  | 1.13          |
# |    value_loss           | 6.63e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 134           |
# |    iterations           | 7             |
# |    time_elapsed         | 4173          |
# |    total_timesteps      | 560000        |
# | train/                  |               |
# |    approx_kl            | 0.00047222615 |
# |    clip_fraction        | 0.000404      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.55         |
# |    explained_variance   | 1.93e-05      |
# |    learning_rate        | 0.000976      |
# |    loss                 | 3.41e+09      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | 4.64e-05      |
# |    std                  | 1.15          |
# |    value_loss           | 6.63e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 134           |
# |    iterations           | 8             |
# |    time_elapsed         | 4770          |
# |    total_timesteps      | 640000        |
# | train/                  |               |
# |    approx_kl            | 0.00045951936 |
# |    clip_fraction        | 0.000382      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.57         |
# |    explained_variance   | 2.15e-05      |
# |    learning_rate        | 0.000972      |
# |    loss                 | 3.25e+09      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | 6.5e-05       |
# |    std                  | 1.18          |
# |    value_loss           | 6.62e+09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | -1.89e+07    |
# | time/                   |              |
# |    fps                  | 134          |
# |    iterations           | 9            |
# |    time_elapsed         | 5364         |
# |    total_timesteps      | 720000       |
# | train/                  |              |
# |    approx_kl            | 0.0005313092 |
# |    clip_fraction        | 0.00058      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.6         |
# |    explained_variance   | 2.31e-05     |
# |    learning_rate        | 0.000968     |
# |    loss                 | 3.35e+09     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -2.8e-05     |
# |    std                  | 1.21         |
# |    value_loss           | 6.61e+09     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | -1.89e+07    |
# | time/                   |              |
# |    fps                  | 134          |
# |    iterations           | 10           |
# |    time_elapsed         | 5958         |
# |    total_timesteps      | 800000       |
# | train/                  |              |
# |    approx_kl            | 0.0005132931 |
# |    clip_fraction        | 0.000578     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.62        |
# |    explained_variance   | 2.55e-05     |
# |    learning_rate        | 0.000964     |
# |    loss                 | 3.32e+09     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -5.24e-05    |
# |    std                  | 1.24         |
# |    value_loss           | 6.62e+09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 133           |
# |    iterations           | 11            |
# |    time_elapsed         | 6576          |
# |    total_timesteps      | 880000        |
# | train/                  |               |
# |    approx_kl            | 0.00045769193 |
# |    clip_fraction        | 0.000391      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.64         |
# |    explained_variance   | 2.74e-05      |
# |    learning_rate        | 0.00096       |
# |    loss                 | 3.21e+09      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | 7.04e-05      |
# |    std                  | 1.26          |
# |    value_loss           | 6.61e+09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | -1.89e+07    |
# | time/                   |              |
# |    fps                  | 133          |
# |    iterations           | 12           |
# |    time_elapsed         | 7172         |
# |    total_timesteps      | 960000       |
# | train/                  |              |
# |    approx_kl            | 0.0005053959 |
# |    clip_fraction        | 0.000489     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.66        |
# |    explained_variance   | 2.92e-05     |
# |    learning_rate        | 0.000956     |
# |    loss                 | 3.31e+09     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -7.53e-05    |
# |    std                  | 1.29         |
# |    value_loss           | 6.61e+09     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | -1.89e+07    |
# | time/                   |              |
# |    fps                  | 133          |
# |    iterations           | 13           |
# |    time_elapsed         | 7771         |
# |    total_timesteps      | 1040000      |
# | train/                  |              |
# |    approx_kl            | 0.0004660137 |
# |    clip_fraction        | 0.000444     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.69        |
# |    explained_variance   | 3.17e-05     |
# |    learning_rate        | 0.000952     |
# |    loss                 | 3.42e+09     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -3.01e-05    |
# |    std                  | 1.32         |
# |    value_loss           | 6.61e+09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 133           |
# |    iterations           | 14            |
# |    time_elapsed         | 8367          |
# |    total_timesteps      | 1120000       |
# | train/                  |               |
# |    approx_kl            | 0.00046188672 |
# |    clip_fraction        | 0.000414      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.71         |
# |    explained_variance   | 3.3e-05       |
# |    learning_rate        | 0.000948      |
# |    loss                 | 3.3e+09       |
# |    n_updates            | 130           |
# |    policy_gradient_loss | 3.56e-05      |
# |    std                  | 1.35          |
# |    value_loss           | 6.61e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 133           |
# |    iterations           | 15            |
# |    time_elapsed         | 8965          |
# |    total_timesteps      | 1200000       |
# | train/                  |               |
# |    approx_kl            | 0.00048703386 |
# |    clip_fraction        | 0.000447      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.73         |
# |    explained_variance   | 3.46e-05      |
# |    learning_rate        | 0.000944      |
# |    loss                 | 3.21e+09      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -8.01e-05     |
# |    std                  | 1.39          |
# |    value_loss           | 6.6e+09       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | -1.89e+07    |
# | time/                   |              |
# |    fps                  | 133          |
# |    iterations           | 16           |
# |    time_elapsed         | 9558         |
# |    total_timesteps      | 1280000      |
# | train/                  |              |
# |    approx_kl            | 0.0004651745 |
# |    clip_fraction        | 0.000399     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 3.68e-05     |
# |    learning_rate        | 0.00094      |
# |    loss                 | 3.3e+09      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -1.68e-05    |
# |    std                  | 1.42         |
# |    value_loss           | 6.6e+09      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | -1.89e+07    |
# | time/                   |              |
# |    fps                  | 134          |
# |    iterations           | 17           |
# |    time_elapsed         | 10148        |
# |    total_timesteps      | 1360000      |
# | train/                  |              |
# |    approx_kl            | 0.0004850502 |
# |    clip_fraction        | 0.000468     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | 3.87e-05     |
# |    learning_rate        | 0.000936     |
# |    loss                 | 3.36e+09     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -8.44e-05    |
# |    std                  | 1.45         |
# |    value_loss           | 6.6e+09      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | -1.89e+07    |
# | time/                   |              |
# |    fps                  | 134          |
# |    iterations           | 18           |
# |    time_elapsed         | 10740        |
# |    total_timesteps      | 1440000      |
# | train/                  |              |
# |    approx_kl            | 0.0005089131 |
# |    clip_fraction        | 0.000488     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.8         |
# |    explained_variance   | 4.04e-05     |
# |    learning_rate        | 0.000932     |
# |    loss                 | 3.25e+09     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000132    |
# |    std                  | 1.49         |
# |    value_loss           | 6.6e+09      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 134           |
# |    iterations           | 19            |
# |    time_elapsed         | 11332         |
# |    total_timesteps      | 1520000       |
# | train/                  |               |
# |    approx_kl            | 0.00046450834 |
# |    clip_fraction        | 0.000454      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.83         |
# |    explained_variance   | 4.18e-05      |
# |    learning_rate        | 0.000928      |
# |    loss                 | 3.38e+09      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -4.45e-05     |
# |    std                  | 1.52          |
# |    value_loss           | 6.59e+09      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -1.89e+07   |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 20          |
# |    time_elapsed         | 11922       |
# |    total_timesteps      | 1600000     |
# | train/                  |             |
# |    approx_kl            | 0.000423226 |
# |    clip_fraction        | 0.000318    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 4.3e-05     |
# |    learning_rate        | 0.000924    |
# |    loss                 | 3.22e+09    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 4.63e-05    |
# |    std                  | 1.55        |
# |    value_loss           | 6.59e+09    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 134           |
# |    iterations           | 21            |
# |    time_elapsed         | 12518         |
# |    total_timesteps      | 1680000       |
# | train/                  |               |
# |    approx_kl            | 0.00041415897 |
# |    clip_fraction        | 0.000297      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.87         |
# |    explained_variance   | 4.43e-05      |
# |    learning_rate        | 0.00092       |
# |    loss                 | 3.3e+09       |
# |    n_updates            | 200           |
# |    policy_gradient_loss | 6.01e-05      |
# |    std                  | 1.59          |
# |    value_loss           | 6.58e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 134           |
# |    iterations           | 22            |
# |    time_elapsed         | 13111         |
# |    total_timesteps      | 1760000       |
# | train/                  |               |
# |    approx_kl            | 0.00045143286 |
# |    clip_fraction        | 0.000335      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.89         |
# |    explained_variance   | 4.67e-05      |
# |    learning_rate        | 0.000916      |
# |    loss                 | 3.34e+09      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -6.8e-05      |
# |    std                  | 1.62          |
# |    value_loss           | 6.58e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 134           |
# |    iterations           | 23            |
# |    time_elapsed         | 13705         |
# |    total_timesteps      | 1840000       |
# | train/                  |               |
# |    approx_kl            | 0.00041762888 |
# |    clip_fraction        | 0.000325      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.91         |
# |    explained_variance   | 4.82e-05      |
# |    learning_rate        | 0.000912      |
# |    loss                 | 3.17e+09      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | 5.07e-05      |
# |    std                  | 1.66          |
# |    value_loss           | 6.58e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 134           |
# |    iterations           | 24            |
# |    time_elapsed         | 14300         |
# |    total_timesteps      | 1920000       |
# | train/                  |               |
# |    approx_kl            | 0.00044802396 |
# |    clip_fraction        | 0.000338      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 4.91e-05      |
# |    learning_rate        | 0.000908      |
# |    loss                 | 3.27e+09      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -3.75e-05     |
# |    std                  | 1.7           |
# |    value_loss           | 6.57e+09      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -1.89e+07   |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 25          |
# |    time_elapsed         | 14729       |
# |    total_timesteps      | 2000000     |
# | train/                  |             |
# |    approx_kl            | 0.000443533 |
# |    clip_fraction        | 0.000341    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 5.17e-05    |
# |    learning_rate        | 0.000904    |
# |    loss                 | 3.3e+09     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -4.26e-06   |
# |    std                  | 1.73        |
# |    value_loss           | 6.57e+09    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 137           |
# |    iterations           | 26            |
# |    time_elapsed         | 15152         |
# |    total_timesteps      | 2080000       |
# | train/                  |               |
# |    approx_kl            | 0.00042860457 |
# |    clip_fraction        | 0.000338      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.98         |
# |    explained_variance   | 5.42e-05      |
# |    learning_rate        | 0.0009        |
# |    loss                 | 3.34e+09      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -2.01e-05     |
# |    std                  | 1.77          |
# |    value_loss           | 6.57e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 138           |
# |    iterations           | 27            |
# |    time_elapsed         | 15576         |
# |    total_timesteps      | 2160000       |
# | train/                  |               |
# |    approx_kl            | 0.00045330415 |
# |    clip_fraction        | 0.000419      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2            |
# |    explained_variance   | 5.35e-05      |
# |    learning_rate        | 0.000896      |
# |    loss                 | 3.34e+09      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -5.67e-05     |
# |    std                  | 1.81          |
# |    value_loss           | 6.56e+09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | -1.89e+07    |
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 28           |
# |    time_elapsed         | 16000        |
# |    total_timesteps      | 2240000      |
# | train/                  |              |
# |    approx_kl            | 0.0004196158 |
# |    clip_fraction        | 0.000317     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.02        |
# |    explained_variance   | 5.53e-05     |
# |    learning_rate        | 0.000892     |
# |    loss                 | 3.38e+09     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -4.23e-06    |
# |    std                  | 1.85         |
# |    value_loss           | 6.55e+09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 141           |
# |    iterations           | 29            |
# |    time_elapsed         | 16424         |
# |    total_timesteps      | 2320000       |
# | train/                  |               |
# |    approx_kl            | 0.00040694335 |
# |    clip_fraction        | 0.00028       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.05         |
# |    explained_variance   | 6.1e-05       |
# |    learning_rate        | 0.000888      |
# |    loss                 | 3.31e+09      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -2.85e-06     |
# |    std                  | 1.89          |
# |    value_loss           | 6.57e+09      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -1.89e+07   |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 30          |
# |    time_elapsed         | 16848       |
# |    total_timesteps      | 2400000     |
# | train/                  |             |
# |    approx_kl            | 0.000490888 |
# |    clip_fraction        | 0.000468    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 6e-05       |
# |    learning_rate        | 0.000884    |
# |    loss                 | 3.31e+09    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.000232   |
# |    std                  | 1.94        |
# |    value_loss           | 6.56e+09    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | -1.89e+07    |
# | time/                   |              |
# |    fps                  | 143          |
# |    iterations           | 31           |
# |    time_elapsed         | 17272        |
# |    total_timesteps      | 2480000      |
# | train/                  |              |
# |    approx_kl            | 0.0003952145 |
# |    clip_fraction        | 0.000265     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 6.28e-05     |
# |    learning_rate        | 0.00088      |
# |    loss                 | 3.35e+09     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 2.7e-05      |
# |    std                  | 1.98         |
# |    value_loss           | 6.56e+09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 144           |
# |    iterations           | 32            |
# |    time_elapsed         | 17696         |
# |    total_timesteps      | 2560000       |
# | train/                  |               |
# |    approx_kl            | 0.00041444914 |
# |    clip_fraction        | 0.000325      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.11         |
# |    explained_variance   | 6.59e-05      |
# |    learning_rate        | 0.000876      |
# |    loss                 | 3.26e+09      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -3.16e-05     |
# |    std                  | 2.02          |
# |    value_loss           | 6.57e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 145           |
# |    iterations           | 33            |
# |    time_elapsed         | 18119         |
# |    total_timesteps      | 2640000       |
# | train/                  |               |
# |    approx_kl            | 0.00036356665 |
# |    clip_fraction        | 0.000195      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.13         |
# |    explained_variance   | 7.06e-05      |
# |    learning_rate        | 0.000872      |
# |    loss                 | 3.25e+09      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | 5.29e-05      |
# |    std                  | 2.06          |
# |    value_loss           | 6.58e+09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | -1.89e+07    |
# | time/                   |              |
# |    fps                  | 146          |
# |    iterations           | 34           |
# |    time_elapsed         | 18542        |
# |    total_timesteps      | 2720000      |
# | train/                  |              |
# |    approx_kl            | 0.0004167646 |
# |    clip_fraction        | 0.000304     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.15        |
# |    explained_variance   | 6.67e-05     |
# |    learning_rate        | 0.000868     |
# |    loss                 | 3.18e+09     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -4.12e-05    |
# |    std                  | 2.11         |
# |    value_loss           | 6.55e+09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 147           |
# |    iterations           | 35            |
# |    time_elapsed         | 18966         |
# |    total_timesteps      | 2800000       |
# | train/                  |               |
# |    approx_kl            | 0.00036945252 |
# |    clip_fraction        | 0.000219      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.17         |
# |    explained_variance   | 6.98e-05      |
# |    learning_rate        | 0.000864      |
# |    loss                 | 3.3e+09       |
# |    n_updates            | 340           |
# |    policy_gradient_loss | 2.52e-05      |
# |    std                  | 2.15          |
# |    value_loss           | 6.55e+09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | -1.89e+07    |
# | time/                   |              |
# |    fps                  | 148          |
# |    iterations           | 36           |
# |    time_elapsed         | 19390        |
# |    total_timesteps      | 2880000      |
# | train/                  |              |
# |    approx_kl            | 0.0004004557 |
# |    clip_fraction        | 0.000272     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.19        |
# |    explained_variance   | 7.27e-05     |
# |    learning_rate        | 0.00086      |
# |    loss                 | 3.12e+09     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -4.37e-05    |
# |    std                  | 2.2          |
# |    value_loss           | 6.56e+09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 149           |
# |    iterations           | 37            |
# |    time_elapsed         | 19814         |
# |    total_timesteps      | 2960000       |
# | train/                  |               |
# |    approx_kl            | 0.00038777915 |
# |    clip_fraction        | 0.00029       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.22         |
# |    explained_variance   | 7.21e-05      |
# |    learning_rate        | 0.000856      |
# |    loss                 | 3.31e+09      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | 2.58e-05      |
# |    std                  | 2.24          |
# |    value_loss           | 6.54e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 150           |
# |    iterations           | 38            |
# |    time_elapsed         | 20238         |
# |    total_timesteps      | 3040000       |
# | train/                  |               |
# |    approx_kl            | 0.00037632545 |
# |    clip_fraction        | 0.000236      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.24         |
# |    explained_variance   | 7.37e-05      |
# |    learning_rate        | 0.000852      |
# |    loss                 | 3.19e+09      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | 3.45e-05      |
# |    std                  | 2.29          |
# |    value_loss           | 6.54e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 151           |
# |    iterations           | 39            |
# |    time_elapsed         | 20662         |
# |    total_timesteps      | 3120000       |
# | train/                  |               |
# |    approx_kl            | 0.00038666872 |
# |    clip_fraction        | 0.000256      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.26         |
# |    explained_variance   | 7.73e-05      |
# |    learning_rate        | 0.000848      |
# |    loss                 | 3.12e+09      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -3.36e-05     |
# |    std                  | 2.34          |
# |    value_loss           | 6.55e+09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | -1.89e+07    |
# | time/                   |              |
# |    fps                  | 151          |
# |    iterations           | 40           |
# |    time_elapsed         | 21085        |
# |    total_timesteps      | 3200000      |
# | train/                  |              |
# |    approx_kl            | 0.0003589294 |
# |    clip_fraction        | 0.00023      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.28        |
# |    explained_variance   | 7.89e-05     |
# |    learning_rate        | 0.000844     |
# |    loss                 | 3.31e+09     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 3.63e-05     |
# |    std                  | 2.38         |
# |    value_loss           | 6.55e+09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 152           |
# |    iterations           | 41            |
# |    time_elapsed         | 21509         |
# |    total_timesteps      | 3280000       |
# | train/                  |               |
# |    approx_kl            | 0.00037428152 |
# |    clip_fraction        | 0.000243      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 7.79e-05      |
# |    learning_rate        | 0.00084       |
# |    loss                 | 3.3e+09       |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -1.14e-05     |
# |    std                  | 2.43          |
# |    value_loss           | 6.53e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 153           |
# |    iterations           | 42            |
# |    time_elapsed         | 21935         |
# |    total_timesteps      | 3360000       |
# | train/                  |               |
# |    approx_kl            | 0.00032778017 |
# |    clip_fraction        | 0.000141      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.32         |
# |    explained_variance   | 7.78e-05      |
# |    learning_rate        | 0.000836      |
# |    loss                 | 3.12e+09      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | 9.07e-05      |
# |    std                  | 2.48          |
# |    value_loss           | 6.52e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 153           |
# |    iterations           | 43            |
# |    time_elapsed         | 22360         |
# |    total_timesteps      | 3440000       |
# | train/                  |               |
# |    approx_kl            | 0.00033419032 |
# |    clip_fraction        | 0.000139      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.34         |
# |    explained_variance   | 7.75e-05      |
# |    learning_rate        | 0.000832      |
# |    loss                 | 3.26e+09      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | 8.14e-05      |
# |    std                  | 2.53          |
# |    value_loss           | 6.51e+09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | -1.89e+07    |
# | time/                   |              |
# |    fps                  | 154          |
# |    iterations           | 44           |
# |    time_elapsed         | 22783        |
# |    total_timesteps      | 3520000      |
# | train/                  |              |
# |    approx_kl            | 0.0003495522 |
# |    clip_fraction        | 0.000169     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.36        |
# |    explained_variance   | 8.15e-05     |
# |    learning_rate        | 0.000828     |
# |    loss                 | 3.25e+09     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 5.23e-05     |
# |    std                  | 2.58         |
# |    value_loss           | 6.52e+09     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -1.89e+07   |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 45          |
# |    time_elapsed         | 23208       |
# |    total_timesteps      | 3600000     |
# | train/                  |             |
# |    approx_kl            | 0.000339799 |
# |    clip_fraction        | 0.000177    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.38       |
# |    explained_variance   | 8.72e-05    |
# |    learning_rate        | 0.000824    |
# |    loss                 | 3.34e+09    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 5.76e-05    |
# |    std                  | 2.63        |
# |    value_loss           | 6.53e+09    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 155           |
# |    iterations           | 46            |
# |    time_elapsed         | 23632         |
# |    total_timesteps      | 3680000       |
# | train/                  |               |
# |    approx_kl            | 0.00034537815 |
# |    clip_fraction        | 0.000185      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.4          |
# |    explained_variance   | 8.45e-05      |
# |    learning_rate        | 0.00082       |
# |    loss                 | 3.27e+09      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | 5.19e-05      |
# |    std                  | 2.68          |
# |    value_loss           | 6.51e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 47            |
# |    time_elapsed         | 24056         |
# |    total_timesteps      | 3760000       |
# | train/                  |               |
# |    approx_kl            | 0.00036792527 |
# |    clip_fraction        | 0.000199      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.42         |
# |    explained_variance   | 8.92e-05      |
# |    learning_rate        | 0.000816      |
# |    loss                 | 3.34e+09      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -3.84e-05     |
# |    std                  | 2.74          |
# |    value_loss           | 6.52e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 156           |
# |    iterations           | 48            |
# |    time_elapsed         | 24479         |
# |    total_timesteps      | 3840000       |
# | train/                  |               |
# |    approx_kl            | 0.00032860745 |
# |    clip_fraction        | 0.00016       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.44         |
# |    explained_variance   | 9.24e-05      |
# |    learning_rate        | 0.000812      |
# |    loss                 | 3.32e+09      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | 2.57e-05      |
# |    std                  | 2.79          |
# |    value_loss           | 6.53e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 157           |
# |    iterations           | 49            |
# |    time_elapsed         | 24903         |
# |    total_timesteps      | 3920000       |
# | train/                  |               |
# |    approx_kl            | 0.00036346566 |
# |    clip_fraction        | 0.00024       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.45         |
# |    explained_variance   | 9.2e-05       |
# |    learning_rate        | 0.000808      |
# |    loss                 | 3.34e+09      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -4.98e-05     |
# |    std                  | 2.85          |
# |    value_loss           | 6.52e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 157           |
# |    iterations           | 50            |
# |    time_elapsed         | 25327         |
# |    total_timesteps      | 4000000       |
# | train/                  |               |
# |    approx_kl            | 0.00031698035 |
# |    clip_fraction        | 0.000112      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.47         |
# |    explained_variance   | 9.74e-05      |
# |    learning_rate        | 0.000804      |
# |    loss                 | 3.35e+09      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | 5.59e-05      |
# |    std                  | 2.9           |
# |    value_loss           | 6.53e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 4e+03         |
# |    ep_rew_mean          | -1.89e+07     |
# | time/                   |               |
# |    fps                  | 158           |
# |    iterations           | 51            |
# |    time_elapsed         | 25751         |
# |    total_timesteps      | 4080000       |
# | train/                  |               |
# |    approx_kl            | 0.00036094277 |
# |    clip_fraction        | 0.000248      |
# ...
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> # Train the agent
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> model.learn(total_timesteps=20000000,
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a>     callback=[
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a>         checkpoint_callback,
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a>         WandbCallback(
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a>             gradient_save_freq=10000,
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a>             model_save_path=f"models/ppocuadratico",
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a>             model_save_freq=10000,
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=13'>14</a>             verbose=2,
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=14'>15</a>         ),
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a>     ],
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a> )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\ppo\ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\on_policy_algorithm.py:259, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     256 assert self.env is not None
#     258 while self.num_timesteps < total_timesteps:
# --> 259     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     261     if continue_training is False:
#     262         break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\on_policy_algorithm.py:178, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     175 if isinstance(self.action_space, spaces.Box):
#     176     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 178 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     180 self.num_timesteps += env.num_envs
#     182 # Give access to local variables
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:197, in VecEnv.step(self, actions)
#     190 """
#     191 Step the environments with the given action
#     192
#     193 :param actions: the action
#     194 :return: observation, reward, done, information
#     195 """
#     196 self.step_async(actions)
# --> 197 return self.step_wait()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\PPO.ipynb Cell 7 line BobinaEnv.step(self, action)
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=137'>138</a> def step(self, action):
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=138'>139</a>   # Apply action
# --> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=139'>140</a>   self.state, self.crash = self.bobina.step(action[0])
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=140'>141</a>   self.airgap, self.velocidad, self.distancia, self.current = self.state
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=142'>143</a>   # Reduce the time of the experiment
#
# c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\PPO.ipynb Cell 7 line Bobina.step(self, target_voltage, verbose)
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=104'>105</a> def step(self, target_voltage, verbose = False):
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=105'>106</a>   # Calculate vertical force and current
# --> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=106'>107</a>   vertical_force, self.current = self.vertical_force(airgap = self.airgap, target_voltage = target_voltage, temperature = 40)
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=107'>108</a>   if verbose: print("Fuerza vertical: ", vertical_force)
#     <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=108'>109</a>   # Calculate next airgap and velocity
#
# c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\PPO.ipynb Cell 7 line Bobina.vertical_force(self, airgap, target_voltage, temperature)
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=48'>49</a> def vertical_force(self, airgap, target_voltage, temperature):
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=49'>50</a>   # Get current from RL circuit
# ---> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=50'>51</a>   I = self.RL(airgap = airgap, target_voltage = target_voltage, temperature = temperature)
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=52'>53</a>   # Clip result
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=53'>54</a>   if I > 45:
#
# c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\PPO.ipynb Cell 7 line Bobina.RL(self, airgap, target_voltage, temperature)
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=33'>34</a> V = target_voltage
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=34'>35</a> I = self.current
# ---> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=35'>36</a> L = self.L(airgap = airgap, current = self.current)
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=36'>37</a> dIdt = ((V/R) - I)/(L/R)
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=37'>38</a> self.steps_RL.append(dIdt)
#
# c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\PPO.ipynb Cell 7 line Bobina.L(self, airgap, current)
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=44'>45</a> def L(self, airgap, current):
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=45'>46</a>   # Return predicted inductance
# ---> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/PPO.ipynb#W3sZmlsZQ%3D%3D?line=46'>47</a>   return float(self.inductance.predict(np.array([[airgap, current]]))[0])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\ensemble\_forest.py:1004, in ForestRegressor.predict(self, X)
#    1002 # Parallel loop
#    1003 lock = threading.Lock()
# -> 1004 Parallel(n_jobs=n_jobs, verbose=self.verbose, require="sharedmem")(
#    1005     delayed(_accumulate_prediction)(e.predict, X, [y_hat], lock)
#    1006     for e in self.estimators_
#    1007 )
#    1009 y_hat /= len(self.estimators_)
#    1011 return y_hat
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\ensemble\_forest.py:664, in _accumulate_prediction(predict, X, out, lock)
#     657 def _accumulate_prediction(predict, X, out, lock):
#     658     """
#     659     This is a utility function for joblib's Parallel.
#     660
#     661     It can't go locally in ForestClassifier or ForestRegressor, because joblib
#     662     complains that it cannot pickle it when placed there.
#     663     """
# --> 664     prediction = predict(X, check_input=False)
#     665     with lock:
#     666         if len(out) == 1:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\tree\_classes.py:506, in BaseDecisionTree.predict(self, X, check_input)
#     504 check_is_fitted(self)
#     505 X = self._validate_X_predict(X, check_input)
# --> 506 proba = self.tree_.predict(X)
#     507 n_samples = X.shape[0]
#     509 # Classification
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
model.policy
# Out:
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (pi_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (vf_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=4, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=4, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=1, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
import numpy as np
import torch as th
import time

MODEL_PATH = f"models/ppocuadratico/model.zip"

# Create and wrap the environment
env = BobinaEnv(duration = 4)

# Load the trained agent
model = PPO.load(MODEL_PATH, env=env)

# Evaluate the agent
for i in range(5):
    obs, seed = env.reset()
    done = False
    episode_reward = 0
    velocidad = 0
    current = 0
    observations = []
    noises = []
    error = obs -19.5
    timepredict = 0
    timemodel = 0
    while not done:
        #noise = random.uniform(-1, 1)
        #obs = obs + noise
        observations.append(obs)
        #noises.append(noise)
        t1 = time.time()
        action, _states = model.predict(np.array([obs, velocidad, error, current]), deterministic=True)
        t2 = time.time()
        #print(action)
        #if env.airgap > 10.1: action = max(action, [-50])
        #print(action)
        t3 = time.time()
        state, reward, terminated, truncated, info = env.step(np.array(action))
        t4 = time.time()
        obs, velocidad, error, current = state
        done = truncated or terminated
        episode_reward += reward
        timepredict += t2 - t1
        timemodel += t4 - t3
        noises.append(action)
    print("Time predict", timepredict)
    print("Time model", timemodel)
    print("Episode reward", episode_reward)
    #print(noises)
    env.render("yes")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Time predict 2.038398504257202
# Time model 28.249844074249268
# Episode reward -345011.91880669864
# Time predict 2.0703630447387695
# Time model 28.64287042617798
# Episode reward -345011.91880669864
# Time predict 1.9565157890319824
# Time model 28.91672706604004
# Episode reward -345011.91880669864
# Time predict 2.0105221271514893
# Time model 28.061734914779663
# Episode reward -345011.91880669864
# Time predict 2.001551866531372
# Time model 27.71768879890442
# Episode reward -345011.91880669864
