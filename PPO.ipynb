# %%
from gymnasium import Env
from gymnasium.spaces.box import Box
import numpy as np
import random
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.noise import NormalActionNoise
import wandb
from wandb.integration.sb3 import WandbCallback
import os
import matplotlib.pyplot as plt
import scipy.io
import scipy
import numpy as np
import pickle
import warnings
import math
from typing import Callable
warnings.filterwarnings("ignore")

# %%
class Bobina():
  """ 
  Coil model for the Hybrid Electromagnetic Suspension
  """
  def __init__(self, masa_pod = 200, airgap = 23):
    self.masa_pod = masa_pod
    self.airgap = airgap
    self.aceleracion = []
    self.velocidad = []
    mat = scipy.io.loadmat('./coil/hems.mat')
    self.hems = mat["hems"][0][0]
    self.airgaps = self.hems[0][0]
    self.currents = self.hems[1][0]
    self.force_vertical = pickle.load(open("./coil/mlp_vertical.pkl", 'rb'))
    self.flux = self.hems[3]
    self.force_horizontal = self.hems[4]
    self.inductance = pickle.load(open("./coil/rf_inductance.pkl", 'rb'))
    self.resistance = self.hems[6][0][0]
    self.min_distance = self.airgaps[0]
    self.max_distance = self.airgaps[-1]
    self.airgapinicial = airgap
    self.crash = False
    self.current = 0
    self.steps_RL = []

  def integral(self, lista, h = 1):
    return sum(h*(lista[i]+lista[i+1])/2 for i in range(len(lista)-1))

  def RL(self, airgap, target_voltage, temperature):
    # Resistance-Inductance circuit

    # Get resistance of the coil
    R = self.R(current = self.current, temperature = temperature)   
    V = target_voltage
    I = self.current
    L = self.L(airgap = airgap, current = self.current)
    dIdt = ((V/R) - I)/(L/R)                                      
    self.steps_RL.append(dIdt)                                   
    current = self.integral(self.steps_RL, h = 0.001)                          
    return current                                                  

  def R(self, current, temperature):
    return self.resistance                                         

  def L(self, airgap, current):
    # Return predicted inductance
    return float(self.inductance.predict(np.array([[airgap, current]]))[0])

  def vertical_force(self, airgap, target_voltage, temperature):
    # Get current from RL circuit
    I = self.RL(airgap = airgap, target_voltage = target_voltage, temperature = temperature) 
    
    # Clip result
    if I > 45:
      I = 45
    elif I < -45:
      I = -45
    self.current = I
    # Get vertical force from 
    FI = self.FI_vertical(airgap = airgap, current = I)                    
    return FI, I


  def FI_vertical(self, airgap, current):
    # Return predicted vertical force
    return float(self.force_vertical.predict(np.array([[airgap, current]])))    


  def next_airgap(self, masa_pod, vertical_force, verbose = False):
    # Devide the mass of the pod by 4 coils
    masa = masa_pod/4  
    # Calculate weight
    peso = masa * 9.8    
    # Get total force                                                       
    fuerza = peso - vertical_force
    if verbose: print("Fuerza resultante: ", fuerza)   
    # Calculate acceleration                                     
    aceleracion = fuerza/masa
    if verbose: print("Aceleración: ", aceleracion)                                         
    self.aceleracion.append(aceleracion)       
    # Calculate velocity                                
    velocidad = self.integral(self.aceleracion, 0.001)
    if verbose: print("Integral primera (velocidad): ", velocidad)                          
    self.velocidad.append(velocidad)               
    # Calculate position (x1000 as to transform from m to mm)                            
    posicion = self.airgapinicial + self.integral(self.velocidad, 0.001)*1000 
    if verbose: print("Integral segunda (posición): ", posicion)

    # Clip position
    if posicion > self.max_distance:
      airgap = self.max_distance
      self.aceleracion = [0]
      self.velocidad = [0]  
      #self.crash = True     
      self.airgapinicial = self.max_distance                                               
    elif posicion < self.min_distance:
      airgap = self.min_distance
      self.aceleracion = [0]
      self.velocidad = [0]
      #self.crash = True
      self.airgapinicial = self.min_distance
    else: airgap = posicion
    return airgap, velocidad

  def step(self, target_voltage, verbose = False):
    # Calculate vertical force and current
    vertical_force, self.current = self.vertical_force(airgap = self.airgap, target_voltage = target_voltage, temperature = 40)
    if verbose: print("Fuerza vertical: ", vertical_force)
    # Calculate next airgap and velocity
    self.airgap, velocidad = self.next_airgap(self.masa_pod, vertical_force, verbose = verbose)
    #noise = np.random.normal(0,0.5)
    #self.airgap = self.airgap + noise     
    return (np.float32(self.airgap), np.float32(velocidad), np.float32(self.airgap - 19.5), np.float32(self.current)), self.crash
class BobinaEnv(Env):
  """
  Custom Gym Environment for the Hybrid Electromagnetic Suspension, considering just one coil.
  """
  def __init__(self, masa_pod = 200, airgap = 10, duration = 10):
    # Actions: Voltage applied to the coil
    self.action_space = Box(low=np.array([-100]), high = np.array([50]), dtype=np.float32)
    # Observations: Airgap to the ceiling, velocity, distance to the objective, current of the coil
    self.observation_space = Box(low=np.array([10, -np.inf, -10, -45]), high = np.array([23, np.inf, 10, 45]), dtype=np.float32)
    # Initial parameters
    self.state = np.array([airgap, 0, airgap - 19.5, 0])
    self.airgapinicial = airgap
    self.duration = duration
    self.timeleft = duration
    self.crash = False
    self.masa_pod = masa_pod
    self.bobina = Bobina(masa_pod = self.masa_pod, airgap = self.airgapinicial)
    self.steps = []
    self.airgap = airgap
    self.distancia = 0
    self.velocidad = 0
    self.current = 0


  def step(self, action):
    # Apply action
    self.state, self.crash = self.bobina.step(action[0])
    self.airgap, self.velocidad, self.distancia, self.current = self.state

    # Reduce the time of the experiment
    self.timeleft -= 0.001

    # Calculate reward
    reward = -abs(self.distancia)

    # Check if experiment is done
    if self.timeleft <= 0:
      truncated = True
    else: truncated = False
    # Set placeholder for info
    info = {}
    # Only if we implemented the crash
    if self.crash:
      reward = - 50000
      terminated = True
    else:
      terminated = False
    self.steps.append(self.state)
    return self.state, reward, terminated, truncated, info


  def render(self, yes = "yes"):
    # create data
    x = list(range(0,len(self.steps)))
    y = [step[0] for step in self.steps]
    objective = [19.5]*len(self.steps)

    # plot lines
    fig = plt.figure(figsize=(10,5))
    ax = fig.add_subplot(111)
    ax.tick_params(axis='x', colors='white')    #setting up X-axis tick color to red
    ax.tick_params(axis='y', colors='white')  #setting up Y-axis tick color to black

    plt.plot(x, y, label = "States")
    plt.plot(x, objective, label = "Objective")
    plt.legend()
    plt.show()

  def reset(self, seed = 0):
    # Reset experiment choosing randomly the start (ceiling or floor)
    airgap = random.choice([19.5])
    self.state = self.airgapinicial
    self.bobina = Bobina(masa_pod = self.masa_pod, airgap = airgap)
    # Reset time
    self.timeleft = self.duration
    self.crash = False
    self.steps = []
    return self.state, seed

# %%
run = wandb.init(
    project="1gdlppo",
    sync_tensorboard=True,
    monitor_gym=True,
)

# Create log dir
log_dir = "1gdlppo/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = BobinaEnv( airgap = 19.5,duration = 4 )
env = Monitor(env, log_dir)

def linear_schedule(initial_value: float) -> Callable[[float], float]:
    """
    Linear learning rate schedule.

    :param initial_value: Initial learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return progress_remaining * initial_value

    return func

model = PPO("MlpPolicy", env,learning_rate = linear_schedule(0.001), n_steps = 80000, batch_size=512, ent_coef=0.2, seed = 42, verbose=1, tensorboard_log=log_dir)
# Out:
# Finishing last run (ID:mvepdgy8) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▄▄▅▅▆▆▆▇▇█████</td></tr><tr><td>time/fps</td><td>████▇█▇▇▇▇▇▇▅▄▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂</td></tr><tr><td>train/approx_kl</td><td>▄▅▄▄▃▃▂▂▂▃▂▂▂▂▃▂▂▂▃▂▂█▂▁▁▁▁▁▁▁▁</td></tr><tr><td>train/clip_fraction</td><td>▇▇▇█▃▃▃▃▃▃▂▂▂▂▅▂▂▂▃▂▂█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/clip_range</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>██▇▇▆▆▆▆▅▅▅▅▄▄▄▄▄▃▃▃▃▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>train/explained_variance</td><td>▁▄▅▆██████████████████▇████████</td></tr><tr><td>train/learning_rate</td><td>███▇▇▇▇▆▆▆▆▅▅▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▁▁▁</td></tr><tr><td>train/loss</td><td>▇█▇▆▅▄▄▃▃▂▂▂▂▂▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/policy_gradient_loss</td><td>▇▇████▆▆▇█▄▄▅▅▇▄▄▄▆▄▄▆▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/std</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▃▃▃▅▅▆▆▇▇▇███</td></tr><tr><td>train/value_loss</td><td>██▇▆▅▄▄▃▃▂▃▂▂▂▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>1280000</td></tr><tr><td>rollout/ep_len_mean</td><td>4001.0</td></tr><tr><td>rollout/ep_rew_mean</td><td>-13804.10547</td></tr><tr><td>time/fps</td><td>184.0</td></tr><tr><td>train/approx_kl</td><td>1e-05</td></tr><tr><td>train/clip_fraction</td><td>0.0</td></tr><tr><td>train/clip_range</td><td>0.2</td></tr><tr><td>train/entropy_loss</td><td>-6.87877</td></tr><tr><td>train/explained_variance</td><td>0.99204</td></tr><tr><td>train/learning_rate</td><td>1e-05</td></tr><tr><td>train/loss</td><td>-1.20789</td></tr><tr><td>train/policy_gradient_loss</td><td>-0.0</td></tr><tr><td>train/std</td><td>235.47968</td></tr><tr><td>train/value_loss</td><td>2.89421</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">splendid-bird-7</strong> at: <a href='https://wandb.ai/hyperloopupv/1gdlppo/runs/mvepdgy8' target="_blank">https://wandb.ai/hyperloopupv/1gdlppo/runs/mvepdgy8</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20231210_010533-mvepdgy8\logs</code>
# Successfully finished last run (ID:mvepdgy8). Initializing new run:<br/>
# wandb version 0.16.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\wandb\run-20231210_122916-jv6kkwmv</code>
# Syncing run <strong><a href='https://wandb.ai/hyperloopupv/1gdlppo/runs/jv6kkwmv' target="_blank">giddy-fire-8</a></strong> to <a href='https://wandb.ai/hyperloopupv/1gdlppo' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hyperloopupv/1gdlppo' target="_blank">https://wandb.ai/hyperloopupv/1gdlppo</a>
#  View run at <a href='https://wandb.ai/hyperloopupv/1gdlppo/runs/jv6kkwmv' target="_blank">https://wandb.ai/hyperloopupv/1gdlppo/runs/jv6kkwmv</a>
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
# Create checkpoint callback
checkpoint_callback = CheckpointCallback(
    save_freq=10000, save_path=log_dir, name_prefix="rl_ppo_1gdlobj"
)

# Train the agent
model.learn(total_timesteps=2000000,
    callback=[
        checkpoint_callback,
        WandbCallback(
            gradient_save_freq=10000,
            model_save_path=f"models/{run.id}",
            model_save_freq=10000,
            verbose=2,
        ),
    ],
)
# Out:
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Logging to 1gdlppo/PPO_7
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -3.63e+04 |
# | time/              |           |
# |    fps             | 180       |
# |    iterations      | 1         |
# |    time_elapsed    | 442       |
# |    total_timesteps | 80000     |
# ----------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -3.63e+04  |
# | time/                   |            |
# |    fps                  | 179        |
# |    iterations           | 2          |
# |    time_elapsed         | 890        |
# |    total_timesteps      | 160000     |
# | train/                  |            |
# |    approx_kl            | 0.14227572 |
# |    clip_fraction        | 0.528      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.72      |
# |    explained_variance   | -0.00153   |
# |    learning_rate        | 0.00096    |
# |    loss                 | 1.37e+03   |
# |    n_updates            | 10         |
# |    policy_gradient_loss | 0.031      |
# |    std                  | 1.54       |
# |    value_loss           | 1.09e+04   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -3.63e+04  |
# | time/                   |            |
# |    fps                  | 163        |
# |    iterations           | 3          |
# |    time_elapsed         | 1471       |
# |    total_timesteps      | 240000     |
# | train/                  |            |
# |    approx_kl            | 0.11811881 |
# |    clip_fraction        | 0.486      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.12      |
# |    explained_variance   | 0.655      |
# |    learning_rate        | 0.00092    |
# |    loss                 | 1.11e+03   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | 0.0265     |
# |    std                  | 2.27       |
# |    value_loss           | 9.25e+03   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 4e+03     |
# |    ep_rew_mean          | -3.54e+04 |
# | time/                   |           |
# |    fps                  | 153       |
# |    iterations           | 4         |
# |    time_elapsed         | 2089      |
# |    total_timesteps      | 320000    |
# | train/                  |           |
# |    approx_kl            | 0.3075106 |
# |    clip_fraction        | 0.568     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.6      |
# |    explained_variance   | 0.842     |
# |    learning_rate        | 0.00088   |
# |    loss                 | 643       |
# |    n_updates            | 30        |
# |    policy_gradient_loss | 0.0391    |
# |    std                  | 5.03      |
# |    value_loss           | 6.91e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -3.44e+04  |
# | time/                   |            |
# |    fps                  | 148        |
# |    iterations           | 5          |
# |    time_elapsed         | 2684       |
# |    total_timesteps      | 400000     |
# | train/                  |            |
# |    approx_kl            | 0.04607726 |
# |    clip_fraction        | 0.259      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.24      |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.00084    |
# |    loss                 | 328        |
# |    n_updates            | 40         |
# |    policy_gradient_loss | 0.0204     |
# |    std                  | 6.35       |
# |    value_loss           | 4.32e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -3.38e+04   |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 6           |
# |    time_elapsed         | 3275        |
# |    total_timesteps      | 480000      |
# | train/                  |             |
# |    approx_kl            | 0.043214288 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0008      |
# |    loss                 | 112         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.0218      |
# |    std                  | 7.91        |
# |    value_loss           | 2.7e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -3.29e+04  |
# | time/                   |            |
# |    fps                  | 144        |
# |    iterations           | 7          |
# |    time_elapsed         | 3881       |
# |    total_timesteps      | 560000     |
# | train/                  |            |
# |    approx_kl            | 0.04420586 |
# |    clip_fraction        | 0.16       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.66      |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.00076    |
# |    loss                 | 71.2       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | 0.0182     |
# |    std                  | 9.96       |
# |    value_loss           | 2.15e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -3.07e+04  |
# | time/                   |            |
# |    fps                  | 143        |
# |    iterations           | 8          |
# |    time_elapsed         | 4471       |
# |    total_timesteps      | 640000     |
# | train/                  |            |
# |    approx_kl            | 0.04325536 |
# |    clip_fraction        | 0.118      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.89      |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.00072    |
# |    loss                 | 42.7       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | 0.0191     |
# |    std                  | 12.5       |
# |    value_loss           | 1.56e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -3.02e+04  |
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 9          |
# |    time_elapsed         | 5147       |
# |    total_timesteps      | 720000     |
# | train/                  |            |
# |    approx_kl            | 0.02673725 |
# |    clip_fraction        | 0.101      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.08      |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.00068    |
# |    loss                 | 35.6       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | 0.0153     |
# |    std                  | 14.8       |
# |    value_loss           | 721        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -2.98e+04  |
# | time/                   |            |
# |    fps                  | 138        |
# |    iterations           | 10         |
# |    time_elapsed         | 5770       |
# |    total_timesteps      | 800000     |
# | train/                  |            |
# |    approx_kl            | 0.04254654 |
# |    clip_fraction        | 0.109      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.27      |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.00064    |
# |    loss                 | 64.7       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | 0.0179     |
# |    std                  | 18.4       |
# |    value_loss           | 710        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -2.71e+04   |
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 11          |
# |    time_elapsed         | 6383        |
# |    total_timesteps      | 880000      |
# | train/                  |             |
# |    approx_kl            | 0.035894763 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.49       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0006      |
# |    loss                 | 39.9        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.018       |
# |    std                  | 22.5        |
# |    value_loss           | 521         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -2.51e+04   |
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 12          |
# |    time_elapsed         | 6993        |
# |    total_timesteps      | 960000      |
# | train/                  |             |
# |    approx_kl            | 0.046325404 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.72       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.00056     |
# |    loss                 | 34.1        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.0187      |
# |    std                  | 28.4        |
# |    value_loss           | 267         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -2.42e+04   |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 13          |
# |    time_elapsed         | 7598        |
# |    total_timesteps      | 1040000     |
# | train/                  |             |
# |    approx_kl            | 0.042701762 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.91       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.00052     |
# |    loss                 | 6.24        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.0134      |
# |    std                  | 35.6        |
# |    value_loss           | 199         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -2.12e+04   |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 14          |
# |    time_elapsed         | 8199        |
# |    total_timesteps      | 1120000     |
# | train/                  |             |
# |    approx_kl            | 0.043197315 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.16       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.00048     |
# |    loss                 | 0.316       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.017       |
# |    std                  | 44.7        |
# |    value_loss           | 120         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -1.83e+04  |
# | time/                   |            |
# |    fps                  | 136        |
# |    iterations           | 15         |
# |    time_elapsed         | 8809       |
# |    total_timesteps      | 1200000    |
# | train/                  |            |
# |    approx_kl            | 0.26876608 |
# |    clip_fraction        | 0.573      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.59      |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.00044    |
# |    loss                 | 0.972      |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.0268     |
# |    std                  | 87.5       |
# |    value_loss           | 39.5       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 4e+03     |
# |    ep_rew_mean          | -1.72e+04 |
# | time/                   |           |
# |    fps                  | 136       |
# |    iterations           | 16        |
# |    time_elapsed         | 9402      |
# |    total_timesteps      | 1280000   |
# | train/                  |           |
# |    approx_kl            | 0.1798131 |
# |    clip_fraction        | 0.457     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.17     |
# |    explained_variance   | 0.963     |
# |    learning_rate        | 0.0004    |
# |    loss                 | -1.15     |
# |    n_updates            | 150       |
# |    policy_gradient_loss | 0.0115    |
# |    std                  | 147       |
# |    value_loss           | 13.9      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -1.56e+04  |
# | time/                   |            |
# |    fps                  | 136        |
# |    iterations           | 17         |
# |    time_elapsed         | 9994       |
# |    total_timesteps      | 1360000    |
# | train/                  |            |
# |    approx_kl            | 0.13821681 |
# |    clip_fraction        | 0.393      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.65      |
# |    explained_variance   | 0.979      |
# |    learning_rate        | 0.00036    |
# |    loss                 | -0.907     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.00591    |
# |    std                  | 230        |
# |    value_loss           | 7.17       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -1.42e+04  |
# | time/                   |            |
# |    fps                  | 136        |
# |    iterations           | 18         |
# |    time_elapsed         | 10586      |
# |    total_timesteps      | 1440000    |
# | train/                  |            |
# |    approx_kl            | 0.07528973 |
# |    clip_fraction        | 0.2        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.02      |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.00032    |
# |    loss                 | -0.0134    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | 0.00445    |
# |    std                  | 317        |
# |    value_loss           | 3.91       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -1.38e+04   |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 19          |
# |    time_elapsed         | 11175       |
# |    total_timesteps      | 1520000     |
# | train/                  |             |
# |    approx_kl            | 0.046267357 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.3        |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.00028     |
# |    loss                 | -1.29       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00281     |
# |    std                  | 405         |
# |    value_loss           | 2.22        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -1.38e+04  |
# | time/                   |            |
# |    fps                  | 136        |
# |    iterations           | 20         |
# |    time_elapsed         | 11762      |
# |    total_timesteps      | 1600000    |
# | train/                  |            |
# |    approx_kl            | 0.03939151 |
# |    clip_fraction        | 0.0849     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.55      |
# |    explained_variance   | 0.987      |
# |    learning_rate        | 0.00024    |
# |    loss                 | -1.43      |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.00249    |
# |    std                  | 506        |
# |    value_loss           | 1.54       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -1.38e+04   |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 21          |
# |    time_elapsed         | 12350       |
# |    total_timesteps      | 1680000     |
# | train/                  |             |
# |    approx_kl            | 0.014322134 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.72       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -1.37       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00059     |
# |    std                  | 577         |
# |    value_loss           | 1.86        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4e+03      |
# |    ep_rew_mean          | -1.38e+04  |
# | time/                   |            |
# |    fps                  | 136        |
# |    iterations           | 22         |
# |    time_elapsed         | 12939      |
# |    total_timesteps      | 1760000    |
# | train/                  |            |
# |    approx_kl            | 0.00983598 |
# |    clip_fraction        | 0.0388     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.84      |
# |    explained_variance   | 0.989      |
# |    learning_rate        | 0.00016    |
# |    loss                 | -1.5       |
# |    n_updates            | 210        |
# |    policy_gradient_loss | 0.000654   |
# |    std                  | 643        |
# |    value_loss           | 1.28       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -1.38e+04   |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 23          |
# |    time_elapsed         | 13530       |
# |    total_timesteps      | 1840000     |
# | train/                  |             |
# |    approx_kl            | 0.008670992 |
# |    clip_fraction        | 0.0314      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.93       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.00012     |
# |    loss                 | -1.58       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00019     |
# |    std                  | 710         |
# |    value_loss           | 0.969       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4e+03       |
# |    ep_rew_mean          | -1.38e+04   |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 24          |
# |    time_elapsed         | 14121       |
# |    total_timesteps      | 1920000     |
# | train/                  |             |
# |    approx_kl            | 0.002152351 |
# |    clip_fraction        | 0.00669     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.01       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 8e-05       |
# |    loss                 | -1.58       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -3.41e-05   |
# |    std                  | 746         |
# |    value_loss           | 1.36        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4e+03        |
# |    ep_rew_mean          | -1.38e+04    |
# | time/                   |              |
# |    fps                  | 135          |
# |    iterations           | 25           |
# |    time_elapsed         | 14714        |
# |    total_timesteps      | 2000000      |
# | train/                  |              |
# |    approx_kl            | 0.0006165792 |
# |    clip_fraction        | 0.000653     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.05        |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 4e-05        |
# |    loss                 | -1.59        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -1.97e-05    |
# |    std                  | 766          |
# |    value_loss           | 1.8          |
# ------------------------------------------

# %%
import numpy as np
import torch as th
import time

MODEL_PATH = f"models/{run.id}/model.zip"

# Create and wrap the environment
env = BobinaEnv(duration = 4)

# Load the trained agent
model = PPO.load(MODEL_PATH, env=env)

# Evaluate the agent
for i in range(5):
    obs, seed = env.reset()
    done = False
    episode_reward = 0
    velocidad = 0
    current = 0
    observations = []
    noises = []
    error = obs -19.5
    timepredict = 0
    timemodel = 0
    while not done:
        #noise = random.uniform(-1, 1)
        #obs = obs + noise
        observations.append(obs)
        #noises.append(noise)
        t1 = time.time()
        action, _states = model.predict(np.array([obs, velocidad, error, current]), deterministic=True)
        t2 = time.time()
        #print(action)
        #if env.airgap > 10.1: action = max(action, [-50])
        #print(action)
        t3 = time.time()
        state, reward, terminated, truncated, info = env.step(np.array(action))
        t4 = time.time()
        obs, velocidad, error, current = state
        done = truncated or terminated
        episode_reward += reward
        timepredict += t2 - t1
        timemodel += t4 - t3
        noises.append(action)
    print("Time predict", timepredict)
    print("Time model", timemodel)
    print("Episode reward", episode_reward)
    #print(noises)
    env.render("yes")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Time predict 1.8906049728393555
# Time model 26.90673565864563
# Episode reward -37165.76989588367
# Time predict 1.8721048831939697
# Time model 26.801254987716675
# Episode reward -37165.76989588367
# Time predict 1.7903857231140137
# Time model 26.30690574645996
# Episode reward -37165.76989588367
# Time predict 1.7760982513427734
# Time model 26.29116702079773
# Episode reward -37165.76989588367
# Time predict 1.8437609672546387
# Time model 27.070508003234863
# Episode reward -37165.76989588367
