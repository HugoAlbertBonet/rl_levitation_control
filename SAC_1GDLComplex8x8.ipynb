# %%
from gymnasium import Env
from gymnasium.spaces.box import Box
import numpy as np
import random
from stable_baselines3 import SAC
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.noise import NormalActionNoise
import wandb
from wandb.integration.sb3 import WandbCallback
import os
import matplotlib.pyplot as plt
import scipy.io
import numpy as np
import pickle
import warnings
import math
warnings.filterwarnings("ignore")

# %%
class BobinaEnv(Env):
  """
  Custom Gym Environment for the Hybrid Electromagnetic Suspension, considering just one coil.
  """
  def __init__(self, masa_pod = 200, airgap = 10, duration = 10):
    # Actions: Voltage applied to the coil
    self.action_space = Box(low=np.array([-100]), high = np.array([50]), dtype=np.float32)
    # Observations: Airgap to the ceiling, velocity, distance to the objective, current of the coil
    self.observation_space = Box(low=np.array([10, -np.inf, -10, -45]), high = np.array([23, np.inf, 10, 45]), dtype=np.float32)
    # Initial parameters
    self.state = np.array([airgap, 0, airgap - 19.5, 0])
    self.airgapinicial = airgap
    self.duration = duration
    self.timeleft = duration
    self.crash = False
    self.masa_pod = masa_pod
    self.bobina = Bobina(masa_pod = self.masa_pod, airgap = self.airgapinicial)
    self.steps = []
    self.airgap = airgap
    self.distancia = 0
    self.velocidad = 0
    self.current = 0


  def step(self, action):
    # Apply action
    self.state, self.crash = self.bobina.step(action[0])
    self.airgap, self.velocidad, self.distancia, self.current = self.state

    # Reduce the time of the experiment
    self.timeleft -= 0.001

    # Calculate reward
    reward = -abs(self.distancia)

    # Check if experiment is done
    if self.timeleft <= 0:
      truncated = True
    else: truncated = False
    # Set placeholder for info
    info = {}
    # Only if we implemented the crash
    if self.crash:
      reward = - 50000
      terminated = True
    else:
      terminated = False
    self.steps.append(self.state)
    return self.state, reward, terminated, truncated, info


  def render(self, yes = "yes"):
    # create data
    x = list(range(0,len(self.steps)))
    y = [step[0] for step in self.steps]
    objective = [19.5]*len(self.steps)

    # plot lines
    fig = plt.figure(figsize=(10,5))
    ax = fig.add_subplot(111)
    ax.tick_params(axis='x', colors='white')    #setting up X-axis tick color to red
    ax.tick_params(axis='y', colors='white')  #setting up Y-axis tick color to black

    plt.plot(x, y, label = "States")
    plt.plot(x, objective, label = "Objective")
    plt.legend()
    plt.show()

  def reset(self, seed = 0):
    # Reset experiment choosing randomly the start (ceiling or floor)
    airgap = random.choice([10, 23])
    self.state = self.airgapinicial
    self.bobina = Bobina(masa_pod = self.masa_pod, airgap = airgap)
    # Reset time
    self.timeleft = self.duration
    self.crash = False
    self.steps = []
    return self.state, seed

# %%
class Bobina():
  """ 
  Coil model for the Hybrid Electromagnetic Suspension
  """
  def __init__(self, masa_pod = 200, airgap = 23):
    self.masa_pod = masa_pod
    self.airgap = airgap
    self.aceleracion = []
    self.velocidad = []
    mat = scipy.io.loadmat('./coil/hems.mat')
    self.hems = mat["hems"][0][0]
    self.airgaps = self.hems[0][0]
    self.currents = self.hems[1][0]
    self.force_vertical = pickle.load(open("./coil/mlp_vertical.pkl", 'rb'))
    self.flux = self.hems[3]
    self.force_horizontal = self.hems[4]
    self.inductance = pickle.load(open("./coil/rf_inductance.pkl", 'rb'))
    self.resistance = self.hems[6][0][0]
    self.min_distance = self.airgaps[0]
    self.max_distance = self.airgaps[-1]
    self.airgapinicial = airgap
    self.crash = False
    self.current = 0
    self.steps_RL = []

  def integral(self, lista, h = 1):
    return sum(h*(lista[i]+lista[i+1])/2 for i in range(len(lista)-1))

  def RL(self, airgap, target_voltage, temperature):
    # Resistance-Inductance circuit

    # Get resistance of the coil
    R = self.R(current = self.current, temperature = temperature)   
    V = target_voltage
    I = self.current
    L = self.L(airgap = airgap, current = self.current)
    dIdt = ((V/R) - I)/(L/R)                                      
    self.steps_RL.append(dIdt)                                   
    current = self.integral(self.steps_RL, h = 0.001)                          
    return current                                                  

  def R(self, current, temperature):
    return self.resistance                                         

  def L(self, airgap, current):
    # Return predicted inductance
    return float(self.inductance.predict(np.array([[airgap, current]]))[0])

  def vertical_force(self, airgap, target_voltage, temperature):
    # Get current from RL circuit
    I = self.RL(airgap = airgap, target_voltage = target_voltage, temperature = temperature) 
    
    # Clip result
    if I > 45:
      I = 45
    elif I < -45:
      I = -45
    self.current = I
    # Get vertical force from 
    FI = self.FI_vertical(airgap = airgap, current = I)                    
    return FI, I


  def FI_vertical(self, airgap, current):
    # Return predicted vertical force
    return float(self.force_vertical.predict(np.array([[airgap, current]])))    


  def next_airgap(self, masa_pod, vertical_force, verbose = False):
    # Devide the mass of the pod by 4 coils
    masa = masa_pod/4  
    # Calculate weight
    peso = masa * 9.8    
    # Get total force                                                       
    fuerza = peso - vertical_force
    if verbose: print("Fuerza resultante: ", fuerza)   
    # Calculate acceleration                                     
    aceleracion = fuerza/masa
    if verbose: print("Aceleración: ", aceleracion)                                         
    self.aceleracion.append(aceleracion)       
    # Calculate velocity                                
    velocidad = self.integral(self.aceleracion, 0.001)
    if verbose: print("Integral primera (velocidad): ", velocidad)                          
    self.velocidad.append(velocidad)               
    # Calculate position (x1000 as to transform from m to mm)                            
    posicion = self.airgapinicial + self.integral(self.velocidad, 0.001)*1000 
    if verbose: print("Integral segunda (posición): ", posicion)

    # Clip position
    if posicion > self.max_distance:
      airgap = self.max_distance
      self.aceleracion = [0]
      self.velocidad = [0]  
      #self.crash = True     
      self.airgapinicial = self.max_distance                                               
    elif posicion < self.min_distance:
      airgap = self.min_distance
      self.aceleracion = [0]
      self.velocidad = [0]
      #self.crash = True
      self.airgapinicial = self.min_distance
    else: airgap = posicion
    return airgap, velocidad

  def step(self, target_voltage, verbose = False):
    # Calculate vertical force and current
    vertical_force, self.current = self.vertical_force(airgap = self.airgap, target_voltage = target_voltage, temperature = 40)
    if verbose: print("Fuerza vertical: ", vertical_force)
    # Calculate next airgap and velocity
    self.airgap, velocidad = self.next_airgap(self.masa_pod, vertical_force, verbose = verbose)
    #noise = np.random.normal(0,0.5)
    #self.airgap = self.airgap + noise     
    return (np.float32(self.airgap), np.float32(velocidad), np.float32(self.airgap - 19.5), np.float32(self.current)), self.crash

# %%
run = wandb.init(
    project="1gdlcomplex",
    sync_tensorboard=True,
    monitor_gym=True,
)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: huguito (hyperloopupv). Use `wandb login --relogin` to force relogin
# wandb version 0.16.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\wandb\run-20231205_193107-o2bbuwlo</code>
# Syncing run <strong><a href='https://wandb.ai/hyperloopupv/1gdlcomplex/runs/o2bbuwlo' target="_blank">bright-mountain-51</a></strong> to <a href='https://wandb.ai/hyperloopupv/1gdlcomplex' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hyperloopupv/1gdlcomplex' target="_blank">https://wandb.ai/hyperloopupv/1gdlcomplex</a>
#  View run at <a href='https://wandb.ai/hyperloopupv/1gdlcomplex/runs/o2bbuwlo' target="_blank">https://wandb.ai/hyperloopupv/1gdlcomplex/runs/o2bbuwlo</a>

# %%
# Create log dir
log_dir = "1gdlcomplex/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = BobinaEnv( duration = 4 )
env = Monitor(env, log_dir)

# %%
from typing import Callable

def linear_schedule(initial_value: float) -> Callable[[float], float]:
    """
    Linear learning rate schedule.

    :param initial_value: Initial learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return progress_remaining * initial_value

    return func

# para el critic , qf=[400, 300], para el actor pi=[300, 200]
policy_kwargs = dict(net_arch=dict(pi=[8, 8], qf=[256, 256]))

model = SAC("MlpPolicy", env,learning_rate = linear_schedule(0.001),  policy_kwargs=policy_kwargs, verbose=1, tensorboard_log=log_dir)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
# Create checkpoint callback
checkpoint_callback = CheckpointCallback(
    save_freq=10000, save_path=log_dir, name_prefix="rl_sac_1gdlsimple"
)

# %%
# Train the agent
model.learn(total_timesteps=1250000,
    callback=[
        checkpoint_callback,
        WandbCallback(
            gradient_save_freq=10000,
            model_save_path=f"models/{run.id}",
            model_save_freq=10000,
            verbose=2,
        ),
    ],
)
# Out:
# Logging to 1gdlcomplex/SAC_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -1.4e+04 |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 58       |
# |    time_elapsed    | 274      |
# |    total_timesteps | 16004    |
# | train/             |          |
# |    actor_loss      | 192      |
# |    critic_loss     | 0.0399   |
# |    ent_coef        | 0.000208 |
# |    ent_coef_loss   | 1.82     |
# |    learning_rate   | 0.000987 |
# |    n_updates       | 15903    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -2e+04   |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 55       |
# |    time_elapsed    | 572      |
# |    total_timesteps | 32008    |
# | train/             |          |
# |    actor_loss      | 301      |
# |    critic_loss     | 0.00417  |
# |    ent_coef        | 0.00014  |
# |    ent_coef_loss   | -0.315   |
# |    learning_rate   | 0.000974 |
# |    n_updates       | 31907    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.39e+04 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 55        |
# |    time_elapsed    | 865       |
# |    total_timesteps | 48012     |
# | train/             |           |
# |    actor_loss      | 468       |
# |    critic_loss     | 0.308     |
# |    ent_coef        | 0.0124    |
# |    ent_coef_loss   | -0.287    |
# |    learning_rate   | 0.000962  |
# |    n_updates       | 47911     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.64e+04 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 54        |
# |    time_elapsed    | 1170      |
# |    total_timesteps | 64016     |
# | train/             |           |
# |    actor_loss      | 587       |
# |    critic_loss     | 1.66      |
# |    ent_coef        | 0.00858   |
# |    ent_coef_loss   | 2.9       |
# |    learning_rate   | 0.000949  |
# |    n_updates       | 63915     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.41e+04 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 53        |
# |    time_elapsed    | 1499      |
# |    total_timesteps | 80020     |
# | train/             |           |
# |    actor_loss      | 517       |
# |    critic_loss     | 0.788     |
# |    ent_coef        | 0.0723    |
# |    ent_coef_loss   | -0.0126   |
# |    learning_rate   | 0.000936  |
# |    n_updates       | 79919     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.24e+04 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 52        |
# |    time_elapsed    | 1839      |
# |    total_timesteps | 96024     |
# | train/             |           |
# |    actor_loss      | 477       |
# |    critic_loss     | 0.509     |
# |    ent_coef        | 0.0466    |
# |    ent_coef_loss   | -0.936    |
# |    learning_rate   | 0.000923  |
# |    n_updates       | 95923     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.11e+04 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 51        |
# |    time_elapsed    | 2176      |
# |    total_timesteps | 112028    |
# | train/             |           |
# |    actor_loss      | 444       |
# |    critic_loss     | 9.75      |
# |    ent_coef        | 0.0503    |
# |    ent_coef_loss   | -1.13     |
# |    learning_rate   | 0.00091   |
# |    n_updates       | 111927    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.99e+04 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 51        |
# |    time_elapsed    | 2504      |
# |    total_timesteps | 128032    |
# | train/             |           |
# |    actor_loss      | 422       |
# |    critic_loss     | 1.27      |
# |    ent_coef        | 0.138     |
# |    ent_coef_loss   | 0.57      |
# |    learning_rate   | 0.000898  |
# |    n_updates       | 127931    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.86e+04 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 50        |
# |    time_elapsed    | 2833      |
# |    total_timesteps | 144036    |
# | train/             |           |
# |    actor_loss      | 405       |
# |    critic_loss     | 1.58      |
# |    ent_coef        | 0.152     |
# |    ent_coef_loss   | 0.0448    |
# |    learning_rate   | 0.000885  |
# |    n_updates       | 143935    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.75e+04 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 50        |
# |    time_elapsed    | 3170      |
# |    total_timesteps | 160040    |
# | train/             |           |
# |    actor_loss      | 367       |
# |    critic_loss     | 1.99      |
# |    ent_coef        | 0.173     |
# |    ent_coef_loss   | -0.327    |
# |    learning_rate   | 0.000872  |
# |    n_updates       | 159939    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.64e+04 |
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 50        |
# |    time_elapsed    | 3516      |
# |    total_timesteps | 176044    |
# | train/             |           |
# |    actor_loss      | 355       |
# |    critic_loss     | 1.26      |
# |    ent_coef        | 0.22      |
# |    ent_coef_loss   | 0.136     |
# |    learning_rate   | 0.000859  |
# |    n_updates       | 175943    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.51e+04 |
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 49        |
# |    time_elapsed    | 3869      |
# |    total_timesteps | 192048    |
# | train/             |           |
# |    actor_loss      | 327       |
# |    critic_loss     | 5.4       |
# |    ent_coef        | 0.263     |
# |    ent_coef_loss   | 0.0668    |
# |    learning_rate   | 0.000846  |
# |    n_updates       | 191947    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.41e+04 |
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 49        |
# |    time_elapsed    | 4223      |
# |    total_timesteps | 208052    |
# | train/             |           |
# |    actor_loss      | 281       |
# |    critic_loss     | 1.8       |
# |    ent_coef        | 0.269     |
# |    ent_coef_loss   | 0.13      |
# |    learning_rate   | 0.000834  |
# |    n_updates       | 207951    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.32e+04 |
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 49        |
# |    time_elapsed    | 4563      |
# |    total_timesteps | 224056    |
# | train/             |           |
# |    actor_loss      | 255       |
# |    critic_loss     | 2.4       |
# |    ent_coef        | 0.234     |
# |    ent_coef_loss   | 0.223     |
# |    learning_rate   | 0.000821  |
# |    n_updates       | 223955    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.24e+04 |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 48        |
# |    time_elapsed    | 4902      |
# |    total_timesteps | 240060    |
# | train/             |           |
# |    actor_loss      | 216       |
# |    critic_loss     | 222       |
# |    ent_coef        | 0.225     |
# |    ent_coef_loss   | -0.135    |
# |    learning_rate   | 0.000808  |
# |    n_updates       | 239959    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.17e+04 |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 48        |
# |    time_elapsed    | 5251      |
# |    total_timesteps | 256064    |
# | train/             |           |
# |    actor_loss      | 225       |
# |    critic_loss     | 1.46      |
# |    ent_coef        | 0.208     |
# |    ent_coef_loss   | 0.0939    |
# |    learning_rate   | 0.000795  |
# |    n_updates       | 255963    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.11e+04 |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 48        |
# |    time_elapsed    | 5601      |
# |    total_timesteps | 272068    |
# | train/             |           |
# |    actor_loss      | 197       |
# |    critic_loss     | 2.22      |
# |    ent_coef        | 0.166     |
# |    ent_coef_loss   | -0.292    |
# |    learning_rate   | 0.000782  |
# |    n_updates       | 271967    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.06e+04 |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 48        |
# |    time_elapsed    | 5945      |
# |    total_timesteps | 288072    |
# | train/             |           |
# |    actor_loss      | 187       |
# |    critic_loss     | 2.8       |
# |    ent_coef        | 0.143     |
# |    ent_coef_loss   | 0.194     |
# |    learning_rate   | 0.00077   |
# |    n_updates       | 287971    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.01e+04 |
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 48        |
# |    time_elapsed    | 6282      |
# |    total_timesteps | 304076    |
# | train/             |           |
# |    actor_loss      | 184       |
# |    critic_loss     | 2.1       |
# |    ent_coef        | 0.122     |
# |    ent_coef_loss   | -0.131    |
# |    learning_rate   | 0.000757  |
# |    n_updates       | 303975    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -9.65e+03 |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 48        |
# |    time_elapsed    | 6619      |
# |    total_timesteps | 320080    |
# | train/             |           |
# |    actor_loss      | 167       |
# |    critic_loss     | 1.15      |
# |    ent_coef        | 0.108     |
# |    ent_coef_loss   | 0.492     |
# |    learning_rate   | 0.000744  |
# |    n_updates       | 319979    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -9.25e+03 |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 48        |
# |    time_elapsed    | 6954      |
# |    total_timesteps | 336084    |
# | train/             |           |
# |    actor_loss      | 147       |
# |    critic_loss     | 1.32      |
# |    ent_coef        | 0.0922    |
# |    ent_coef_loss   | -0.103    |
# |    learning_rate   | 0.000731  |
# |    n_updates       | 335983    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -8.87e+03 |
# | time/              |           |
# |    episodes        | 88        |
# |    fps             | 48        |
# |    time_elapsed    | 7290      |
# |    total_timesteps | 352088    |
# | train/             |           |
# |    actor_loss      | 134       |
# |    critic_loss     | 2.49      |
# |    ent_coef        | 0.0884    |
# |    ent_coef_loss   | 0.215     |
# |    learning_rate   | 0.000718  |
# |    n_updates       | 351987    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -8.55e+03 |
# | time/              |           |
# |    episodes        | 92        |
# |    fps             | 48        |
# |    time_elapsed    | 7641      |
# |    total_timesteps | 368092    |
# | train/             |           |
# |    actor_loss      | 136       |
# |    critic_loss     | 0.729     |
# |    ent_coef        | 0.0774    |
# |    ent_coef_loss   | -0.0377   |
# |    learning_rate   | 0.000706  |
# |    n_updates       | 367991    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -8.25e+03 |
# | time/              |           |
# |    episodes        | 96        |
# |    fps             | 48        |
# |    time_elapsed    | 7997      |
# |    total_timesteps | 384096    |
# | train/             |           |
# |    actor_loss      | 146       |
# |    critic_loss     | 0.941     |
# |    ent_coef        | 0.0749    |
# |    ent_coef_loss   | 0.137     |
# |    learning_rate   | 0.000693  |
# |    n_updates       | 383995    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -7.97e+03 |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 47        |
# |    time_elapsed    | 8338      |
# |    total_timesteps | 400100    |
# | train/             |           |
# |    actor_loss      | 133       |
# |    critic_loss     | 0.909     |
# |    ent_coef        | 0.0674    |
# |    ent_coef_loss   | 0.459     |
# |    learning_rate   | 0.00068   |
# |    n_updates       | 399999    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -7.45e+03 |
# | time/              |           |
# |    episodes        | 104       |
# |    fps             | 47        |
# |    time_elapsed    | 8693      |
# |    total_timesteps | 416104    |
# | train/             |           |
# |    actor_loss      | 135       |
# |    critic_loss     | 1.15      |
# |    ent_coef        | 0.0606    |
# |    ent_coef_loss   | -0.105    |
# |    learning_rate   | 0.000667  |
# |    n_updates       | 416003    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -6.46e+03 |
# | time/              |           |
# |    episodes        | 108       |
# |    fps             | 47        |
# |    time_elapsed    | 9044      |
# |    total_timesteps | 432108    |
# | train/             |           |
# |    actor_loss      | 128       |
# |    critic_loss     | 0.499     |
# |    ent_coef        | 0.0495    |
# |    ent_coef_loss   | 0.667     |
# |    learning_rate   | 0.000654  |
# |    n_updates       | 432007    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -5.22e+03 |
# | time/              |           |
# |    episodes        | 112       |
# |    fps             | 47        |
# |    time_elapsed    | 9383      |
# |    total_timesteps | 448112    |
# | train/             |           |
# |    actor_loss      | 118       |
# |    critic_loss     | 0.996     |
# |    ent_coef        | 0.0553    |
# |    ent_coef_loss   | -0.218    |
# |    learning_rate   | 0.000642  |
# |    n_updates       | 448011    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -3.94e+03 |
# | time/              |           |
# |    episodes        | 116       |
# |    fps             | 47        |
# |    time_elapsed    | 9724      |
# |    total_timesteps | 464116    |
# | train/             |           |
# |    actor_loss      | 109       |
# |    critic_loss     | 0.689     |
# |    ent_coef        | 0.0504    |
# |    ent_coef_loss   | -0.0609   |
# |    learning_rate   | 0.000629  |
# |    n_updates       | 464015    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -3.38e+03 |
# | time/              |           |
# |    episodes        | 120       |
# |    fps             | 47        |
# |    time_elapsed    | 10067     |
# |    total_timesteps | 480120    |
# | train/             |           |
# |    actor_loss      | 113       |
# |    critic_loss     | 0.787     |
# |    ent_coef        | 0.0394    |
# |    ent_coef_loss   | -0.0267   |
# |    learning_rate   | 0.000616  |
# |    n_updates       | 480019    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.85e+03 |
# | time/              |           |
# |    episodes        | 124       |
# |    fps             | 47        |
# |    time_elapsed    | 10409     |
# |    total_timesteps | 496124    |
# | train/             |           |
# |    actor_loss      | 122       |
# |    critic_loss     | 0.532     |
# |    ent_coef        | 0.039     |
# |    ent_coef_loss   | 0.227     |
# |    learning_rate   | 0.000603  |
# |    n_updates       | 496023    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.35e+03 |
# | time/              |           |
# |    episodes        | 128       |
# |    fps             | 47        |
# |    time_elapsed    | 10737     |
# |    total_timesteps | 512128    |
# | train/             |           |
# |    actor_loss      | 100       |
# |    critic_loss     | 0.548     |
# |    ent_coef        | 0.0354    |
# |    ent_coef_loss   | 0.405     |
# |    learning_rate   | 0.00059   |
# |    n_updates       | 512027    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.92e+03 |
# | time/              |           |
# |    episodes        | 132       |
# |    fps             | 47        |
# |    time_elapsed    | 11086     |
# |    total_timesteps | 528132    |
# | train/             |           |
# |    actor_loss      | 107       |
# |    critic_loss     | 0.622     |
# |    ent_coef        | 0.0361    |
# |    ent_coef_loss   | 0.429     |
# |    learning_rate   | 0.000577  |
# |    n_updates       | 528031    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.62e+03 |
# | time/              |           |
# |    episodes        | 136       |
# |    fps             | 47        |
# |    time_elapsed    | 11445     |
# |    total_timesteps | 544136    |
# | train/             |           |
# |    actor_loss      | 77.6      |
# |    critic_loss     | 0.586     |
# |    ent_coef        | 0.0368    |
# |    ent_coef_loss   | -0.673    |
# |    learning_rate   | 0.000565  |
# |    n_updates       | 544035    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.35e+03 |
# | time/              |           |
# |    episodes        | 140       |
# |    fps             | 47        |
# |    time_elapsed    | 11803     |
# |    total_timesteps | 560140    |
# | train/             |           |
# |    actor_loss      | 90.5      |
# |    critic_loss     | 0.44      |
# |    ent_coef        | 0.0327    |
# |    ent_coef_loss   | -0.339    |
# |    learning_rate   | 0.000552  |
# |    n_updates       | 560039    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 144       |
# |    fps             | 47        |
# |    time_elapsed    | 12153     |
# |    total_timesteps | 576144    |
# | train/             |           |
# |    actor_loss      | 88.2      |
# |    critic_loss     | 0.756     |
# |    ent_coef        | 0.0321    |
# |    ent_coef_loss   | -0.327    |
# |    learning_rate   | 0.000539  |
# |    n_updates       | 576043    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 148       |
# |    fps             | 47        |
# |    time_elapsed    | 12513     |
# |    total_timesteps | 592148    |
# | train/             |           |
# |    actor_loss      | 93.3      |
# |    critic_loss     | 2.62      |
# |    ent_coef        | 0.0336    |
# |    ent_coef_loss   | -0.205    |
# |    learning_rate   | 0.000526  |
# |    n_updates       | 592047    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.14e+03 |
# | time/              |           |
# |    episodes        | 152       |
# |    fps             | 47        |
# |    time_elapsed    | 12870     |
# |    total_timesteps | 608152    |
# | train/             |           |
# |    actor_loss      | 84.5      |
# |    critic_loss     | 0.408     |
# |    ent_coef        | 0.0372    |
# |    ent_coef_loss   | -0.579    |
# |    learning_rate   | 0.000513  |
# |    n_updates       | 608051    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.12e+03 |
# | time/              |           |
# |    episodes        | 156       |
# |    fps             | 47        |
# |    time_elapsed    | 13227     |
# |    total_timesteps | 624156    |
# | train/             |           |
# |    actor_loss      | 85.6      |
# |    critic_loss     | 0.43      |
# |    ent_coef        | 0.036     |
# |    ent_coef_loss   | 0.0959    |
# |    learning_rate   | 0.000501  |
# |    n_updates       | 624055    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.08e+03 |
# | time/              |           |
# |    episodes        | 160       |
# |    fps             | 47        |
# |    time_elapsed    | 13585     |
# |    total_timesteps | 640160    |
# | train/             |           |
# |    actor_loss      | 81.5      |
# |    critic_loss     | 0.443     |
# |    ent_coef        | 0.032     |
# |    ent_coef_loss   | -0.35     |
# |    learning_rate   | 0.000488  |
# |    n_updates       | 640059    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.05e+03 |
# | time/              |           |
# |    episodes        | 164       |
# |    fps             | 47        |
# |    time_elapsed    | 13940     |
# |    total_timesteps | 656164    |
# | train/             |           |
# |    actor_loss      | 90.1      |
# |    critic_loss     | 0.737     |
# |    ent_coef        | 0.0353    |
# |    ent_coef_loss   | 0.142     |
# |    learning_rate   | 0.000475  |
# |    n_updates       | 656063    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.02e+03 |
# | time/              |           |
# |    episodes        | 168       |
# |    fps             | 47        |
# |    time_elapsed    | 14284     |
# |    total_timesteps | 672168    |
# | train/             |           |
# |    actor_loss      | 82.1      |
# |    critic_loss     | 0.843     |
# |    ent_coef        | 0.0289    |
# |    ent_coef_loss   | 0.689     |
# |    learning_rate   | 0.000462  |
# |    n_updates       | 672067    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -996     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 47       |
# |    time_elapsed    | 14625    |
# |    total_timesteps | 688172   |
# | train/             |          |
# |    actor_loss      | 86.2     |
# |    critic_loss     | 0.607    |
# |    ent_coef        | 0.0296   |
# |    ent_coef_loss   | 0.405    |
# |    learning_rate   | 0.000449 |
# |    n_updates       | 688071   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -961     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 47       |
# |    time_elapsed    | 14976    |
# |    total_timesteps | 704176   |
# | train/             |          |
# |    actor_loss      | 86.4     |
# |    critic_loss     | 1.01     |
# |    ent_coef        | 0.0255   |
# |    ent_coef_loss   | 1.08     |
# |    learning_rate   | 0.000437 |
# |    n_updates       | 704075   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -926     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 46       |
# |    time_elapsed    | 15344    |
# |    total_timesteps | 720180   |
# | train/             |          |
# |    actor_loss      | 89.1     |
# |    critic_loss     | 0.891    |
# |    ent_coef        | 0.0263   |
# |    ent_coef_loss   | 0.0391   |
# |    learning_rate   | 0.000424 |
# |    n_updates       | 720079   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -903     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 46       |
# |    time_elapsed    | 15705    |
# |    total_timesteps | 736184   |
# | train/             |          |
# |    actor_loss      | 64.4     |
# |    critic_loss     | 0.472    |
# |    ent_coef        | 0.0286   |
# |    ent_coef_loss   | 0.134    |
# |    learning_rate   | 0.000411 |
# |    n_updates       | 736083   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -877     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 46       |
# |    time_elapsed    | 16067    |
# |    total_timesteps | 752188   |
# | train/             |          |
# |    actor_loss      | 78       |
# |    critic_loss     | 0.428    |
# |    ent_coef        | 0.0297   |
# |    ent_coef_loss   | -0.087   |
# |    learning_rate   | 0.000398 |
# |    n_updates       | 752087   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -855     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 46       |
# |    time_elapsed    | 16434    |
# |    total_timesteps | 768192   |
# | train/             |          |
# |    actor_loss      | 64.3     |
# |    critic_loss     | 0.226    |
# |    ent_coef        | 0.0245   |
# |    ent_coef_loss   | -0.153   |
# |    learning_rate   | 0.000385 |
# |    n_updates       | 768091   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -824     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 46       |
# |    time_elapsed    | 16786    |
# |    total_timesteps | 784196   |
# | train/             |          |
# |    actor_loss      | 65.3     |
# |    critic_loss     | 0.693    |
# |    ent_coef        | 0.0262   |
# |    ent_coef_loss   | -0.15    |
# |    learning_rate   | 0.000373 |
# |    n_updates       | 784095   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -801     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 46       |
# |    time_elapsed    | 17137    |
# |    total_timesteps | 800200   |
# | train/             |          |
# |    actor_loss      | 58.7     |
# |    critic_loss     | 0.425    |
# |    ent_coef        | 0.0254   |
# |    ent_coef_loss   | 0.315    |
# |    learning_rate   | 0.00036  |
# |    n_updates       | 800099   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -807     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 46       |
# |    time_elapsed    | 17485    |
# |    total_timesteps | 816204   |
# | train/             |          |
# |    actor_loss      | 69       |
# |    critic_loss     | 0.279    |
# |    ent_coef        | 0.0272   |
# |    ent_coef_loss   | 0.188    |
# |    learning_rate   | 0.000347 |
# |    n_updates       | 816103   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -782     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 46       |
# |    time_elapsed    | 17834    |
# |    total_timesteps | 832208   |
# | train/             |          |
# |    actor_loss      | 60.3     |
# |    critic_loss     | 0.166    |
# |    ent_coef        | 0.0261   |
# |    ent_coef_loss   | -0.904   |
# |    learning_rate   | 0.000334 |
# |    n_updates       | 832107   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -764     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 46       |
# |    time_elapsed    | 18182    |
# |    total_timesteps | 848212   |
# | train/             |          |
# |    actor_loss      | 61.5     |
# |    critic_loss     | 0.355    |
# |    ent_coef        | 0.0233   |
# |    ent_coef_loss   | -0.00746 |
# |    learning_rate   | 0.000321 |
# |    n_updates       | 848111   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -712     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 46       |
# |    time_elapsed    | 18550    |
# |    total_timesteps | 864216   |
# | train/             |          |
# |    actor_loss      | 72.3     |
# |    critic_loss     | 0.416    |
# |    ent_coef        | 0.0225   |
# |    ent_coef_loss   | 0.387    |
# |    learning_rate   | 0.000309 |
# |    n_updates       | 864115   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -693     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 46       |
# |    time_elapsed    | 18919    |
# |    total_timesteps | 880220   |
# | train/             |          |
# |    actor_loss      | 41.8     |
# |    critic_loss     | 0.356    |
# |    ent_coef        | 0.019    |
# |    ent_coef_loss   | 0.0916   |
# |    learning_rate   | 0.000296 |
# |    n_updates       | 880119   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -671     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 46       |
# |    time_elapsed    | 19279    |
# |    total_timesteps | 896224   |
# | train/             |          |
# |    actor_loss      | 69       |
# |    critic_loss     | 0.204    |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | 0.552    |
# |    learning_rate   | 0.000283 |
# |    n_updates       | 896123   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -662     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 46       |
# |    time_elapsed    | 19639    |
# |    total_timesteps | 912228   |
# | train/             |          |
# |    actor_loss      | 61       |
# |    critic_loss     | 0.343    |
# |    ent_coef        | 0.0196   |
# |    ent_coef_loss   | 0.381    |
# |    learning_rate   | 0.00027  |
# |    n_updates       | 912127   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -664     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 46       |
# |    time_elapsed    | 20006    |
# |    total_timesteps | 928232   |
# | train/             |          |
# |    actor_loss      | 49.6     |
# |    critic_loss     | 0.372    |
# |    ent_coef        | 0.0182   |
# |    ent_coef_loss   | -0.0866  |
# |    learning_rate   | 0.000257 |
# |    n_updates       | 928131   |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\SAC_1GDLComplex8x8.ipynb Cell 8 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> # Train the agent
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> model.learn(total_timesteps=1250000,
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a>     callback=[
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a>         checkpoint_callback,
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a>         WandbCallback(
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8.ipynb#X22sZmlsZQ%3D%3D?line=5'>6</a>             gradient_save_freq=10000,
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8.ipynb#X22sZmlsZQ%3D%3D?line=6'>7</a>             model_save_path=f"models/{run.id}",
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8.ipynb#X22sZmlsZQ%3D%3D?line=7'>8</a>             model_save_freq=10000,
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8.ipynb#X22sZmlsZQ%3D%3D?line=8'>9</a>             verbose=2,
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8.ipynb#X22sZmlsZQ%3D%3D?line=9'>10</a>         ),
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8.ipynb#X22sZmlsZQ%3D%3D?line=10'>11</a>     ],
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8.ipynb#X22sZmlsZQ%3D%3D?line=11'>12</a> )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\sac\sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\off_policy_algorithm.py:331, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     329         # Special case when the user passes `gradient_steps=0`
#     330         if gradient_steps > 0:
# --> 331             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     333 callback.on_training_end()
#     335 return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\sac\sac.py:281, in SAC.train(self, gradient_steps, batch_size)
#     279 self.actor.optimizer.zero_grad()
#     280 actor_loss.backward()
# --> 281 self.actor.optimizer.step()
#     283 # Update target networks
#     284 if gradient_step % self.target_update_interval == 0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\optim\optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\optim\optimizer.py:33, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      31 try:
#      32     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 33     ret = func(self, *args, **kwargs)
#      34 finally:
#      35     torch.set_grad_enabled(prev_grad)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\optim\adam.py:141, in Adam.step(self, closure)
#     130     beta1, beta2 = group['betas']
#     132     self._init_group(
#     133         group,
#     134         params_with_grad,
#    (...)
#     138         max_exp_avg_sqs,
#     139         state_steps)
# --> 141     adam(
#     142         params_with_grad,
#     143         grads,
#     144         exp_avgs,
#     145         exp_avg_sqs,
#     146         max_exp_avg_sqs,
#     147         state_steps,
#     148         amsgrad=group['amsgrad'],
#     149         beta1=beta1,
#     150         beta2=beta2,
#     151         lr=group['lr'],
#     152         weight_decay=group['weight_decay'],
#     153         eps=group['eps'],
#     154         maximize=group['maximize'],
#     155         foreach=group['foreach'],
#     156         capturable=group['capturable'],
#     157         differentiable=group['differentiable'],
#     158         fused=group['fused'],
#     159         grad_scale=getattr(self, "grad_scale", None),
#     160         found_inf=getattr(self, "found_inf", None),
#     161     )
#     163 return loss
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\optim\adam.py:281, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     278 else:
#     279     func = _single_tensor_adam
# --> 281 func(params,
#     282      grads,
#     283      exp_avgs,
#     284      exp_avg_sqs,
#     285      max_exp_avg_sqs,
#     286      state_steps,
#     287      amsgrad=amsgrad,
#     288      beta1=beta1,
#     289      beta2=beta2,
#     290      lr=lr,
#     291      weight_decay=weight_decay,
#     292      eps=eps,
#     293      maximize=maximize,
#     294      capturable=capturable,
#     295      differentiable=differentiable,
#     296      grad_scale=grad_scale,
#     297      found_inf=found_inf)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\optim\adam.py:332, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     329     assert param.is_cuda and step_t.is_cuda, "If capturable=True, params and state_steps must be CUDA tensors."
#     331 # update step
# --> 332 step_t += 1
#     334 if weight_decay != 0:
#     335     grad = grad.add(param, alpha=weight_decay)
#
# KeyboardInterrupt:

# %%
episodes = 3
state, seed = env.reset()
for episode in range(1, episodes+1):
    state, seed = env.reset()
    done = False
    score = 0
    while not done:
        action = env.action_space.sample()
        n_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))

# %%
import numpy as np
import torch as th
import time

MODEL_PATH = f"models/{run.id}/model.zip"

# Create and wrap the environment
env = BobinaEnv(duration = 4)

# Load the trained agent
model = SAC.load(MODEL_PATH, env=env)

# Evaluate the agent
for i in range(5):
    obs, seed = env.reset()
    done = False
    episode_reward = 0
    velocidad = 0
    current = 0
    observations = []
    noises = []
    error = obs -19.5
    timepredict = 0
    timemodel = 0
    while not done:
        #noise = random.uniform(-1, 1)
        #obs = obs + noise
        observations.append(obs)
        #noises.append(noise)
        t1 = time.time()
        action, _states = model.predict(np.array([obs, velocidad, error, current]), deterministic=True)
        t2 = time.time()
        #print(action)
        #if env.airgap > 10.1: action = max(action, [-50])
        #print(action)
        t3 = time.time()
        state, reward, terminated, truncated, info = env.step(np.array(action))
        t4 = time.time()
        obs, velocidad, error, current = state
        done = truncated or terminated
        episode_reward += reward
        timepredict += t2 - t1
        timemodel += t4 - t3
        noises.append(action)
    print("Time predict", timepredict)
    print("Time model", timemodel)
    print("Episode reward", episode_reward)
    print(noises)
    env.render("yes")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Time predict 1.7971992492675781
# Time model 22.776419639587402
# Episode reward -316.7213057948975
type=float32), array([-14.642838], dtype=float32), array([-12.988846], dtype=float32), array([-10.3400345], dtype=float32), array([-8.578423], dtype=float32), array([-4.3432007], dtype=float32), array([1.6576691], dtype=float32), array([1.0997162], dtype=float32), array([-2.7849274], dtype=float32), array([-2.8328857], dtype=float32), array([0.8121872], dtype=float32), array([2.5358276], dtype=float32), array([3.7124252], dtype=float32), array([3.710434], dtype=float32), array([3.31176], dtype=float32), array([3.5073776], dtype=float32), array([3.6333237], dtype=float32), array([2.4241714], dtype=float32), array([0.4704895], dtype=float32), array([-0.7433014], dtype=float32), array([-1.0512924], dtype=float32), array([-1.45047], dtype=float32), array([-2.4172516], dtype=float32), array([-4.2006683], dtype=float32), array([-3.6437225], dtype=float32), array([-1.7050247], dtype=float32), array([-1.4804001], dtype=float32), array([-2.7212448], dtype= ...
# Time predict 1.8264706134796143
# Time model 22.719101190567017
# Episode reward -1152.3184350770898
# [array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.730286], dtype=float32), array([-99.695335], dtype=float32), array([-99.61323], dtype=float32), array([-99.51295], dtype=float32), array([-99.391685], dtype=float32), array([-99.33803], dtype=float32), array([-99.32541], dtype=float32), array([-99.30596], dtype=float32), array([-99.27921], dtype=float32), array([-98.996605], dtype=float32), array([-98.235664], dtype=float32), array([-96.9898], dtype=float32), array([-96.493416], dtype=float32), array([-96.53156], dtype=float32), array([-96.57261], dtype=float32), array([-96.616455], dtype=float32), array([-96.663025], dtype=float32), array([-96.71223], dtype=float32), array([-96.76396], dtype=float32), array([-96.81816], dtype=float32), array([-96.874695], dtype=float32), array([-96.9335], dtype=float32), array([-96.99443], dtype=float32), array([-97.057365], dtype=float32), array([-97.12223], dtype=float32), array([-97.18887], dtype=float32), array([-97.25169], dtype=float32), array([-97.106186], dtype=float32), array([-96.970245], dtype=float32), array([-96.82229], dtype=float32), array([-96.661095], dtype=float32), array([-96.48527], dtype=float32), array([-96.29323], dtype=float32), array([-96.08321], dtype=float32), array([-95.85325], dtype=float32), array([-95.601204], dtype=float32), array([-95.32478], dtype=float32), array([-95.02118], dtype=float32), array([-94.6873], dtype=float32), array([-94.26376], dtype=float32), array([-93.677986], dtype=float32), array([-93.01446], dtype=float32), array([-92.26134], dtype=float32), array([-91.40515], dtype=float32), array([-90.430176], dtype=float32), array([-89.318436], dtype=float32), array([-88.049095], dtype=float32), array([-86.59852], dtype=float32), array([-84.93981], dtype=float32), array([-83.0429], dtype=float32), array([-80.9449], dtype=float32), array([-79.73077], dtype=float32), array([-78.41447], dtype=float32), array([-76.98722], dtype=float32), array([-75.439575], dtype=float32), array([-73.76141], dtype=float32), array([-71.94234], dtype=float32), array([-69.97151], dtype=float32), array([-67.83786], dtype=float32), array([-65.53009], dtype=float32), array([-63.03771], dtype=float32), array([-60.35021], dtype=float32), array([-57.458332], dtype=float32), array([-54.354282], dtype=float32), array([-51.03414], dtype=float32), array([-47.501835], dtype=float32), array([-43.763596], dtype=float32), array([-39.825974], dtype=float32), array([-35.70199], dtype=float32), array([36.29657], dtype=float32), array([48.61374], dtype=float32), array([48.912292], dtype=float32), array([49.23053], dtype=float32), array([49.46129], dtype=float32), array([49.62674], dtype=float32), array([49.709198], dtype=float32), array([49.673462], dtype=float32), array([49.632233], dtype=float32), array([49.608612], dtype=float32), array([49.582733], dtype=float32), array([49.554367], dtype=float32), array([49.38954], dtype=float32), array([48.194992], dtype=float32), array([48.38867], dtype=float32), array([48.81308], dtype=float32), array([49.224213], dtype=float32), array([49.44345], dtype=float32), array([49.60466], dtype=float32), array([49.721832], dtype=float32), array([49.806137], dtype=float32), array([49.832535], dtype=float32), array([49.831528], dtype=float32), array([49.830765], dtype=float32), array([49.83023], dtype=float32), array([49.829865], dtype=float32), array([49.829697], ...

# %%
run.id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\SAC_1GDLComplex8x8.ipynb Cell 11 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> run.id
#
# NameError: name 'run' is not defined

# %%
import torch as th

from stable_baselines3 import SAC

#import onnx
import onnxruntime as ort
import numpy as np


class OnnxablePolicy(th.nn.Module):
    def __init__(self, actor: th.nn.Module):
        super().__init__()
        # Removing the flatten layer because it can't be onnxed
        self.actor = th.nn.Sequential(
            actor.latent_pi,
            actor.mu,
            # For gSDE
            # th.nn.Hardtanh(min_val=-actor.clip_mean, max_val=actor.clip_mean),
            # Squash the output
            th.nn.Tanh(),
        )

    def forward(self, observation: th.Tensor) -> th.Tensor:
        # NOTE: You may have to process (normalize) observation in the correct
        #       way before using this. See `common.preprocessing.preprocess_obs`
        return self.actor(observation)


# Example: model = SAC("MlpPolicy", "Pendulum-v1")
model = SAC.load(f"models/{run.id}/model.zip", device="cpu")
onnxable_model = OnnxablePolicy(model.policy.actor)

observation_size = model.observation_space.shape
dummy_input = th.randn(1, *observation_size)
th.onnx.export(
    onnxable_model,
    dummy_input,
    "1gdlComplex8x8.onnx",
    opset_version=9,
    input_names=["input"],
)

##### Load and test with onnx

import onnxruntime as ort
import numpy as np

onnx_path = "1gdlComplex8x8.onnx"

observation = np.zeros((1, *observation_size)).astype(np.float32)
ort_sess = ort.InferenceSession(onnx_path)
action = ort_sess.run(None, {"input": observation})
# Out:
# ============== Diagnostic Run torch.onnx.export version 2.0.0+cpu ==============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %%
model.policy
# Out:
# SACPolicy(
#   (actor): Actor(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (latent_pi): Sequential(
#       (0): Linear(in_features=4, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=8, bias=True)
#       (3): ReLU()
#     )
#     (mu): Linear(in_features=8, out_features=1, bias=True)
#     (log_std): Linear(in_features=8, out_features=1, bias=True)
#   )
#   (critic): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (critic_target): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )

# %%
# See "ONNX export" for imports and OnnxablePolicy
jit_path = "1gdlComplex.pt"

# Trace and optimize the module
traced_module = th.jit.trace(onnxable_model.eval(), dummy_input)
frozen_module = th.jit.freeze(traced_module)
frozen_module = th.jit.optimize_for_inference(frozen_module)
th.jit.save(frozen_module, jit_path)

##### Load and test with torch

import torch as th

dummy_input = th.randn(1, *observation_size)
loaded_module = th.jit.load(jit_path)
action_jit = loaded_module(dummy_input)
