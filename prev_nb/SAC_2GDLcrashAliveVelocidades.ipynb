# %%
from gymnasium import Env
from gymnasium.spaces.box import Box
import numpy as np
import random
from stable_baselines3 import SAC
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.noise import NormalActionNoise
import wandb
from wandb.integration.sb3 import WandbCallback
import os
import matplotlib.pyplot as plt
import scipy.io
import numpy as np
import pickle
import warnings
import math
warnings.filterwarnings("ignore")

# %%
class BobinaEnv(Env):
  """
  Custom Gym Environment for the Hybrid Electromagnetic Suspension, considering just two degrees of freedom.
  """
  def __init__(self, alive = 20, masa_pod = 250, airgap = 16.3, duration = 10, dist_cm = 0.7, inercia= 70, min_distance = 9, max_distance = 22.5):
    # Actions: Voltage applied to the coil
    self.action_space = Box(low=np.array([-100, -100]), high = np.array([100, 100]), dtype=np.float32)
    # Observations: Airgap to the ceiling, velocity, distance to the objective, current of the coil
    self.observation_space = Box(low=np.array([-10, -10, -np.inf, -np.inf, -45, -45]), high = np.array([10, 10, np.inf, np.inf, 45, 45]), dtype=np.float32)
    # Initial parameters
    self.state = np.array([airgap - 16.3, airgap - 16.3, 0, 0, 0, 0])
    self.airgapinicial = airgap
    self.duration = duration
    self.timeleft = duration
    self.crash = False
    self.masa_pod = masa_pod
    self.sistema = TwoGDL(masa_pod = self.masa_pod, airgap = self.airgapinicial, dist_cm = dist_cm, inercia= inercia, min_distance = min_distance, max_distance = max_distance)
    self.steps = []
    self.airgap1 = airgap
    self.airgap2 = airgap
    self.distancia1 = 0
    self.distancia2 = 0
    self.velocidad = 0
    self.current1 = 0
    self.current2 = 0
    self.alive = alive
    self.vel = 0
    self.velangular = 0


  def step(self, action):
    # Apply action
    self.state, self.crash = self.sistema.step(action[0],action[1])
    self.distancia1, self.distancia2, self.vel, self.velangular, self.current1, self.current2 = self.state

    # Reduce the time of the experiment
    self.timeleft -= 0.001

    # Calculate reward
    reward = self.alive -abs(self.distancia1) -abs(self.distancia2) 

    """if self.airgap >= 23: reward = -500
    elif self.airgap <= 10: reward = -500
    else: reward = -abs(self.current)"""

    # Check if experiment is done
    if self.timeleft <= 0:
      truncated = True
    else: truncated = False
    # Set placeholder for info
    info = {}
    # Only if we implemented the crash
    if self.crash:
      reward = - 100000
      terminated = True
    else:
      terminated = False
    self.steps.append(self.state)
    return self.state, reward, terminated, truncated, info


  def render(self, yes = "yes"):
    # create data
    x = list(range(0,len(self.steps)))
    y1 = [16.3+step[0] for step in self.steps]
    y2 = [16.3+step[1] for step in self.steps]
    objective = [16.3]*len(self.steps)

    # plot lines
    fig = plt.figure(figsize=(10,5))
    ax = fig.add_subplot(111)
    ax.tick_params(axis='x', colors='white')    #setting up X-axis tick color to red
    ax.tick_params(axis='y', colors='white')  #setting up Y-axis tick color to black
    ax.set_ylim(bottom=8, top=22.5)
    plt.xlabel("Time (s)", color='white')
    plt.ylabel("Airgap (mm)", color='white')
    plt.title("Airgap evolution", color='white')


    plt.plot(x, y1, label = "Airgap 1")
    plt.plot(x, y2, label = "Airgap 2")
    plt.plot(x, objective, label = "Objective")
    plt.legend()
    plt.show()

  def reset(self, seed = 0):
    # Reset experiment choosing randomly the start (ceiling or floor)
    airgap = random.choice([16.3])
    self.state = np.array([airgap - 16.3, airgap - 16.3, 0, 0, 0, 0])
    self.distancia1, self.distancia2, self.current1, self.vel, self.velangular, self.current2 = self.state
    self.sistema = TwoGDL(masa_pod = self.masa_pod, airgap = airgap, dist_cm = 0.7, inercia= 70, min_distance = 9, max_distance = 22.5)
    
    # Reset time
    self.timeleft = self.duration
    self.crash = False
    self.steps = []
    return self.state, seed

# %%
class Bobina():
  """ 
  Coil model for the Hybrid Electromagnetic Suspension
  """
  def __init__(self, masa_pod = 250, airgap = 22.5, min_distance = 9, max_distance = 22.5):
    self.masa_pod = masa_pod
    self.airgap = airgap
    self.aceleracion = []
    self.velocidad = []
    mat = scipy.io.loadmat('./coil/hems.mat')
    self.hems = mat["hems"][0][0]
    self.airgaps = self.hems[0][0]
    self.currents = self.hems[1][0]
    self.force_vertical = pickle.load(open("./coil/mlp_vertical.pkl", 'rb'))
    self.flux = self.hems[3]
    self.force_horizontal = self.hems[4]
    self.inductance = pickle.load(open("./coil/rf_inductance.pkl", 'rb'))
    self.resistance = self.hems[6][0][0]
    self.min_distance = min_distance
    self.max_distance = max_distance
    self.airgapinicial = airgap
    self.crash = False
    self.current = 0
    self.steps_RL = []

  def integral(self, lista, h = 1):
    return sum(h*(lista[i]+lista[i+1])/2 for i in range(len(lista)-1))

  def RL(self, airgap, target_voltage, temperature):
    # Resistance-Inductance circuit

    # Get resistance of the coil
    R = self.R(current = self.current, temperature = temperature)   
    V = target_voltage
    I = self.current
    L = self.L(airgap = airgap, current = self.current)
    dIdt = ((V/R) - I)/(L/R)                                      
    self.steps_RL.append(dIdt)                                   
    current = self.integral(self.steps_RL, h = 0.001)                          
    return current                                                  

  def R(self, current, temperature):
    return self.resistance                                         

  def L(self, airgap, current):
    # Return predicted inductance
    return float(self.inductance.predict(np.array([[airgap, current]]))[0])

  def vertical_force(self, airgap, target_voltage, temperature):
    # Get current from RL circuit
    I = self.RL(airgap = airgap, target_voltage = target_voltage, temperature = temperature) 
    
    # Clip result
    if I > 45:
      I = 45
    elif I < -45:
      I = -45
    self.current = I
    # Get vertical force from 
    FI = self.FI_vertical(airgap = airgap, current = I)                    
    return FI, I


  def FI_vertical(self, airgap, current):
    # Return predicted vertical force
    return float(self.force_vertical.predict(np.array([[airgap, current]])))    


  def next_airgap(self, masa_pod, vertical_force, verbose = False):
    # Devide the mass of the pod by 4 coils
    masa = masa_pod/4  
    # Calculate weight
    peso = masa * 9.8    
    # Get total force                                                       
    fuerza = peso - vertical_force
    if verbose: print("Fuerza resultante: ", fuerza)   
    # Calculate acceleration                                     
    aceleracion = fuerza/masa
    if verbose: print("Aceleración: ", aceleracion)                                         
    self.aceleracion.append(aceleracion)       
    # Calculate velocity                                
    velocidad = self.integral(self.aceleracion, 0.001)
    if verbose: print("Integral primera (velocidad): ", velocidad)                          
    self.velocidad.append(velocidad)               
    # Calculate position (x1000 as to transform from m to mm)                            
    posicion = self.airgapinicial + self.integral(self.velocidad, 0.001)*1000 
    if verbose: print("Integral segunda (posición): ", posicion)

    # Clip position
    if posicion > self.max_distance:
      airgap = self.max_distance
      self.aceleracion = [0]
      self.velocidad = [0]  
      #self.crash = True     
      self.airgapinicial = self.max_distance                                               
    elif posicion < self.min_distance:
      airgap = self.min_distance
      self.aceleracion = [0]
      self.velocidad = [0]
      #self.crash = True
      self.airgapinicial = self.min_distance
    else: airgap = posicion
    return airgap, velocidad

  def step(self, target_voltage, verbose = False):
    # Calculate vertical force and current
    vertical_force, self.current = self.vertical_force(airgap = self.airgap, target_voltage = target_voltage, temperature = 40)
    if verbose: print("Fuerza vertical: ", vertical_force)
    # Calculate next airgap and velocity
    self.airgap, velocidad = self.next_airgap(self.masa_pod, vertical_force, verbose = verbose)
    #noise = np.random.normal(0,0.5)
    #self.airgap = self.airgap + noise     
    return (np.float32(self.airgap), np.float32(velocidad), np.float32(self.airgap - 16.3), np.float32(self.current)), self.crash

# %%
class TwoGDL():
    def __init__(self, masa_pod = 250, airgap = 22.5, dist_cm = 0.7, inercia= 70, min_distance = 9, max_distance = 22.5):
        self.masa_pod = masa_pod
        self.airgap1 = airgap
        self.airgap1_list = [airgap]
        self.airgap2 = airgap
        self.airgap2_list = [airgap]
        self.dist_cm = dist_cm
        self.inercia = inercia
        self.airgapinicial = airgap
        self.min_distance = min_distance
        self.max_distance = max_distance
        self.b1 = Bobina(masa_pod = self.masa_pod, airgap = self.airgap1, min_distance = self.min_distance, max_distance = self.max_distance)
        self.b2 = Bobina(masa_pod = self.masa_pod, airgap = self.airgap2, min_distance = self.min_distance, max_distance = self.max_distance)
        self.crash = False
        self.angulo = [0]
        self.alpha = [0]
        self.integral_alpha = 0
        self.omega = [0]
        self.integral_omega = 0
        self.altura = [0]
        self.aceleracion = [0]
        self.integral_aceleracion = 0
        self.velocidad = [0]
        self.integral_velocidad = 0
    
    def integral(self, lista, h = 1):
        return sum(h*(lista[i]+lista[i+1])/2 for i in range(len(lista)-1))
    
    def fast_integral(self, last, lista, h = 0.001):
        return last + h*(lista[-1]+lista[-2])/2
    
    def get_angulo(self, f1, f2):
        F1 = f1*self.dist_cm
        F2 = -f2*self.dist_cm
        M = F1+F2
        alpha = M/self.inercia
        self.alpha.append(alpha)
        omega = self.fast_integral(self.integral_alpha, self.alpha, 0.001)
        self.integral_alpha = omega
        self.omega.append(omega)
        angulo = self.fast_integral(self.integral_omega, self.omega, 0.001)
        self.integral_omega = angulo
        self.angulo.append(angulo)
        return angulo
    
    def get_altura(self, f1, f2):
        F = (self.masa_pod/2)*9.8 - f1 - f2
        a = F/(self.masa_pod/2)
        self.aceleracion.append(a)
        v = self.fast_integral(self.integral_aceleracion, self.aceleracion, 0.001)
        self.integral_aceleracion = v
        self.velocidad.append(v)
        zpos = self.fast_integral(self.integral_velocidad,self.velocidad, 0.001)
        self.integral_velocidad = zpos
        zpos = self.airgapinicial + zpos*1000
        self.altura.append(zpos)
        return zpos
    
    def pos2airgap(self, pos, theta):
        airgap1 = pos + self.dist_cm*math.sin(theta)*1000
        airgap2 = pos - self.dist_cm*math.sin(theta)*1000
        return airgap1, airgap2
    
    def step(self, target_voltage1, target_voltage2, verbose = False):
        # Calculate vertical force and current
        vertical_force1, current1 = self.b1.vertical_force(airgap = self.airgap1, target_voltage = target_voltage1, temperature = 40)
        vertical_force2, current2 = self.b2.vertical_force(airgap = self.airgap2, target_voltage = target_voltage2, temperature = 40)
        if verbose: print("Fuerza vertical 1: ", vertical_force1)
        if verbose: print("Fuerza vertical 2: ", vertical_force2)
        angulo = self.get_angulo(f1 = vertical_force1, f2 = vertical_force2)
        zpos = self.get_altura(f1 = vertical_force1, f2 = vertical_force2)
        self.airgap1, self.airgap2 = self.pos2airgap(pos = zpos, theta = angulo)
        self.airgap1_list.append(self.airgap1)
        self.airgap2_list.append(self.airgap2)
        if verbose: print("Airgap 1: ", self.airgap1)
        if verbose: print("Airgap 2: ", self.airgap2)
        if self.airgap1 > self.max_distance or self.airgap2 > self.max_distance:
            self.airgap1 = self.max_distance
            self.airgap2 = self.max_distance
            self.crash = True
            self.angulo = [0]
            self.alpha = [0]
            self.integral_alpha = 0
            self.omega = [0]
            self.integral_omega = 0
            self.altura = [0]
            self.aceleracion = [0]
            self.integral_aceleracion = 0
            self.velocidad = [0]
            self.integral_velocidad = 0
            self.airgapinicial = self.max_distance
        elif self.airgap1 < self.min_distance or self.airgap2 < self.min_distance:
            self.airgap1 = self.min_distance
            self.airgap2 = self.min_distance
            self.crash = True
            self.angulo = [0]
            self.alpha = [0]
            self.integral_alpha = 0
            self.omega = [0]
            self.integral_omega = 0
            self.altura = [0]
            self.aceleracion = [0]
            self.integral_aceleracion = 0
            self.velocidad = [0]
            self.integral_velocidad = 0
            self.airgapinicial = self.min_distance
        #return (np.float32(self.airgap1 -16.3), np.float32(self.airgap2-16.3), np.float32(current1), np.float32(current2)), self.crash
        return (np.float32(self.airgap1 -16.3), np.float32(self.airgap2-16.3), np.float32(self.integral_aceleracion), np.float32(self.integral_alpha), np.float32(current1), np.float32(current2)), self.crash
        #return (np.float32(self.airgap1_list[-2] -16.3), np.float32(self.airgap1_list[-1] -16.3), np.float32(self.airgap2_list[-2] -16.3), np.float32(self.airgap2_list[-1] -16.3), np.float32(current1), np.float32(current2)), self.crash
        #añadir una que returnee los 2 errores y las 2 velocidades

# %%
run = wandb.init(
    project="2gdl",
    sync_tensorboard=True,
    monitor_gym=True,
)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: huguito (hyperloopupv). Use `wandb login --relogin` to force relogin
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\rl_levitation_control\wandb\run-20240112_081346-jbb25ejg</code>
# Syncing run <strong><a href='https://wandb.ai/hyperloopupv/2gdl/runs/jbb25ejg' target="_blank">rose-serenity-13</a></strong> to <a href='https://wandb.ai/hyperloopupv/2gdl' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hyperloopupv/2gdl' target="_blank">https://wandb.ai/hyperloopupv/2gdl</a>
#  View run at <a href='https://wandb.ai/hyperloopupv/2gdl/runs/jbb25ejg' target="_blank">https://wandb.ai/hyperloopupv/2gdl/runs/jbb25ejg</a>

# %%
# Create log dir
log_dir = "2gdl/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = BobinaEnv( duration = 5 )
env = Monitor(env, log_dir)

# %%
from typing import Callable

def linear_schedule(initial_value: float) -> Callable[[float], float]:
    """
    Linear learning rate schedule.

    :param initial_value: Initial learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return progress_remaining * initial_value

    return func

# para el critic , qf=[400, 300], para el actor pi=[300, 200]
policy_kwargs = dict(net_arch=dict(pi=[8, 8], qf=[256, 256]))
model = SAC("MlpPolicy", env,learning_rate = linear_schedule(0.001), policy_kwargs=policy_kwargs, verbose=1, tensorboard_log=log_dir)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
MODEL_PATH = f"models/2gdl8x8.2/model.zip"

# Create and wrap the environment
env = BobinaEnv(duration = 5)

# Load the trained agent
model = SAC.load(MODEL_PATH, env=env, learning_rate = linear_schedule(0.0001))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Create checkpoint callback
checkpoint_callback = CheckpointCallback(
    save_freq=10000, save_path=log_dir, name_prefix="2gdl"
)

# %%
# Train the agent
model.learn(total_timesteps=8250000,
    callback=[
        checkpoint_callback,
        WandbCallback(
            gradient_save_freq=10000,
            model_save_path=f"models/2gdl8x8alive",
            model_save_freq=10000,
            verbose=2,
        ),
    ],
)
# Out:
# Logging to 2gdl/SAC_25
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 108       |
# |    ep_rew_mean     | -9.82e+04 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 28        |
# |    time_elapsed    | 15        |
# |    total_timesteps | 430       |
# | train/             |           |
# |    actor_loss      | 660       |
# |    critic_loss     | 3.91e+07  |
# |    ent_coef        | 0.774     |
# |    ent_coef_loss   | 0.403     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 329       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 83.5      |
# |    ep_rew_mean     | -9.86e+04 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 28        |
# |    time_elapsed    | 23        |
# |    total_timesteps | 668       |
# | train/             |           |
# |    actor_loss      | 2.28e+03  |
# |    critic_loss     | 7.39e+07  |
# |    ent_coef        | 1         |
# |    ent_coef_loss   | -0.0105   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 567       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 75.7      |
# |    ep_rew_mean     | -9.87e+04 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 28        |
# |    time_elapsed    | 31        |
# |    total_timesteps | 908       |
# | train/             |           |
# |    actor_loss      | 3.58e+03  |
# |    critic_loss     | 1.3e+08   |
# |    ent_coef        | 1.36      |
# |    ent_coef_loss   | -1.42     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 807       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 71.2      |
# |    ep_rew_mean     | -9.88e+04 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 28        |
# |    time_elapsed    | 40        |
# |    total_timesteps | 1139      |
# | train/             |           |
# |    actor_loss      | 5.51e+03  |
# |    critic_loss     | 1.41e+08  |
# |    ent_coef        | 1.85      |
# |    ent_coef_loss   | -3.53     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1038      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 68        |
# |    ep_rew_mean     | -9.89e+04 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 28        |
# |    time_elapsed    | 48        |
# |    total_timesteps | 1361      |
# | train/             |           |
# |    actor_loss      | 7.63e+03  |
# |    critic_loss     | 5.14e+07  |
# |    ent_coef        | 2.5       |
# |    ent_coef_loss   | -5.73     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1260      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 66.2      |
# |    ep_rew_mean     | -9.89e+04 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 27        |
# |    time_elapsed    | 57        |
# |    total_timesteps | 1588      |
# | train/             |           |
# |    actor_loss      | 8.7e+03   |
# |    critic_loss     | 3.03e+06  |
# |    ent_coef        | 3.3       |
# |    ent_coef_loss   | -7.26     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1487      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 65.1      |
# |    ep_rew_mean     | -9.89e+04 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 27        |
# |    time_elapsed    | 65        |
# |    total_timesteps | 1823      |
# | train/             |           |
# |    actor_loss      | 1.2e+04   |
# |    critic_loss     | 8.09e+07  |
# |    ent_coef        | 4.26      |
# |    ent_coef_loss   | -7.81     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1722      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 64.5      |
# |    ep_rew_mean     | -9.89e+04 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 27        |
# |    time_elapsed    | 75        |
# |    total_timesteps | 2063      |
# | train/             |           |
# |    actor_loss      | 1.43e+04  |
# |    critic_loss     | 9.82e+07  |
# |    ent_coef        | 5.39      |
# |    ent_coef_loss   | -8.44     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1962      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 64.4      |
# |    ep_rew_mean     | -9.89e+04 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 27        |
# |    time_elapsed    | 84        |
# |    total_timesteps | 2318      |
# | train/             |           |
# |    actor_loss      | 1.53e+04  |
# |    critic_loss     | 3.35e+07  |
# |    ent_coef        | 6.97      |
# |    ent_coef_loss   | -10.3     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2217      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 64.4      |
# |    ep_rew_mean     | -9.89e+04 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 27        |
# |    time_elapsed    | 94        |
# |    total_timesteps | 2575      |
# | train/             |           |
# |    actor_loss      | 1.94e+04  |
# |    critic_loss     | 2.09e+07  |
# |    ent_coef        | 8.89      |
# |    ent_coef_loss   | -11.5     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2474      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 64.5      |
# |    ep_rew_mean     | -9.89e+04 |
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 27        |
# |    time_elapsed    | 102       |
# |    total_timesteps | 2837      |
# | train/             |           |
# |    actor_loss      | 1.9e+04   |
# |    critic_loss     | 1.17e+07  |
# |    ent_coef        | 11.3      |
# |    ent_coef_loss   | -12.1     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2736      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 64.3      |
# |    ep_rew_mean     | -9.89e+04 |
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 27        |
# |    time_elapsed    | 112       |
# |    total_timesteps | 3087      |
# | train/             |           |
# |    actor_loss      | 2.2e+04   |
# |    critic_loss     | 2.86e+07  |
# |    ent_coef        | 14.1      |
# |    ent_coef_loss   | -10.9     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2986      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 63.9      |
# |    ep_rew_mean     | -9.89e+04 |
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 27        |
# |    time_elapsed    | 121       |
# |    total_timesteps | 3323      |
# | train/             |           |
# |    actor_loss      | 2.01e+04  |
# |    critic_loss     | 1.47e+07  |
# |    ent_coef        | 17        |
# |    ent_coef_loss   | -11.3     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3222      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63.4     |
# |    ep_rew_mean     | -9.9e+04 |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 27       |
# |    time_elapsed    | 129      |
# |    total_timesteps | 3550     |
# | train/             |          |
# |    actor_loss      | 2.23e+04 |
# |    critic_loss     | 1.29e+06 |
# |    ent_coef        | 20.1     |
# |    ent_coef_loss   | -9.73    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3449     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63       |
# |    ep_rew_mean     | -9.9e+04 |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 27       |
# |    time_elapsed    | 137      |
# |    total_timesteps | 3778     |
# | train/             |          |
# |    actor_loss      | 2.41e+04 |
# |    critic_loss     | 9.31e+06 |
# |    ent_coef        | 23.7     |
# |    ent_coef_loss   | -9.57    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3677     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 62.6     |
# |    ep_rew_mean     | -9.9e+04 |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 27       |
# |    time_elapsed    | 145      |
# |    total_timesteps | 4009     |
# | train/             |          |
# |    actor_loss      | 2.6e+04  |
# |    critic_loss     | 1.03e+07 |
# |    ent_coef        | 27.9     |
# |    ent_coef_loss   | -10.1    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3908     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 62.3     |
# |    ep_rew_mean     | -9.9e+04 |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 27       |
# |    time_elapsed    | 153      |
# |    total_timesteps | 4236     |
# | train/             |          |
# |    actor_loss      | 2.34e+04 |
# |    critic_loss     | 1.96e+07 |
# |    ent_coef        | 32.4     |
# |    ent_coef_loss   | -7.25    |
# |    learning_rate   | 0.000999 |
# |    n_updates       | 4135     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 63.3      |
# |    ep_rew_mean     | -9.89e+04 |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 27        |
# |    time_elapsed    | 164       |
# |    total_timesteps | 4557      |
# | train/             |           |
# |    actor_loss      | 2.65e+04  |
# |    critic_loss     | 8.1e+06   |
# |    ent_coef        | 39.5      |
# |    ent_coef_loss   | -8.28     |
# |    learning_rate   | 0.000999  |
# |    n_updates       | 4456      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 66.6      |
# |    ep_rew_mean     | -9.89e+04 |
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 27        |
# |    time_elapsed    | 182       |
# |    total_timesteps | 5061      |
# | train/             |           |
# |    actor_loss      | 2.69e+04  |
# |    critic_loss     | 2.31e+06  |
# |    ent_coef        | 51.4      |
# |    ent_coef_loss   | -3.64     |
# |    learning_rate   | 0.000999  |
# |    n_updates       | 4960      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 72.3      |
# |    ep_rew_mean     | -9.88e+04 |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 27        |
# |    time_elapsed    | 206       |
# |    total_timesteps | 5785      |
# | train/             |           |
# |    actor_loss      | 2.92e+04  |
# |    critic_loss     | 3.48e+06  |
# |    ent_coef        | 64.5      |
# |    ent_coef_loss   | -2.06     |
# |    learning_rate   | 0.000999  |
# |    n_updates       | 5684      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 77.8      |
# |    ep_rew_mean     | -9.87e+04 |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 28        |
# |    time_elapsed    | 232       |
# |    total_timesteps | 6534      |
# | train/             |           |
# |    actor_loss      | 2.97e+04  |
# |    critic_loss     | 2.44e+06  |
# |    ent_coef        | 69.2      |
# |    ent_coef_loss   | 0.379     |
# |    learning_rate   | 0.000999  |
# |    n_updates       | 6433      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 82.4      |
# |    ep_rew_mean     | -9.86e+04 |
# | time/              |           |
# |    episodes        | 88        |
# |    fps             | 28        |
# |    time_elapsed    | 257       |
# |    total_timesteps | 7247      |
# | train/             |           |
# |    actor_loss      | 2.95e+04  |
# |    critic_loss     | 1.34e+06  |
# |    ent_coef        | 73.3      |
# |    ent_coef_loss   | -1.26     |
# |    learning_rate   | 0.000999  |
# |    n_updates       | 7146      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 85.8      |
# |    ep_rew_mean     | -9.85e+04 |
# | time/              |           |
# |    episodes        | 92        |
# |    fps             | 28        |
# |    time_elapsed    | 279       |
# |    total_timesteps | 7892      |
# | train/             |           |
# |    actor_loss      | 2.73e+04  |
# |    critic_loss     | 1.36e+06  |
# |    ent_coef        | 78.8      |
# |    ent_coef_loss   | 1.17      |
# |    learning_rate   | 0.000999  |
# |    n_updates       | 7791      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 89.6      |
# |    ep_rew_mean     | -9.84e+04 |
# | time/              |           |
# |    episodes        | 96        |
# |    fps             | 28        |
# |    time_elapsed    | 303       |
# |    total_timesteps | 8597      |
# | train/             |           |
# |    actor_loss      | 2.98e+04  |
# |    critic_loss     | 7.9e+05   |
# |    ent_coef        | 66.9      |
# |    ent_coef_loss   | 0.547     |
# |    learning_rate   | 0.000999  |
# |    n_updates       | 8496      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 93.8      |
# |    ep_rew_mean     | -9.84e+04 |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 28        |
# |    time_elapsed    | 330       |
# |    total_timesteps | 9377      |
# | train/             |           |
# |    actor_loss      | 2.92e+04  |
# |    critic_loss     | 6.43e+05  |
# |    ent_coef        | 54.7      |
# |    ent_coef_loss   | 0.953     |
# |    learning_rate   | 0.000999  |
# |    n_updates       | 9276      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 97.7      |
# |    ep_rew_mean     | -9.83e+04 |
# | time/              |           |
# |    episodes        | 104       |
# |    fps             | 28        |
# |    time_elapsed    | 359       |
# |    total_timesteps | 10200     |
# | train/             |           |
# |    actor_loss      | 2.7e+04   |
# |    critic_loss     | 6.2e+05   |
# |    ent_coef        | 48.3      |
# |    ent_coef_loss   | -0.627    |
# |    learning_rate   | 0.000999  |
# |    n_updates       | 10099     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 103       |
# |    ep_rew_mean     | -9.82e+04 |
# | time/              |           |
# |    episodes        | 108       |
# |    fps             | 28        |
# |    time_elapsed    | 385       |
# |    total_timesteps | 10948     |
# | train/             |           |
# |    actor_loss      | 2.44e+04  |
# |    critic_loss     | 6.55e+05  |
# |    ent_coef        | 47.8      |
# |    ent_coef_loss   | -0.109    |
# |    learning_rate   | 0.000999  |
# |    n_updates       | 10847     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 108       |
# |    ep_rew_mean     | -9.81e+04 |
# | time/              |           |
# |    episodes        | 112       |
# |    fps             | 28        |
# |    time_elapsed    | 413       |
# |    total_timesteps | 11715     |
# | train/             |           |
# |    actor_loss      | 3.06e+04  |
# |    critic_loss     | 2.88e+06  |
# |    ent_coef        | 53.4      |
# |    ent_coef_loss   | -0.82     |
# |    learning_rate   | 0.000999  |
# |    n_updates       | 11614     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 114      |
# |    ep_rew_mean     | -9.8e+04 |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 28       |
# |    time_elapsed    | 442      |
# |    total_timesteps | 12551    |
# | train/             |          |
# |    actor_loss      | 2.77e+04 |
# |    critic_loss     | 6.83e+05 |
# |    ent_coef        | 51.4     |
# |    ent_coef_loss   | -1.13    |
# |    learning_rate   | 0.000998 |
# |    n_updates       | 12450    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 120       |
# |    ep_rew_mean     | -9.79e+04 |
# | time/              |           |
# |    episodes        | 120       |
# |    fps             | 28        |
# |    time_elapsed    | 471       |
# |    total_timesteps | 13404     |
# | train/             |           |
# |    actor_loss      | 2.25e+04  |
# |    critic_loss     | 3.26e+05  |
# |    ent_coef        | 39        |
# |    ent_coef_loss   | 0.636     |
# |    learning_rate   | 0.000998  |
# |    n_updates       | 13303     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 125       |
# |    ep_rew_mean     | -9.78e+04 |
# | time/              |           |
# |    episodes        | 124       |
# |    fps             | 28        |
# |    time_elapsed    | 496       |
# |    total_timesteps | 14114     |
# | train/             |           |
# |    actor_loss      | 2.42e+04  |
# |    critic_loss     | 4.85e+05  |
# |    ent_coef        | 33.6      |
# |    ent_coef_loss   | -0.261    |
# |    learning_rate   | 0.000998  |
# |    n_updates       | 14013     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 129       |
# |    ep_rew_mean     | -9.77e+04 |
# | time/              |           |
# |    episodes        | 128       |
# |    fps             | 28        |
# |    time_elapsed    | 517       |
# |    total_timesteps | 14721     |
# | train/             |           |
# |    actor_loss      | 2.75e+04  |
# |    critic_loss     | 4.91e+06  |
# |    ent_coef        | 29.7      |
# |    ent_coef_loss   | 0.206     |
# |    learning_rate   | 0.000998  |
# |    n_updates       | 14620     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 132       |
# |    ep_rew_mean     | -9.77e+04 |
# | time/              |           |
# |    episodes        | 132       |
# |    fps             | 28        |
# |    time_elapsed    | 537       |
# |    total_timesteps | 15290     |
# | train/             |           |
# |    actor_loss      | 2.26e+04  |
# |    critic_loss     | 2.16e+06  |
# |    ent_coef        | 29.8      |
# |    ent_coef_loss   | 0.332     |
# |    learning_rate   | 0.000998  |
# |    n_updates       | 15189     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 135       |
# |    ep_rew_mean     | -9.76e+04 |
# | time/              |           |
# |    episodes        | 136       |
# |    fps             | 28        |
# |    time_elapsed    | 556       |
# |    total_timesteps | 15850     |
# | train/             |           |
# |    actor_loss      | 2.26e+04  |
# |    critic_loss     | 1.62e+06  |
# |    ent_coef        | 29.7      |
# |    ent_coef_loss   | 0.106     |
# |    learning_rate   | 0.000998  |
# |    n_updates       | 15749     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 138       |
# |    ep_rew_mean     | -9.76e+04 |
# | time/              |           |
# |    episodes        | 140       |
# |    fps             | 28        |
# |    time_elapsed    | 576       |
# |    total_timesteps | 16412     |
# | train/             |           |
# |    actor_loss      | 2.45e+04  |
# |    critic_loss     | 2.18e+05  |
# |    ent_coef        | 30.8      |
# |    ent_coef_loss   | -0.655    |
# |    learning_rate   | 0.000998  |
# |    n_updates       | 16311     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 141       |
# |    ep_rew_mean     | -9.75e+04 |
# | time/              |           |
# |    episodes        | 144       |
# |    fps             | 28        |
# |    time_elapsed    | 595       |
# |    total_timesteps | 16965     |
# | train/             |           |
# |    actor_loss      | 2.59e+04  |
# |    critic_loss     | 2.59e+06  |
# |    ent_coef        | 30        |
# |    ent_coef_loss   | -1.14     |
# |    learning_rate   | 0.000998  |
# |    n_updates       | 16864     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 144       |
# |    ep_rew_mean     | -9.75e+04 |
# | time/              |           |
# |    episodes        | 148       |
# |    fps             | 28        |
# |    time_elapsed    | 614       |
# |    total_timesteps | 17515     |
# | train/             |           |
# |    actor_loss      | 2.63e+04  |
# |    critic_loss     | 4.61e+06  |
# |    ent_coef        | 29.2      |
# |    ent_coef_loss   | -1.27     |
# |    learning_rate   | 0.000998  |
# |    n_updates       | 17414     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 147       |
# |    ep_rew_mean     | -9.74e+04 |
# | time/              |           |
# |    episodes        | 152       |
# |    fps             | 28        |
# |    time_elapsed    | 633       |
# |    total_timesteps | 18060     |
# | train/             |           |
# |    actor_loss      | 2.66e+04  |
# |    critic_loss     | 4.18e+06  |
# |    ent_coef        | 29.6      |
# |    ent_coef_loss   | -0.63     |
# |    learning_rate   | 0.000998  |
# |    n_updates       | 17959     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 150       |
# |    ep_rew_mean     | -9.74e+04 |
# | time/              |           |
# |    episodes        | 156       |
# |    fps             | 28        |
# |    time_elapsed    | 651       |
# |    total_timesteps | 18578     |
# | train/             |           |
# |    actor_loss      | 2.26e+04  |
# |    critic_loss     | 1.71e+06  |
# |    ent_coef        | 31.2      |
# |    ent_coef_loss   | -0.16     |
# |    learning_rate   | 0.000998  |
# |    n_updates       | 18477     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 153       |
# |    ep_rew_mean     | -9.73e+04 |
# | time/              |           |
# |    episodes        | 160       |
# |    fps             | 28        |
# |    time_elapsed    | 669       |
# |    total_timesteps | 19107     |
# | train/             |           |
# |    actor_loss      | 2.72e+04  |
# |    critic_loss     | 3.22e+05  |
# |    ent_coef        | 32.7      |
# |    ent_coef_loss   | -0.755    |
# |    learning_rate   | 0.000998  |
# |    n_updates       | 19006     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 156       |
# |    ep_rew_mean     | -9.73e+04 |
# | time/              |           |
# |    episodes        | 164       |
# |    fps             | 28        |
# |    time_elapsed    | 687       |
# |    total_timesteps | 19638     |
# | train/             |           |
# |    actor_loss      | 2.93e+04  |
# |    critic_loss     | 2.66e+05  |
# |    ent_coef        | 34        |
# |    ent_coef_loss   | 0.553     |
# |    learning_rate   | 0.000998  |
# |    n_updates       | 19537     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 160       |
# |    ep_rew_mean     | -9.72e+04 |
# | time/              |           |
# |    episodes        | 168       |
# |    fps             | 28        |
# |    time_elapsed    | 708       |
# |    total_timesteps | 20195     |
# | train/             |           |
# |    actor_loss      | 2.71e+04  |
# |    critic_loss     | 2.08e+06  |
# |    ent_coef        | 32.3      |
# |    ent_coef_loss   | -0.338    |
# |    learning_rate   | 0.000998  |
# |    n_updates       | 20094     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 164       |
# |    ep_rew_mean     | -9.71e+04 |
# | time/              |           |
# |    episodes        | 172       |
# |    fps             | 28        |
# |    time_elapsed    | 732       |
# |    total_timesteps | 20910     |
# | train/             |           |
# |    actor_loss      | 2.61e+04  |
# |    critic_loss     | 3.5e+05   |
# |    ent_coef        | 35.1      |
# |    ent_coef_loss   | -0.0165   |
# |    learning_rate   | 0.000997  |
# |    n_updates       | 20809     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 171      |
# |    ep_rew_mean     | -9.7e+04 |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 28       |
# |    time_elapsed    | 773      |
# |    total_timesteps | 22115    |
# | train/             |          |
# |    actor_loss      | 2.45e+04 |
# |    critic_loss     | 3.04e+05 |
# |    ent_coef        | 43.8     |
# |    ent_coef_loss   | 0.847    |
# |    learning_rate   | 0.000997 |
# |    n_updates       | 22014    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 183       |
# |    ep_rew_mean     | -9.68e+04 |
# | time/              |           |
# |    episodes        | 180       |
# |    fps             | 28        |
# |    time_elapsed    | 841       |
# |    total_timesteps | 24124     |
# | train/             |           |
# |    actor_loss      | 2.83e+04  |
# |    critic_loss     | 5.16e+05  |
# |    ent_coef        | 41.6      |
# |    ent_coef_loss   | -1.07     |
# |    learning_rate   | 0.000997  |
# |    n_updates       | 24023     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 199       |
# |    ep_rew_mean     | -9.66e+04 |
# | time/              |           |
# |    episodes        | 184       |
# |    fps             | 28        |
# |    time_elapsed    | 919       |
# |    total_timesteps | 26397     |
# | train/             |           |
# |    actor_loss      | 2.23e+04  |
# |    critic_loss     | 3.99e+05  |
# |    ent_coef        | 39.1      |
# |    ent_coef_loss   | -1.21     |
# |    learning_rate   | 0.000997  |
# |    n_updates       | 26296     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 225       |
# |    ep_rew_mean     | -9.62e+04 |
# | time/              |           |
# |    episodes        | 188       |
# |    fps             | 28        |
# |    time_elapsed    | 1035      |
# |    total_timesteps | 29746     |
# | train/             |           |
# |    actor_loss      | 1.79e+04  |
# |    critic_loss     | 6.32e+05  |
# |    ent_coef        | 25.7      |
# |    ent_coef_loss   | 0.111     |
# |    learning_rate   | 0.000996  |
# |    n_updates       | 29645     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 319       |
# |    ep_rew_mean     | -9.46e+04 |
# | time/              |           |
# |    episodes        | 192       |
# |    fps             | 28        |
# |    time_elapsed    | 1390      |
# |    total_timesteps | 39780     |
# | train/             |           |
# |    actor_loss      | 1.7e+04   |
# |    critic_loss     | 8.31e+05  |
# |    ent_coef        | 20.9      |
# |    ent_coef_loss   | -0.00673  |
# |    learning_rate   | 0.000995  |
# |    n_updates       | 39679     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 369       |
# |    ep_rew_mean     | -9.38e+04 |
# | time/              |           |
# |    episodes        | 196       |
# |    fps             | 28        |
# |    time_elapsed    | 1588      |
# |    total_timesteps | 45455     |
# | train/             |           |
# |    actor_loss      | 1.23e+04  |
# |    critic_loss     | 5.28e+05  |
# |    ent_coef        | 18        |
# |    ent_coef_loss   | -0.356    |
# |    learning_rate   | 0.000994  |
# |    n_updates       | 45354     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 385       |
# |    ep_rew_mean     | -9.35e+04 |
# | time/              |           |
# |    episodes        | 200       |
# |    fps             | 28        |
# |    time_elapsed    | 1670      |
# |    total_timesteps | 47845     |
# | train/             |           |
# |    actor_loss      | 1.22e+04  |
# |    critic_loss     | 6.7e+05   |
# |    ent_coef        | 17.3      |
# |    ent_coef_loss   | 0.133     |
# |    learning_rate   | 0.000994  |
# |    n_updates       | 47744     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 402       |
# |    ep_rew_mean     | -9.32e+04 |
# | time/              |           |
# |    episodes        | 204       |
# |    fps             | 28        |
# |    time_elapsed    | 1760      |
# |    total_timesteps | 50433     |
# | train/             |           |
# |    actor_loss      | 1.34e+04  |
# |    critic_loss     | 4.73e+05  |
# |    ent_coef        | 16.2      |
# |    ent_coef_loss   | 0.408     |
# |    learning_rate   | 0.000994  |
# |    n_updates       | 50332     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 425       |
# |    ep_rew_mean     | -9.28e+04 |
# | time/              |           |
# |    episodes        | 208       |
# |    fps             | 28        |
# |    time_elapsed    | 1866      |
# |    total_timesteps | 53483     |
# | train/             |           |
# |    actor_loss      | 1.28e+04  |
# |    critic_loss     | 2.57e+05  |
# |    ent_coef        | 18.3      |
# |    ent_coef_loss   | 0.09      |
# |    learning_rate   | 0.000994  |
# |    n_updates       | 53382     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 498       |
# |    ep_rew_mean     | -9.15e+04 |
# | time/              |           |
# |    episodes        | 212       |
# |    fps             | 28        |
# |    time_elapsed    | 2149      |
# |    total_timesteps | 61501     |
# | train/             |           |
# |    actor_loss      | 1.04e+04  |
# |    critic_loss     | 4.9e+05   |
# |    ent_coef        | 20.7      |
# |    ent_coef_loss   | -0.158    |
# |    learning_rate   | 0.000993  |
# |    n_updates       | 61400     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 573       |
# |    ep_rew_mean     | -9.03e+04 |
# | time/              |           |
# |    episodes        | 216       |
# |    fps             | 28        |
# |    time_elapsed    | 2443      |
# |    total_timesteps | 69844     |
# | train/             |           |
# |    actor_loss      | 1.12e+04  |
# |    critic_loss     | 5.66e+05  |
# |    ent_coef        | 18.7      |
# |    ent_coef_loss   | -0.309    |
# |    learning_rate   | 0.000992  |
# |    n_updates       | 69743     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 670       |
# |    ep_rew_mean     | -8.86e+04 |
# | time/              |           |
# |    episodes        | 220       |
# |    fps             | 28        |
# |    time_elapsed    | 2822      |
# |    total_timesteps | 80445     |
# | train/             |           |
# |    actor_loss      | 9.93e+03  |
# |    critic_loss     | 1.26e+07  |
# |    ent_coef        | 17.4      |
# |    ent_coef_loss   | -0.117    |
# |    learning_rate   | 0.00099   |
# |    n_updates       | 80344     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 731       |
# |    ep_rew_mean     | -8.76e+04 |
# | time/              |           |
# |    episodes        | 224       |
# |    fps             | 28        |
# |    time_elapsed    | 3059      |
# |    total_timesteps | 87205     |
# | train/             |           |
# |    actor_loss      | 8.37e+03  |
# |    critic_loss     | 4.85e+05  |
# |    ent_coef        | 17.3      |
# |    ent_coef_loss   | 0.515     |
# |    learning_rate   | 0.000989  |
# |    n_updates       | 87104     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -8.67e+04 |
# | time/              |           |
# |    episodes        | 228       |
# |    fps             | 28        |
# |    time_elapsed    | 3258      |
# |    total_timesteps | 92862     |
# | train/             |           |
# |    actor_loss      | 8.96e+03  |
# |    critic_loss     | 1.35e+06  |
# |    ent_coef        | 19.3      |
# |    ent_coef_loss   | -0.526    |
# |    learning_rate   | 0.000989  |
# |    n_updates       | 92761     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 829      |
# |    ep_rew_mean     | -8.6e+04 |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 28       |
# |    time_elapsed    | 3443     |
# |    total_timesteps | 98144    |
# | train/             |          |
# |    actor_loss      | 7.08e+03 |
# |    critic_loss     | 1.64e+06 |
# |    ent_coef        | 21.4     |
# |    ent_coef_loss   | 0.419    |
# |    learning_rate   | 0.000988 |
# |    n_updates       | 98043    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 903       |
# |    ep_rew_mean     | -8.47e+04 |
# | time/              |           |
# |    episodes        | 236       |
# |    fps             | 28        |
# |    time_elapsed    | 3727      |
# |    total_timesteps | 106169    |
# | train/             |           |
# |    actor_loss      | 7.71e+03  |
# |    critic_loss     | 9.77e+05  |
# |    ent_coef        | 22.3      |
# |    ent_coef_loss   | 0.218     |
# |    learning_rate   | 0.000987  |
# |    n_updates       | 106068    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 971       |
# |    ep_rew_mean     | -8.36e+04 |
# | time/              |           |
# |    episodes        | 240       |
# |    fps             | 28        |
# |    time_elapsed    | 3986      |
# |    total_timesteps | 113502    |
# | train/             |           |
# |    actor_loss      | 5.43e+03  |
# |    critic_loss     | 5.44e+05  |
# |    ent_coef        | 18.6      |
# |    ent_coef_loss   | 0.163     |
# |    learning_rate   | 0.000986  |
# |    n_updates       | 113401    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.13e+03  |
# |    ep_rew_mean     | -7.78e+04 |
# | time/              |           |
# |    episodes        | 244       |
# |    fps             | 28        |
# |    time_elapsed    | 4592      |
# |    total_timesteps | 130017    |
# | train/             |           |
# |    actor_loss      | 5.5e+03   |
# |    critic_loss     | 9.48e+06  |
# |    ent_coef        | 13.4      |
# |    ent_coef_loss   | 0.538     |
# |    learning_rate   | 0.000984  |
# |    n_updates       | 129916    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.33e+03  |
# |    ep_rew_mean     | -7.02e+04 |
# | time/              |           |
# |    episodes        | 248       |
# |    fps             | 28        |
# |    time_elapsed    | 5327      |
# |    total_timesteps | 150017    |
# | train/             |           |
# |    actor_loss      | 7.64e+03  |
# |    critic_loss     | 8.28e+05  |
# |    ent_coef        | 14.1      |
# |    ent_coef_loss   | -0.535    |
# |    learning_rate   | 0.000982  |
# |    n_updates       | 149916    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.5e+03   |
# |    ep_rew_mean     | -6.39e+04 |
# | time/              |           |
# |    episodes        | 252       |
# |    fps             | 28        |
# |    time_elapsed    | 5971      |
# |    total_timesteps | 167606    |
# | train/             |           |
# |    actor_loss      | 5.16e+03  |
# |    critic_loss     | 7.35e+05  |
# |    ent_coef        | 10.1      |
# |    ent_coef_loss   | 0.421     |
# |    learning_rate   | 0.00098   |
# |    n_updates       | 167505    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.51e+03  |
# |    ep_rew_mean     | -6.37e+04 |
# | time/              |           |
# |    episodes        | 256       |
# |    fps             | 28        |
# |    time_elapsed    | 6043      |
# |    total_timesteps | 169656    |
# | train/             |           |
# |    actor_loss      | 4.37e+03  |
# |    critic_loss     | 5.53e+05  |
# |    ent_coef        | 11.2      |
# |    ent_coef_loss   | 0.922     |
# |    learning_rate   | 0.000979  |
# |    n_updates       | 169555    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.52e+03  |
# |    ep_rew_mean     | -6.35e+04 |
# | time/              |           |
# |    episodes        | 260       |
# |    fps             | 28        |
# |    time_elapsed    | 6102      |
# |    total_timesteps | 171376    |
# | train/             |           |
# |    actor_loss      | 3.9e+03   |
# |    critic_loss     | 2.52e+05  |
# |    ent_coef        | 12.3      |
# |    ent_coef_loss   | 0.686     |
# |    learning_rate   | 0.000979  |
# |    n_updates       | 171275    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.53e+03  |
# |    ep_rew_mean     | -6.34e+04 |
# | time/              |           |
# |    episodes        | 264       |
# |    fps             | 28        |
# |    time_elapsed    | 6150      |
# |    total_timesteps | 172787    |
# | train/             |           |
# |    actor_loss      | 7.27e+03  |
# |    critic_loss     | 9.27e+05  |
# |    ent_coef        | 12.1      |
# |    ent_coef_loss   | -0.647    |
# |    learning_rate   | 0.000979  |
# |    n_updates       | 172686    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.55e+03  |
# |    ep_rew_mean     | -6.32e+04 |
# | time/              |           |
# |    episodes        | 268       |
# |    fps             | 28        |
# |    time_elapsed    | 6219      |
# |    total_timesteps | 174761    |
# | train/             |           |
# |    actor_loss      | 7.37e+03  |
# |    critic_loss     | 1.08e+06  |
# |    ent_coef        | 12.7      |
# |    ent_coef_loss   | -1.49     |
# |    learning_rate   | 0.000979  |
# |    n_updates       | 174660    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.72e+03  |
# |    ep_rew_mean     | -5.73e+04 |
# | time/              |           |
# |    episodes        | 272       |
# |    fps             | 27        |
# |    time_elapsed    | 6936      |
# |    total_timesteps | 192510    |
# | train/             |           |
# |    actor_loss      | 6.2e+03   |
# |    critic_loss     | 3.84e+05  |
# |    ent_coef        | 10.6      |
# |    ent_coef_loss   | -0.559    |
# |    learning_rate   | 0.000977  |
# |    n_updates       | 192409    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.9e+03   |
# |    ep_rew_mean     | -4.99e+04 |
# | time/              |           |
# |    episodes        | 276       |
# |    fps             | 27        |
# |    time_elapsed    | 7674      |
# |    total_timesteps | 212510    |
# | train/             |           |
# |    actor_loss      | 6.23e+03  |
# |    critic_loss     | 6.84e+05  |
# |    ent_coef        | 8.12      |
# |    ent_coef_loss   | -0.367    |
# |    learning_rate   | 0.000974  |
# |    n_updates       | 212409    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.08e+03  |
# |    ep_rew_mean     | -4.27e+04 |
# | time/              |           |
# |    episodes        | 280       |
# |    fps             | 27        |
# |    time_elapsed    | 8450      |
# |    total_timesteps | 232510    |
# | train/             |           |
# |    actor_loss      | 6.71e+03  |
# |    critic_loss     | 3.96e+05  |
# |    ent_coef        | 6.82      |
# |    ent_coef_loss   | -0.2      |
# |    learning_rate   | 0.000972  |
# |    n_updates       | 232409    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.26e+03  |
# |    ep_rew_mean     | -3.55e+04 |
# | time/              |           |
# |    episodes        | 284       |
# |    fps             | 27        |
# |    time_elapsed    | 9270      |
# |    total_timesteps | 252510    |
# | train/             |           |
# |    actor_loss      | 7.13e+03  |
# |    critic_loss     | 3.15e+05  |
# |    ent_coef        | 7.27      |
# |    ent_coef_loss   | -0.674    |
# |    learning_rate   | 0.000969  |
# |    n_updates       | 252409    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.43e+03  |
# |    ep_rew_mean     | -2.84e+04 |
# | time/              |           |
# |    episodes        | 288       |
# |    fps             | 27        |
# |    time_elapsed    | 10076     |
# |    total_timesteps | 272510    |
# | train/             |           |
# |    actor_loss      | 5.52e+03  |
# |    critic_loss     | 2.87e+05  |
# |    ent_coef        | 7.02      |
# |    ent_coef_loss   | -0.0992   |
# |    learning_rate   | 0.000967  |
# |    n_updates       | 272409    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.53e+03  |
# |    ep_rew_mean     | -2.26e+04 |
# | time/              |           |
# |    episodes        | 292       |
# |    fps             | 26        |
# |    time_elapsed    | 10871     |
# |    total_timesteps | 292510    |
# | train/             |           |
# |    actor_loss      | 5e+03     |
# |    critic_loss     | 4e+05     |
# |    ent_coef        | 6.32      |
# |    ent_coef_loss   | -0.363    |
# |    learning_rate   | 0.000965  |
# |    n_updates       | 292409    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.67e+03  |
# |    ep_rew_mean     | -1.59e+04 |
# | time/              |           |
# |    episodes        | 296       |
# |    fps             | 26        |
# |    time_elapsed    | 11663     |
# |    total_timesteps | 312510    |
# | train/             |           |
# |    actor_loss      | 4.01e+03  |
# |    critic_loss     | 3.17e+05  |
# |    ent_coef        | 5.27      |
# |    ent_coef_loss   | 0.326     |
# |    learning_rate   | 0.000962  |
# |    n_updates       | 312409    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.85e+03  |
# |    ep_rew_mean     | -8.67e+03 |
# | time/              |           |
# |    episodes        | 300       |
# |    fps             | 26        |
# |    time_elapsed    | 12467     |
# |    total_timesteps | 332510    |
# | train/             |           |
# |    actor_loss      | 4.56e+03  |
# |    critic_loss     | 1.75e+05  |
# |    ent_coef        | 4.74      |
# |    ent_coef_loss   | 0.0369    |
# |    learning_rate   | 0.00096   |
# |    n_updates       | 332409    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 3.02e+03  |
# |    ep_rew_mean     | -1.48e+03 |
# | time/              |           |
# |    episodes        | 304       |
# |    fps             | 26        |
# |    time_elapsed    | 13294     |
# |    total_timesteps | 352510    |
# | train/             |           |
# |    actor_loss      | 2.71e+03  |
# |    critic_loss     | 1.3e+05   |
# |    ent_coef        | 3.91      |
# |    ent_coef_loss   | 0.538     |
# |    learning_rate   | 0.000957  |
# |    n_updates       | 352409    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.19e+03 |
# |    ep_rew_mean     | 5.76e+03 |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 26       |
# |    time_elapsed    | 14110    |
# |    total_timesteps | 372510   |
# | train/             |          |
# |    actor_loss      | 3.48e+03 |
# |    critic_loss     | 1.26e+05 |
# |    ent_coef        | 4.71     |
# |    ent_coef_loss   | -0.183   |
# |    learning_rate   | 0.000955 |
# |    n_updates       | 372409   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.31e+03 |
# |    ep_rew_mean     | 1.21e+04 |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 26       |
# |    time_elapsed    | 14830    |
# |    total_timesteps | 392510   |
# | train/             |          |
# |    actor_loss      | 3.26e+03 |
# |    critic_loss     | 2.19e+05 |
# |    ent_coef        | 4.02     |
# |    ent_coef_loss   | -0.298   |
# |    learning_rate   | 0.000952 |
# |    n_updates       | 392409   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.43e+03 |
# |    ep_rew_mean     | 1.81e+04 |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 26       |
# |    time_elapsed    | 15549    |
# |    total_timesteps | 412510   |
# | train/             |          |
# |    actor_loss      | 3.26e+03 |
# |    critic_loss     | 2.6e+05  |
# |    ent_coef        | 3.34     |
# |    ent_coef_loss   | -0.178   |
# |    learning_rate   | 0.00095  |
# |    n_updates       | 412409   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.52e+03 |
# |    ep_rew_mean     | 2.38e+04 |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 26       |
# |    time_elapsed    | 16270    |
# |    total_timesteps | 432510   |
# | train/             |          |
# |    actor_loss      | 2.85e+03 |
# |    critic_loss     | 1.72e+05 |
# |    ent_coef        | 2.64     |
# |    ent_coef_loss   | -0.161   |
# |    learning_rate   | 0.000948 |
# |    n_updates       | 432409   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.61e+03 |
# |    ep_rew_mean     | 2.71e+04 |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 26       |
# |    time_elapsed    | 16837    |
# |    total_timesteps | 448408   |
# | train/             |          |
# |    actor_loss      | 2.19e+03 |
# |    critic_loss     | 1.81e+05 |
# |    ent_coef        | 3.01     |
# |    ent_coef_loss   | 0.126    |
# |    learning_rate   | 0.000946 |
# |    n_updates       | 448307   |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 3.66e+03  |
# |    ep_rew_mean     | 3.2e+04   |
# | time/              |           |
# |    episodes        | 552       |
# |    fps             | 27        |
# |    time_elapsed    | 53280     |
# |    total_timesteps | 1454476   |
# | train/             |           |
# |    actor_loss      | -1.78e+03 |
# |    critic_loss     | 1.98e+04  |
# |    ent_coef        | 0.758     |
# |    ent_coef_loss   | -0.0633   |
# |    learning_rate   | 0.000824  |
# |    n_updates       | 1454375   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 3.47e+03  |
# |    ep_rew_mean     | 2.44e+04  |
# | time/              |           |
# |    episodes        | 556       |
# |    fps             | 27        |
# |    time_elapsed    | 53303     |
# |    total_timesteps | 1455164   |
# | train/             |           |
# |    actor_loss      | -1.86e+03 |
# |    critic_loss     | 7.27e+03  |
# |    ent_coef        | 0.807     |
# |    ent_coef_loss   | -0.0105   |
# |    learning_rate   | 0.000824  |
# |    n_updates       | 1455063   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 3.31e+03  |
# |    ep_rew_mean     | 1.85e+04  |
# | time/              |           |
# |    episodes        | 560       |
# |    fps             | 27        |
# |    time_elapsed    | 53365     |
# |    total_timesteps | 1457071   |
# | train/             |           |
# |    actor_loss      | -1.85e+03 |
# |    critic_loss     | 3.51e+03  |
# |    ent_coef        | 0.763     |
# |    ent_coef_loss   | 0.0138    |
# |    learning_rate   | 0.000823  |
# |    n_updates       | 1456970   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 3.13e+03  |
# |    ep_rew_mean     | 1.11e+04  |
# | time/              |           |
# |    episodes        | 564       |
# |    fps             | 27        |
# |    time_elapsed    | 53425     |
# |    total_timesteps | 1458893   |
# | train/             |           |
# |    actor_loss      | -1.56e+03 |
# |    critic_loss     | 7.64e+04  |
# |    ent_coef        | 2.85      |
# |    ent_coef_loss   | -0.704    |
# |    learning_rate   | 0.000823  |
# |    n_updates       | 1458792   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.93e+03  |
# |    ep_rew_mean     | 3.48e+03  |
# | time/              |           |
# |    episodes        | 568       |
# |    fps             | 27        |
# |    time_elapsed    | 53438     |
# |    total_timesteps | 1459315   |
# | train/             |           |
# |    actor_loss      | -2.12e+03 |
# |    critic_loss     | 2.92e+03  |
# |    ent_coef        | 3.64      |
# |    ent_coef_loss   | -0.0758   |
# |    learning_rate   | 0.000823  |
# |    n_updates       | 1459214   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.74e+03  |
# |    ep_rew_mean     | -4.05e+03 |
# | time/              |           |
# |    episodes        | 572       |
# |    fps             | 27        |
# |    time_elapsed    | 53452     |
# |    total_timesteps | 1459732   |
# | train/             |           |
# |    actor_loss      | -1.92e+03 |
# |    critic_loss     | 2.28e+05  |
# |    ent_coef        | 3.78      |
# |    ent_coef_loss   | 1.41      |
# |    learning_rate   | 0.000823  |
# |    n_updates       | 1459631   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.54e+03  |
# |    ep_rew_mean     | -1.17e+04 |
# | time/              |           |
# |    episodes        | 576       |
# |    fps             | 27        |
# |    time_elapsed    | 53466     |
# |    total_timesteps | 1460159   |
# | train/             |           |
# |    actor_loss      | -2.19e+03 |
# |    critic_loss     | 5.92e+03  |
# |    ent_coef        | 3.24      |
# |    ent_coef_loss   | 0.25      |
# |    learning_rate   | 0.000823  |
# |    n_updates       | 1460058   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.36e+03  |
# |    ep_rew_mean     | -1.91e+04 |
# | time/              |           |
# |    episodes        | 580       |
# |    fps             | 27        |
# |    time_elapsed    | 53510     |
# |    total_timesteps | 1461527   |
# | train/             |           |
# |    actor_loss      | -2.1e+03  |
# |    critic_loss     | 1.37e+04  |
# |    ent_coef        | 2.18      |
# |    ent_coef_loss   | 0.594     |
# |    learning_rate   | 0.000823  |
# |    n_updates       | 1461426   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.19e+03  |
# |    ep_rew_mean     | -2.63e+04 |
# | time/              |           |
# |    episodes        | 584       |
# |    fps             | 27        |
# |    time_elapsed    | 53627     |
# |    total_timesteps | 1465092   |
# | train/             |           |
# |    actor_loss      | -2.06e+03 |
# |    critic_loss     | 8.38e+04  |
# |    ent_coef        | 1.24      |
# |    ent_coef_loss   | -0.146    |
# |    learning_rate   | 0.000822  |
# |    n_updates       | 1464991   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.19e+03  |
# |    ep_rew_mean     | -2.68e+04 |
# | time/              |           |
# |    episodes        | 588       |
# |    fps             | 27        |
# |    time_elapsed    | 54329     |
# |    total_timesteps | 1485092   |
# | train/             |           |
# |    actor_loss      | -2.25e+03 |
# |    critic_loss     | 4.88e+04  |
# |    ent_coef        | 2.09      |
# |    ent_coef_loss   | 0.124     |
# |    learning_rate   | 0.00082   |
# |    n_updates       | 1484991   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.19e+03  |
# |    ep_rew_mean     | -2.82e+04 |
# | time/              |           |
# |    episodes        | 592       |
# |    fps             | 27        |
# |    time_elapsed    | 54990     |
# |    total_timesteps | 1504802   |
# | train/             |           |
# |    actor_loss      | -1.75e+03 |
# |    critic_loss     | 2.79e+03  |
# |    ent_coef        | 0.72      |
# |    ent_coef_loss   | -0.0275   |
# |    learning_rate   | 0.000818  |
# |    n_updates       | 1504701   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.23e+03  |
# |    ep_rew_mean     | -2.65e+04 |
# | time/              |           |
# |    episodes        | 596       |
# |    fps             | 27        |
# |    time_elapsed    | 55490     |
# |    total_timesteps | 1524802   |
# | train/             |           |
# |    actor_loss      | -826      |
# |    critic_loss     | 8.12e+04  |
# |    ent_coef        | 0.71      |
# |    ent_coef_loss   | 0.0651    |
# |    learning_rate   | 0.000815  |
# |    n_updates       | 1524701   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.27e+03  |
# |    ep_rew_mean     | -2.54e+04 |
# | time/              |           |
# |    episodes        | 600       |
# |    fps             | 27        |
# |    time_elapsed    | 55983     |
# |    total_timesteps | 1544802   |
# | train/             |           |
# |    actor_loss      | -1.16e+03 |
# |    critic_loss     | 4.36e+04  |
# |    ent_coef        | 0.686     |
# |    ent_coef_loss   | -0.0147   |
# |    learning_rate   | 0.000813  |
# |    n_updates       | 1544701   |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\rl_levitation_control\SAC_2GDLcrashAliveVelocidades.ipynb Cell 10 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/rl_levitation_control/SAC_2GDLcrashAliveVelocidades.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> # Train the agent
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/rl_levitation_control/SAC_2GDLcrashAliveVelocidades.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> model.learn(total_timesteps=8250000,
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/rl_levitation_control/SAC_2GDLcrashAliveVelocidades.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a>     callback=[
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/rl_levitation_control/SAC_2GDLcrashAliveVelocidades.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a>         checkpoint_callback,
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/rl_levitation_control/SAC_2GDLcrashAliveVelocidades.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a>         WandbCallback(
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/rl_levitation_control/SAC_2GDLcrashAliveVelocidades.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a>             gradient_save_freq=10000,
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/rl_levitation_control/SAC_2GDLcrashAliveVelocidades.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a>             model_save_path=f"models/2gdl8x8alive",
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/rl_levitation_control/SAC_2GDLcrashAliveVelocidades.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a>             model_save_freq=10000,
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/rl_levitation_control/SAC_2GDLcrashAliveVelocidades.ipynb#X12sZmlsZQ%3D%3D?line=8'>9</a>             verbose=2,
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/rl_levitation_control/SAC_2GDLcrashAliveVelocidades.ipynb#X12sZmlsZQ%3D%3D?line=9'>10</a>         ),
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/rl_levitation_control/SAC_2GDLcrashAliveVelocidades.ipynb#X12sZmlsZQ%3D%3D?line=10'>11</a>     ],
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/rl_levitation_control/SAC_2GDLcrashAliveVelocidades.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a> )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\sac\sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\off_policy_algorithm.py:331, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     329         # Special case when the user passes `gradient_steps=0`
#     330         if gradient_steps > 0:
# --> 331             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     333 callback.on_training_end()
#     335 return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\sac\sac.py:268, in SAC.train(self, gradient_steps, batch_size)
#     266 self.critic.optimizer.zero_grad()
#     267 critic_loss.backward()
# --> 268 self.critic.optimizer.step()
#     270 # Compute actor loss
#     271 # Alternative: actor_loss = th.mean(log_prob - qf1_pi)
#     272 # Min over all critic networks
#     273 q_values_pi = th.cat(self.critic(replay_data.observations, actions_pi), dim=1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\optim\optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\optim\optimizer.py:33, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      31 try:
#      32     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 33     ret = func(self, *args, **kwargs)
#      34 finally:
#      35     torch.set_grad_enabled(prev_grad)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\optim\adam.py:141, in Adam.step(self, closure)
#     130     beta1, beta2 = group['betas']
#     132     self._init_group(
#     133         group,
#     134         params_with_grad,
#    (...)
#     138         max_exp_avg_sqs,
#     139         state_steps)
# --> 141     adam(
#     142         params_with_grad,
#     143         grads,
#     144         exp_avgs,
#     145         exp_avg_sqs,
#     146         max_exp_avg_sqs,
#     147         state_steps,
#     148         amsgrad=group['amsgrad'],
#     149         beta1=beta1,
#     150         beta2=beta2,
#     151         lr=group['lr'],
#     152         weight_decay=group['weight_decay'],
#     153         eps=group['eps'],
#     154         maximize=group['maximize'],
#     155         foreach=group['foreach'],
#     156         capturable=group['capturable'],
#     157         differentiable=group['differentiable'],
#     158         fused=group['fused'],
#     159         grad_scale=getattr(self, "grad_scale", None),
#     160         found_inf=getattr(self, "found_inf", None),
#     161     )
#     163 return loss
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\optim\adam.py:281, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     278 else:
#     279     func = _single_tensor_adam
# --> 281 func(params,
#     282      grads,
#     283      exp_avgs,
#     284      exp_avg_sqs,
#     285      max_exp_avg_sqs,
#     286      state_steps,
#     287      amsgrad=amsgrad,
#     288      beta1=beta1,
#     289      beta2=beta2,
#     290      lr=lr,
#     291      weight_decay=weight_decay,
#     292      eps=eps,
#     293      maximize=maximize,
#     294      capturable=capturable,
#     295      differentiable=differentiable,
#     296      grad_scale=grad_scale,
#     297      found_inf=found_inf)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\optim\adam.py:393, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     390 else:
#     391     denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
# --> 393 param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:

# %%
episodes = 3
state, seed = env.reset()
for episode in range(1, episodes+1):
    state, seed = env.reset()
    done = False
    score = 0
    while not done:
        action = env.action_space.sample()
        n_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# Episode:1 Score:-57087.66697450366
# Episode:2 Score:-57169.60609087738
# Episode:3 Score:-57424.86711319699

# %%
b = Bobina()
b.airgap = 9

# %%
b.step(100)
# Out:
# ((20.00214, -0.10582279, 3.7021403, 45.0), False)

# %%
import numpy as np
import torch as th
import time

MODEL_PATH = f"models/2gdl8x8alive/model.zip"

# Create and wrap the environment
env = BobinaEnv(duration = 6)

# Load the trained agent
model = SAC.load(MODEL_PATH, env=env, learning_rate = 0.00001)

# Evaluate the agent
for i in range(1):
    obs, seed = env.reset()
    done = False
    episode_reward = 0
    velocidad = 0
    current = 0
    observations = []
    noises = []
    timepredict = 0
    timemodel = 0
    distancia1, distancia2, vel, velangular, current1, current2 = obs
    while not done:
        #noise = random.uniform(-1, 1)
        #obs = obs + noise
        observations.append(obs)
        #noises.append(noise)
        t1 = time.time()
        action, _states = model.predict(np.array([distancia1, distancia2, vel, velangular, current1, current2]), deterministic=True)
        t2 = time.time()
        #print(action)
        #if env.airgap > 10.1: action = max(action, [-50])
        #print(action)
        t3 = time.time()
        state, reward, terminated, truncated, info = env.step(np.array(action))
        t4 = time.time()
        distancia1, distancia2, vel, velangular, current1, current2 = state
        done = truncated or terminated
        episode_reward += reward
        timepredict += t2 - t1
        timemodel += t4 - t3
        noises.append(action)
    print("Time predict", timepredict)
    print("Time model", timemodel)
    print("Episode reward", episode_reward)
    print(noises)
    env.render("yes")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Time predict 2.9350807666778564
# Time model 63.32553696632385
# Episode reward 118262.30219220565
# [array([-23.273544, -72.080414], dtype=float32), array([-23.50933 , -72.057335], dtype=float32), array([-17.99871 , -16.209045], dtype=float32), array([-9.921661, 23.055077], dtype=float32), array([-2.6200485,  2.438507 ], dtype=float32), array([  0.83205414, -23.705986  ], dtype=float32), array([ -0.19450378, -13.991295  ], dtype=float32), array([-2.3221588,  8.349968 ], dtype=float32), array([-2.5392761,  7.554474 ], dtype=float32), array([-1.4634933, -8.988403 ], dtype=float32), array([ -1.171608, -13.341164], dtype=float32), array([-1.8595428, -2.948021 ], dtype=float32), array([-2.1978683,  3.2639236], dtype=float32), array([-1.7231369, -2.2937546], dtype=float32), array([-1.2672958, -8.229622 ], dtype=float32), array([-1.4046631, -5.938545 ], dtype=float32), array([-1.7050018 , -0.99414825], dtype=float32), array([-1.6327591, -1.1572113], dtype=float32), array([-1.3377838, -4.6785507], dtype=float32), array([-1.2442398, -5.5246735], dtype=float32), array([-1.3675308, -3.2162628], dtype=float32), array([-1.4137955, -1.8958511], dtype=float32), array([-1.2854614, -3.1129608], dtype=float32), array([-1.1617126, -4.3614655], dtype=float32), array([-1.1656494, -3.8127213], dtype=float32), array([-1.2016449, -2.725769 ], dtype=float32), array([-1.1548462, -2.7662964], dtype=float32), array([-1.0616837, -3.5133667], dtype=float32), array([-1.0150528, -3.658722 ], dtype=float32), array([-1.0158386, -3.1296616], dtype=float32), array([-0.9982681, -2.8382568], dtype=float32), array([-0.9427948, -3.0970688], dtype=float32), array([-0.8907547, -3.3449478], dtype=float32), array([-0.86782074, -3.1987762 ], dtype=float32), array([-0.8520889, -2.948822 ], dtype=float32), array([-0.8187561, -2.9515686], dtype=float32), array([-0.7766571, -3.1021194], dtype=float32), array([-0.74585724, -3.1158295 ], dtype=float32), array([-0.7260208, -2.9865189], dtype=float32), array([-0.70241547, -2.9155045 ], dtype=float32), array([-0.67144775, -2.9645538 ], dtype=float32), array([-0.6423416, -3.0075455], dtype=float32), array([-0.62047577, -2.9647903 ], dtype=float32), array([-0.6009064, -2.9031754], dtype=float32), array([-0.57810974, -2.8990173 ], dtype=float32), array([-0.55443573, -2.9260101 ], dtype=float32), array([-0.53409576, -2.922493  ], dtype=float32), array([-0.51698303, -2.8894806 ], dtype=float32), array([-0.6932831, -2.7601242], dtype=float32), array([-0.93244934, -2.7564087 ], dtype=float32), array([-1.0397797, -3.0470276], dtype=float32), array([-1.0564423, -3.303299 ], dtype=float32), array([-1.0612335, -3.2344666], dtype=float32), array([-1.0681   , -3.0407639], dtype=float32), array([-1.0596848, -3.0319672], dtype=float32), array([-1.0430679, -3.1605225], dtype=float32), array([-1.0403519, -3.1901627], dtype=float32), array([-1.0508652, -3.0966187], dtype=float32), array([-1.0559158, -3.0482635], dtype=float32), array([-1.0495987, -3.103447 ], dtype=float32), array([-1.0437622, -3.1507797], dtype=float32), array([-1.0459061, -3.1178284], dtype=float32), array([-1.048912 , -3.0703888], dtype=float32), array([-1.0457382, -3.0790863], dtype=float32), array([-1.0397568, -3.1125412], dtype=float32), array([-1.0370865, -3.110077 ], dtype=float32), array([-1.0369873, -3.0796356], dtype=float32), array([-1.034317, -3.068924], dtype=float32), array([-1.0287399, -3.083786 ], dtype=float32), array([-1.0234985, -3.0906143], dtype=float32), array([-1.019989 , -3.0756989], dtype=float32), array([-1.0159607, -3.0609894], dtype=float32), array([-1.0102386, -3.061905 ], dtype=float32), array([-1.0037079, -3.0668564], dtype=float32), array([-0.99794006, -3.0609589 ], dtype=float32), array([-0.992363 , -3.0488434], dtype=float32), array([-0.9858322, -3.043335 ], dtype=float32), array([-0.9782486, -3.0437927], dtype=float32), array([-0.97078705, -3.0406418 ], dtype=float32), array([-0.96347046, -3.032013  ], dtype=float32), array([-0.9556503, -3.024414 ], dtype=float32), array([-0.9471588, -3.0209045], dtype=float32), array([-0.93829346, -3.0177383  ...
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import torch as th

from stable_baselines3 import SAC

#import onnx
import onnxruntime as ort
import numpy as np


class OnnxablePolicy(th.nn.Module):
    def __init__(self, actor: th.nn.Module):
        super().__init__()
        # Removing the flatten layer because it can't be onnxed
        self.actor = th.nn.Sequential(
            actor.latent_pi,
            actor.mu,
            # For gSDE
            # th.nn.Hardtanh(min_val=-actor.clip_mean, max_val=actor.clip_mean),
            # Squash the output
            th.nn.Tanh(),
        )

    def forward(self, observation: th.Tensor) -> th.Tensor:
        # NOTE: You may have to process (normalize) observation in the correct
        #       way before using this. See `common.preprocessing.preprocess_obs`
        return self.actor(observation)


# Example: model = SAC("MlpPolicy", "Pendulum-v1")
model = SAC.load(f"models/sac8x8h9.3/model.zip", device="cpu")
onnxable_model = OnnxablePolicy(model.policy.actor)

observation_size = model.observation_space.shape
dummy_input = th.randn(1, *observation_size)
th.onnx.export(
    onnxable_model,
    dummy_input,
    "./ONNX/1gdlComplexH98x8.onnx",
    opset_version=9,
    input_names=["input"],
)

##### Load and test with onnx

import onnxruntime as ort
import numpy as np

onnx_path = "./ONNX/1gdlComplexH98x8.onnx"

observation = np.zeros((1, *observation_size)).astype(np.float32)
ort_sess = ort.InferenceSession(onnx_path)
action = ort_sess.run(None, {"input": observation})
# Out:
# ============== Diagnostic Run torch.onnx.export version 2.0.0+cpu ==============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
model.policy
# Out:
# SACPolicy(
#   (actor): Actor(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (latent_pi): Sequential(
#       (0): Linear(in_features=4, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=8, bias=True)
#       (3): ReLU()
#     )
#     (mu): Linear(in_features=8, out_features=1, bias=True)
#     (log_std): Linear(in_features=8, out_features=1, bias=True)
#   )
#   (critic): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (critic_target): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )

# %%
# See "ONNX export" for imports and OnnxablePolicy
jit_path = "1gdlComplex.pt"

# Trace and optimize the module
traced_module = th.jit.trace(onnxable_model.eval(), dummy_input)
frozen_module = th.jit.freeze(traced_module)
frozen_module = th.jit.optimize_for_inference(frozen_module)
th.jit.save(frozen_module, jit_path)

##### Load and test with torch

import torch as th

dummy_input = th.randn(1, *observation_size)
loaded_module = th.jit.load(jit_path)
action_jit = loaded_module(dummy_input)
