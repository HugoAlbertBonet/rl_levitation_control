# %%
from gymnasium import Env
from gymnasium.spaces.box import Box
import numpy as np
import random
from stable_baselines3 import SAC
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback, StopTrainingOnRewardThreshold, EvalCallback
from stable_baselines3.common.noise import NormalActionNoise
import wandb
from wandb.integration.sb3 import WandbCallback
import os
import matplotlib.pyplot as plt
import scipy.io
import numpy as np
import pickle
import warnings
import math
warnings.filterwarnings("ignore")

# %%
class BobinaEnvTest(Env):
  """
  Custom Gym Environment for the Hybrid Electromagnetic Suspension, considering just two degrees of freedom.
  """
  def __init__(self, alive = 20, masa_pod = 250, airgap = 16.3, duration = 10, dist_cm = 0.7, inercia= 70, min_distance = 9, max_distance = 22.5):
    # Actions: Voltage applied to the coil
    self.action_space = Box(low=np.array([-100, -100]), high = np.array([100, 100]), dtype=np.float32)
    # Observations: Airgap to the ceiling, velocity, distance to the objective, current of the coil
    self.observation_space = Box(low=np.array([-10, -10, -np.inf, -np.inf, -45, -45]), high = np.array([10, 10, np.inf, np.inf, 45, 45]), dtype=np.float32)
    # Initial parameters
    airgap = random.uniform(15.3, 17.3)
    self.state = np.array([airgap - 16.3, airgap - 16.3, 0, 0, 0, 0])
    self.airgapinicial = airgap
    self.duration = duration
    self.timeleft = duration
    self.crash = False
    self.masa_pod = masa_pod
    self.sistema = TwoGDL(masa_pod = self.masa_pod, airgap = self.airgapinicial, dist_cm = dist_cm, inercia= inercia, min_distance = min_distance, max_distance = max_distance)
    self.steps = []
    self.airgap1 = airgap
    self.airgap2 = airgap
    self.distancia1 = 0
    self.distancia2 = 0
    self.velocidad = 0
    self.current1 = 0
    self.current2 = 0
    self.alive = alive
    self.vel = 0
    self.velangular = 0


  def step(self, action):
    # Apply action
    self.state, self.crash, angulo, error = self.sistema.step(action[0],action[1])
    self.distancia1, self.distancia2, self.vel, self.velangular, self.current1, self.current2 = self.state

    # Reduce the time of the experiment
    self.timeleft -= 0.001

    # Calculate reward
    reward = -abs(self.distancia1) -abs(self.distancia2) - 10000*self.crash

    """if self.airgap >= 23: reward = -500
    elif self.airgap <= 10: reward = -500
    else: reward = -abs(self.current)"""

    # Check if experiment is done
    if self.timeleft <= 0:
      truncated = True
    else: truncated = False
    # Set placeholder for info
    info = {}
    # Only if we implemented the crash
    """if self.crash:
      reward = - 100000
      terminated = True
    else:
      terminated = False"""
    terminated = False
    self.steps.append(self.state)
    return self.state, reward, terminated, truncated, info


  def render(self, yes = "yes", normalize = True, seed = 0):
    # create data
    x = list(range(0,len(self.steps)))
    y1 = [16.3+step[0] for step in self.steps]
    y2 = [16.3+step[1] for step in self.steps]
    objective = [16.3]*len(self.steps)

    # plot lines
    fig = plt.figure(figsize=(10,5))
    ax = fig.add_subplot(111)
    #ax.tick_params(axis='x', colors='white')    #setting up X-axis tick color to red
    #ax.tick_params(axis='y', colors='white')  #setting up Y-axis tick color to black
    if normalize: ax.set_ylim(bottom=8, top=23)
    plt.xlabel("Time (s)") #, color='white')
    plt.ylabel("Airgap (mm)") #, color='white')
    plt.title("Airgap evolution") #, color='white')

    plt.plot(x, y1, label = "Airgap 1")
    plt.plot(x, y2, label = "Airgap 2")
    plt.plot(x, objective, label = "Objective")
    plt.legend()
    #if self.steps[0][0] < 0: plt.savefig("images/top-2gdl8x8nocrash.png")
    #else: plt.savefig("images/bottom-2gdl8x8nocrash.png")
    plt.savefig(f"images/2gdl8x8nocrashsituation{seed}.png")
    plt.show()

  def reset(self, seed = 0):
    # Reset experiment choosing randomly the start (ceiling or floor)
    airgap = random.uniform(9.5, 22)
    #self.state = np.array([airgap - 16.3, airgap - 16.3, 0, 0, 0, 0])
    self.sistema = TwoGDL(masa_pod = self.masa_pod, airgap = airgap, dist_cm = 0.7, inercia= 70, min_distance = 9, max_distance = 22.5)
    angulo = random.uniform(-0.008, 0.008)
    self.vel = random.uniform(-0.2, 0.2)
    self.velangular = random.uniform(-0.3, 0.3)
    self.current1 = 0
    self.current2 = 0
    airgap1, airgap2 = self.sistema.pos2airgap(pos = airgap, theta = angulo)
    self.distancia1, self.distancia2 = airgap1-16.3, airgap2-16.3
    self.state= self.distancia1, self.distancia2, self.vel, self.velangular, self.current1, self.current2
    self.sistema.integral_aceleracion = self.vel
    self.sistema.integral_alpha = self.velangular
    self.sistema.integral_omega = angulo
    self.state, self.crash = self.sistema.step(0,0)
    self.distancia11, self.distancia12, self.distancia21, self.distancia22, self.current1, self.current2 = self.state
    
    # Reset time
    self.timeleft = self.duration
    self.crash = False
    self.steps = []
    return self.state, seed

# %%
class TestSpeedEnv(Env):
  """
  Custom Gym Environment for the Hybrid Electromagnetic Suspension, considering just two degrees of freedom.
  """
  def __init__(self, alive = 20, masa_pod = 250, airgap = 16.3, duration = 10, dist_cm = 0.7, inercia= 70, min_distance = 9, max_distance = 22.5):
    # Actions: Voltage applied to the coil
    self.action_space = Box(low=np.array([-100, -100]), high = np.array([100, 100]), dtype=np.float32)
    # Observations: Airgap to the ceiling, velocity, distance to the objective, current of the coil
    self.observation_space = Box(low=np.array([-10, -10, -10, -10, -45, -45]), high = np.array([10, 10, 10, 10, 45, 45]), dtype=np.float32)
    # Initial parameters
    airgap = random.uniform(10, 21.5)
    variacion = random.uniform(-0.06, 0.06)
    self.state = np.array([airgap - 16.3, airgap + variacion - 16.3, airgap - 16.3, airgap + variacion - 16.3, 0, 0])
    self.airgapinicial = airgap + variacion
    self.duration = duration
    self.timeleft = duration
    self.crash = False
    self.masa_pod = masa_pod
    self.sistema = TwoGDL(masa_pod = self.masa_pod, airgap = self.airgapinicial, dist_cm = dist_cm, inercia= inercia, min_distance = min_distance, max_distance = max_distance)
    self.sistema.integral_aceleracion = variacion
    self.steps = []
    self.airgap1 = airgap
    self.airgap2 = airgap 
    self.distancia1 = 0
    self.distancia2 = 0
    self.velocidad = 0
    self.current1 = 0
    self.current2 = 0
    self.alive = alive
    self.vel = variacion
    self.velangular = 0
    self.prev_error = (airgap - 16.3/7.3)**2


  def step(self, action):
    # Apply action
    self.state, self.crash = self.sistema.step(action[0],action[1])
    self.distancia11, self.distancia12, self.distancia21, self.distancia22, self.current1, self.current2 = self.state

    # Reduce the time of the experiment
    self.timeleft -= 0.001

    # Calculate reward
    error = ((self.distancia12/7.3)**2 + (self.distancia22/7.3)**2)/2
    reward_raw = 1 - error
    if self.crash: 
      reward_bonus = -0.4
    else:
      if self.prev_error > error: reward_bonus = 0.2
      else: reward_bonus = -0.2

    reward = reward_raw + reward_bonus
    self.prev_error = error



    # Check if experiment is done
    if self.timeleft <= 0:
      truncated = True
    else: truncated = False
    # Set placeholder for info
    info = {}
    # Only if we implemented the crash
    """if self.crash:
      reward = - 100000
      terminated = True
    else:
      terminated = False"""
    terminated = False
    self.steps.append(self.state)
    return self.state, reward, terminated, truncated, info


  def render(self, yes = "yes", normalize = True, seed = 0):
    # create data
    x = list(range(0,len(self.steps)))
    y1 = [16.3+step[0] for step in self.steps]
    y2 = [16.3+step[2] for step in self.steps]
    objective = [16.3]*len(self.steps)

    # plot lines
    fig = plt.figure(figsize=(10,5))
    ax = fig.add_subplot(111)
    #ax.tick_params(axis='x', colors='white')    #setting up X-axis tick color to red
    #ax.tick_params(axis='y', colors='white')  #setting up Y-axis tick color to black
    if normalize: ax.set_ylim(bottom=8, top=23)
    plt.xlabel("Time (s)") #, color='white')
    plt.ylabel("Airgap (mm)") #, color='white')
    plt.title("Airgap evolution") #, color='white')

    plt.plot(x, y1, label = "Airgap 1")
    plt.plot(x, y2, label = "Airgap 2")
    plt.plot(x, objective, label = "Objective")
    plt.legend()
    #if self.steps[0][0] < 0: plt.savefig("images/top-2gdl8x8nocrash.png")
    #else: plt.savefig("images/bottom-2gdl8x8nocrash.png")
    plt.savefig(f"images/2gdl8x8nocrashsituation{seed}.png")
    plt.show()

  def reset(self, seed = 0):
    # Reset experiment choosing randomly the start (ceiling or floor)
    airgap = random.uniform(10, 21.5)
    variacion = random.uniform(-0.06, 0.06)
    self.state = np.array([airgap - 16.3, airgap + variacion - 16.3, airgap - 16.3, airgap + variacion - 16.3, 0, 0])
    self.sistema = TwoGDL(masa_pod = self.masa_pod, airgap = airgap, dist_cm = 0.7, inercia= 70, min_distance = 9, max_distance = 22.5)
    self.sistema.integral_aceleracion = variacion
    self.vel = variacion
    
    # Reset time
    self.timeleft = self.duration
    self.crash = False
    self.steps = []
    return self.state, seed

# %%
class BobinaEnv(Env):
  """
  Custom Gym Environment for the Hybrid Electromagnetic Suspension, considering just two degrees of freedom.
  """
  def __init__(self, alive = 20, masa_pod = 250, airgap = 16.3, duration = 10, dist_cm = 0.7, inercia= 70, min_distance = 9, max_distance = 22.5):
    # Actions: Voltage applied to the coil
    self.action_space = Box(low=np.array([-100, -100]), high = np.array([100, 100]), dtype=np.float32)
    # Observations: Airgap to the ceiling, velocity, distance to the objective, current of the coil
    self.observation_space = Box(low=np.array([-10, -10, -10, -10, -45, -45]), high = np.array([10, 10, 10, 10, 45, 45]), dtype=np.float32)
    # Initial parameters
    airgap = random.choice([13, 19])
    self.state = np.array([airgap - 16.3, airgap - 16.3, airgap - 16.3, airgap - 16.3, 0, 0])
    self.airgapinicial = airgap
    self.duration = duration
    self.timeleft = duration
    self.crash = False
    self.masa_pod = masa_pod
    self.sistema = TwoGDL(masa_pod = self.masa_pod, airgap = self.airgapinicial, dist_cm = dist_cm, inercia= inercia, min_distance = min_distance, max_distance = max_distance)
    self.steps = []
    self.airgap1 = airgap
    self.airgap2 = airgap
    self.distancia1 = 0
    self.distancia2 = 0
    self.velocidad = 0
    self.current1 = 0
    self.current2 = 0
    self.alive = alive
    self.vel = 0
    self.velangular = 0
    self.prev_error = (airgap - 16.3/7.3)**2


  def step(self, action):
    # Apply action
    self.state, self.crash = self.sistema.step(action[0],action[1])
    self.distancia11, self.distancia12, self.distancia21, self.distancia22, self.current1, self.current2 = self.state

    # Reduce the time of the experiment
    self.timeleft -= 0.001

    # Calculate reward
    error = ((self.distancia12/7.3)**2 + (self.distancia22/7.3)**2)/2
    reward_raw = 1 - error
    if error > (4.7/7.3)**2: 
      reward_bonus = -0.4
    else:
      if self.prev_error > error: reward_bonus = 0.2
      else: reward_bonus = -0.2

    reward = reward_raw + reward_bonus
    self.prev_error = error



    # Check if experiment is done
    if self.timeleft <= 0:
      truncated = True
    else: truncated = False
    # Set placeholder for info
    info = {}
    # Only if we implemented the crash
    """if self.crash:
      reward = - 100000
      terminated = True
    else:
      terminated = False"""
    terminated = False
    self.steps.append(self.state)
    return self.state, reward, terminated, truncated, info


  def render(self, yes = "yes", normalize = True, seed = 0):
    # create data
    x = list(range(0,len(self.steps)))
    y1 = [16.3+step[0] for step in self.steps]
    y2 = [16.3+step[2] for step in self.steps]
    objective = [16.3]*len(self.steps)

    # plot lines
    fig = plt.figure(figsize=(10,5))
    ax = fig.add_subplot(111)
    #ax.tick_params(axis='x', colors='white')    #setting up X-axis tick color to red
    #ax.tick_params(axis='y', colors='white')  #setting up Y-axis tick color to black
    if normalize: ax.set_ylim(bottom=8, top=23)
    plt.xlabel("Time (s)") #, color='white')
    plt.ylabel("Airgap (mm)") #, color='white')
    plt.title("Airgap evolution") #, color='white')

    plt.plot(x, y1, label = "Airgap 1")
    plt.plot(x, y2, label = "Airgap 2")
    plt.plot(x, objective, label = "Objective")
    plt.legend()
    #if self.steps[0][0] < 0: plt.savefig("images/top-2gdl8x8nocrash.png")
    #else: plt.savefig("images/bottom-2gdl8x8nocrash.png")
    plt.savefig(f"images/2gdl8x8nocrashsituation{seed}.png")
    plt.show()

  def reset(self, seed = 0):
    # Reset experiment choosing randomly the start (ceiling or floor)
    airgap = random.choice([13, 19])
    self.state = np.array([airgap - 16.3, airgap - 16.3, airgap - 16.3, airgap - 16.3, 0, 0])
    self.sistema = TwoGDL(masa_pod = self.masa_pod, airgap = airgap, dist_cm = 0.7, inercia= 70, min_distance = 9, max_distance = 22.5)
    
    # Reset time
    self.timeleft = self.duration
    self.crash = False
    self.steps = []
    return self.state, seed

# %%
class Bobina():
  """ 
  Coil model for the Hybrid Electromagnetic Suspension
  """
  def __init__(self, masa_pod = 250, airgap = 22.5, min_distance = 9, max_distance = 22.5):
    self.masa_pod = masa_pod
    self.airgap = airgap
    self.aceleracion = []
    self.velocidad = []
    mat = scipy.io.loadmat('./coil/hems.mat')
    self.hems = mat["hems"][0][0]
    self.airgaps = self.hems[0][0]
    self.currents = self.hems[1][0]
    self.force_vertical = pickle.load(open("./coil/mlp_vertical.pkl", 'rb'))
    self.flux = self.hems[3]
    self.force_horizontal = self.hems[4]
    self.inductance = pickle.load(open("./coil/rf_inductance.pkl", 'rb'))
    self.resistance = self.hems[6][0][0]
    self.min_distance = min_distance
    self.max_distance = max_distance
    self.airgapinicial = airgap
    self.crash = False
    self.current = 0
    self.steps_RL = []

  def integral(self, lista, h = 1):
    return sum(h*(lista[i]+lista[i+1])/2 for i in range(len(lista)-1))

  def RL(self, airgap, target_voltage, temperature):
    # Resistance-Inductance circuit

    # Get resistance of the coil
    R = self.R(current = self.current, temperature = temperature)   
    V = target_voltage
    I = self.current
    L = self.L(airgap = airgap, current = self.current)
    dIdt = ((V/R) - I)/(L/R)                                      
    self.steps_RL.append(dIdt)                                   
    current = self.integral(self.steps_RL, h = 0.001)                          
    return current                                                  

  def R(self, current, temperature):
    return self.resistance                                         

  def L(self, airgap, current):
    # Return predicted inductance
    return float(self.inductance.predict(np.array([[airgap, current]]))[0])

  def vertical_force(self, airgap, target_voltage, temperature):
    # Get current from RL circuit
    I = self.RL(airgap = airgap, target_voltage = target_voltage, temperature = temperature) 
    
    # Clip result
    if I > 45:
      I = 45
    elif I < -45:
      I = -45
    self.current = I
    # Get vertical force from 
    FI = self.FI_vertical(airgap = airgap, current = I)                    
    return FI, I


  def FI_vertical(self, airgap, current):
    # Return predicted vertical force
    return float(self.force_vertical.predict(np.array([[airgap, current]])))    


  def next_airgap(self, masa_pod, vertical_force, verbose = False):
    # Devide the mass of the pod by 4 coils
    masa = masa_pod/4  
    # Calculate weight
    peso = masa * 9.8    
    # Get total force                                                       
    fuerza = peso - vertical_force
    if verbose: print("Fuerza resultante: ", fuerza)   
    # Calculate acceleration                                     
    aceleracion = fuerza/masa
    if verbose: print("Aceleración: ", aceleracion)                                         
    self.aceleracion.append(aceleracion)       
    # Calculate velocity                                
    velocidad = self.integral(self.aceleracion, 0.001)
    if verbose: print("Integral primera (velocidad): ", velocidad)                          
    self.velocidad.append(velocidad)               
    # Calculate position (x1000 as to transform from m to mm)                            
    posicion = self.airgapinicial + self.integral(self.velocidad, 0.001)*1000 
    if verbose: print("Integral segunda (posición): ", posicion)

    # Clip position
    if posicion > self.max_distance:
      airgap = self.max_distance
      self.aceleracion = [0]
      self.velocidad = [0]  
      #self.crash = True     
      self.airgapinicial = self.max_distance                                               
    elif posicion < self.min_distance:
      airgap = self.min_distance
      self.aceleracion = [0]
      self.velocidad = [0]
      #self.crash = True
      self.airgapinicial = self.min_distance
    else: airgap = posicion
    return airgap, velocidad

  def step(self, target_voltage, verbose = False):
    # Calculate vertical force and current
    vertical_force, self.current = self.vertical_force(airgap = self.airgap, target_voltage = target_voltage, temperature = 40)
    if verbose: print("Fuerza vertical: ", vertical_force)
    # Calculate next airgap and velocity
    self.airgap, velocidad = self.next_airgap(self.masa_pod, vertical_force, verbose = verbose)
    #noise = np.random.normal(0,0.5)
    #self.airgap = self.airgap + noise     
    return (np.float32(self.airgap), np.float32(velocidad), np.float32(self.airgap - 16.3), np.float32(self.current)), self.crash

# %%
class TwoGDL():
    def __init__(self, masa_pod = 250, airgap = 22.5, dist_cm = 0.7, inercia= 70, min_distance = 9, max_distance = 22.5):
        self.masa_pod = masa_pod
        self.airgap1 = airgap
        self.airgap1_list = [airgap, airgap]
        self.airgap2 = airgap
        self.airgap2_list = [airgap, airgap]
        self.dist_cm = dist_cm
        self.inercia = inercia
        self.airgapinicial = airgap
        self.min_distance = min_distance
        self.max_distance = max_distance
        self.b1 = Bobina(masa_pod = self.masa_pod, airgap = self.airgap1, min_distance = self.min_distance, max_distance = self.max_distance)
        self.b2 = Bobina(masa_pod = self.masa_pod, airgap = self.airgap2, min_distance = self.min_distance, max_distance = self.max_distance)
        self.crash = False
        self.angulo = [0]
        self.alpha = [0]
        self.integral_alpha = 0
        self.omega = [0]
        self.integral_omega = 0
        self.altura = [0]
        self.aceleracion = [0]
        self.integral_aceleracion = 0
        self.velocidad = [0]
        self.integral_velocidad = 0
    
    def integral(self, lista, h = 1):
        return sum(h*(lista[i]+lista[i+1])/2 for i in range(len(lista)-1))
    
    def fast_integral(self, last, lista, h = 0.001):
        return last + h*(lista[-1]+lista[-2])/2
    
    def get_angulo(self, f1, f2):
        F1 = f1*self.dist_cm
        F2 = -f2*self.dist_cm
        M = F1+F2
        alpha = M/self.inercia
        self.alpha.append(alpha)
        omega = self.fast_integral(self.integral_alpha, self.alpha, 0.001)
        self.integral_alpha = omega
        self.omega.append(omega)
        angulo = self.fast_integral(self.integral_omega, self.omega, 0.001)
        self.integral_omega = angulo
        self.angulo.append(angulo)
        return angulo
    
    def get_altura(self, f1, f2):
        F = (self.masa_pod/2)*9.8 - f1 - f2
        a = F/(self.masa_pod/2)
        self.aceleracion.append(a)
        v = self.fast_integral(self.integral_aceleracion, self.aceleracion, 0.001)
        self.integral_aceleracion = v
        self.velocidad.append(v)
        zpos = self.fast_integral(self.integral_velocidad,self.velocidad, 0.001)
        self.integral_velocidad = zpos
        zpos = self.airgapinicial + zpos*1000
        self.altura.append(zpos)
        return zpos
    
    def pos2airgap(self, pos, theta):
        airgap1 = pos + self.dist_cm*math.sin(theta)*1000
        airgap2 = pos - self.dist_cm*math.sin(theta)*1000
        return airgap1, airgap2
    
    def step(self, target_voltage1, target_voltage2, verbose = False):
        # Calculate vertical force and current
        self.crash = False
        vertical_force1, current1 = self.b1.vertical_force(airgap = self.airgap1, target_voltage = target_voltage1, temperature = 40)
        vertical_force2, current2 = self.b2.vertical_force(airgap = self.airgap2, target_voltage = target_voltage2, temperature = 40)
        if verbose: print("Fuerza vertical 1: ", vertical_force1)
        if verbose: print("Fuerza vertical 2: ", vertical_force2)
        angulo = self.get_angulo(f1 = vertical_force1, f2 = vertical_force2)
        zpos = self.get_altura(f1 = vertical_force1, f2 = vertical_force2)
        self.airgap1, self.airgap2 = self.pos2airgap(pos = zpos, theta = angulo)
        self.airgap1_list.append(self.airgap1)
        self.airgap2_list.append(self.airgap2)
        if verbose: print("Airgap 1: ", self.airgap1)
        if verbose: print("Airgap 2: ", self.airgap2)
        if self.airgap1 > self.max_distance or self.airgap2 > self.max_distance:
            self.airgap1 = self.max_distance
            self.airgap2 = self.max_distance
            self.crash = True
            self.angulo = [0]
            self.alpha = [0]
            self.integral_alpha = 0
            self.omega = [0]
            self.integral_omega = 0
            self.altura = [0]
            self.aceleracion = [0]
            self.integral_aceleracion = 0
            self.velocidad = [0]
            self.integral_velocidad = 0
            self.airgapinicial = self.max_distance
        elif self.airgap1 < self.min_distance or self.airgap2 < self.min_distance:
            self.airgap1 = self.min_distance
            self.airgap2 = self.min_distance
            self.crash = True
            self.angulo = [0]
            self.alpha = [0]
            self.integral_alpha = 0
            self.omega = [0]
            self.integral_omega = 0
            self.altura = [0]
            self.aceleracion = [0]
            self.integral_aceleracion = 0
            self.velocidad = [0]
            self.integral_velocidad = 0
            self.airgapinicial = self.min_distance
        #return (np.float32(self.airgap1 -16.3), np.float32(self.airgap2-16.3), np.float32(current1), np.float32(current2)), self.crash
        #return (np.float32(self.airgap1 -16.3), np.float32(self.airgap2-16.3), np.float32(self.integral_aceleracion), np.float32(self.integral_alpha), np.float32(current1), np.float32(current2)), self.crash, angulo, zpos - 16.3
        return (np.float32(self.airgap1_list[-2] -16.3), np.float32(self.airgap1_list[-1] -16.3), np.float32(self.airgap2_list[-2] -16.3), np.float32(self.airgap2_list[-1] -16.3), np.float32(current1), np.float32(current2)), self.crash
        #añadir una que returnee los 2 errores y las 2 velocidades

# %%
run = wandb.init(
    project="2gdl",
    sync_tensorboard=True,
    monitor_gym=True,
)
# Out:
# Finishing last run (ID:kswgn991) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▂▂▂▂▂▂▂▂▂▃▃▄▄▅▅▆▆▇▇████████████████████</td></tr><tr><td>time/fps</td><td>██████████▅▅▅▅▅▅▅▅▅▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/actor_loss</td><td>▁▆▇█████████▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>train/critic_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/ent_coef</td><td>█▃▂▁▁▁▁▁▁▁▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/ent_coef_loss</td><td>▃▂▃▃▁▃▂▂▃▂▃▃▃▃▃▃▃▄▃▂▂▂▃▃▁▃▄▄▃▃▁▄▅▂█▂▄▄▂▄</td></tr><tr><td>train/learning_rate</td><td>████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>1740000</td></tr><tr><td>rollout/ep_len_mean</td><td>5000.0</td></tr><tr><td>rollout/ep_rew_mean</td><td>5001.50684</td></tr><tr><td>time/fps</td><td>37.0</td></tr><tr><td>train/actor_loss</td><td>-107.01126</td></tr><tr><td>train/critic_loss</td><td>0.10015</td></tr><tr><td>train/ent_coef</td><td>0.00789</td></tr><tr><td>train/ent_coef_loss</td><td>0.96396</td></tr><tr><td>train/learning_rate</td><td>0.00083</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vital-tree-47</strong> at: <a href='https://wandb.ai/hyperloopupv/2gdl/runs/kswgn991' target="_blank">https://wandb.ai/hyperloopupv/2gdl/runs/kswgn991</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 2 other file(s)
# Find logs at: <code>.\wandb\run-20240204_200104-kswgn991\logs</code>
# Successfully finished last run (ID:kswgn991). Initializing new run:<br/>
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\rl_levitation_control\wandb\run-20240205_102400-ycbqifra</code>
# Syncing run <strong><a href='https://wandb.ai/hyperloopupv/2gdl/runs/ycbqifra' target="_blank">youthful-waterfall-48</a></strong> to <a href='https://wandb.ai/hyperloopupv/2gdl' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hyperloopupv/2gdl' target="_blank">https://wandb.ai/hyperloopupv/2gdl</a>
#  View run at <a href='https://wandb.ai/hyperloopupv/2gdl/runs/ycbqifra' target="_blank">https://wandb.ai/hyperloopupv/2gdl/runs/ycbqifra</a>

# %%
# Create log dir
log_dir = "2gdl/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = BobinaEnv( duration = 5 )
env = Monitor(env, log_dir)

# %%
from typing import Callable

def linear_schedule(initial_value: float) -> Callable[[float], float]:
    """
    Linear learning rate schedule.

    :param initial_value: Initial learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return progress_remaining * initial_value

    return func

# para el critic , qf=[400, 300], para el actor pi=[300, 200]
policy_kwargs = dict(net_arch=dict(pi=[8, 8], qf=[256, 256]))
model = SAC("MlpPolicy", env,learning_rate = linear_schedule(0.001), policy_kwargs=policy_kwargs, verbose=1, tensorboard_log=log_dir, device="auto")
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
MODEL_PATH = f"models/2gdl8x8fs-passalis.3/model.zip"

# Create and wrap the environment
env = BobinaEnv(duration = 5)

# Load the trained agent
model = SAC.load(MODEL_PATH, env=env, learning_rate = linear_schedule(0.00001))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Create checkpoint callback
checkpoint_callback = CheckpointCallback(
    save_freq=10000, save_path=log_dir, name_prefix="2gdl"
)


callback_on_best = StopTrainingOnRewardThreshold(reward_threshold=5900, verbose=1)
eval_callback = EvalCallback(env, callback_on_new_best=callback_on_best, verbose=1)

# %%
# Train the agent
model.learn(total_timesteps=10000000,
    callback=[
        checkpoint_callback,
        #eval_callback,
        WandbCallback(
            gradient_save_freq=10000,
            model_save_path=f"models/2gdl8x8fs-passalis.3.13a19",
            model_save_freq=10000,
            verbose=2,
        ),
    ],
)
# Out:
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Logging to 2gdl/SAC_36
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -1.56e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 33        |
# |    time_elapsed    | 601       |
# |    total_timesteps | 20000     |
# | train/             |           |
# |    actor_loss      | 40.9      |
# |    critic_loss     | 0.424     |
# |    ent_coef        | 0.00752   |
# |    ent_coef_loss   | 51.1      |
# |    learning_rate   | 9.98e-06  |
# |    n_updates       | 1769798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -1.24e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 32        |
# |    time_elapsed    | 1215      |
# |    total_timesteps | 40000     |
# | train/             |           |
# |    actor_loss      | 34.8      |
# |    critic_loss     | 0.361     |
# |    ent_coef        | 0.00908   |
# |    ent_coef_loss   | 19.8      |
# |    learning_rate   | 9.96e-06  |
# |    n_updates       | 1789798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -1.36e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 32        |
# |    time_elapsed    | 1831      |
# |    total_timesteps | 60000     |
# | train/             |           |
# |    actor_loss      | 40.6      |
# |    critic_loss     | 0.0691    |
# |    ent_coef        | 0.0111    |
# |    ent_coef_loss   | 24        |
# |    learning_rate   | 9.94e-06  |
# |    n_updates       | 1809798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -1.25e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 32        |
# |    time_elapsed    | 2447      |
# |    total_timesteps | 80000     |
# | train/             |           |
# |    actor_loss      | 33.4      |
# |    critic_loss     | 0.11      |
# |    ent_coef        | 0.0132    |
# |    ent_coef_loss   | 4.41      |
# |    learning_rate   | 9.92e-06  |
# |    n_updates       | 1829798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -1.25e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 32        |
# |    time_elapsed    | 3066      |
# |    total_timesteps | 100000    |
# | train/             |           |
# |    actor_loss      | 31.7      |
# |    critic_loss     | 0.0447    |
# |    ent_coef        | 0.0159    |
# |    ent_coef_loss   | 1.69      |
# |    learning_rate   | 9.9e-06   |
# |    n_updates       | 1849798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -1.19e+03 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 32        |
# |    time_elapsed    | 3680      |
# |    total_timesteps | 120000    |
# | train/             |           |
# |    actor_loss      | 29.6      |
# |    critic_loss     | 0.00767   |
# |    ent_coef        | 0.0171    |
# |    ent_coef_loss   | -0.199    |
# |    learning_rate   | 9.88e-06  |
# |    n_updates       | 1869798   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -1.2e+03 |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 32       |
# |    time_elapsed    | 4292     |
# |    total_timesteps | 140000   |
# | train/             |          |
# |    actor_loss      | 29.2     |
# |    critic_loss     | 0.00957  |
# |    ent_coef        | 0.0146   |
# |    ent_coef_loss   | -1.44    |
# |    learning_rate   | 9.86e-06 |
# |    n_updates       | 1889798  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -1.14e+03 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 32        |
# |    time_elapsed    | 4896      |
# |    total_timesteps | 160000    |
# | train/             |           |
# |    actor_loss      | 29.3      |
# |    critic_loss     | 0.96      |
# |    ent_coef        | 0.0145    |
# |    ent_coef_loss   | 2.78      |
# |    learning_rate   | 9.84e-06  |
# |    n_updates       | 1909798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -1.07e+03 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 32        |
# |    time_elapsed    | 5512      |
# |    total_timesteps | 180000    |
# | train/             |           |
# |    actor_loss      | 27.7      |
# |    critic_loss     | 0.945     |
# |    ent_coef        | 0.0142    |
# |    ent_coef_loss   | -0.687    |
# |    learning_rate   | 9.82e-06  |
# |    n_updates       | 1929798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -1.11e+03 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 32        |
# |    time_elapsed    | 6114      |
# |    total_timesteps | 200000    |
# | train/             |           |
# |    actor_loss      | 26.3      |
# |    critic_loss     | 0.877     |
# |    ent_coef        | 0.0138    |
# |    ent_coef_loss   | 0.185     |
# |    learning_rate   | 9.8e-06   |
# |    n_updates       | 1949798   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -806     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 32       |
# |    time_elapsed    | 6717     |
# |    total_timesteps | 220000   |
# | train/             |          |
# |    actor_loss      | 20.7     |
# |    critic_loss     | 0.139    |
# |    ent_coef        | 0.0147   |
# |    ent_coef_loss   | 0.212    |
# |    learning_rate   | 9.78e-06 |
# |    n_updates       | 1969798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -436     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 32       |
# |    time_elapsed    | 7332     |
# |    total_timesteps | 240000   |
# | train/             |          |
# |    actor_loss      | 15.2     |
# |    critic_loss     | 0.0735   |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | 0.903    |
# |    learning_rate   | 9.76e-06 |
# |    n_updates       | 1989798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -231     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 32       |
# |    time_elapsed    | 7934     |
# |    total_timesteps | 260000   |
# | train/             |          |
# |    actor_loss      | 15       |
# |    critic_loss     | 0.018    |
# |    ent_coef        | 0.0172   |
# |    ent_coef_loss   | -0.549   |
# |    learning_rate   | 9.74e-06 |
# |    n_updates       | 2009798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -57.8    |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 32       |
# |    time_elapsed    | 8536     |
# |    total_timesteps | 280000   |
# | train/             |          |
# |    actor_loss      | 5.16     |
# |    critic_loss     | 0.438    |
# |    ent_coef        | 0.0154   |
# |    ent_coef_loss   | 0.458    |
# |    learning_rate   | 9.72e-06 |
# |    n_updates       | 2029798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -91.1    |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 32       |
# |    time_elapsed    | 9138     |
# |    total_timesteps | 300000   |
# | train/             |          |
# |    actor_loss      | 7.73     |
# |    critic_loss     | 7.22     |
# |    ent_coef        | 0.0147   |
# |    ent_coef_loss   | -0.384   |
# |    learning_rate   | 9.7e-06  |
# |    n_updates       | 2049798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -47.1    |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 32       |
# |    time_elapsed    | 9741     |
# |    total_timesteps | 320000   |
# | train/             |          |
# |    actor_loss      | 7.03     |
# |    critic_loss     | 0.0558   |
# |    ent_coef        | 0.0135   |
# |    ent_coef_loss   | -1.62    |
# |    learning_rate   | 9.68e-06 |
# |    n_updates       | 2069798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -68.4    |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 32       |
# |    time_elapsed    | 10344    |
# |    total_timesteps | 340000   |
# | train/             |          |
# |    actor_loss      | 5.98     |
# |    critic_loss     | 0.124    |
# |    ent_coef        | 0.0114   |
# |    ent_coef_loss   | -0.743   |
# |    learning_rate   | 9.66e-06 |
# |    n_updates       | 2089798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -95.8    |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 32       |
# |    time_elapsed    | 10947    |
# |    total_timesteps | 360000   |
# | train/             |          |
# |    actor_loss      | 6.28     |
# |    critic_loss     | 0.413    |
# |    ent_coef        | 0.00959  |
# |    ent_coef_loss   | -1.86    |
# |    learning_rate   | 9.64e-06 |
# |    n_updates       | 2109798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -109     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 32       |
# |    time_elapsed    | 11549    |
# |    total_timesteps | 380000   |
# | train/             |          |
# |    actor_loss      | 5.52     |
# |    critic_loss     | 0.043    |
# |    ent_coef        | 0.00796  |
# |    ent_coef_loss   | -4.5     |
# |    learning_rate   | 9.62e-06 |
# |    n_updates       | 2129798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -124     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 32       |
# |    time_elapsed    | 12149    |
# |    total_timesteps | 400000   |
# | train/             |          |
# |    actor_loss      | 3.08     |
# |    critic_loss     | 0.0423   |
# |    ent_coef        | 0.00659  |
# |    ent_coef_loss   | -2.83    |
# |    learning_rate   | 9.6e-06  |
# |    n_updates       | 2149798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 0.732    |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 32       |
# |    time_elapsed    | 12751    |
# |    total_timesteps | 420000   |
# | train/             |          |
# |    actor_loss      | 5.4      |
# |    critic_loss     | 0.122    |
# |    ent_coef        | 0.00555  |
# |    ent_coef_loss   | -1.06    |
# |    learning_rate   | 9.58e-06 |
# |    n_updates       | 2169798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -39.8    |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 32       |
# |    time_elapsed    | 13355    |
# |    total_timesteps | 440000   |
# | train/             |          |
# |    actor_loss      | -3.42    |
# |    critic_loss     | 0.0734   |
# |    ent_coef        | 0.00601  |
# |    ent_coef_loss   | -1.16    |
# |    learning_rate   | 9.56e-06 |
# |    n_updates       | 2189798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -86.1    |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 32       |
# |    time_elapsed    | 13957    |
# |    total_timesteps | 460000   |
# | train/             |          |
# |    actor_loss      | 0.265    |
# |    critic_loss     | 0.277    |
# |    ent_coef        | 0.00531  |
# |    ent_coef_loss   | -1.54    |
# |    learning_rate   | 9.54e-06 |
# |    n_updates       | 2209798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -97.2    |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 32       |
# |    time_elapsed    | 14558    |
# |    total_timesteps | 480000   |
# | train/             |          |
# |    actor_loss      | 3.1      |
# |    critic_loss     | 0.332    |
# |    ent_coef        | 0.00532  |
# |    ent_coef_loss   | 1.93     |
# |    learning_rate   | 9.52e-06 |
# |    n_updates       | 2229798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -60.3    |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 32       |
# |    time_elapsed    | 15160    |
# |    total_timesteps | 500000   |
# | train/             |          |
# |    actor_loss      | 1.65     |
# |    critic_loss     | 0.0691   |
# |    ent_coef        | 0.00479  |
# |    ent_coef_loss   | -0.924   |
# |    learning_rate   | 9.5e-06  |
# |    n_updates       | 2249798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -9.63    |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 32       |
# |    time_elapsed    | 15761    |
# |    total_timesteps | 520000   |
# | train/             |          |
# |    actor_loss      | 7.86     |
# |    critic_loss     | 0.0204   |
# |    ent_coef        | 0.00405  |
# |    ent_coef_loss   | -1.39    |
# |    learning_rate   | 9.48e-06 |
# |    n_updates       | 2269798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 14       |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 33       |
# |    time_elapsed    | 16363    |
# |    total_timesteps | 540000   |
# | train/             |          |
# |    actor_loss      | 11.4     |
# |    critic_loss     | 0.226    |
# |    ent_coef        | 0.00351  |
# |    ent_coef_loss   | -1.79    |
# |    learning_rate   | 9.46e-06 |
# |    n_updates       | 2289798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 63.5     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 33       |
# |    time_elapsed    | 16965    |
# |    total_timesteps | 560000   |
# | train/             |          |
# |    actor_loss      | 5.62     |
# |    critic_loss     | 0.0536   |
# |    ent_coef        | 0.00295  |
# |    ent_coef_loss   | -2.75    |
# |    learning_rate   | 9.44e-06 |
# |    n_updates       | 2309798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 82.7     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 33       |
# |    time_elapsed    | 17566    |
# |    total_timesteps | 580000   |
# | train/             |          |
# |    actor_loss      | 2.48     |
# |    critic_loss     | 0.0678   |
# |    ent_coef        | 0.00296  |
# |    ent_coef_loss   | 3.95     |
# |    learning_rate   | 9.42e-06 |
# |    n_updates       | 2329798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 33       |
# |    time_elapsed    | 18168    |
# |    total_timesteps | 600000   |
# | train/             |          |
# |    actor_loss      | 4.77     |
# |    critic_loss     | 0.0286   |
# |    ent_coef        | 0.00276  |
# |    ent_coef_loss   | -1.16    |
# |    learning_rate   | 9.4e-06  |
# |    n_updates       | 2349798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 132      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 33       |
# |    time_elapsed    | 18770    |
# |    total_timesteps | 620000   |
# | train/             |          |
# |    actor_loss      | 6.2      |
# |    critic_loss     | 0.0661   |
# |    ent_coef        | 0.00272  |
# |    ent_coef_loss   | 2.63     |
# |    learning_rate   | 9.38e-06 |
# |    n_updates       | 2369798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 174      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 33       |
# |    time_elapsed    | 19370    |
# |    total_timesteps | 640000   |
# | train/             |          |
# |    actor_loss      | 4        |
# |    critic_loss     | 0.0593   |
# |    ent_coef        | 0.00289  |
# |    ent_coef_loss   | -4.79    |
# |    learning_rate   | 9.36e-06 |
# |    n_updates       | 2389798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 186      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 33       |
# |    time_elapsed    | 19970    |
# |    total_timesteps | 660000   |
# | train/             |          |
# |    actor_loss      | 7.24     |
# |    critic_loss     | 0.256    |
# |    ent_coef        | 0.00241  |
# |    ent_coef_loss   | -3.67    |
# |    learning_rate   | 9.34e-06 |
# |    n_updates       | 2409798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 202      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 33       |
# |    time_elapsed    | 20572    |
# |    total_timesteps | 680000   |
# | train/             |          |
# |    actor_loss      | 5.81     |
# |    critic_loss     | 0.0969   |
# |    ent_coef        | 0.00208  |
# |    ent_coef_loss   | -1.86    |
# |    learning_rate   | 9.32e-06 |
# |    n_updates       | 2429798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 242      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 33       |
# |    time_elapsed    | 21173    |
# |    total_timesteps | 700000   |
# | train/             |          |
# |    actor_loss      | 5.83     |
# |    critic_loss     | 0.0704   |
# |    ent_coef        | 0.00192  |
# |    ent_coef_loss   | -0.929   |
# |    learning_rate   | 9.3e-06  |
# |    n_updates       | 2449798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 142      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 33       |
# |    time_elapsed    | 21776    |
# |    total_timesteps | 720000   |
# | train/             |          |
# |    actor_loss      | 8.3      |
# |    critic_loss     | 0.437    |
# |    ent_coef        | 0.00197  |
# |    ent_coef_loss   | 2.71     |
# |    learning_rate   | 9.28e-06 |
# |    n_updates       | 2469798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -20.1    |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 33       |
# |    time_elapsed    | 22377    |
# |    total_timesteps | 740000   |
# | train/             |          |
# |    actor_loss      | 2.65     |
# |    critic_loss     | 0.139    |
# |    ent_coef        | 0.00201  |
# |    ent_coef_loss   | -1.51    |
# |    learning_rate   | 9.26e-06 |
# |    n_updates       | 2489798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -120     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 33       |
# |    time_elapsed    | 22976    |
# |    total_timesteps | 760000   |
# | train/             |          |
# |    actor_loss      | 8.76     |
# |    critic_loss     | 0.0413   |
# |    ent_coef        | 0.00177  |
# |    ent_coef_loss   | 0.881    |
# |    learning_rate   | 9.24e-06 |
# |    n_updates       | 2509798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -223     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 33       |
# |    time_elapsed    | 23579    |
# |    total_timesteps | 780000   |
# | train/             |          |
# |    actor_loss      | 3.62     |
# |    critic_loss     | 0.19     |
# |    ent_coef        | 0.00207  |
# |    ent_coef_loss   | 2.4      |
# |    learning_rate   | 9.22e-06 |
# |    n_updates       | 2529798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -69.7    |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 33       |
# |    time_elapsed    | 24179    |
# |    total_timesteps | 800000   |
# | train/             |          |
# |    actor_loss      | 2.73     |
# |    critic_loss     | 0.346    |
# |    ent_coef        | 0.00207  |
# |    ent_coef_loss   | -0.0315  |
# |    learning_rate   | 9.2e-06  |
# |    n_updates       | 2549798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 2.78     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 33       |
# |    time_elapsed    | 24781    |
# |    total_timesteps | 820000   |
# | train/             |          |
# |    actor_loss      | 1.49     |
# |    critic_loss     | 1.41     |
# |    ent_coef        | 0.00232  |
# |    ent_coef_loss   | 46.6     |
# |    learning_rate   | 9.18e-06 |
# |    n_updates       | 2569798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 65.6     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 33       |
# |    time_elapsed    | 25383    |
# |    total_timesteps | 840000   |
# | train/             |          |
# |    actor_loss      | 2.55     |
# |    critic_loss     | 1.22     |
# |    ent_coef        | 0.00276  |
# |    ent_coef_loss   | 19.9     |
# |    learning_rate   | 9.16e-06 |
# |    n_updates       | 2589798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 68.1     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 33       |
# |    time_elapsed    | 25984    |
# |    total_timesteps | 860000   |
# | train/             |          |
# |    actor_loss      | 4.88     |
# |    critic_loss     | 0.704    |
# |    ent_coef        | 0.0033   |
# |    ent_coef_loss   | 11.4     |
# |    learning_rate   | 9.14e-06 |
# |    n_updates       | 2609798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 89.2     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 33       |
# |    time_elapsed    | 26583    |
# |    total_timesteps | 880000   |
# | train/             |          |
# |    actor_loss      | 5.39     |
# |    critic_loss     | 1.46     |
# |    ent_coef        | 0.00395  |
# |    ent_coef_loss   | 15.6     |
# |    learning_rate   | 9.12e-06 |
# |    n_updates       | 2629798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 138      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 33       |
# |    time_elapsed    | 27184    |
# |    total_timesteps | 900000   |
# | train/             |          |
# |    actor_loss      | 0.924    |
# |    critic_loss     | 0.561    |
# |    ent_coef        | 0.00474  |
# |    ent_coef_loss   | 16.2     |
# |    learning_rate   | 9.1e-06  |
# |    n_updates       | 2649798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 126      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 33       |
# |    time_elapsed    | 27786    |
# |    total_timesteps | 920000   |
# | train/             |          |
# |    actor_loss      | 0.979    |
# |    critic_loss     | 0.748    |
# |    ent_coef        | 0.00568  |
# |    ent_coef_loss   | 15.9     |
# |    learning_rate   | 9.08e-06 |
# |    n_updates       | 2669798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 33       |
# |    time_elapsed    | 28388    |
# |    total_timesteps | 940000   |
# | train/             |          |
# |    actor_loss      | 10.6     |
# |    critic_loss     | 1.51     |
# |    ent_coef        | 0.00678  |
# |    ent_coef_loss   | 9.23     |
# |    learning_rate   | 9.06e-06 |
# |    n_updates       | 2689798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 175      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 33       |
# |    time_elapsed    | 28991    |
# |    total_timesteps | 960000   |
# | train/             |          |
# |    actor_loss      | 9.27     |
# |    critic_loss     | 0.898    |
# |    ent_coef        | 0.00803  |
# |    ent_coef_loss   | 2.87     |
# |    learning_rate   | 9.04e-06 |
# |    n_updates       | 2709798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 33       |
# |    time_elapsed    | 29593    |
# |    total_timesteps | 980000   |
# | train/             |          |
# |    actor_loss      | 8.82     |
# |    critic_loss     | 0.254    |
# |    ent_coef        | 0.00952  |
# |    ent_coef_loss   | 3.34     |
# |    learning_rate   | 9.02e-06 |
# |    n_updates       | 2729798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 125      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 33       |
# |    time_elapsed    | 30194    |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | 8.08     |
# |    critic_loss     | 0.185    |
# |    ent_coef        | 0.0111   |
# |    ent_coef_loss   | 2.45     |
# |    learning_rate   | 9e-06    |
# |    n_updates       | 2749798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 122      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 33       |
# |    time_elapsed    | 30795    |
# |    total_timesteps | 1020000  |
# | train/             |          |
# |    actor_loss      | 5.24     |
# |    critic_loss     | 0.413    |
# |    ent_coef        | 0.0123   |
# |    ent_coef_loss   | -0.0499  |
# |    learning_rate   | 8.98e-06 |
# |    n_updates       | 2769798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 119      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 33       |
# |    time_elapsed    | 31392    |
# |    total_timesteps | 1040000  |
# | train/             |          |
# |    actor_loss      | 4.16     |
# |    critic_loss     | 0.135    |
# |    ent_coef        | 0.0121   |
# |    ent_coef_loss   | 0.94     |
# |    learning_rate   | 8.96e-06 |
# |    n_updates       | 2789798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 117      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 33       |
# |    time_elapsed    | 31993    |
# |    total_timesteps | 1060000  |
# | train/             |          |
# |    actor_loss      | 1.91     |
# |    critic_loss     | 0.202    |
# |    ent_coef        | 0.0116   |
# |    ent_coef_loss   | -0.299   |
# |    learning_rate   | 8.94e-06 |
# |    n_updates       | 2809798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 118      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 33       |
# |    time_elapsed    | 32600    |
# |    total_timesteps | 1080000  |
# | train/             |          |
# |    actor_loss      | 5.73     |
# |    critic_loss     | 0.212    |
# |    ent_coef        | 0.011    |
# |    ent_coef_loss   | 1.13     |
# |    learning_rate   | 8.92e-06 |
# |    n_updates       | 2829798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 116      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 33       |
# |    time_elapsed    | 33225    |
# |    total_timesteps | 1100000  |
# | train/             |          |
# |    actor_loss      | 5.26     |
# |    critic_loss     | 0.251    |
# |    ent_coef        | 0.0103   |
# |    ent_coef_loss   | -0.413   |
# |    learning_rate   | 8.9e-06  |
# |    n_updates       | 2849798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 119      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 33       |
# |    time_elapsed    | 33858    |
# |    total_timesteps | 1120000  |
# | train/             |          |
# |    actor_loss      | 4.57     |
# |    critic_loss     | 0.12     |
# |    ent_coef        | 0.00923  |
# |    ent_coef_loss   | -0.985   |
# |    learning_rate   | 8.88e-06 |
# |    n_updates       | 2869798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 33       |
# |    time_elapsed    | 34492    |
# |    total_timesteps | 1140000  |
# | train/             |          |
# |    actor_loss      | 4        |
# |    critic_loss     | 0.0316   |
# |    ent_coef        | 0.00798  |
# |    ent_coef_loss   | -2.02    |
# |    learning_rate   | 8.86e-06 |
# |    n_updates       | 2889798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 33       |
# |    time_elapsed    | 35126    |
# |    total_timesteps | 1160000  |
# | train/             |          |
# |    actor_loss      | 3.76     |
# |    critic_loss     | 0.125    |
# |    ent_coef        | 0.00687  |
# |    ent_coef_loss   | -2.75    |
# |    learning_rate   | 8.84e-06 |
# |    n_updates       | 2909798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 93.4     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 32       |
# |    time_elapsed    | 35760    |
# |    total_timesteps | 1180000  |
# | train/             |          |
# |    actor_loss      | 3.71     |
# |    critic_loss     | 0.184    |
# |    ent_coef        | 0.00597  |
# |    ent_coef_loss   | -0.77    |
# |    learning_rate   | 8.82e-06 |
# |    n_updates       | 2929798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 94.1     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 32       |
# |    time_elapsed    | 36394    |
# |    total_timesteps | 1200000  |
# | train/             |          |
# |    actor_loss      | -8.7     |
# |    critic_loss     | 0.976    |
# |    ent_coef        | 0.00533  |
# |    ent_coef_loss   | 1.33     |
# |    learning_rate   | 8.8e-06  |
# |    n_updates       | 2949798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 83.9     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 32       |
# |    time_elapsed    | 37028    |
# |    total_timesteps | 1220000  |
# | train/             |          |
# |    actor_loss      | -160     |
# |    critic_loss     | 810      |
# |    ent_coef        | 0.00639  |
# |    ent_coef_loss   | 10.8     |
# |    learning_rate   | 8.78e-06 |
# |    n_updates       | 2969798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 78.2     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 32       |
# |    time_elapsed    | 37659    |
# |    total_timesteps | 1240000  |
# | train/             |          |
# |    actor_loss      | -426     |
# |    critic_loss     | 4.81e+03 |
# |    ent_coef        | 0.00764  |
# |    ent_coef_loss   | 17.8     |
# |    learning_rate   | 8.76e-06 |
# |    n_updates       | 2989798  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | 66.3     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 32       |
# |    time_elapsed    | 38294    |
# |    total_timesteps | 1260000  |
# | train/             |          |
# |    actor_loss      | -804     |
# |    critic_loss     | 1.58e+04 |
# |    ent_coef        | 0.00911  |
# |    ent_coef_loss   | 23.7     |
# |    learning_rate   | 8.74e-06 |
# |    n_updates       | 3009798  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | 59.6      |
# | time/              |           |
# |    episodes        | 256       |
# |    fps             | 32        |
# |    time_elapsed    | 38928     |
# |    total_timesteps | 1280000   |
# | train/             |           |
# |    actor_loss      | -1.92e+03 |
# |    critic_loss     | 1.31e+04  |
# |    ent_coef        | 0.0109    |
# |    ent_coef_loss   | 65.3      |
# |    learning_rate   | 8.72e-06  |
# |    n_updates       | 3029798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -94.7     |
# | time/              |           |
# |    episodes        | 260       |
# |    fps             | 32        |
# |    time_elapsed    | 39561     |
# |    total_timesteps | 1300000   |
# | train/             |           |
# |    actor_loss      | -2.65e+03 |
# |    critic_loss     | 4.64e+04  |
# |    ent_coef        | 0.013     |
# |    ent_coef_loss   | 63        |
# |    learning_rate   | 8.7e-06   |
# |    n_updates       | 3049798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -213      |
# | time/              |           |
# |    episodes        | 264       |
# |    fps             | 32        |
# |    time_elapsed    | 40195     |
# |    total_timesteps | 1320000   |
# | train/             |           |
# |    actor_loss      | -3.19e+03 |
# |    critic_loss     | 7.16e+04  |
# |    ent_coef        | 0.0155    |
# |    ent_coef_loss   | 76.5      |
# |    learning_rate   | 8.68e-06  |
# |    n_updates       | 3069798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -282      |
# | time/              |           |
# |    episodes        | 268       |
# |    fps             | 32        |
# |    time_elapsed    | 40829     |
# |    total_timesteps | 1340000   |
# | train/             |           |
# |    actor_loss      | -4.59e+03 |
# |    critic_loss     | 2.71e+05  |
# |    ent_coef        | 0.0184    |
# |    ent_coef_loss   | 78.1      |
# |    learning_rate   | 8.66e-06  |
# |    n_updates       | 3089798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -284      |
# | time/              |           |
# |    episodes        | 272       |
# |    fps             | 32        |
# |    time_elapsed    | 41463     |
# |    total_timesteps | 1360000   |
# | train/             |           |
# |    actor_loss      | -4.72e+03 |
# |    critic_loss     | 3.89e+05  |
# |    ent_coef        | 0.0219    |
# |    ent_coef_loss   | 76.7      |
# |    learning_rate   | 8.64e-06  |
# |    n_updates       | 3109798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -314      |
# | time/              |           |
# |    episodes        | 276       |
# |    fps             | 32        |
# |    time_elapsed    | 42097     |
# |    total_timesteps | 1380000   |
# | train/             |           |
# |    actor_loss      | -8.82e+03 |
# |    critic_loss     | 6.34e+05  |
# |    ent_coef        | 0.026     |
# |    ent_coef_loss   | 75.4      |
# |    learning_rate   | 8.62e-06  |
# |    n_updates       | 3129798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -368      |
# | time/              |           |
# |    episodes        | 280       |
# |    fps             | 32        |
# |    time_elapsed    | 42734     |
# |    total_timesteps | 1400000   |
# | train/             |           |
# |    actor_loss      | -1.69e+04 |
# |    critic_loss     | 5.99e+07  |
# |    ent_coef        | 0.0308    |
# |    ent_coef_loss   | 76.2      |
# |    learning_rate   | 8.6e-06   |
# |    n_updates       | 3149798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -478      |
# | time/              |           |
# |    episodes        | 284       |
# |    fps             | 32        |
# |    time_elapsed    | 43369     |
# |    total_timesteps | 1420000   |
# | train/             |           |
# |    actor_loss      | -1.68e+04 |
# |    critic_loss     | 9.18e+05  |
# |    ent_coef        | 0.0366    |
# |    ent_coef_loss   | 70        |
# |    learning_rate   | 8.58e-06  |
# |    n_updates       | 3169798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -487      |
# | time/              |           |
# |    episodes        | 288       |
# |    fps             | 32        |
# |    time_elapsed    | 44003     |
# |    total_timesteps | 1440000   |
# | train/             |           |
# |    actor_loss      | -1.68e+04 |
# |    critic_loss     | 1.64e+06  |
# |    ent_coef        | 0.0434    |
# |    ent_coef_loss   | 54.1      |
# |    learning_rate   | 8.56e-06  |
# |    n_updates       | 3189798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -492      |
# | time/              |           |
# |    episodes        | 292       |
# |    fps             | 32        |
# |    time_elapsed    | 44606     |
# |    total_timesteps | 1460000   |
# | train/             |           |
# |    actor_loss      | -2.53e+04 |
# |    critic_loss     | 8.42e+05  |
# |    ent_coef        | 0.0516    |
# |    ent_coef_loss   | 63.1      |
# |    learning_rate   | 8.54e-06  |
# |    n_updates       | 3209798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -496      |
# | time/              |           |
# |    episodes        | 296       |
# |    fps             | 32        |
# |    time_elapsed    | 45241     |
# |    total_timesteps | 1480000   |
# | train/             |           |
# |    actor_loss      | -3.07e+04 |
# |    critic_loss     | 1.09e+06  |
# |    ent_coef        | 0.0612    |
# |    ent_coef_loss   | 59.9      |
# |    learning_rate   | 8.52e-06  |
# |    n_updates       | 3229798   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -492     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 32       |
# |    time_elapsed    | 45876    |
# |    total_timesteps | 1500000  |
# | train/             |          |
# |    actor_loss      | -3.6e+04 |
# |    critic_loss     | 1.61e+06 |
# |    ent_coef        | 0.0724   |
# |    ent_coef_loss   | 44.3     |
# |    learning_rate   | 8.5e-06  |
# |    n_updates       | 3249798  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -542      |
# | time/              |           |
# |    episodes        | 304       |
# |    fps             | 32        |
# |    time_elapsed    | 46510     |
# |    total_timesteps | 1520000   |
# | train/             |           |
# |    actor_loss      | -3.92e+04 |
# |    critic_loss     | 1.32e+06  |
# |    ent_coef        | 0.0858    |
# |    ent_coef_loss   | 42.7      |
# |    learning_rate   | 8.48e-06  |
# |    n_updates       | 3269798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -562      |
# | time/              |           |
# |    episodes        | 308       |
# |    fps             | 32        |
# |    time_elapsed    | 47145     |
# |    total_timesteps | 1540000   |
# | train/             |           |
# |    actor_loss      | -3.83e+04 |
# |    critic_loss     | 9.88e+05  |
# |    ent_coef        | 0.102     |
# |    ent_coef_loss   | 41.2      |
# |    learning_rate   | 8.46e-06  |
# |    n_updates       | 3289798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -582      |
# | time/              |           |
# |    episodes        | 312       |
# |    fps             | 32        |
# |    time_elapsed    | 47780     |
# |    total_timesteps | 1560000   |
# | train/             |           |
# |    actor_loss      | -3.56e+04 |
# |    critic_loss     | 3.01e+05  |
# |    ent_coef        | 0.121     |
# |    ent_coef_loss   | 38.8      |
# |    learning_rate   | 8.44e-06  |
# |    n_updates       | 3309798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -616      |
# | time/              |           |
# |    episodes        | 316       |
# |    fps             | 32        |
# |    time_elapsed    | 48414     |
# |    total_timesteps | 1580000   |
# | train/             |           |
# |    actor_loss      | -3.79e+04 |
# |    critic_loss     | 5.77e+05  |
# |    ent_coef        | 0.143     |
# |    ent_coef_loss   | 39.2      |
# |    learning_rate   | 8.42e-06  |
# |    n_updates       | 3329798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -647      |
# | time/              |           |
# |    episodes        | 320       |
# |    fps             | 32        |
# |    time_elapsed    | 49050     |
# |    total_timesteps | 1600000   |
# | train/             |           |
# |    actor_loss      | -4.43e+04 |
# |    critic_loss     | 3.08e+05  |
# |    ent_coef        | 0.169     |
# |    ent_coef_loss   | 29.1      |
# |    learning_rate   | 8.4e-06   |
# |    n_updates       | 3349798   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -691     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 32       |
# |    time_elapsed    | 49686    |
# |    total_timesteps | 1620000  |
# | train/             |          |
# |    actor_loss      | -4.3e+04 |
# |    critic_loss     | 4.8e+05  |
# |    ent_coef        | 0.2      |
# |    ent_coef_loss   | 29.4     |
# |    learning_rate   | 8.38e-06 |
# |    n_updates       | 3369798  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -713      |
# | time/              |           |
# |    episodes        | 328       |
# |    fps             | 32        |
# |    time_elapsed    | 50322     |
# |    total_timesteps | 1640000   |
# | train/             |           |
# |    actor_loss      | -4.39e+04 |
# |    critic_loss     | 3.73e+05  |
# |    ent_coef        | 0.236     |
# |    ent_coef_loss   | 26        |
# |    learning_rate   | 8.36e-06  |
# |    n_updates       | 3389798   |
# ----------------------------------
# ...
# |    ep_rew_mean     | -404      |
# | time/              |           |
# |    episodes        | 576       |
# |    fps             | 32        |
# |    time_elapsed    | 89653     |
# |    total_timesteps | 2880000   |
# | train/             |           |
# |    actor_loss      | -2.47e+04 |
# |    critic_loss     | 1.34e+05  |
# |    ent_coef        | 11        |
# |    ent_coef_loss   | 0.195     |
# |    learning_rate   | 7.12e-06  |
# |    n_updates       | 4629798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -405      |
# | time/              |           |
# |    episodes        | 580       |
# |    fps             | 32        |
# |    time_elapsed    | 90285     |
# |    total_timesteps | 2900000   |
# | train/             |           |
# |    actor_loss      | -1.23e+04 |
# |    critic_loss     | 8.73e+04  |
# |    ent_coef        | 9.89      |
# |    ent_coef_loss   | 0.942     |
# |    learning_rate   | 7.1e-06   |
# |    n_updates       | 4649798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -407      |
# | time/              |           |
# |    episodes        | 584       |
# |    fps             | 32        |
# |    time_elapsed    | 90918     |
# |    total_timesteps | 2920000   |
# | train/             |           |
# |    actor_loss      | -8.55e+03 |
# |    critic_loss     | 1.29e+06  |
# |    ent_coef        | 8.6       |
# |    ent_coef_loss   | 1.8       |
# |    learning_rate   | 7.08e-06  |
# |    n_updates       | 4669798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -408      |
# | time/              |           |
# |    episodes        | 588       |
# |    fps             | 32        |
# |    time_elapsed    | 91550     |
# |    total_timesteps | 2940000   |
# | train/             |           |
# |    actor_loss      | -5.78e+03 |
# |    critic_loss     | 8.8e+04   |
# |    ent_coef        | 7.49      |
# |    ent_coef_loss   | 1.25      |
# |    learning_rate   | 7.06e-06  |
# |    n_updates       | 4689798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -411      |
# | time/              |           |
# |    episodes        | 592       |
# |    fps             | 32        |
# |    time_elapsed    | 92183     |
# |    total_timesteps | 2960000   |
# | train/             |           |
# |    actor_loss      | -4.63e+03 |
# |    critic_loss     | 4.92e+04  |
# |    ent_coef        | 6.57      |
# |    ent_coef_loss   | 0.268     |
# |    learning_rate   | 7.04e-06  |
# |    n_updates       | 4709798   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -405     |
# | time/              |          |
# |    episodes        | 596      |
# |    fps             | 32       |
# |    time_elapsed    | 92817    |
# |    total_timesteps | 2980000  |
# | train/             |          |
# |    actor_loss      | -4.2e+03 |
# |    critic_loss     | 1.92e+05 |
# |    ent_coef        | 7.02     |
# |    ent_coef_loss   | -0.0542  |
# |    learning_rate   | 7.02e-06 |
# |    n_updates       | 4729798  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -434      |
# | time/              |           |
# |    episodes        | 600       |
# |    fps             | 32        |
# |    time_elapsed    | 93449     |
# |    total_timesteps | 3000000   |
# | train/             |           |
# |    actor_loss      | -4.23e+03 |
# |    critic_loss     | 2.4e+05   |
# |    ent_coef        | 6.77      |
# |    ent_coef_loss   | 0.776     |
# |    learning_rate   | 7e-06     |
# |    n_updates       | 4749798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -463      |
# | time/              |           |
# |    episodes        | 604       |
# |    fps             | 32        |
# |    time_elapsed    | 94082     |
# |    total_timesteps | 3020000   |
# | train/             |           |
# |    actor_loss      | -3.78e+03 |
# |    critic_loss     | 2.56e+04  |
# |    ent_coef        | 6.01      |
# |    ent_coef_loss   | 0.918     |
# |    learning_rate   | 6.98e-06  |
# |    n_updates       | 4769798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -491      |
# | time/              |           |
# |    episodes        | 608       |
# |    fps             | 32        |
# |    time_elapsed    | 94717     |
# |    total_timesteps | 3040000   |
# | train/             |           |
# |    actor_loss      | -2.23e+03 |
# |    critic_loss     | 1.77e+04  |
# |    ent_coef        | 5.29      |
# |    ent_coef_loss   | 1.79      |
# |    learning_rate   | 6.96e-06  |
# |    n_updates       | 4789798   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -505     |
# | time/              |          |
# |    episodes        | 612      |
# |    fps             | 32       |
# |    time_elapsed    | 95349    |
# |    total_timesteps | 3060000  |
# | train/             |          |
# |    actor_loss      | -1.8e+03 |
# |    critic_loss     | 3.61e+04 |
# |    ent_coef        | 4.66     |
# |    ent_coef_loss   | 1.1      |
# |    learning_rate   | 6.94e-06 |
# |    n_updates       | 4809798  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -534      |
# | time/              |           |
# |    episodes        | 616       |
# |    fps             | 32        |
# |    time_elapsed    | 95981     |
# |    total_timesteps | 3080000   |
# | train/             |           |
# |    actor_loss      | -1.58e+03 |
# |    critic_loss     | 6.79e+04  |
# |    ent_coef        | 4.11      |
# |    ent_coef_loss   | 0.876     |
# |    learning_rate   | 6.92e-06  |
# |    n_updates       | 4829798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -576      |
# | time/              |           |
# |    episodes        | 620       |
# |    fps             | 32        |
# |    time_elapsed    | 96614     |
# |    total_timesteps | 3100000   |
# | train/             |           |
# |    actor_loss      | -1.33e+03 |
# |    critic_loss     | 1.19e+04  |
# |    ent_coef        | 3.62      |
# |    ent_coef_loss   | 0.802     |
# |    learning_rate   | 6.9e-06   |
# |    n_updates       | 4849798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -591      |
# | time/              |           |
# |    episodes        | 624       |
# |    fps             | 32        |
# |    time_elapsed    | 97246     |
# |    total_timesteps | 3120000   |
# | train/             |           |
# |    actor_loss      | -1.18e+03 |
# |    critic_loss     | 2.17e+04  |
# |    ent_coef        | 3.25      |
# |    ent_coef_loss   | -0.0832   |
# |    learning_rate   | 6.88e-06  |
# |    n_updates       | 4869798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -594      |
# | time/              |           |
# |    episodes        | 628       |
# |    fps             | 32        |
# |    time_elapsed    | 97878     |
# |    total_timesteps | 3140000   |
# | train/             |           |
# |    actor_loss      | -2.39e+03 |
# |    critic_loss     | 1.63e+04  |
# |    ent_coef        | 3.44      |
# |    ent_coef_loss   | -1.44     |
# |    learning_rate   | 6.86e-06  |
# |    n_updates       | 4889798   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5e+03    |
# |    ep_rew_mean     | -619     |
# | time/              |          |
# |    episodes        | 632      |
# |    fps             | 32       |
# |    time_elapsed    | 98509    |
# |    total_timesteps | 3160000  |
# | train/             |          |
# |    actor_loss      | -4.1e+03 |
# |    critic_loss     | 5.56e+03 |
# |    ent_coef        | 3.93     |
# |    ent_coef_loss   | -1.33    |
# |    learning_rate   | 6.84e-06 |
# |    n_updates       | 4909798  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -620      |
# | time/              |           |
# |    episodes        | 636       |
# |    fps             | 32        |
# |    time_elapsed    | 99142     |
# |    total_timesteps | 3180000   |
# | train/             |           |
# |    actor_loss      | -4.42e+03 |
# |    critic_loss     | 2.18e+04  |
# |    ent_coef        | 4.39      |
# |    ent_coef_loss   | -0.263    |
# |    learning_rate   | 6.82e-06  |
# |    n_updates       | 4929798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -616      |
# | time/              |           |
# |    episodes        | 640       |
# |    fps             | 32        |
# |    time_elapsed    | 99776     |
# |    total_timesteps | 3200000   |
# | train/             |           |
# |    actor_loss      | -4.81e+03 |
# |    critic_loss     | 6.88e+03  |
# |    ent_coef        | 4.2       |
# |    ent_coef_loss   | 0.00724   |
# |    learning_rate   | 6.8e-06   |
# |    n_updates       | 4949798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -615      |
# | time/              |           |
# |    episodes        | 644       |
# |    fps             | 32        |
# |    time_elapsed    | 100408    |
# |    total_timesteps | 3220000   |
# | train/             |           |
# |    actor_loss      | -4.44e+03 |
# |    critic_loss     | 2.54e+04  |
# |    ent_coef        | 3.97      |
# |    ent_coef_loss   | 0.202     |
# |    learning_rate   | 6.78e-06  |
# |    n_updates       | 4969798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -612      |
# | time/              |           |
# |    episodes        | 648       |
# |    fps             | 32        |
# |    time_elapsed    | 101043    |
# |    total_timesteps | 3240000   |
# | train/             |           |
# |    actor_loss      | -3.84e+03 |
# |    critic_loss     | 7.29e+03  |
# |    ent_coef        | 4.02      |
# |    ent_coef_loss   | -0.298    |
# |    learning_rate   | 6.76e-06  |
# |    n_updates       | 4989798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -612      |
# | time/              |           |
# |    episodes        | 652       |
# |    fps             | 32        |
# |    time_elapsed    | 101677    |
# |    total_timesteps | 3260000   |
# | train/             |           |
# |    actor_loss      | -3.98e+03 |
# |    critic_loss     | 1.54e+04  |
# |    ent_coef        | 4.34      |
# |    ent_coef_loss   | -0.326    |
# |    learning_rate   | 6.74e-06  |
# |    n_updates       | 5009798   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5e+03     |
# |    ep_rew_mean     | -612      |
# | time/              |           |
# |    episodes        | 656       |
# |    fps             | 32        |
# |    time_elapsed    | 102309    |
# |    total_timesteps | 3280000   |
# | train/             |           |
# |    actor_loss      | -4.42e+03 |
# |    critic_loss     | 7.93e+04  |
# |    ent_coef        | 4.34      |
# |    ent_coef_loss   | 0.193     |
# |    learning_rate   | 6.72e-06  |
# |    n_updates       | 5029798   |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [39], in <cell line: 2>()
#       1 # Train the agent
# ----> 2 model.learn(total_timesteps=10000000,
#       3     callback=[
#       4         checkpoint_callback,
#       5         #eval_callback,
#       6         WandbCallback(
#       7             gradient_save_freq=10000,
#       8             model_save_path=f"models/2gdl8x8fs-passalis.3.13a19",
#       9             model_save_freq=10000,
#      10             verbose=2,
#      11         ),
#      12     ],
#      13 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\sac\sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\off_policy_algorithm.py:331, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     329         # Special case when the user passes `gradient_steps=0`
#     330         if gradient_steps > 0:
# --> 331             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     333 callback.on_training_end()
#     335 return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\sac\sac.py:280, in SAC.train(self, gradient_steps, batch_size)
#     278 # Optimize the actor
#     279 self.actor.optimizer.zero_grad()
# --> 280 actor_loss.backward()
#     281 self.actor.optimizer.step()
#     283 # Update target networks
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\autograd\__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
episodes = 3
state, seed = env.reset()
for episode in range(1, episodes+1):
    state, seed = env.reset()
    done = False
    score = 0
    while not done:
        action = env.action_space.sample()
        n_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# Episode:1 Score:-57087.66697450366
# Episode:2 Score:-57169.60609087738
# Episode:3 Score:-57424.86711319699

# %%
b = Bobina()
b.airgap = 9

# %%
b.step(100)
# Out:
# ((20.00214, -0.10582279, 3.7021403, 45.0), False)

# %%
import numpy as np
import torch as th
import time

MODEL_PATH = f"models/2gdl8x8fs-passalis.3/model.zip"

# Create and wrap the environment
env = BobinaEnv(duration = 5)

# Load the trained agent
model = SAC.load(MODEL_PATH, env=env, learning_rate = 0.00001)

# Evaluate the agent
for i in range(5):
    obs, seed = env.reset()
    print(obs)
    done = False
    episode_reward = 0
    velocidad = 0
    current = 0
    observations = []
    noises = []
    timepredict = 0
    timemodel = 0
    distancia11, distancia12, distancia21, distancia22, current1, current2 = obs
    while not done:
        #noise = random.uniform(-1, 1)
        #obs = obs + noise
        observations.append(obs)
        #noises.append(noise)
        t1 = time.time()
        action, _states = model.predict(np.array([distancia11, distancia12, distancia21, distancia22, current1, current2]), deterministic=True)
        t2 = time.time()
        #print(action)
        #if env.airgap > 10.1: action = max(action, [-50])
        #print(action)
        t3 = time.time()
        state, reward, terminated, truncated, info = env.step(np.array(action))
        t4 = time.time()
        distancia11, distancia12, distancia21, distancia22, current1, current2 = state
        done = truncated or terminated
        episode_reward += reward
        timepredict += t2 - t1
        timemodel += t4 - t3
        noises.append((current1, current2))
    print("Time predict", timepredict)
    print("Time model", timemodel)
    print("Episode reward", episode_reward)
    print(noises)
    env.render("yes", normalize = True, seed = f"speedpassalis2-{i}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# [2.7 2.7 2.7 2.7 0.  0. ]
# Time predict 12.815144538879395
# Time model 52.202550411224365
# Episode reward -575.2583364136034
# [(0.0, 0.0), (2.5094633, -2.9395971), (5.143944, -4.5197616), (7.947735, -3.1944308), (10.80696, -0.31599566), (13.740314, 0.6530006), (16.74051, -1.3413504), (19.753511, -4.315764), (22.809559, -7.118457), (25.827309, -9.734469), (28.70153, -12.183189), (31.412012, -14.489819), (33.96379, -16.675743), (36.369286, -18.757612), (38.632183, -20.752008), (40.759315, -22.667667), (42.76556, -24.509312), (44.654594, -26.281322), (45.0, -27.98704), (45.0, -29.62929), (45.0, -31.210794), (45.0, -32.733917), (45.0, -34.200447), (45.0, -35.612675), (45.0, -36.973396), (45.0, -38.284348), (45.0, -39.547237), (45.0, -40.763992), (45.0, -41.936428), (45.0, -43.06622), (45.0, -44.155064), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -44.651134), (45.0, -40.53746), (45.0, -39.030575), (45.0, -40.265327), (45.0, -41.50513), (45.0, -42.698917), (45.0, -43.847404), (45.0, -44.95232), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, -45.0), (45.0, - ...
# [-3.3 -3.3 -3.3 -3.3  0.   0. ]
# Time predict 13.238987922668457
# Time model 52.71763014793396
# Episode reward -1935.4961827298403
# [(0.0, 0.0), (-3.2007136, -0.6107305), (-6.2625575, -1.7202879), (-9.023527, -3.4947023), (-11.510396, -5.6907187), (-13.794446, -7.9783006), (-15.918674, -10.195968), (-17.894579, -12.321871), (-19.727386, -14.278045), (-21.443483, -15.946075), (-23.043541, -17.122711), (-24.509716, -17.539457), (-25.842958, -17.070236), (-27.070423, -15.843277), (-28.229517, -14.127568), (-29.353754, -12.151037), (-30.464775, -10.059033), (-31.571186, -7.944142), (-32.673546, -5.8561425), (-33.76846, -3.8434703), (-34.842113, -1.9356045), (-35.88519, -0.19661304), (-36.901814, 1.2674564), (-37.895447, 2.3869555), (-38.868534, 3.1305788), (-39.822876, 3.5162785), (-40.75978, 3.5970855), (-41.66851, 3.5467038), (-42.516544, 3.2052994), (-43.276672, 2.1648464), (-43.92299, 0.5662553), (-44.40542, -1.1678078), (-44.667152, -2.7693732), (-44.67155, -4.1084776), (-44.423843, -5.137067), (-43.97234, -5.839153), (-43.387997, -6.232615), (-42.738697, -6.3660846), (-42.07343, -6.2986455), (-41.419605, -6.1009307), (-40.786816, -5.8498034), (-40.171597, -5.608821), (-39.562317, -5.4181213), (-38.94411, -5.292404), (-38.30314, -5.228971), (-37.63674, -5.2130756), (-36.938946, -5.2218933), (-36.15554, -5.0586), (-35.229908, -4.444816), (-34.197807, -3.3765116), (-33.150734, -2.0363407), (-32.150444, -0.580519), (-31.213566, 0.88515466), (-30.328926, 2.2877095), (-29.474703, 3.571899), (-28.627441, 4.714046), (-27.767632, 5.718437), (-26.882332, 6.606136), (-25.974165, 7.4163904), (-25.043613, 8.178095), (-24.087679, 8.914524), (-23.115263, 9.645699), (-22.136786, 10.37092), (-21.167765, 11.081807), (-20.219734, 11.77787), (-19.29555, 12.454799), (-18.398777, 13.094655), (-17.532642, 13.688432), (-16.70575, 14.236079), (-15.924331, 14.728246), (-15.1850195, 15.165898), (-14.488807, 15.553982), (-13.840437, 15.89935), (-13.247777, 16.214996), (-12.715998, 16.51214), (-13.526528, 18.233797), (-15.623668, 21.337822), (-17.63345, 24.319), (-19.526266, 27.15024), (-21.308182, 29.846764), (-22.995914, 32.477997), (-24.611176, 35.031563), (-26.151405, 37.449997), (-27.621172, 39.737522), (-29.034494, 41.887547), (-30.396324, 43.904575), (-31.711966, 45.0), (-32.98481, 45.0), (-34.216827, 45.0), (-35.409615, 45.0), (-36.564507, 45.0), (-37.682793, 45.0), (-38.765736, 45.0), (-39.814598, 45.0), (-40.83066, 45.0), (-41.815315, 45.0), (-42.76953, 45.0), (-43.69413, 45.0), (-44.59022, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), (-45.0, 45.0), ( ...
# [2.7 2.7 2.7 2.7 0.  0. ]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [31], in <cell line: 14>()
#      30 #noises.append(noise)
#      31 t1 = time.time()
# ---> 32 action, _states = model.predict(np.array([distancia11, distancia12, distancia21, distancia22, current1, current2]), deterministic=True)
#      33 t2 = time.time()
#      34 #print(action)
#      35 #if env.airgap > 10.1: action = max(action, [-50])
#      36 #print(action)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\base_class.py:555, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     535 def predict(
#     536     self,
#     537     observation: Union[np.ndarray, Dict[str, np.ndarray]],
#    (...)
#     540     deterministic: bool = False,
#     541 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     542     """
#     543     Get the policy action from an observation (and optional hidden state).
#     544     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     553         (used in recurrent policies)
#     554     """
# --> 555     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\policies.py:346, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     343 # Switch to eval mode (this affects batch norm / dropout)
#     344 self.set_training_mode(False)
# --> 346 observation, vectorized_env = self.obs_to_tensor(observation)
#     348 with th.no_grad():
#     349     actions = self._predict(observation, deterministic=deterministic)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\policies.py:268, in BaseModel.obs_to_tensor(self, observation)
#     265     # Add batch dimension if needed
#     266     observation = observation.reshape((-1, *self.observation_space.shape))
# --> 268 observation = obs_as_tensor(observation, self.device)
#     269 return observation, vectorized_env
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\utils.py:483, in obs_as_tensor(obs, device)
#     475 """
#     476 Moves the observation to the given device.
#     477
#    (...)
#     480 :return: PyTorch tensor of the observation on a desired device.
#     481 """
#     482 if isinstance(obs, np.ndarray):
# --> 483     return th.as_tensor(obs, device=device)
#     484 elif isinstance(obs, dict):
#     485     return {key: th.as_tensor(_obs, device=device) for (key, _obs) in obs.items()}
#
# KeyboardInterrupt:

# %%
import torch as th

from stable_baselines3 import SAC

#import onnx
import onnxruntime as ort
import numpy as np


class OnnxablePolicy(th.nn.Module):
    def __init__(self, actor: th.nn.Module):
        super().__init__()
        # Removing the flatten layer because it can't be onnxed
        self.actor = th.nn.Sequential(
            actor.latent_pi,
            actor.mu,
            # For gSDE
            # th.nn.Hardtanh(min_val=-actor.clip_mean, max_val=actor.clip_mean),
            # Squash the output
            th.nn.Tanh(),
        )

    def forward(self, observation: th.Tensor) -> th.Tensor:
        # NOTE: You may have to process (normalize) observation in the correct
        #       way before using this. See `common.preprocessing.preprocess_obs`
        return self.actor(observation)


# Example: model = SAC("MlpPolicy", "Pendulum-v1")
model = SAC.load(f"models/sac8x8h9.3/model.zip", device="cpu")
onnxable_model = OnnxablePolicy(model.policy.actor)

observation_size = model.observation_space.shape
dummy_input = th.randn(1, *observation_size)
th.onnx.export(
    onnxable_model,
    dummy_input,
    "./ONNX/1gdlComplexH98x8.onnx",
    opset_version=9,
    input_names=["input"],
)

##### Load and test with onnx

import onnxruntime as ort
import numpy as np

onnx_path = "./ONNX/1gdlComplexH98x8.onnx"

observation = np.zeros((1, *observation_size)).astype(np.float32)
ort_sess = ort.InferenceSession(onnx_path)
action = ort_sess.run(None, {"input": observation})
# Out:
# ============== Diagnostic Run torch.onnx.export version 2.0.0+cpu ==============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
model.policy
# Out:
# SACPolicy(
#   (actor): Actor(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (latent_pi): Sequential(
#       (0): Linear(in_features=4, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=8, bias=True)
#       (3): ReLU()
#     )
#     (mu): Linear(in_features=8, out_features=1, bias=True)
#     (log_std): Linear(in_features=8, out_features=1, bias=True)
#   )
#   (critic): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (critic_target): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )

# %%
# See "ONNX export" for imports and OnnxablePolicy
jit_path = "1gdlComplex.pt"

# Trace and optimize the module
traced_module = th.jit.trace(onnxable_model.eval(), dummy_input)
frozen_module = th.jit.freeze(traced_module)
frozen_module = th.jit.optimize_for_inference(frozen_module)
th.jit.save(frozen_module, jit_path)

##### Load and test with torch

import torch as th

dummy_input = th.randn(1, *observation_size)
loaded_module = th.jit.load(jit_path)
action_jit = loaded_module(dummy_input)
