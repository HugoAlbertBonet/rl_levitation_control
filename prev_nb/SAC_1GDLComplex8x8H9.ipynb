# %%
from gymnasium import Env
from gymnasium.spaces.box import Box
import numpy as np
import random
from stable_baselines3 import SAC
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.noise import NormalActionNoise
import wandb
from wandb.integration.sb3 import WandbCallback
import os
import matplotlib.pyplot as plt
import scipy.io
import numpy as np
import pickle
import warnings
import math
warnings.filterwarnings("ignore")

# %% [markdown]
# # Siguientes pasos
# * Ir cambiando estado inicial (primero posición y luego también velocidad y corriente)
# * Añadir datos de este año
# * Cambiar reward a corriente

# %%
class BobinaEnv(Env):
  """
  Custom Gym Environment for the Hybrid Electromagnetic Suspension, considering just one coil.
  """
  def __init__(self, masa_pod = 250, airgap = 16.3, duration = 10):
    # Actions: Voltage applied to the coil
    self.action_space = Box(low=np.array([-100]), high = np.array([100]), dtype=np.float32)
    # Observations: Airgap to the ceiling, velocity, distance to the objective, current of the coil
    self.observation_space = Box(low=np.array([9, -np.inf, -10, -45]), high = np.array([22.5, np.inf, 10, 45]), dtype=np.float32)
    # Initial parameters
    self.state = np.array([airgap, 0, airgap - 16.3, 0])
    self.airgapinicial = airgap
    self.duration = duration
    self.timeleft = duration
    self.crash = False
    self.masa_pod = masa_pod
    self.bobina = Bobina(masa_pod = self.masa_pod, airgap = self.airgapinicial)
    self.steps = []
    self.airgap = airgap
    self.distancia = 0
    self.velocidad = 0
    self.current = 0


  def step(self, action):
    # Apply action
    self.state, self.crash = self.bobina.step(action[0])
    self.airgap, self.velocidad, self.distancia, self.current = self.state

    # Reduce the time of the experiment
    self.timeleft -= 0.001

    # Calculate reward
    reward = -abs(self.distancia)

    """if self.airgap >= 23: reward = -500
    elif self.airgap <= 10: reward = -500
    else: reward = -abs(self.current)"""

    # Check if experiment is done
    if self.timeleft <= 0:
      truncated = True
    else: truncated = False
    # Set placeholder for info
    info = {}
    # Only if we implemented the crash
    if self.crash:
      reward = - 50000
      terminated = True
    else:
      terminated = False
    self.steps.append(self.state)
    return self.state, reward, terminated, truncated, info


  def render(self, yes = "yes"):
    # create data
    x = list(range(0,len(self.steps)))
    y = [step[0] for step in self.steps]
    objective = [16.3]*len(self.steps)

    # plot lines
    fig = plt.figure(figsize=(10,5))
    ax = fig.add_subplot(111)
    ax.tick_params(axis='x', colors='white')    #setting up X-axis tick color to red
    ax.tick_params(axis='y', colors='white')  #setting up Y-axis tick color to black

    plt.plot(x, y, label = "States")
    plt.plot(x, objective, label = "Objective")
    plt.legend()
    plt.show()

  def reset(self, seed = 0):
    # Reset experiment choosing randomly the start (ceiling or floor)
    airgap = random.choice([9, 22.5])
    self.state = self.observation_space.sample()
    self.airgap, self.velocidad, self.distancia, self.current = self.state
    self.bobina = Bobina(masa_pod = self.masa_pod, airgap = self.airgap)
    self.bobina.velocidad = [self.velocidad]
    self.bobina.aceleracion = [random.choice(list(range(-50, 50, 2)))/10]
    # Reset time
    self.timeleft = self.duration
    self.crash = False
    self.steps = []
    return self.state, seed

# %%
class Bobina():
  """ 
  Coil model for the Hybrid Electromagnetic Suspension
  """
  def __init__(self, masa_pod = 250, airgap = 22.5):
    self.masa_pod = masa_pod
    self.airgap = airgap
    self.aceleracion = []
    self.velocidad = []
    mat = scipy.io.loadmat('./coil/hems.mat')
    self.hems = mat["hems"][0][0]
    self.airgaps = self.hems[0][0]
    self.currents = self.hems[1][0]
    self.force_vertical = pickle.load(open("./coil/mlp_vertical.pkl", 'rb'))
    self.flux = self.hems[3]
    self.force_horizontal = self.hems[4]
    self.inductance = pickle.load(open("./coil/rf_inductance.pkl", 'rb'))
    self.resistance = self.hems[6][0][0]
    self.min_distance = 9
    self.max_distance = 22.5
    self.airgapinicial = airgap
    self.crash = False
    self.current = 0
    self.steps_RL = []

  def integral(self, lista, h = 1):
    return sum(h*(lista[i]+lista[i+1])/2 for i in range(len(lista)-1))

  def RL(self, airgap, target_voltage, temperature):
    # Resistance-Inductance circuit

    # Get resistance of the coil
    R = self.R(current = self.current, temperature = temperature)   
    V = target_voltage
    I = self.current
    L = self.L(airgap = airgap, current = self.current)
    dIdt = ((V/R) - I)/(L/R)                                      
    self.steps_RL.append(dIdt)                                   
    current = self.integral(self.steps_RL, h = 0.001)                          
    return current                                                  

  def R(self, current, temperature):
    return self.resistance                                         

  def L(self, airgap, current):
    # Return predicted inductance
    return float(self.inductance.predict(np.array([[airgap, current]]))[0])

  def vertical_force(self, airgap, target_voltage, temperature):
    # Get current from RL circuit
    I = self.RL(airgap = airgap, target_voltage = target_voltage, temperature = temperature) 
    
    # Clip result
    if I > 45:
      I = 45
    elif I < -45:
      I = -45
    self.current = I
    # Get vertical force from 
    FI = self.FI_vertical(airgap = airgap, current = I)                    
    return FI, I


  def FI_vertical(self, airgap, current):
    # Return predicted vertical force
    return float(self.force_vertical.predict(np.array([[airgap, current]])))    


  def next_airgap(self, masa_pod, vertical_force, verbose = False):
    # Devide the mass of the pod by 4 coils
    masa = masa_pod/4  
    # Calculate weight
    peso = masa * 9.8    
    # Get total force                                                       
    fuerza = peso - vertical_force
    if verbose: print("Fuerza resultante: ", fuerza)   
    # Calculate acceleration                                     
    aceleracion = fuerza/masa
    if verbose: print("Aceleración: ", aceleracion)                                         
    self.aceleracion.append(aceleracion)       
    # Calculate velocity                                
    velocidad = self.integral(self.aceleracion, 0.001)
    if verbose: print("Integral primera (velocidad): ", velocidad)                          
    self.velocidad.append(velocidad)               
    # Calculate position (x1000 as to transform from m to mm)                            
    posicion = self.airgapinicial + self.integral(self.velocidad, 0.001)*1000 
    if verbose: print("Integral segunda (posición): ", posicion)

    # Clip position
    if posicion > self.max_distance:
      airgap = self.max_distance
      self.aceleracion = [0]
      self.velocidad = [0]  
      #self.crash = True     
      self.airgapinicial = self.max_distance                                               
    elif posicion < self.min_distance:
      airgap = self.min_distance
      self.aceleracion = [0]
      self.velocidad = [0]
      #self.crash = True
      self.airgapinicial = self.min_distance
    else: airgap = posicion
    return airgap, velocidad

  def step(self, target_voltage, verbose = False):
    # Calculate vertical force and current
    vertical_force, self.current = self.vertical_force(airgap = self.airgap, target_voltage = target_voltage, temperature = 40)
    if verbose: print("Fuerza vertical: ", vertical_force)
    # Calculate next airgap and velocity
    self.airgap, velocidad = self.next_airgap(self.masa_pod, vertical_force, verbose = verbose)
    #noise = np.random.normal(0,0.5)
    #self.airgap = self.airgap + noise     
    return (np.float32(self.airgap), np.float32(velocidad), np.float32(self.airgap - 16.3), np.float32(self.current)), self.crash

# %%
run = wandb.init(
    project="1gdlcomplex",
    sync_tensorboard=True,
    monitor_gym=True,
)
# Out:
# Finishing last run (ID:xghzssv3) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>SAC_43/global_step</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>SAC_43/rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>SAC_43/rollout/ep_rew_mean</td><td>▁▁▃▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████</td></tr><tr><td>SAC_43/time/fps</td><td>█████▆▆▃▃▃▃▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>SAC_43/train/actor_loss</td><td>▅█▆▅▅▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>SAC_43/train/critic_loss</td><td>▁▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>SAC_43/train/ent_coef</td><td>█▄▄▅▃▃▅▃▃▃▅▂▃▃▃▂▂▃▃▂▃▂▂▃▃▂▄▃▂▂▁▁</td></tr><tr><td>SAC_43/train/ent_coef_loss</td><td>▄█▆▇▃▃▅▄▄▃▄▆▆▄▆▃▇▅▃▆▄▂▆▅▅▄▃▅▃▁▅▄</td></tr><tr><td>SAC_43/train/learning_rate</td><td>███▇▇▇▇▆▆▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▁▁▁</td></tr><tr><td>global_step</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇████████████████████</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▂▄▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████████</td></tr><tr><td>time/fps</td><td>█████████▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/actor_loss</td><td>▇█▆▅▄▄▃▃▃▂▂▂▂▂▂▂▂▂▁▂▂▂▂▂▂▁▁▁▁▁▁▂▁▁▁▁</td></tr><tr><td>train/critic_loss</td><td>▁▇▄▂▃▂▃▂▂▂▂▁▂▂▂▁▁▁▁▁▁▁▁█▃▁▁▁▂▁▁▁▁▁▁▁</td></tr><tr><td>train/ent_coef</td><td>▁▇█▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▂▁▂▂▁▂</td></tr><tr><td>train/ent_coef_loss</td><td>▃▃▃▃▃▆▂▄▄▄▄▃▅▃▄▄▆▃█▅▁▇▃▃▄▄▃▄▃▄▃▃▄▄▃▃</td></tr><tr><td>train/learning_rate</td><td>███▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>SAC_43/global_step</td><td>512128</td></tr><tr><td>SAC_43/rollout/ep_len_mean</td><td>4001.0</td></tr><tr><td>SAC_43/rollout/ep_rew_mean</td><td>-157.69664</td></tr><tr><td>SAC_43/time/fps</td><td>36.0</td></tr><tr><td>SAC_43/train/actor_loss</td><td>46.7533</td></tr><tr><td>SAC_43/train/critic_loss</td><td>0.10843</td></tr><tr><td>SAC_43/train/ent_coef</td><td>0.004</td></tr><tr><td>SAC_43/train/ent_coef_loss</td><td>-0.44946</td></tr><tr><td>SAC_43/train/learning_rate</td><td>0.00059</td></tr><tr><td>global_step</td><td>576144</td></tr><tr><td>rollout/ep_len_mean</td><td>4001.0</td></tr><tr><td>rollout/ep_rew_mean</td><td>-89.90549</td></tr><tr><td>time/fps</td><td>36.0</td></tr><tr><td>train/actor_loss</td><td>16.19841</td></tr><tr><td>train/critic_loss</td><td>0.12707</td></tr><tr><td>train/ent_coef</td><td>0.01677</td></tr><tr><td>train/ent_coef_loss</td><td>-0.04531</td></tr><tr><td>train/learning_rate</td><td>0.00054</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">volcanic-capybara-70</strong> at: <a href='https://wandb.ai/hyperloopupv/1gdlcomplex/runs/xghzssv3' target="_blank">https://wandb.ai/hyperloopupv/1gdlcomplex/runs/xghzssv3</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 4 other file(s)
# Find logs at: <code>.\wandb\run-20231219_083820-xghzssv3\logs</code>
# Successfully finished last run (ID:xghzssv3). Initializing new run:<br/>
# wandb version 0.16.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\wandb\run-20231219_191541-4ro8dcop</code>
# Syncing run <strong><a href='https://wandb.ai/hyperloopupv/1gdlcomplex/runs/4ro8dcop' target="_blank">deep-durian-72</a></strong> to <a href='https://wandb.ai/hyperloopupv/1gdlcomplex' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hyperloopupv/1gdlcomplex' target="_blank">https://wandb.ai/hyperloopupv/1gdlcomplex</a>
#  View run at <a href='https://wandb.ai/hyperloopupv/1gdlcomplex/runs/4ro8dcop' target="_blank">https://wandb.ai/hyperloopupv/1gdlcomplex/runs/4ro8dcop</a>

# %%
# Create log dir
log_dir = "1gdlcomplex/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = BobinaEnv( duration = 4 )
env = Monitor(env, log_dir)

# %%
from typing import Callable

def linear_schedule(initial_value: float) -> Callable[[float], float]:
    """
    Linear learning rate schedule.

    :param initial_value: Initial learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return progress_remaining * initial_value

    return func

# para el critic , qf=[400, 300], para el actor pi=[300, 200]
policy_kwargs = dict(net_arch=dict(pi=[8, 8], qf=[256, 256]))
model = SAC("MlpPolicy", env,learning_rate = linear_schedule(0.001),  policy_kwargs=policy_kwargs, verbose=1, tensorboard_log=log_dir)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
MODEL_PATH = f"models/sac8x8h9.3/model.zip"

# Create and wrap the environment
env = BobinaEnv(duration = 4)

# Load the trained agent
model = SAC.load(MODEL_PATH, env=env, learning_rate = linear_schedule(0.0001))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Create checkpoint callback
checkpoint_callback = CheckpointCallback(
    save_freq=10000, save_path=log_dir, name_prefix="rl_sac_1gdlcomplex"
)

# %%
# Train the agent
model.learn(total_timesteps=1250000,
    callback=[
        checkpoint_callback,
        WandbCallback(
            gradient_save_freq=10000,
            model_save_path=f"models/sac8x8h9.3",
            model_save_freq=10000,
            verbose=2,
        ),
    ],
)
# Out:
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Logging to 1gdlcomplex/SAC_50
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.58e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 47        |
# |    time_elapsed    | 335       |
# |    total_timesteps | 16004     |
# | train/             |           |
# |    actor_loss      | 17.9      |
# |    critic_loss     | 0.114     |
# |    ent_coef        | 0.023     |
# |    ent_coef_loss   | -2.58     |
# |    learning_rate   | 9.87e-05  |
# |    n_updates       | 1129081   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -6.63e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 47        |
# |    time_elapsed    | 675       |
# |    total_timesteps | 32008     |
# | train/             |           |
# |    actor_loss      | 111       |
# |    critic_loss     | 0.173     |
# |    ent_coef        | 0.0489    |
# |    ent_coef_loss   | -0.0785   |
# |    learning_rate   | 9.74e-05  |
# |    n_updates       | 1145085   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -6.67e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 47        |
# |    time_elapsed    | 1015      |
# |    total_timesteps | 48012     |
# | train/             |           |
# |    actor_loss      | 118       |
# |    critic_loss     | 0.548     |
# |    ent_coef        | 0.0893    |
# |    ent_coef_loss   | -0.108    |
# |    learning_rate   | 9.62e-05  |
# |    n_updates       | 1161089   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -5.46e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 47        |
# |    time_elapsed    | 1354      |
# |    total_timesteps | 64016     |
# | train/             |           |
# |    actor_loss      | 102       |
# |    critic_loss     | 1.04      |
# |    ent_coef        | 0.0835    |
# |    ent_coef_loss   | 0.175     |
# |    learning_rate   | 9.49e-05  |
# |    n_updates       | 1177093   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -4.64e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 47        |
# |    time_elapsed    | 1685      |
# |    total_timesteps | 80020     |
# | train/             |           |
# |    actor_loss      | 76.1      |
# |    critic_loss     | 0.664     |
# |    ent_coef        | 0.073     |
# |    ent_coef_loss   | -0.26     |
# |    learning_rate   | 9.36e-05  |
# |    n_updates       | 1193097   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -4.09e+03 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 47        |
# |    time_elapsed    | 2017      |
# |    total_timesteps | 96024     |
# | train/             |           |
# |    actor_loss      | 49.5      |
# |    critic_loss     | 0.861     |
# |    ent_coef        | 0.0739    |
# |    ent_coef_loss   | -0.61     |
# |    learning_rate   | 9.23e-05  |
# |    n_updates       | 1209101   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -3.67e+03 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 47        |
# |    time_elapsed    | 2353      |
# |    total_timesteps | 112028    |
# | train/             |           |
# |    actor_loss      | 54.2      |
# |    critic_loss     | 0.424     |
# |    ent_coef        | 0.0401    |
# |    ent_coef_loss   | 0.104     |
# |    learning_rate   | 9.1e-05   |
# |    n_updates       | 1225105   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -3.3e+03 |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 47       |
# |    time_elapsed    | 2691     |
# |    total_timesteps | 128032   |
# | train/             |          |
# |    actor_loss      | 52.6     |
# |    critic_loss     | 0.635    |
# |    ent_coef        | 0.0518   |
# |    ent_coef_loss   | -0.532   |
# |    learning_rate   | 8.98e-05 |
# |    n_updates       | 1241109  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -3.19e+03 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 47        |
# |    time_elapsed    | 3027      |
# |    total_timesteps | 144036    |
# | train/             |           |
# |    actor_loss      | 53.3      |
# |    critic_loss     | 0.512     |
# |    ent_coef        | 0.0268    |
# |    ent_coef_loss   | 0.68      |
# |    learning_rate   | 8.85e-05  |
# |    n_updates       | 1257113   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -3.36e+03 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 47        |
# |    time_elapsed    | 3364      |
# |    total_timesteps | 160040    |
# | train/             |           |
# |    actor_loss      | 59.6      |
# |    critic_loss     | 0.676     |
# |    ent_coef        | 0.0212    |
# |    ent_coef_loss   | -0.0222   |
# |    learning_rate   | 8.72e-05  |
# |    n_updates       | 1273117   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -3.25e+03 |
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 47        |
# |    time_elapsed    | 3701      |
# |    total_timesteps | 176044    |
# | train/             |           |
# |    actor_loss      | 59        |
# |    critic_loss     | 0.297     |
# |    ent_coef        | 0.0428    |
# |    ent_coef_loss   | -0.274    |
# |    learning_rate   | 8.59e-05  |
# |    n_updates       | 1289121   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -3.06e+03 |
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 47        |
# |    time_elapsed    | 4037      |
# |    total_timesteps | 192048    |
# | train/             |           |
# |    actor_loss      | 48.6      |
# |    critic_loss     | 0.372     |
# |    ent_coef        | 0.0488    |
# |    ent_coef_loss   | -0.397    |
# |    learning_rate   | 8.46e-05  |
# |    n_updates       | 1305125   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.93e+03 |
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 47        |
# |    time_elapsed    | 4373      |
# |    total_timesteps | 208052    |
# | train/             |           |
# |    actor_loss      | 58.1      |
# |    critic_loss     | 0.645     |
# |    ent_coef        | 0.0202    |
# |    ent_coef_loss   | 0.714     |
# |    learning_rate   | 8.34e-05  |
# |    n_updates       | 1321129   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.79e+03 |
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 47        |
# |    time_elapsed    | 4710      |
# |    total_timesteps | 224056    |
# | train/             |           |
# |    actor_loss      | 46.3      |
# |    critic_loss     | 0.306     |
# |    ent_coef        | 0.0303    |
# |    ent_coef_loss   | 0.18      |
# |    learning_rate   | 8.21e-05  |
# |    n_updates       | 1337133   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.65e+03 |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 47        |
# |    time_elapsed    | 5046      |
# |    total_timesteps | 240060    |
# | train/             |           |
# |    actor_loss      | 40.7      |
# |    critic_loss     | 0.282     |
# |    ent_coef        | 0.0324    |
# |    ent_coef_loss   | -0.0695   |
# |    learning_rate   | 8.08e-05  |
# |    n_updates       | 1353137   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.55e+03 |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 47        |
# |    time_elapsed    | 5382      |
# |    total_timesteps | 256064    |
# | train/             |           |
# |    actor_loss      | 39.3      |
# |    critic_loss     | 0.881     |
# |    ent_coef        | 0.0217    |
# |    ent_coef_loss   | -0.6      |
# |    learning_rate   | 7.95e-05  |
# |    n_updates       | 1369141   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.47e+03 |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 47        |
# |    time_elapsed    | 5722      |
# |    total_timesteps | 272068    |
# | train/             |           |
# |    actor_loss      | 35.9      |
# |    critic_loss     | 1.29      |
# |    ent_coef        | 0.033     |
# |    ent_coef_loss   | 0.725     |
# |    learning_rate   | 7.82e-05  |
# |    n_updates       | 1385145   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.39e+03 |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 47        |
# |    time_elapsed    | 6059      |
# |    total_timesteps | 288072    |
# | train/             |           |
# |    actor_loss      | 33.3      |
# |    critic_loss     | 0.273     |
# |    ent_coef        | 0.0191    |
# |    ent_coef_loss   | -0.334    |
# |    learning_rate   | 7.7e-05   |
# |    n_updates       | 1401149   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.31e+03 |
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 47        |
# |    time_elapsed    | 6398      |
# |    total_timesteps | 304076    |
# | train/             |           |
# |    actor_loss      | 38.1      |
# |    critic_loss     | 0.334     |
# |    ent_coef        | 0.0282    |
# |    ent_coef_loss   | -0.184    |
# |    learning_rate   | 7.57e-05  |
# |    n_updates       | 1417153   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.25e+03 |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 47        |
# |    time_elapsed    | 6733      |
# |    total_timesteps | 320080    |
# | train/             |           |
# |    actor_loss      | 33.7      |
# |    critic_loss     | 0.197     |
# |    ent_coef        | 0.021     |
# |    ent_coef_loss   | -0.386    |
# |    learning_rate   | 7.44e-05  |
# |    n_updates       | 1433157   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.18e+03 |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 47        |
# |    time_elapsed    | 7063      |
# |    total_timesteps | 336084    |
# | train/             |           |
# |    actor_loss      | 28.6      |
# |    critic_loss     | 0.729     |
# |    ent_coef        | 0.0246    |
# |    ent_coef_loss   | -0.369    |
# |    learning_rate   | 7.31e-05  |
# |    n_updates       | 1449161   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.13e+03 |
# | time/              |           |
# |    episodes        | 88        |
# |    fps             | 47        |
# |    time_elapsed    | 7395      |
# |    total_timesteps | 352088    |
# | train/             |           |
# |    actor_loss      | 35.8      |
# |    critic_loss     | 0.282     |
# |    ent_coef        | 0.0156    |
# |    ent_coef_loss   | -1.17     |
# |    learning_rate   | 7.18e-05  |
# |    n_updates       | 1465165   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.14e+03 |
# | time/              |           |
# |    episodes        | 92        |
# |    fps             | 47        |
# |    time_elapsed    | 7721      |
# |    total_timesteps | 368092    |
# | train/             |           |
# |    actor_loss      | 34        |
# |    critic_loss     | 0.152     |
# |    ent_coef        | 0.0199    |
# |    ent_coef_loss   | -0.241    |
# |    learning_rate   | 7.06e-05  |
# |    n_updates       | 1481169   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.11e+03 |
# | time/              |           |
# |    episodes        | 96        |
# |    fps             | 47        |
# |    time_elapsed    | 8053      |
# |    total_timesteps | 384096    |
# | train/             |           |
# |    actor_loss      | 35.5      |
# |    critic_loss     | 0.14      |
# |    ent_coef        | 0.0377    |
# |    ent_coef_loss   | -0.239    |
# |    learning_rate   | 6.93e-05  |
# |    n_updates       | 1497173   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -2.05e+03 |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 47        |
# |    time_elapsed    | 8389      |
# |    total_timesteps | 400100    |
# | train/             |           |
# |    actor_loss      | 42.1      |
# |    critic_loss     | 0.492     |
# |    ent_coef        | 0.0308    |
# |    ent_coef_loss   | -0.022    |
# |    learning_rate   | 6.8e-05   |
# |    n_updates       | 1513177   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -2e+03   |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 47       |
# |    time_elapsed    | 8736     |
# |    total_timesteps | 416104   |
# | train/             |          |
# |    actor_loss      | 39.7     |
# |    critic_loss     | 0.357    |
# |    ent_coef        | 0.0281   |
# |    ent_coef_loss   | 0.271    |
# |    learning_rate   | 6.67e-05 |
# |    n_updates       | 1529181  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.61e+03 |
# | time/              |           |
# |    episodes        | 108       |
# |    fps             | 47        |
# |    time_elapsed    | 9141      |
# |    total_timesteps | 432108    |
# | train/             |           |
# |    actor_loss      | 26        |
# |    critic_loss     | 0.294     |
# |    ent_coef        | 0.0326    |
# |    ent_coef_loss   | -0.233    |
# |    learning_rate   | 6.54e-05  |
# |    n_updates       | 1545185   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.38e+03 |
# | time/              |           |
# |    episodes        | 112       |
# |    fps             | 46        |
# |    time_elapsed    | 9683      |
# |    total_timesteps | 448112    |
# | train/             |           |
# |    actor_loss      | 34        |
# |    critic_loss     | 0.268     |
# |    ent_coef        | 0.0155    |
# |    ent_coef_loss   | 0.351     |
# |    learning_rate   | 6.42e-05  |
# |    n_updates       | 1561189   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.34e+03 |
# | time/              |           |
# |    episodes        | 116       |
# |    fps             | 45        |
# |    time_elapsed    | 10240     |
# |    total_timesteps | 464116    |
# | train/             |           |
# |    actor_loss      | 30.3      |
# |    critic_loss     | 0.668     |
# |    ent_coef        | 0.0231    |
# |    ent_coef_loss   | 0.281     |
# |    learning_rate   | 6.29e-05  |
# |    n_updates       | 1577193   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.33e+03 |
# | time/              |           |
# |    episodes        | 120       |
# |    fps             | 44        |
# |    time_elapsed    | 10785     |
# |    total_timesteps | 480120    |
# | train/             |           |
# |    actor_loss      | 31.7      |
# |    critic_loss     | 0.581     |
# |    ent_coef        | 0.0205    |
# |    ent_coef_loss   | -0.522    |
# |    learning_rate   | 6.16e-05  |
# |    n_updates       | 1593197   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.32e+03 |
# | time/              |           |
# |    episodes        | 124       |
# |    fps             | 43        |
# |    time_elapsed    | 11338     |
# |    total_timesteps | 496124    |
# | train/             |           |
# |    actor_loss      | 35.6      |
# |    critic_loss     | 0.361     |
# |    ent_coef        | 0.0223    |
# |    ent_coef_loss   | 0.68      |
# |    learning_rate   | 6.03e-05  |
# |    n_updates       | 1609201   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.32e+03 |
# | time/              |           |
# |    episodes        | 128       |
# |    fps             | 43        |
# |    time_elapsed    | 11890     |
# |    total_timesteps | 512128    |
# | train/             |           |
# |    actor_loss      | 33.8      |
# |    critic_loss     | 0.199     |
# |    ent_coef        | 0.0242    |
# |    ent_coef_loss   | -0.281    |
# |    learning_rate   | 5.9e-05   |
# |    n_updates       | 1625205   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.32e+03 |
# | time/              |           |
# |    episodes        | 132       |
# |    fps             | 42        |
# |    time_elapsed    | 12440     |
# |    total_timesteps | 528132    |
# | train/             |           |
# |    actor_loss      | 34        |
# |    critic_loss     | 0.214     |
# |    ent_coef        | 0.0255    |
# |    ent_coef_loss   | -0.0952   |
# |    learning_rate   | 5.77e-05  |
# |    n_updates       | 1641209   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.25e+03 |
# | time/              |           |
# |    episodes        | 136       |
# |    fps             | 41        |
# |    time_elapsed    | 12999     |
# |    total_timesteps | 544136    |
# | train/             |           |
# |    actor_loss      | 25.6      |
# |    critic_loss     | 0.202     |
# |    ent_coef        | 0.0297    |
# |    ent_coef_loss   | 0.0378    |
# |    learning_rate   | 5.65e-05  |
# |    n_updates       | 1657213   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.09e+03 |
# | time/              |           |
# |    episodes        | 140       |
# |    fps             | 41        |
# |    time_elapsed    | 13567     |
# |    total_timesteps | 560140    |
# | train/             |           |
# |    actor_loss      | 29.4      |
# |    critic_loss     | 0.366     |
# |    ent_coef        | 0.0269    |
# |    ent_coef_loss   | -0.853    |
# |    learning_rate   | 5.52e-05  |
# |    n_updates       | 1673217   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.04e+03 |
# | time/              |           |
# |    episodes        | 144       |
# |    fps             | 40        |
# |    time_elapsed    | 14121     |
# |    total_timesteps | 576144    |
# | train/             |           |
# |    actor_loss      | 25.8      |
# |    critic_loss     | 0.585     |
# |    ent_coef        | 0.0187    |
# |    ent_coef_loss   | 0.127     |
# |    learning_rate   | 5.39e-05  |
# |    n_updates       | 1689221   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.04e+03 |
# | time/              |           |
# |    episodes        | 148       |
# |    fps             | 40        |
# |    time_elapsed    | 14677     |
# |    total_timesteps | 592148    |
# | train/             |           |
# |    actor_loss      | 26.6      |
# |    critic_loss     | 0.179     |
# |    ent_coef        | 0.0177    |
# |    ent_coef_loss   | 0.0416    |
# |    learning_rate   | 5.26e-05  |
# |    n_updates       | 1705225   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.03e+03 |
# | time/              |           |
# |    episodes        | 152       |
# |    fps             | 39        |
# |    time_elapsed    | 15245     |
# |    total_timesteps | 608152    |
# | train/             |           |
# |    actor_loss      | 28.4      |
# |    critic_loss     | 0.488     |
# |    ent_coef        | 0.022     |
# |    ent_coef_loss   | -0.334    |
# |    learning_rate   | 5.13e-05  |
# |    n_updates       | 1721229   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.03e+03 |
# | time/              |           |
# |    episodes        | 156       |
# |    fps             | 39        |
# |    time_elapsed    | 15807     |
# |    total_timesteps | 624156    |
# | train/             |           |
# |    actor_loss      | 29.5      |
# |    critic_loss     | 0.464     |
# |    ent_coef        | 0.021     |
# |    ent_coef_loss   | 0.86      |
# |    learning_rate   | 5.01e-05  |
# |    n_updates       | 1737233   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.03e+03 |
# | time/              |           |
# |    episodes        | 160       |
# |    fps             | 39        |
# |    time_elapsed    | 16368     |
# |    total_timesteps | 640160    |
# | train/             |           |
# |    actor_loss      | 28.3      |
# |    critic_loss     | 0.246     |
# |    ent_coef        | 0.0183    |
# |    ent_coef_loss   | 0.2       |
# |    learning_rate   | 4.88e-05  |
# |    n_updates       | 1753237   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4e+03     |
# |    ep_rew_mean     | -1.01e+03 |
# | time/              |           |
# |    episodes        | 164       |
# |    fps             | 38        |
# |    time_elapsed    | 16945     |
# |    total_timesteps | 656164    |
# | train/             |           |
# |    actor_loss      | 27.6      |
# |    critic_loss     | 1.34      |
# |    ent_coef        | 0.0193    |
# |    ent_coef_loss   | 0.188     |
# |    learning_rate   | 4.75e-05  |
# |    n_updates       | 1769241   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -997     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 38       |
# |    time_elapsed    | 17524    |
# |    total_timesteps | 672168   |
# | train/             |          |
# |    actor_loss      | 28.7     |
# |    critic_loss     | 0.215    |
# |    ent_coef        | 0.0215   |
# |    ent_coef_loss   | -0.244   |
# |    learning_rate   | 4.62e-05 |
# |    n_updates       | 1785245  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -983     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 38       |
# |    time_elapsed    | 18095    |
# |    total_timesteps | 688172   |
# | train/             |          |
# |    actor_loss      | 18.6     |
# |    critic_loss     | 0.0859   |
# |    ent_coef        | 0.0189   |
# |    ent_coef_loss   | -0.612   |
# |    learning_rate   | 4.49e-05 |
# |    n_updates       | 1801249  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -977     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 37       |
# |    time_elapsed    | 18667    |
# |    total_timesteps | 704176   |
# | train/             |          |
# |    actor_loss      | 20.5     |
# |    critic_loss     | 0.1      |
# |    ent_coef        | 0.0167   |
# |    ent_coef_loss   | -0.22    |
# |    learning_rate   | 4.37e-05 |
# |    n_updates       | 1817253  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -962     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 37       |
# |    time_elapsed    | 19236    |
# |    total_timesteps | 720180   |
# | train/             |          |
# |    actor_loss      | 24.9     |
# |    critic_loss     | 0.303    |
# |    ent_coef        | 0.0208   |
# |    ent_coef_loss   | 0.383    |
# |    learning_rate   | 4.24e-05 |
# |    n_updates       | 1833257  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -946     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 37       |
# |    time_elapsed    | 19808    |
# |    total_timesteps | 736184   |
# | train/             |          |
# |    actor_loss      | 16.8     |
# |    critic_loss     | 0.106    |
# |    ent_coef        | 0.0289   |
# |    ent_coef_loss   | 0.0741   |
# |    learning_rate   | 4.11e-05 |
# |    n_updates       | 1849261  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -929     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 36       |
# |    time_elapsed    | 20381    |
# |    total_timesteps | 752188   |
# | train/             |          |
# |    actor_loss      | 23.2     |
# |    critic_loss     | 0.162    |
# |    ent_coef        | 0.0209   |
# |    ent_coef_loss   | 0.176    |
# |    learning_rate   | 3.98e-05 |
# |    n_updates       | 1865265  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -858     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 36       |
# |    time_elapsed    | 20955    |
# |    total_timesteps | 768192   |
# | train/             |          |
# |    actor_loss      | 19       |
# |    critic_loss     | 0.0956   |
# |    ent_coef        | 0.0217   |
# |    ent_coef_loss   | 0.0234   |
# |    learning_rate   | 3.85e-05 |
# |    n_updates       | 1881269  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -828     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 36       |
# |    time_elapsed    | 21527    |
# |    total_timesteps | 784196   |
# | train/             |          |
# |    actor_loss      | 20.3     |
# |    critic_loss     | 0.102    |
# |    ent_coef        | 0.0219   |
# |    ent_coef_loss   | -0.587   |
# |    learning_rate   | 3.73e-05 |
# |    n_updates       | 1897273  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -825     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 36       |
# |    time_elapsed    | 22100    |
# |    total_timesteps | 800200   |
# | train/             |          |
# |    actor_loss      | 22.1     |
# |    critic_loss     | 0.102    |
# |    ent_coef        | 0.0202   |
# |    ent_coef_loss   | -0.292   |
# |    learning_rate   | 3.6e-05  |
# |    n_updates       | 1913277  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -798     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 36       |
# |    time_elapsed    | 22671    |
# |    total_timesteps | 816204   |
# | train/             |          |
# |    actor_loss      | 22.3     |
# |    critic_loss     | 0.117    |
# |    ent_coef        | 0.0193   |
# |    ent_coef_loss   | 0.539    |
# |    learning_rate   | 3.47e-05 |
# |    n_updates       | 1929281  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -779     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 35       |
# |    time_elapsed    | 23236    |
# |    total_timesteps | 832208   |
# | train/             |          |
# |    actor_loss      | 17.7     |
# |    critic_loss     | 0.191    |
# |    ent_coef        | 0.0185   |
# |    ent_coef_loss   | 0.304    |
# |    learning_rate   | 3.34e-05 |
# |    n_updates       | 1945285  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -764     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 35       |
# |    time_elapsed    | 23786    |
# |    total_timesteps | 848212   |
# | train/             |          |
# |    actor_loss      | 17.5     |
# |    critic_loss     | 0.234    |
# |    ent_coef        | 0.0191   |
# |    ent_coef_loss   | 0.15     |
# |    learning_rate   | 3.21e-05 |
# |    n_updates       | 1961289  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -746     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 35       |
# |    time_elapsed    | 24340    |
# |    total_timesteps | 864216   |
# | train/             |          |
# |    actor_loss      | 18.7     |
# |    critic_loss     | 0.236    |
# |    ent_coef        | 0.0214   |
# |    ent_coef_loss   | 0.0697   |
# |    learning_rate   | 3.09e-05 |
# |    n_updates       | 1977293  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -724     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 35       |
# |    time_elapsed    | 24908    |
# |    total_timesteps | 880220   |
# | train/             |          |
# |    actor_loss      | 22.2     |
# |    critic_loss     | 0.103    |
# |    ent_coef        | 0.0229   |
# |    ent_coef_loss   | 0.591    |
# |    learning_rate   | 2.96e-05 |
# |    n_updates       | 1993297  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -704     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 35       |
# |    time_elapsed    | 25477    |
# |    total_timesteps | 896224   |
# | train/             |          |
# |    actor_loss      | 15.1     |
# |    critic_loss     | 0.076    |
# |    ent_coef        | 0.0236   |
# |    ent_coef_loss   | -0.13    |
# |    learning_rate   | 2.83e-05 |
# |    n_updates       | 2009301  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -679     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 35       |
# |    time_elapsed    | 26046    |
# |    total_timesteps | 912228   |
# | train/             |          |
# |    actor_loss      | 22       |
# |    critic_loss     | 0.194    |
# |    ent_coef        | 0.025    |
# |    ent_coef_loss   | 0.354    |
# |    learning_rate   | 2.7e-05  |
# |    n_updates       | 2025305  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -676     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 34       |
# |    time_elapsed    | 26617    |
# |    total_timesteps | 928232   |
# | train/             |          |
# |    actor_loss      | 14.2     |
# |    critic_loss     | 0.174    |
# |    ent_coef        | 0.0208   |
# |    ent_coef_loss   | -0.925   |
# |    learning_rate   | 2.57e-05 |
# |    n_updates       | 2041309  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4e+03    |
# |    ep_rew_mean     | -680     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 34       |
# |    time_elapsed    | 27176    |
# |    total_timesteps | 944236   |
# | train/             |          |
# |    actor_loss      | 15.2     |
# |    critic_loss     | 0.0918   |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | 0.14     |
# |    learning_rate   | 2.45e-05 |
# |    n_updates       | 2057313  |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\hugoa\H9\RL\GitHub Vrain\rl_levitation_control\SAC_1GDLComplex8x8H9.ipynb Cell 10 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8H9.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> # Train the agent
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8H9.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> model.learn(total_timesteps=1250000,
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8H9.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a>     callback=[
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8H9.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>         checkpoint_callback,
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8H9.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a>         WandbCallback(
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8H9.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a>             gradient_save_freq=10000,
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8H9.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a>             model_save_path=f"models/sac8x8h9.3",
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8H9.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a>             model_save_freq=10000,
#       <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8H9.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a>             verbose=2,
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8H9.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a>         ),
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8H9.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a>     ],
#      <a href='vscode-notebook-cell:/c%3A/Users/hugoa/H9/RL/GitHub%20Vrain/rl_levitation_control/SAC_1GDLComplex8x8H9.ipynb#X11sZmlsZQ%3D%3D?line=11'>12</a> )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\sac\sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\off_policy_algorithm.py:331, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     329         # Special case when the user passes `gradient_steps=0`
#     330         if gradient_steps > 0:
# --> 331             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     333 callback.on_training_end()
#     335 return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\sac\sac.py:285, in SAC.train(self, gradient_steps, batch_size)
#     283 # Update target networks
#     284 if gradient_step % self.target_update_interval == 0:
# --> 285     polyak_update(self.critic.parameters(), self.critic_target.parameters(), self.tau)
#     286     # Copy running stats, see GH issue #996
#     287     polyak_update(self.batch_norm_stats, self.batch_norm_stats_target, 1.0)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\stable_baselines3\common\utils.py:470, in polyak_update(params, target_params, tau)
#     467 with th.no_grad():
#     468     # zip does not raise an exception if length of parameters does not match.
#     469     for param, target_param in zip_strict(params, target_params):
# --> 470         target_param.data.mul_(1 - tau)
#     471         th.add(target_param.data, param.data, alpha=tau, out=target_param.data)
#
# KeyboardInterrupt:

# %%
episodes = 3
state, seed = env.reset()
for episode in range(1, episodes+1):
    state, seed = env.reset()
    done = False
    score = 0
    while not done:
        action = env.action_space.sample()
        n_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# Episode:1 Score:-1981494.4585288865
# Episode:2 Score:-1979754.8377862521
# Episode:3 Score:-1983431.8486917282

# %%
b = Bobina()
b.airgap = 9

# %%
b.step(100)
# Out:
# ((20.00214, -0.10582279, 3.7021403, 45.0), False)

# %%
import numpy as np
import torch as th
import time

MODEL_PATH = f"models/sac8x8h9.3/model.zip"

# Create and wrap the environment
env = BobinaEnv(duration = 4)

# Load the trained agent
model = SAC.load(MODEL_PATH, env=env, learning_rate = 0.00001)

# Evaluate the agent
for i in range(5):
    obs, seed = env.reset()
    done = False
    episode_reward = 0
    velocidad = 0
    current = 0
    observations = []
    noises = []
    error = obs -16.3
    timepredict = 0
    timemodel = 0
    obs, velocidad, error, current = obs
    while not done:
        #noise = random.uniform(-1, 1)
        #obs = obs + noise
        observations.append(obs)
        #noises.append(noise)
        t1 = time.time()
        action, _states = model.predict(np.array([obs, velocidad, error, current]), deterministic=True)
        t2 = time.time()
        #print(action)
        #if env.airgap > 10.1: action = max(action, [-50])
        #print(action)
        t3 = time.time()
        state, reward, terminated, truncated, info = env.step(np.array(action))
        t4 = time.time()
        obs, velocidad, error, current = state
        done = truncated or terminated
        episode_reward += reward
        timepredict += t2 - t1
        timemodel += t4 - t3
        noises.append(action)
    print("Time predict", timepredict)
    print("Time model", timemodel)
    print("Episode reward", episode_reward)
    print(noises)
    env.render("yes")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Time predict 7.927037000656128
# Time model 24.088590145111084
# Episode reward -397.482838049531
# [array([99.99742], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([96.286224], dtype=float32), array([45.744934], dtype=float32), array([-57.897747], dtype=float32), array([-65.26582], dtype=float32), array([-41.206024], dtype=float32), array([-14.627441], dtype=float32), array([-14.163918], dtype=float32), array([-29.780548], dtype=float32), array([-37.52848], dtype=float32), array([-33.390556], dtype=float32), array([-26.754356], dtype=float32), array([-26.343796], dtype=float32), array([-31.490753], dtype=float32), array([-36.019814], dtype=float32), array([-37.320763], dtype=float32), array([-36.644108], dtype=float32), array([-35.67305], dtype=float32), array([-34.95256], dtype=float32), array([-34.58358], dtype=float32), array([-34.313652], dtype=float32), array([-33.62623], dtype=float32), array([-32.88633], dtype=float32), array([-32.20565], dtype=float32), array([-31.193672], dtype=float32), array([-29.883438], dtype=float32), array([-28.384949], dtype=float32), array([-26.859093], dtype=float32), array([-24.506966], dtype=float32), array([-19.376457], dtype=float32), array([-12.076515], dtype=float32), array([-6.3343964], dtype=float32), array([-4.164795], dtype=float32), array([-4.444107], dtype=float32), array([-5.307045], dtype=float32), array([-5.6475067], dtype=float32), array([-5.4847946], dtype=float32), array([-5.3256836], dtype=float32), array([-5.403946], dtype=float32), array([-5.6670685], dtype=float32), array([-5.945816], dtype=float32), array([-6.106476], dtype=float32), array([-6.1186523], dtype=float32), array([-3.2032242], dtype=float32), array([-0.07415009], dtype=float32), array([-2.7690964], dtype=float32), array([-12.009201], dtype=float32), array([-15.247505], dtype=float32), array([-4.1843796], dtype=float32), array([1.7267685], dtype=float32), array([-9.540466], dtype=float32), array([-16.98986], dtype=float32), array([-4.928604], dtype=float32), array([5.502716], dtype=float32), array([-11.412323], dtype=float32), array([-44.83804], dtype=float32), array([-25.884773], dtype=float32), array([27.629875], dtype=float32), array([37.633774], dtype=float32), array([-40.60514], dtype=float32), array([-56.98591], dtype=float32), array([51.671524], dtype=float32), array([71.198395], dtype=float32), array([-59.27197], dtype=float32), array([-72.86716], dtype=float32), array([75.0612], dtype=float32), array([77.99347], dtype=float32), array([-80.66142], dtype=float32), array([-81.60333], dtype=float32), array([82.33858], dtype=float32), array([84.20445], dtype=float32), array([-81.63898], dtype=float32), array([-84.755394], dtype=float32), array([81.5423], dtype=float32), array([85.3627], dtype=float32), array([-80.61947], dtype=float32), array([-85.00607], dtype=float32), array([80.576294], dtype=float32), array([84.52194], dtype=float32), array([-81.71386], dtype=float32), array([-84.7587], dtype=float32), array([80.80928], dtype=float32), array([85.1378], dtype=float32), array([-79.89132], dtype=float32), array([-83.60062], dtype=float32), array([79.621765], dtype=float32), array([84.04523], dtype=float32), array([-78.7], dtype=float32), array([-82.77406], dtype=float32), array([77.78244], dtype=float32), array([81.78615], dtype=float32), array([-78.190956], dtype=float32), array([-82.221054], dtype=float32), array([76.36981], dtype=float32), array([80.22032], dtype=float32), array([-76.78076], dtype=float32), array([-81.0365], dtype=float32), array([75.392914], dtype=float32), array([78.76253], dtype=float32), array([-75.79 ...
# Time predict 8.291110515594482
# Time model 23.891554594039917
# Episode reward -541.1328268423676
# [array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([97.805664], dtype=float32), array([90.0968], dtype=float32), array([59.38794], dtype=float32), array([-13.033569], dtype=float32), array([-74.761566], dtype=float32), array([-94.94767], dtype=float32), array([-99.115944], dtype=float32), array([-99.85511], dtype=float32), array([-99.963806], dtype=float32), array([-99.36864], dtype=float32), array([-88.23381], dtype=float32), array([-0.00984955], dtype=float32), array([57.65448], dtype=float32), array([23.98822], dtype=float32), array([-36.756336], dtype=float32), array([-35.441925], dtype=float32), array([-27.404442], dtype=float32), array([-38.747288], dtype=float32), array([-52.022236], dtype=float32), array([-56.647182], dtype=float32), array([-55.675304], dtype=float32), array([-53.135185], dtype=float32), array([-51.72187], dtype=float32), array([-51.52648], dtype=float32), array([-51.544743], dtype=float32), array([-51.184742], dtype=float32), array([-50.07928], dtype=float32), array([-48.34639], dtype=float32), array([-43.9134], dtype=float32), array([-35.146484], dtype=float32), array([-25.449684], dtype=float32), array([-18.863327], dtype=float32), array([-15.665688], dtype=float32), array([-14.240852], dtype=float32), array([-13.064064], dtype=float32), array([-11.505638], dtype=float32), array([-9.67778], dtype=float32), array([-7.9055023], dtype=float32), array([-6.3820267], dtype=float32), array([-5.1171417], dtype=float32), array([-4.032234], dtype=float32), array([-3.0572662], dtype=float32), array([-2.1896667], dtype=float32), array([-1.4248352], dtype=float32), array([-0.72740173], dtype=float32), array([-0.19798279], dtype=float32), array([-0.11170197], dtype=float32), array([-0.58605194], dtype=float32), array([-1.356781], dtype=float32), array([-2.0607681], dtype=float32), array([-2.5549622], dtype=float32), array([-3.207962], dtype=float32), array([-4.311722], dtype=float32), array([-5.5085144], dtype=float32), array([-5.0920944], dtype=float32), array([-0.9952698], dtype=float32), array([-1.1873932], dtype=float32), array([-8.422516], dtype=float32), array([-16.816727], dtype=float32), array([-8.668755], dtype=float32), array([2.825943], dtype=float32), array([-4.3097534], dtype=float32), array([-17.548836], dtype=float32), array([-11.019173], dtype=float32), array([5.316818], dtype=float32), array([0.27718353], dtype=float32), array([-43.409573], dtype=float32), array([-38.364124], dtype=float32), array([16.419388], dtype=float32), array([48.651978], dtype=float32), array([-21.833138], dtype=float32), array([-63.236164], dtype=float32), array([16.471954], dtype=float32), array([77.81207], dtype=float32), array([-14.363876], dtype=float32), array([-78.81757], dtype=float32), array([21.798172], dtype=float32), array([79.871124], dtype=float32), array([-28.905815], dtype=float32), array([-79.15526], dtype=float32), array([40.503876], dtype=float32), array([76.699036], dtype=float32 ...
# Time predict 8.494755983352661
# Time model 24.287930727005005
# Episode reward -418.5301925241947
# [array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([89.75313], dtype=float32), array([45.11789], dtype=float32), array([-40.634163], dtype=float32), array([-76.369286], dtype=float32), array([-25.127983], dtype=float32), array([35.98076], dtype=float32), array([8.037781], dtype=float32), array([-50.63947], dtype=float32), array([-61.651516], dtype=float32), array([-43.58626], dtype=float32), array([-23.12635], dtype=float32), array([-21.57196], dtype=float32), array([-33.074913], dtype=float32), array([-41.359055], dtype=float32), array([-42.399715], dtype=float32), array([-40.552284], dtype=float32), array([-39.280926], dtype=float32), array([-39.143623], dtype=float32), array([-39.367973], dtype=float32), array([-39.221203], dtype=float32), array([-38.63964], dtype=float32), array([-37.876213], dtype=float32), array([-36.88072], dtype=float32), array([-35.60736], dtype=float32), array([-34.268524], dtype=float32), array([-32.91815], dtype=float32), array([-31.363747], dtype=float32), array([-26.895699], dtype=float32), array([-18.264114], dtype=float32), array([-10.02858], dtype=float32), array([-5.8646545], dtype=float32), array([-5.2360764], dtype=float32), array([-5.967552], dtype=float32), array([-6.4067993], dtype=float32), array([-6.0968018], dtype=float32), array([-5.3642426], dtype=float32), array([-4.6715546], dtype=float32), array([-4.245186], dtype=float32), array([-4.086075], dtype=float32), array([-4.1547394], dtype=float32), array([-4.561737], dtype=float32), array([-5.2693634], dtype=float32), array([-5.935646], dtype=float32), array([-6.2926483], dtype=float32), array([-6.30072], dtype=float32), array([-3.8566055], dtype=float32), array([0.03125763], dtype=float32), array([-2.0411987], dtype=float32), array([-10.773079], dtype=float32), array([-16.03067], dtype=float32), array([-5.7943497], dtype=float32), array([2.3559952], dtype=float32), array([-7.5796356], dtype=float32), array([-17.374245], dtype=float32), array([-7.256279], dtype=float32), array([5.6261215], dtype=float32), array([-3.987938], dtype=float32), array([-45.952118], dtype=float32), array([-34.500366], dtype=float32), array([21.660149], dtype=float32), array([47.454376], dtype=float32), array([-30.411781], dtype=float32), array([-63.489998], dtype=float32), array([32.614777], dtype=float32), array([76.453094], dtype=float32), array([-37.103325], dtype=float32), array([-75.31376], dtype=float32), array([53.292603], dtype=float32), array([74.67113], dtype=float32), array([-68.1216], dtype=float32), array([-75.30096], dtype=float32), array([78.52991], dtype=float32), array([79.12962], dtype=float32), array([-82.622406], dtype=float32), array([-83.004745], dtype=float32), array([83.19275], dtype=float32), array([85.45291], dtype=float32), array([-81.37627], dtype=float32), array([-85.3576], dtype=float32), array([80.70561], dtype=float32), array([84.739044], dtype=float32), array([-81.735565], dtype=float32), array([-85.20787], dtype=float32), array([80.13803], dtype=float32), array([84.29454], dtype=float32), array([-80.69831], dtype=float32), array([-83.7698], dtype=float32), array([80.7303], dtype=float32), array([84.40173], dtype=float32), array([-79.318054], dtype=float32), array([-83.20685], dtype=float32), array([78.42995], dtype=float32), array([81.95383], dtype=float32), array([-78.652115], dtype=float32), array([-82.512], dtype=float32), array([77.08911], dtype=float32), array([8 ...
# Time predict 8.535132884979248
# Time model 23.767494678497314
# Episode reward -456.39754498633556
# [array([-100.], dtype=float32), array([-100.], dtype=float32), array([-100.], dtype=float32), array([-100.], dtype=float32), array([-100.], dtype=float32), array([-100.], dtype=float32), array([-100.], dtype=float32), array([-99.99999], dtype=float32), array([-99.999985], dtype=float32), array([-99.99996], dtype=float32), array([-99.99989], dtype=float32), array([-99.99969], dtype=float32), array([-99.99906], dtype=float32), array([-99.99708], dtype=float32), array([-99.99068], dtype=float32), array([-99.96943], dtype=float32), array([-99.86778], dtype=float32), array([-98.52221], dtype=float32), array([-83.89583], dtype=float32), array([-4.531189], dtype=float32), array([54.92154], dtype=float32), array([46.147675], dtype=float32), array([9.483887], dtype=float32), array([-3.607376], dtype=float32), array([14.167725], dtype=float32), array([30.904129], dtype=float32), array([29.708694], dtype=float32), array([20.144379], dtype=float32), array([16.662003], dtype=float32), array([20.736404], dtype=float32), array([24.304321], dtype=float32), array([22.853767], dtype=float32), array([19.280563], dtype=float32), array([17.782356], dtype=float32), array([18.5708], dtype=float32), array([18.967163], dtype=float32), array([17.748688], dtype=float32), array([17.065468], dtype=float32), array([19.516441], dtype=float32), array([22.639717], dtype=float32), array([22.155907], dtype=float32), array([19.01838], dtype=float32), array([16.558578], dtype=float32), array([15.83065], dtype=float32), array([15.512871], dtype=float32), array([14.2137985], dtype=float32), array([12.0774765], dtype=float32), array([10.954987], dtype=float32), array([11.706268], dtype=float32), array([12.615463], dtype=float32), array([12.1896515], dtype=float32), array([11.202049], dtype=float32), array([10.945961], dtype=float32), array([11.324921], dtype=float32), array([11.566399], dtype=float32), array([11.02935], dtype=float32), array([10.348473], dtype=float32), array([10.314178], dtype=float32), array([10.562851], dtype=float32), array([10.4991455], dtype=float32), array([10.013435], dtype=float32), array([9.647308], dtype=float32), array([9.722839], dtype=float32), array([9.797462], dtype=float32), array([9.412025], dtype=float32), array([8.904015], dtype=float32), array([8.82666], dtype=float32), array([8.934212], dtype=float32), array([8.675858], dtype=float32), array([8.173309], dtype=float32), array([7.9507217], dtype=float32), array([7.1095963], dtype=float32), array([-8.012108], dtype=float32), array([-5.2044754], dtype=float32), array([11.73214], dtype=float32), array([6.8590775], dtype=float32), array([-11.777939], dtype=float32), array([-3.1203842], dtype=float32), array([18.150307], dtype=float32), array([8.895096], dtype=float32), array([-7.452736], dtype=float32), array([0.6503906], dtype=float32), array([13.081146], dtype=float32), array([14.493439], dtype=float32), array([7.6798325], dtype=float32), array([2.5258636], dtype=float32), array([3.0485535], dtype=float32), array([5.6552277], dtype=float32), array([6.1688156], dtype=float32), array([4.4177628], dtype=float32), array([2.6732101], dtype=float32), array([2.2392654], dtype=float32), array([2.5101624], dtype=float32), array([2.4290543], dtype=float32), array([1.7872543], dtype=float32), array([1.073204], dtype=float32), array([0.6534958], dtype=float32), array([0.44911194], dtype=float32), array([0.21832275], dtype=float32), array([-0.12774658], dtype=float32), array([-0.49962616], dtype=float32), array([5.1071014], dtype=float32), array([2.1417236], dtype=float32), array([-5.4999084], dtype=float32), array([-6.161934], dtype=float32), array([-0.3601532], dtype=float32), array([0.8619995], dtype=float32), array([-4.999138], dtype=float32), array([-8.291122], dtype=float32), array([-4.422638], dtype=float32), array([-0.7790146], dtype=float32), array([-3.4627914], dtype=float32), array([-7.688057], dtype=float32), array([-6.5604477], dtype=float32), array([-2.5083313], dtype=float32), ar ...
# Time predict 8.52641749382019
# Time model 23.638432025909424
# Episode reward -435.6164725832641
# [array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([98.57109], dtype=float32), array([93.79413], dtype=float32), array([69.142105], dtype=float32), array([-4.0085754], dtype=float32), array([-74.09011], dtype=float32), array([-94.758095], dtype=float32), array([-54.705166], dtype=float32), array([47.18712], dtype=float32), array([48.870605], dtype=float32), array([-27.485321], dtype=float32), array([-68.84979], dtype=float32), array([-62.24381], dtype=float32), array([-36.589085], dtype=float32), array([-20.249146], dtype=float32), array([-27.040604], dtype=float32), array([-40.681328], dtype=float32), array([-46.459816], dtype=float32), array([-45.430923], dtype=float32), array([-42.701412], dtype=float32), array([-41.119587], dtype=float32), array([-40.90134], dtype=float32), array([-41.1612], dtype=float32), array([-40.966755], dtype=float32), array([-40.30005], dtype=float32), array([-39.366238], dtype=float32), array([-37.978436], dtype=float32), array([-36.28293], dtype=float32), array([-34.48459], dtype=float32), array([-29.963684], dtype=float32), array([-21.166298], dtype=float32), array([-12.445396], dtype=float32), array([-7.820343], dtype=float32), array([-6.8702545], dtype=float32), array([-7.095932], dtype=float32), array([-6.865013], dtype=float32), array([-6.0596085], dtype=float32), array([-5.178726], dtype=float32), array([-4.558647], dtype=float32), array([-4.2490387], dtype=float32), array([-4.1293716], dtype=float32), array([-4.058441], dtype=float32), array([-3.992508], dtype=float32), array([-3.9354706], dtype=float32), array([-4.1473007], dtype=float32), array([-4.8183823], dtype=float32), array([-5.6381226], dtype=float32), array([-6.219742], dtype=float32), array([-6.39328], dtype=float32), array([-4.4169083], dtype=float32), array([-0.00033569], dtype=float32), array([-1.5046921], dtype=float32), array([-10.063377], dtype=float32), array([-16.599617], dtype=float32), array([-6.7275314], dtype=float32), array([2.8582916], dtype=float32), array([-6.482086], dtype=float32), array([-17.813477], dtype=float32), array([-8.585861], dtype=float32), array([5.9468155], dtype=float32), array([-2.4012756], dtype=float32), array([-45.100826], dtype=float32), array([-36.052822], dtype=float32), array([19.39943], dtype=float32), array([47.88942], dtype=float32), array([-27.425316], dtype=float32), array([-63.53283], dtype=float32), array([26.799416], dtype=float32), array([76.98204], dtype=float32), array([-29.538551], dtype=float32), array([-76.37002], dtype=float32), array([43.80226], dtype=float32), array([75.78389], dtype=float32), array([-59.052254], dtype=float32), array([-74.82429], dtype=float32), array([72.98085], dtype=float32), array([76.60318], dtype=float32), array([-80.935074], dtype=float32), array([-80.848434], dtype=float32), array([83.5181], dtype=float32), array([84.71651], dtype=float32), array([-82.10953], dtype=float32), array([-85.38675], dtype=float32), array([81.07449], dtype=float32), array([84.91661], dtype=float32), array([-81.78281], dtype=float32), array([-85.27286], dtype=float32), array([80.07292], dtype=float32), array([84.298294], dtype=float32), array([-80.67309], dtype=float32), array([-83.7541], dtype=float32), array([80.73723], dtype=float32), array([84.41997], dtype=float32), array([-79.327126], dtype=float32), array([-83.21632], dtype=float32), array([78.421234], dtype=float32), array( ...

# %%
import torch as th

from stable_baselines3 import SAC

#import onnx
import onnxruntime as ort
import numpy as np


class OnnxablePolicy(th.nn.Module):
    def __init__(self, actor: th.nn.Module):
        super().__init__()
        # Removing the flatten layer because it can't be onnxed
        self.actor = th.nn.Sequential(
            actor.latent_pi,
            actor.mu,
            # For gSDE
            # th.nn.Hardtanh(min_val=-actor.clip_mean, max_val=actor.clip_mean),
            # Squash the output
            th.nn.Tanh(),
        )

    def forward(self, observation: th.Tensor) -> th.Tensor:
        # NOTE: You may have to process (normalize) observation in the correct
        #       way before using this. See `common.preprocessing.preprocess_obs`
        return self.actor(observation)


# Example: model = SAC("MlpPolicy", "Pendulum-v1")
model = SAC.load(f"models/sac8x8h9.3/model.zip", device="cpu")
onnxable_model = OnnxablePolicy(model.policy.actor)

observation_size = model.observation_space.shape
dummy_input = th.randn(1, *observation_size)
th.onnx.export(
    onnxable_model,
    dummy_input,
    "./ONNX/1gdlComplexH98x8.onnx",
    opset_version=9,
    input_names=["input"],
)

##### Load and test with onnx

import onnxruntime as ort
import numpy as np

onnx_path = "./ONNX/1gdlComplexH98x8.onnx"

observation = np.zeros((1, *observation_size)).astype(np.float32)
ort_sess = ort.InferenceSession(onnx_path)
action = ort_sess.run(None, {"input": observation})
# Out:
# ============== Diagnostic Run torch.onnx.export version 2.0.0+cpu ==============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
model.policy
# Out:
# SACPolicy(
#   (actor): Actor(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (latent_pi): Sequential(
#       (0): Linear(in_features=4, out_features=8, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=8, out_features=8, bias=True)
#       (3): ReLU()
#     )
#     (mu): Linear(in_features=8, out_features=1, bias=True)
#     (log_std): Linear(in_features=8, out_features=1, bias=True)
#   )
#   (critic): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (critic_target): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=5, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )

# %%
# See "ONNX export" for imports and OnnxablePolicy
jit_path = "1gdlComplex.pt"

# Trace and optimize the module
traced_module = th.jit.trace(onnxable_model.eval(), dummy_input)
frozen_module = th.jit.freeze(traced_module)
frozen_module = th.jit.optimize_for_inference(frozen_module)
th.jit.save(frozen_module, jit_path)

##### Load and test with torch

import torch as th

dummy_input = th.randn(1, *observation_size)
loaded_module = th.jit.load(jit_path)
action_jit = loaded_module(dummy_input)
